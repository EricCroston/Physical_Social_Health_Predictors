# %%
import warnings
from pathlib import Path
import pandas as pd
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Dense, Dropout, Input, Activation
from keras.optimizers import Adamax, RMSprop, SGD
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from keras.layers import LeakyReLU, ELU, PReLU
import tensorflow as tf
from tensorflow.keras.callbacks import EarlyStopping
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

# %%
# File Path
chd_data_to_load = Path("../Outputs/CHD_sdoh_access.csv")

# Read shcool metrics into Pandas DataFrames
chd_df = pd.read_csv(chd_data_to_load)

chd_df.head()
# Out:
#    county_index  target_chd  AGE65  BROAD  CROWD  HCOST  NOHSDP  POV150  \
# 0          1001         5.7   15.1   14.5    1.5   21.5    10.4    21.7
# 1          1011         7.9   16.2   40.6    0.8   23.9    22.4    46.0
# 2          1021         6.5   16.4   21.7    2.9   16.1    18.2    26.5
# 3          1029         6.5   19.2   27.2    2.1   18.1    16.9    27.3
# 4          1049         7.1   16.9   20.1    3.3   20.9    21.8    35.4
#
#    REMNRTY  SNGPNT  UNEMP  No_Vehicle_10_Miles  No_Vehicle_1_Mile  \
# 0     26.9     7.1    2.8             0.406809           1.528284
# 1     79.6    14.5    3.0             0.733003           3.060290
# 2     20.7     4.5    6.4             0.025205           1.416035
# 3      7.6     4.5    4.5             0.073470           1.302431
# 4     20.4     5.8    4.3             0.000000           1.492076
#
#    No_Vehicle_Half_Mile
# 0              1.914937
# 1              3.967381
# 2              1.718489
# 3              1.436014
# 4              1.816929

# %%
# Divide the percentage values by 100 to prepare for Neural Network
columns_to_scale = chd_df.dtypes[chd_df.dtypes == "float64"].index.tolist()
chd_df[columns_to_scale] = chd_df[columns_to_scale] / 100
chd_df.head()
# Out:
#    county_index  target_chd  AGE65  BROAD  CROWD  HCOST  NOHSDP  POV150  \
# 0          1001       0.057  0.151  0.145  0.015  0.215   0.104   0.217
# 1          1011       0.079  0.162  0.406  0.008  0.239   0.224   0.460
# 2          1021       0.065  0.164  0.217  0.029  0.161   0.182   0.265
# 3          1029       0.065  0.192  0.272  0.021  0.181   0.169   0.273
# 4          1049       0.071  0.169  0.201  0.033  0.209   0.218   0.354
#
#    REMNRTY  SNGPNT  UNEMP  No_Vehicle_10_Miles  No_Vehicle_1_Mile  \
# 0    0.269   0.071  0.028             0.004068           0.015283
# 1    0.796   0.145  0.030             0.007330           0.030603
# 2    0.207   0.045  0.064             0.000252           0.014160
# 3    0.076   0.045  0.045             0.000735           0.013024
# 4    0.204   0.058  0.043             0.000000           0.014921
#
#    No_Vehicle_Half_Mile
# 0              0.019149
# 1              0.039674
# 2              0.017185
# 3              0.014360
# 4              0.018169

# %%
# Split data into our features and target arrays
y = chd_df['target_chd'].values
X = chd_df.drop(columns = ['target_chd', 'county_index']).values

# Split the arrays into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=12)

# Data was prescaled manually so set values to work with the train_model function
X_train_scaled = X_train
X_test_scaled = X_test

# Set the values for input shape and hidden nodes for each layer
input_shape = len(X_train[0])
hidden_nodes_layer1 =  128
hidden_nodes_layer2 = 64
hidden_nodes_layer3 = 32

# %%
def train_model(X_train_scaled, y_train, X_test_scaled, y_test, activation_func='relu'):
    """
    Train a neural network with specified activation function and multiple optimizers.

    Args:
    - X_train_scaled: Scaled training data
    - y_train: Labels for training data
    - X_test_scaled: Scaled test data
    - y_test: Labels for test data
    - activation_func: Activation function to use (e.g., 'relu', 'leaky_relu', 'elu', 'prelu', 'swish')

    Returns:
    - mae_list2: List of mean absolute error for each optimizer
    - loss_list2: List of losses (MSE) for each optimizer
    """
    
    # Custom activation handling
    def get_activation(activation):
        if activation == 'leaky_relu':
            return LeakyReLU(alpha=0.1)  # Custom activation layer
        elif activation == 'elu':
            return ELU(alpha=1.0)  # Custom activation layer
        elif activation == 'prelu':
            return PReLU()  # Custom activation layer
        elif activation == 'swish':  # Or silu
            return Activation(tf.keras.activations.swish)  # Wrap as Activation layer
        else:
            return activation  # For standard activations like 'relu', 'sigmoid', etc.
    
    # Build model
    nn = tf.keras.models.Sequential()

    # Add the input layer
    nn.add(tf.keras.layers.Input(shape=(input_shape,)))
    
    # First hidden layer
    if isinstance(get_activation(activation_func), str):  # If it's a standard activation
        nn.add(tf.keras.layers.Dense(units=128, activation=get_activation(activation_func)))  # Use activation as string
    else:  # If it's a custom activation layer
        nn.add(tf.keras.layers.Dense(units=128))
        nn.add(get_activation(activation_func))  # Add custom activation layer
    
    # Dropout and subsequent layers
    nn.add(Dropout(0.3))
    if isinstance(get_activation(activation_func), str):
        nn.add(tf.keras.layers.Dense(units=64, activation=get_activation(activation_func)))
    else:
        nn.add(tf.keras.layers.Dense(units=64))
        nn.add(get_activation(activation_func))
    
    nn.add(Dropout(0.3))
    if isinstance(get_activation(activation_func), str):
        nn.add(tf.keras.layers.Dense(units=32, activation=get_activation(activation_func)))
    else:
        nn.add(tf.keras.layers.Dense(units=32))
        nn.add(get_activation(activation_func))
    
    # Output layer (for continuous data)
    nn.add(tf.keras.layers.Dense(units=1, activation="linear"))

    # Experiment with different optimizers
    optimizers = {
        'Adamax': Adamax(learning_rate=0.002),
        'RMSprop': RMSprop(learning_rate=0.001),
        'SGD': SGD(learning_rate=0.01, momentum=0.9)
    }

    mae_list2 = []
    loss_list2 = []

    # Iterate through each optimizer
    for name, optimizer in optimizers.items():
        print(f"\nTraining with {name} optimizer and {activation_func} activation function...")
        nn.compile(optimizer=optimizer, loss="mean_squared_error", metrics=["MAE"])

        # Callbacks
        early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
        reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=0.00001)

        # Train the model
        nn.fit(X_train_scaled, y_train, epochs=100, validation_data=(X_test_scaled, y_test),
               callbacks=[early_stopping, reduce_lr], verbose=1)

        # Evaluate the model
        loss, mae = nn.evaluate(X_test_scaled, y_test, verbose=0)
        print(f"{name} Optimizer - Loss (MSE): {loss:.6f}, Mean Absolute Error: {mae:.6f}")
        mae_list2.append(mae)
        loss_list2.append(loss)
    
    return mae_list2, loss_list2

# %%
all_mae_values = []
all_loss_values = []
all_labels = []
all_activation_functions = []
all_optimizers = []

activation_functions = ['relu', 'leaky_relu', 'elu', 'prelu', 'swish']
optimizers = ['Adamax', 'RMSprop', 'SGD']

for activation in activation_functions:
    print(f"\nRunning for activation function: {activation}")
    mae_list, loss_list = train_model(X_train_scaled, y_train, X_test_scaled, y_test, activation_func=activation)
    
    # Append the Mean Absolute Error, loss values and labels for this activation function
    all_mae_values.extend(mae_list)
    all_loss_values.extend(loss_list)
    
    # Create labels combining activation function and optimizer
    for optimizer in optimizers:
        all_labels.append(f"{activation}, {optimizer}")
        all_activation_functions.append(activation)
        all_optimizers.append(optimizer)
# Out:
# Running for activation function: relu
#
# Training with Adamax optimizer and relu activation function...
# Epoch 1/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - MAE: 0.0235 - loss: 0.0011 - val_MAE: 0.0121 - val_loss: 1.8437e-04 - learning_rate: 0.0020
# Epoch 2/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0104 - loss: 1.7793e-04 - val_MAE: 0.0109 - val_loss: 1.4953e-04 - learning_rate: 0.0020
# Epoch 3/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0080 - loss: 1.0810e-04 - val_MAE: 0.0113 - val_loss: 1.5757e-04 - learning_rate: 0.0020
# Epoch 4/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0072 - loss: 9.0484e-05 - val_MAE: 0.0073 - val_loss: 8.1294e-05 - learning_rate: 0.0020
# Epoch 5/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0062 - loss: 6.5580e-05 - val_MAE: 0.0065 - val_loss: 6.6528e-05 - learning_rate: 0.0020
# Epoch 6/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0060 - loss: 6.7086e-05 - val_MAE: 0.0065 - val_loss: 6.5841e-05 - learning_rate: 0.0020
# Epoch 7/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0054 - loss: 5.1656e-05 - val_MAE: 0.0055 - val_loss: 5.1300e-05 - learning_rate: 0.0020
# Epoch 8/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0052 - loss: 4.8025e-05 - val_MAE: 0.0051 - val_loss: 4.4061e-05 - learning_rate: 0.0020
# Epoch 9/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0051 - loss: 4.5800e-05 - val_MAE: 0.0050 - val_loss: 4.1165e-05 - learning_rate: 0.0020
# Epoch 10/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0047 - loss: 3.7666e-05 - val_MAE: 0.0048 - val_loss: 3.9105e-05 - learning_rate: 4.0000e-04
# Epoch 11/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0047 - loss: 3.8548e-05 - val_MAE: 0.0050 - val_loss: 4.0989e-05 - learning_rate: 4.0000e-04
# Epoch 12/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0048 - loss: 4.3210e-05 - val_MAE: 0.0049 - val_loss: 4.0335e-05 - learning_rate: 4.0000e-04
# Epoch 13/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0047 - loss: 3.9055e-05 - val_MAE: 0.0046 - val_loss: 3.5865e-05 - learning_rate: 4.0000e-04
# Epoch 14/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0046 - loss: 3.7618e-05 - val_MAE: 0.0047 - val_loss: 3.7378e-05 - learning_rate: 4.0000e-04
# Epoch 15/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0045 - loss: 3.5842e-05 - val_MAE: 0.0048 - val_loss: 3.8186e-05 - learning_rate: 8.0000e-05
# Epoch 16/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0045 - loss: 3.6662e-05 - val_MAE: 0.0049 - val_loss: 3.9111e-05 - learning_rate: 8.0000e-05
# Epoch 17/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0045 - loss: 3.4813e-05 - val_MAE: 0.0046 - val_loss: 3.6199e-05 - learning_rate: 8.0000e-05
# Epoch 18/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0046 - loss: 3.7554e-05 - val_MAE: 0.0048 - val_loss: 3.8613e-05 - learning_rate: 8.0000e-05
# Epoch 19/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0047 - loss: 3.8134e-05 - val_MAE: 0.0048 - val_loss: 3.7958e-05 - learning_rate: 8.0000e-05
# Epoch 20/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0044 - loss: 3.6030e-05 - val_MAE: 0.0048 - val_loss: 3.7755e-05 - learning_rate: 1.6000e-05
# Epoch 21/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0045 - loss: 3.5928e-05 - val_MAE: 0.0048 - val_loss: 3.7815e-05 - learning_rate: 1.6000e-05
# Epoch 22/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0045 - loss: 3.6505e-05 - val_MAE: 0.0047 - val_loss: 3.7355e-05 - learning_rate: 1.6000e-05
# Epoch 23/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0045 - loss: 3.5430e-05 - val_MAE: 0.0047 - val_loss: 3.7327e-05 - learning_rate: 1.6000e-05
# Adamax Optimizer - Loss (MSE): 0.000036, Mean Absolute Error: 0.004595
#
# Training with RMSprop optimizer and relu activation function...
# Epoch 1/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - MAE: 0.0049 - loss: 4.2862e-05 - val_MAE: 0.0061 - val_loss: 5.6997e-05 - learning_rate: 0.0010
# Epoch 2/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0044 - loss: 3.4341e-05 - val_MAE: 0.0038 - val_loss: 2.5768e-05 - learning_rate: 0.0010
# Epoch 3/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0044 - loss: 3.3115e-05 - val_MAE: 0.0038 - val_loss: 2.5454e-05 - learning_rate: 0.0010
# Epoch 4/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0043 - loss: 3.1331e-05 - val_MAE: 0.0038 - val_loss: 2.5040e-05 - learning_rate: 0.0010
# Epoch 5/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0041 - loss: 2.9655e-05 - val_MAE: 0.0034 - val_loss: 2.0697e-05 - learning_rate: 0.0010
# Epoch 6/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0040 - loss: 2.7894e-05 - val_MAE: 0.0033 - val_loss: 1.8600e-05 - learning_rate: 0.0010
# Epoch 7/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0040 - loss: 2.6334e-05 - val_MAE: 0.0037 - val_loss: 2.3438e-05 - learning_rate: 2.0000e-04
# Epoch 8/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0038 - loss: 2.4870e-05 - val_MAE: 0.0039 - val_loss: 2.6857e-05 - learning_rate: 2.0000e-04
# Epoch 9/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0038 - loss: 2.6750e-05 - val_MAE: 0.0036 - val_loss: 2.2625e-05 - learning_rate: 2.0000e-04
# Epoch 10/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0039 - loss: 2.5903e-05 - val_MAE: 0.0037 - val_loss: 2.4171e-05 - learning_rate: 2.0000e-04
# Epoch 11/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0037 - loss: 2.4243e-05 - val_MAE: 0.0037 - val_loss: 2.4143e-05 - learning_rate: 2.0000e-04
# Epoch 12/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0040 - loss: 2.9019e-05 - val_MAE: 0.0037 - val_loss: 2.3817e-05 - learning_rate: 4.0000e-05
# Epoch 13/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0039 - loss: 2.6700e-05 - val_MAE: 0.0037 - val_loss: 2.3421e-05 - learning_rate: 4.0000e-05
# Epoch 14/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0039 - loss: 2.5361e-05 - val_MAE: 0.0037 - val_loss: 2.3847e-05 - learning_rate: 4.0000e-05
# Epoch 15/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0037 - loss: 2.5162e-05 - val_MAE: 0.0037 - val_loss: 2.4292e-05 - learning_rate: 4.0000e-05
# Epoch 16/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0039 - loss: 2.5414e-05 - val_MAE: 0.0037 - val_loss: 2.4471e-05 - learning_rate: 4.0000e-05
# RMSprop Optimizer - Loss (MSE): 0.000019, Mean Absolute Error: 0.003276
#
# Training with SGD optimizer and relu activation function...
# Epoch 1/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - MAE: 0.0041 - loss: 2.9447e-05 - val_MAE: 0.0040 - val_loss: 2.7180e-05 - learning_rate: 0.0100
# Epoch 2/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0038 - loss: 2.5110e-05 - val_MAE: 0.0035 - val_loss: 2.2054e-05 - learning_rate: 0.0100
# Epoch 3/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0040 - loss: 2.8354e-05 - val_MAE: 0.0037 - val_loss: 2.4350e-05 - learning_rate: 0.0100
# Epoch 4/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0039 - loss: 2.5589e-05 - val_MAE: 0.0036 - val_loss: 2.3208e-05 - learning_rate: 0.0100
# Epoch 5/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0039 - loss: 2.8144e-05 - val_MAE: 0.0037 - val_loss: 2.4388e-05 - learning_rate: 0.0100
# Epoch 6/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0038 - loss: 2.5796e-05 - val_MAE: 0.0037 - val_loss: 2.3449e-05 - learning_rate: 0.0100
# Epoch 7/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0038 - loss: 2.4621e-05 - val_MAE: 0.0038 - val_loss: 2.5214e-05 - learning_rate: 0.0020
# Epoch 8/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0038 - loss: 2.5012e-05 - val_MAE: 0.0037 - val_loss: 2.3763e-05 - learning_rate: 0.0020
# Epoch 9/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0038 - loss: 2.5122e-05 - val_MAE: 0.0037 - val_loss: 2.3503e-05 - learning_rate: 0.0020
# Epoch 10/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0039 - loss: 2.6333e-05 - val_MAE: 0.0038 - val_loss: 2.4548e-05 - learning_rate: 0.0020
# Epoch 11/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0037 - loss: 2.4538e-05 - val_MAE: 0.0037 - val_loss: 2.3563e-05 - learning_rate: 0.0020
# Epoch 12/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0038 - loss: 2.5439e-05 - val_MAE: 0.0036 - val_loss: 2.3290e-05 - learning_rate: 4.0000e-04
# SGD Optimizer - Loss (MSE): 0.000022, Mean Absolute Error: 0.003543
#
# Running for activation function: leaky_relu
#
# Training with Adamax optimizer and leaky_relu activation function...
# Epoch 1/100
# C:\Users\ecros\anaconda3\envs\dev\lib\site-packages\keras\src\layers\activations\leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - MAE: 0.0234 - loss: 0.0012 - val_MAE: 0.0068 - val_loss: 6.2505e-05 - learning_rate: 0.0020
# Epoch 2/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0091 - loss: 1.4743e-04 - val_MAE: 0.0073 - val_loss: 7.2000e-05 - learning_rate: 0.0020
# Epoch 3/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0072 - loss: 9.2801e-05 - val_MAE: 0.0052 - val_loss: 4.2110e-05 - learning_rate: 0.0020
# Epoch 4/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0064 - loss: 7.3191e-05 - val_MAE: 0.0054 - val_loss: 4.3743e-05 - learning_rate: 0.0020
# Epoch 5/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0057 - loss: 6.1717e-05 - val_MAE: 0.0050 - val_loss: 3.8797e-05 - learning_rate: 0.0020
# Epoch 6/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0053 - loss: 4.7583e-05 - val_MAE: 0.0047 - val_loss: 3.4436e-05 - learning_rate: 0.0020
# Epoch 7/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0054 - loss: 5.1060e-05 - val_MAE: 0.0045 - val_loss: 3.2646e-05 - learning_rate: 4.0000e-04
# Epoch 8/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0050 - loss: 4.4104e-05 - val_MAE: 0.0044 - val_loss: 3.1135e-05 - learning_rate: 4.0000e-04
# Epoch 9/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0050 - loss: 4.2315e-05 - val_MAE: 0.0044 - val_loss: 3.0834e-05 - learning_rate: 4.0000e-04
# Epoch 10/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0051 - loss: 4.6004e-05 - val_MAE: 0.0049 - val_loss: 3.6187e-05 - learning_rate: 4.0000e-04
# Epoch 11/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0047 - loss: 4.0367e-05 - val_MAE: 0.0045 - val_loss: 3.2377e-05 - learning_rate: 4.0000e-04
# Epoch 12/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0047 - loss: 3.9921e-05 - val_MAE: 0.0044 - val_loss: 3.1193e-05 - learning_rate: 8.0000e-05
# Epoch 13/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0048 - loss: 4.2037e-05 - val_MAE: 0.0043 - val_loss: 2.9343e-05 - learning_rate: 8.0000e-05
# Epoch 14/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0046 - loss: 3.9788e-05 - val_MAE: 0.0044 - val_loss: 3.0671e-05 - learning_rate: 8.0000e-05
# Epoch 15/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0047 - loss: 3.7463e-05 - val_MAE: 0.0043 - val_loss: 2.9540e-05 - learning_rate: 8.0000e-05
# Epoch 16/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0047 - loss: 3.6765e-05 - val_MAE: 0.0044 - val_loss: 3.1139e-05 - learning_rate: 8.0000e-05
# Epoch 17/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0048 - loss: 4.1768e-05 - val_MAE: 0.0044 - val_loss: 3.0955e-05 - learning_rate: 1.6000e-05
# Epoch 18/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0047 - loss: 3.9220e-05 - val_MAE: 0.0044 - val_loss: 3.0267e-05 - learning_rate: 1.6000e-05
# Epoch 19/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0051 - loss: 4.6622e-05 - val_MAE: 0.0044 - val_loss: 3.0959e-05 - learning_rate: 1.6000e-05
# Epoch 20/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0048 - loss: 3.9251e-05 - val_MAE: 0.0044 - val_loss: 3.0959e-05 - learning_rate: 1.6000e-05
# Epoch 21/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0047 - loss: 3.7035e-05 - val_MAE: 0.0044 - val_loss: 3.0789e-05 - learning_rate: 1.6000e-05
# Epoch 22/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0048 - loss: 3.9922e-05 - val_MAE: 0.0044 - val_loss: 3.0838e-05 - learning_rate: 1.0000e-05
# Epoch 23/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0045 - loss: 3.4772e-05 - val_MAE: 0.0044 - val_loss: 3.0554e-05 - learning_rate: 1.0000e-05
# Adamax Optimizer - Loss (MSE): 0.000029, Mean Absolute Error: 0.004288
#
# Training with RMSprop optimizer and leaky_relu activation function...
# Epoch 1/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - MAE: 0.0051 - loss: 4.4871e-05 - val_MAE: 0.0032 - val_loss: 1.7225e-05 - learning_rate: 0.0010
# Epoch 2/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0048 - loss: 3.8913e-05 - val_MAE: 0.0048 - val_loss: 3.5651e-05 - learning_rate: 0.0010
# Epoch 3/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0045 - loss: 3.4451e-05 - val_MAE: 0.0039 - val_loss: 2.4344e-05 - learning_rate: 0.0010
# Epoch 4/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0047 - loss: 3.7891e-05 - val_MAE: 0.0042 - val_loss: 2.8789e-05 - learning_rate: 0.0010
# Epoch 5/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0042 - loss: 3.0235e-05 - val_MAE: 0.0044 - val_loss: 3.0019e-05 - learning_rate: 0.0010
# Epoch 6/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0043 - loss: 3.0718e-05 - val_MAE: 0.0034 - val_loss: 1.9012e-05 - learning_rate: 0.0010
# Epoch 7/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0040 - loss: 2.8383e-05 - val_MAE: 0.0038 - val_loss: 2.3316e-05 - learning_rate: 2.0000e-04
# Epoch 8/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0039 - loss: 2.6385e-05 - val_MAE: 0.0035 - val_loss: 1.9841e-05 - learning_rate: 2.0000e-04
# Epoch 9/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0040 - loss: 2.7924e-05 - val_MAE: 0.0035 - val_loss: 2.0161e-05 - learning_rate: 2.0000e-04
# Epoch 10/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0038 - loss: 2.5571e-05 - val_MAE: 0.0035 - val_loss: 2.0297e-05 - learning_rate: 2.0000e-04
# Epoch 11/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0039 - loss: 2.6441e-05 - val_MAE: 0.0035 - val_loss: 2.0591e-05 - learning_rate: 2.0000e-04
# RMSprop Optimizer - Loss (MSE): 0.000017, Mean Absolute Error: 0.003231
#
# Training with SGD optimizer and leaky_relu activation function...
# Epoch 1/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - MAE: 0.0048 - loss: 4.0049e-05 - val_MAE: 0.0040 - val_loss: 2.5467e-05 - learning_rate: 0.0100
# Epoch 2/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0045 - loss: 3.5036e-05 - val_MAE: 0.0039 - val_loss: 2.4728e-05 - learning_rate: 0.0100
# Epoch 3/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0046 - loss: 3.7446e-05 - val_MAE: 0.0041 - val_loss: 2.6495e-05 - learning_rate: 0.0100
# Epoch 4/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0044 - loss: 3.4848e-05 - val_MAE: 0.0041 - val_loss: 2.7115e-05 - learning_rate: 0.0100
# Epoch 5/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0044 - loss: 3.3247e-05 - val_MAE: 0.0040 - val_loss: 2.5955e-05 - learning_rate: 0.0100
# Epoch 6/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0043 - loss: 3.2417e-05 - val_MAE: 0.0043 - val_loss: 2.8702e-05 - learning_rate: 0.0100
# Epoch 7/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0044 - loss: 3.1865e-05 - val_MAE: 0.0042 - val_loss: 2.8278e-05 - learning_rate: 0.0020
# Epoch 8/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0044 - loss: 3.3547e-05 - val_MAE: 0.0042 - val_loss: 2.7908e-05 - learning_rate: 0.0020
# Epoch 9/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0044 - loss: 3.4205e-05 - val_MAE: 0.0041 - val_loss: 2.7181e-05 - learning_rate: 0.0020
# Epoch 10/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0044 - loss: 3.5157e-05 - val_MAE: 0.0043 - val_loss: 2.8724e-05 - learning_rate: 0.0020
# Epoch 11/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0044 - loss: 3.4874e-05 - val_MAE: 0.0041 - val_loss: 2.7141e-05 - learning_rate: 0.0020
# Epoch 12/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0045 - loss: 3.3877e-05 - val_MAE: 0.0042 - val_loss: 2.7457e-05 - learning_rate: 4.0000e-04
# SGD Optimizer - Loss (MSE): 0.000025, Mean Absolute Error: 0.003926
#
# Running for activation function: elu
#
# Training with Adamax optimizer and elu activation function...
# Epoch 1/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - MAE: 0.0876 - loss: 0.0147 - val_MAE: 0.0065 - val_loss: 7.2894e-05 - learning_rate: 0.0020
# Epoch 2/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0317 - loss: 0.0017 - val_MAE: 0.0053 - val_loss: 4.3545e-05 - learning_rate: 0.0020
# Epoch 3/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0232 - loss: 9.4385e-04 - val_MAE: 0.0045 - val_loss: 3.6598e-05 - learning_rate: 0.0020
# Epoch 4/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0198 - loss: 6.7892e-04 - val_MAE: 0.0042 - val_loss: 2.9125e-05 - learning_rate: 0.0020
# Epoch 5/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0157 - loss: 4.2570e-04 - val_MAE: 0.0038 - val_loss: 2.3965e-05 - learning_rate: 0.0020
# Epoch 6/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0138 - loss: 3.1202e-04 - val_MAE: 0.0033 - val_loss: 1.8434e-05 - learning_rate: 0.0020
# Epoch 7/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0118 - loss: 2.3766e-04 - val_MAE: 0.0032 - val_loss: 1.7445e-05 - learning_rate: 4.0000e-04
# Epoch 8/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0113 - loss: 2.1463e-04 - val_MAE: 0.0032 - val_loss: 1.6680e-05 - learning_rate: 4.0000e-04
# Epoch 9/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0113 - loss: 2.2198e-04 - val_MAE: 0.0031 - val_loss: 1.6201e-05 - learning_rate: 4.0000e-04
# Epoch 10/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0104 - loss: 1.8616e-04 - val_MAE: 0.0031 - val_loss: 1.5799e-05 - learning_rate: 4.0000e-04
# Epoch 11/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0104 - loss: 1.8732e-04 - val_MAE: 0.0030 - val_loss: 1.5555e-05 - learning_rate: 4.0000e-04
# Epoch 12/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0102 - loss: 1.8313e-04 - val_MAE: 0.0030 - val_loss: 1.5430e-05 - learning_rate: 8.0000e-05
# Epoch 13/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0099 - loss: 1.7549e-04 - val_MAE: 0.0030 - val_loss: 1.5109e-05 - learning_rate: 8.0000e-05
# Epoch 14/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0103 - loss: 1.8751e-04 - val_MAE: 0.0029 - val_loss: 1.4484e-05 - learning_rate: 8.0000e-05
# Epoch 15/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0098 - loss: 1.5821e-04 - val_MAE: 0.0029 - val_loss: 1.4531e-05 - learning_rate: 8.0000e-05
# Epoch 16/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0098 - loss: 1.6647e-04 - val_MAE: 0.0029 - val_loss: 1.4602e-05 - learning_rate: 8.0000e-05
# Epoch 17/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0098 - loss: 1.6357e-04 - val_MAE: 0.0029 - val_loss: 1.4623e-05 - learning_rate: 1.6000e-05
# Epoch 18/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0099 - loss: 1.7203e-04 - val_MAE: 0.0029 - val_loss: 1.4630e-05 - learning_rate: 1.6000e-05
# Epoch 19/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0100 - loss: 1.7514e-04 - val_MAE: 0.0029 - val_loss: 1.4705e-05 - learning_rate: 1.6000e-05
# Epoch 20/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0098 - loss: 1.6225e-04 - val_MAE: 0.0029 - val_loss: 1.4644e-05 - learning_rate: 1.6000e-05
# Epoch 21/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0098 - loss: 1.6512e-04 - val_MAE: 0.0029 - val_loss: 1.4616e-05 - learning_rate: 1.6000e-05
# Epoch 22/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0096 - loss: 1.5884e-04 - val_MAE: 0.0029 - val_loss: 1.4667e-05 - learning_rate: 1.0000e-05
# Epoch 23/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0094 - loss: 1.4954e-04 - val_MAE: 0.0029 - val_loss: 1.4702e-05 - learning_rate: 1.0000e-05
# Epoch 24/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0094 - loss: 1.6225e-04 - val_MAE: 0.0029 - val_loss: 1.4563e-05 - learning_rate: 1.0000e-05
# Adamax Optimizer - Loss (MSE): 0.000014, Mean Absolute Error: 0.002939
#
# Training with RMSprop optimizer and elu activation function...
# Epoch 1/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - MAE: 0.0127 - loss: 3.2068e-04 - val_MAE: 0.0054 - val_loss: 3.7715e-05 - learning_rate: 0.0010
# Epoch 2/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0073 - loss: 8.3062e-05 - val_MAE: 0.0104 - val_loss: 1.2961e-04 - learning_rate: 0.0010
# Epoch 3/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0066 - loss: 6.6335e-05 - val_MAE: 0.0054 - val_loss: 4.3297e-05 - learning_rate: 0.0010
# Epoch 4/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0060 - loss: 5.7095e-05 - val_MAE: 0.0029 - val_loss: 1.4948e-05 - learning_rate: 0.0010
# Epoch 5/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0053 - loss: 4.6918e-05 - val_MAE: 0.0030 - val_loss: 1.6035e-05 - learning_rate: 0.0010
# Epoch 6/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0053 - loss: 4.6876e-05 - val_MAE: 0.0080 - val_loss: 7.5217e-05 - learning_rate: 0.0010
# Epoch 7/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0043 - loss: 3.2569e-05 - val_MAE: 0.0027 - val_loss: 1.3180e-05 - learning_rate: 2.0000e-04
# Epoch 8/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0038 - loss: 2.5282e-05 - val_MAE: 0.0026 - val_loss: 1.2428e-05 - learning_rate: 2.0000e-04
# Epoch 9/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0039 - loss: 2.8359e-05 - val_MAE: 0.0026 - val_loss: 1.1722e-05 - learning_rate: 2.0000e-04
# Epoch 10/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0036 - loss: 2.2058e-05 - val_MAE: 0.0027 - val_loss: 1.2449e-05 - learning_rate: 2.0000e-04
# Epoch 11/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0037 - loss: 2.6513e-05 - val_MAE: 0.0026 - val_loss: 1.1945e-05 - learning_rate: 2.0000e-04
# Epoch 12/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0037 - loss: 2.4006e-05 - val_MAE: 0.0025 - val_loss: 1.1612e-05 - learning_rate: 4.0000e-05
# Epoch 13/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0035 - loss: 2.2180e-05 - val_MAE: 0.0025 - val_loss: 1.1598e-05 - learning_rate: 4.0000e-05
# Epoch 14/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0036 - loss: 2.6162e-05 - val_MAE: 0.0025 - val_loss: 1.1805e-05 - learning_rate: 4.0000e-05
# Epoch 15/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0037 - loss: 2.4252e-05 - val_MAE: 0.0025 - val_loss: 1.1841e-05 - learning_rate: 4.0000e-05
# Epoch 16/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0036 - loss: 2.3466e-05 - val_MAE: 0.0026 - val_loss: 1.2609e-05 - learning_rate: 4.0000e-05
# Epoch 17/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0036 - loss: 2.3962e-05 - val_MAE: 0.0026 - val_loss: 1.1979e-05 - learning_rate: 1.0000e-05
# Epoch 18/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0038 - loss: 2.9198e-05 - val_MAE: 0.0026 - val_loss: 1.1895e-05 - learning_rate: 1.0000e-05
# Epoch 19/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0035 - loss: 2.1974e-05 - val_MAE: 0.0026 - val_loss: 1.1796e-05 - learning_rate: 1.0000e-05
# Epoch 20/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0037 - loss: 2.4465e-05 - val_MAE: 0.0025 - val_loss: 1.2006e-05 - learning_rate: 1.0000e-05
# Epoch 21/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0037 - loss: 2.8184e-05 - val_MAE: 0.0026 - val_loss: 1.2075e-05 - learning_rate: 1.0000e-05
# Epoch 22/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0036 - loss: 2.5469e-05 - val_MAE: 0.0025 - val_loss: 1.1883e-05 - learning_rate: 1.0000e-05
# Epoch 23/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0036 - loss: 2.8844e-05 - val_MAE: 0.0026 - val_loss: 1.1816e-05 - learning_rate: 1.0000e-05
# RMSprop Optimizer - Loss (MSE): 0.000012, Mean Absolute Error: 0.002511
#
# Training with SGD optimizer and elu activation function...
# Epoch 1/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - MAE: 0.0036 - loss: 2.3785e-05 - val_MAE: 0.0025 - val_loss: 1.1613e-05 - learning_rate: 0.0100
# Epoch 2/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0036 - loss: 2.4707e-05 - val_MAE: 0.0025 - val_loss: 1.1737e-05 - learning_rate: 0.0100
# Epoch 3/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0037 - loss: 2.6876e-05 - val_MAE: 0.0025 - val_loss: 1.1470e-05 - learning_rate: 0.0100
# Epoch 4/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0036 - loss: 2.3381e-05 - val_MAE: 0.0025 - val_loss: 1.1584e-05 - learning_rate: 0.0100
# Epoch 5/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0038 - loss: 3.0611e-05 - val_MAE: 0.0025 - val_loss: 1.1591e-05 - learning_rate: 0.0100
# Epoch 6/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0036 - loss: 2.4195e-05 - val_MAE: 0.0025 - val_loss: 1.1524e-05 - learning_rate: 0.0100
# Epoch 7/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0034 - loss: 2.0061e-05 - val_MAE: 0.0025 - val_loss: 1.1515e-05 - learning_rate: 0.0020
# Epoch 8/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0037 - loss: 2.3596e-05 - val_MAE: 0.0025 - val_loss: 1.1692e-05 - learning_rate: 0.0020
# Epoch 9/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0034 - loss: 2.0820e-05 - val_MAE: 0.0025 - val_loss: 1.1521e-05 - learning_rate: 0.0020
# Epoch 10/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0037 - loss: 2.3444e-05 - val_MAE: 0.0026 - val_loss: 1.1614e-05 - learning_rate: 0.0020
# Epoch 11/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0038 - loss: 2.7090e-05 - val_MAE: 0.0025 - val_loss: 1.1504e-05 - learning_rate: 0.0020
# Epoch 12/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0036 - loss: 2.5043e-05 - val_MAE: 0.0025 - val_loss: 1.1516e-05 - learning_rate: 4.0000e-04
# Epoch 13/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0036 - loss: 2.3912e-05 - val_MAE: 0.0025 - val_loss: 1.1523e-05 - learning_rate: 4.0000e-04
# SGD Optimizer - Loss (MSE): 0.000011, Mean Absolute Error: 0.002519
#
# Running for activation function: prelu
#
# Training with Adamax optimizer and prelu activation function...
# Epoch 1/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - MAE: 0.0237 - loss: 0.0011 - val_MAE: 0.0090 - val_loss: 1.2154e-04 - learning_rate: 0.0020
# Epoch 2/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0094 - loss: 1.5247e-04 - val_MAE: 0.0076 - val_loss: 9.3416e-05 - learning_rate: 0.0020
# Epoch 3/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0074 - loss: 9.7030e-05 - val_MAE: 0.0064 - val_loss: 7.0085e-05 - learning_rate: 0.0020
# Epoch 4/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0064 - loss: 7.2121e-05 - val_MAE: 0.0068 - val_loss: 7.6537e-05 - learning_rate: 0.0020
# Epoch 5/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0059 - loss: 6.2787e-05 - val_MAE: 0.0066 - val_loss: 7.1651e-05 - learning_rate: 0.0020
# Epoch 6/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0052 - loss: 4.8687e-05 - val_MAE: 0.0059 - val_loss: 5.8440e-05 - learning_rate: 0.0020
# Epoch 7/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0049 - loss: 4.3177e-05 - val_MAE: 0.0058 - val_loss: 5.5139e-05 - learning_rate: 4.0000e-04
# Epoch 8/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0049 - loss: 4.1723e-05 - val_MAE: 0.0058 - val_loss: 5.6018e-05 - learning_rate: 4.0000e-04
# Epoch 9/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0051 - loss: 4.3257e-05 - val_MAE: 0.0056 - val_loss: 5.1944e-05 - learning_rate: 4.0000e-04
# Epoch 10/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0048 - loss: 4.0180e-05 - val_MAE: 0.0054 - val_loss: 4.9558e-05 - learning_rate: 4.0000e-04
# Epoch 11/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0048 - loss: 4.2329e-05 - val_MAE: 0.0054 - val_loss: 4.7913e-05 - learning_rate: 4.0000e-04
# Epoch 12/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0048 - loss: 3.8190e-05 - val_MAE: 0.0054 - val_loss: 4.8851e-05 - learning_rate: 8.0000e-05
# Epoch 13/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0049 - loss: 4.3068e-05 - val_MAE: 0.0055 - val_loss: 5.0107e-05 - learning_rate: 8.0000e-05
# Epoch 14/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0048 - loss: 3.9704e-05 - val_MAE: 0.0054 - val_loss: 4.9266e-05 - learning_rate: 8.0000e-05
# Epoch 15/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0047 - loss: 3.8125e-05 - val_MAE: 0.0055 - val_loss: 5.0631e-05 - learning_rate: 8.0000e-05
# Epoch 16/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0047 - loss: 3.7126e-05 - val_MAE: 0.0054 - val_loss: 4.9152e-05 - learning_rate: 8.0000e-05
# Epoch 17/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0048 - loss: 4.0190e-05 - val_MAE: 0.0054 - val_loss: 4.8873e-05 - learning_rate: 1.6000e-05
# Epoch 18/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0048 - loss: 4.2863e-05 - val_MAE: 0.0054 - val_loss: 4.8112e-05 - learning_rate: 1.6000e-05
# Epoch 19/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0048 - loss: 4.1530e-05 - val_MAE: 0.0054 - val_loss: 4.8839e-05 - learning_rate: 1.6000e-05
# Epoch 20/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0048 - loss: 3.9424e-05 - val_MAE: 0.0054 - val_loss: 4.9285e-05 - learning_rate: 1.6000e-05
# Epoch 21/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0048 - loss: 3.9284e-05 - val_MAE: 0.0054 - val_loss: 4.9332e-05 - learning_rate: 1.6000e-05
# Adamax Optimizer - Loss (MSE): 0.000048, Mean Absolute Error: 0.005350
#
# Training with RMSprop optimizer and prelu activation function...
# Epoch 1/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - MAE: 0.0050 - loss: 4.2489e-05 - val_MAE: 0.0047 - val_loss: 3.6410e-05 - learning_rate: 0.0010
# Epoch 2/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0048 - loss: 3.8567e-05 - val_MAE: 0.0056 - val_loss: 5.2110e-05 - learning_rate: 0.0010
# Epoch 3/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0047 - loss: 3.5534e-05 - val_MAE: 0.0074 - val_loss: 7.8957e-05 - learning_rate: 0.0010
# Epoch 4/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0047 - loss: 3.8766e-05 - val_MAE: 0.0041 - val_loss: 2.9136e-05 - learning_rate: 0.0010
# Epoch 5/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0044 - loss: 3.3170e-05 - val_MAE: 0.0041 - val_loss: 2.8301e-05 - learning_rate: 0.0010
# Epoch 6/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0042 - loss: 3.0765e-05 - val_MAE: 0.0050 - val_loss: 4.1554e-05 - learning_rate: 0.0010
# Epoch 7/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0041 - loss: 2.9626e-05 - val_MAE: 0.0041 - val_loss: 2.7984e-05 - learning_rate: 2.0000e-04
# Epoch 8/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0041 - loss: 2.9027e-05 - val_MAE: 0.0042 - val_loss: 3.0818e-05 - learning_rate: 2.0000e-04
# Epoch 9/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0042 - loss: 2.8649e-05 - val_MAE: 0.0042 - val_loss: 3.0330e-05 - learning_rate: 2.0000e-04
# Epoch 10/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0042 - loss: 2.9673e-05 - val_MAE: 0.0042 - val_loss: 3.0357e-05 - learning_rate: 2.0000e-04
# Epoch 11/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0041 - loss: 2.8996e-05 - val_MAE: 0.0040 - val_loss: 2.6732e-05 - learning_rate: 2.0000e-04
# Epoch 12/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0040 - loss: 2.9289e-05 - val_MAE: 0.0041 - val_loss: 2.9813e-05 - learning_rate: 4.0000e-05
# Epoch 13/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0040 - loss: 2.7717e-05 - val_MAE: 0.0041 - val_loss: 2.9481e-05 - learning_rate: 4.0000e-05
# Epoch 14/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0040 - loss: 2.7324e-05 - val_MAE: 0.0041 - val_loss: 2.8850e-05 - learning_rate: 4.0000e-05
# Epoch 15/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0040 - loss: 2.7344e-05 - val_MAE: 0.0040 - val_loss: 2.7641e-05 - learning_rate: 4.0000e-05
# Epoch 16/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0042 - loss: 3.0283e-05 - val_MAE: 0.0040 - val_loss: 2.8037e-05 - learning_rate: 4.0000e-05
# Epoch 17/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0039 - loss: 2.6555e-05 - val_MAE: 0.0041 - val_loss: 2.9167e-05 - learning_rate: 1.0000e-05
# Epoch 18/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0040 - loss: 2.7926e-05 - val_MAE: 0.0041 - val_loss: 2.8637e-05 - learning_rate: 1.0000e-05
# Epoch 19/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0040 - loss: 2.6556e-05 - val_MAE: 0.0041 - val_loss: 2.8750e-05 - learning_rate: 1.0000e-05
# Epoch 20/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0039 - loss: 2.5672e-05 - val_MAE: 0.0041 - val_loss: 2.8823e-05 - learning_rate: 1.0000e-05
# Epoch 21/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0040 - loss: 2.7451e-05 - val_MAE: 0.0041 - val_loss: 2.8789e-05 - learning_rate: 1.0000e-05
# RMSprop Optimizer - Loss (MSE): 0.000027, Mean Absolute Error: 0.003970
#
# Training with SGD optimizer and prelu activation function...
# Epoch 1/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - MAE: 0.0042 - loss: 3.0624e-05 - val_MAE: 0.0042 - val_loss: 3.0131e-05 - learning_rate: 0.0100
# Epoch 2/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0040 - loss: 2.8077e-05 - val_MAE: 0.0042 - val_loss: 3.0103e-05 - learning_rate: 0.0100
# Epoch 3/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0040 - loss: 2.7572e-05 - val_MAE: 0.0040 - val_loss: 2.8047e-05 - learning_rate: 0.0100
# Epoch 4/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0042 - loss: 3.0762e-05 - val_MAE: 0.0041 - val_loss: 2.8483e-05 - learning_rate: 0.0100
# Epoch 5/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0040 - loss: 2.7447e-05 - val_MAE: 0.0041 - val_loss: 2.9427e-05 - learning_rate: 0.0100
# Epoch 6/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0040 - loss: 2.7954e-05 - val_MAE: 0.0041 - val_loss: 3.0047e-05 - learning_rate: 0.0100
# Epoch 7/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0040 - loss: 2.8181e-05 - val_MAE: 0.0041 - val_loss: 2.9861e-05 - learning_rate: 0.0020
# Epoch 8/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0040 - loss: 2.7374e-05 - val_MAE: 0.0041 - val_loss: 2.8517e-05 - learning_rate: 0.0020
# Epoch 9/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0041 - loss: 2.7595e-05 - val_MAE: 0.0041 - val_loss: 2.9337e-05 - learning_rate: 0.0020
# Epoch 10/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0040 - loss: 2.6162e-05 - val_MAE: 0.0042 - val_loss: 3.0651e-05 - learning_rate: 0.0020
# Epoch 11/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0040 - loss: 2.8457e-05 - val_MAE: 0.0041 - val_loss: 2.8533e-05 - learning_rate: 0.0020
# Epoch 12/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0041 - loss: 2.9499e-05 - val_MAE: 0.0041 - val_loss: 2.9064e-05 - learning_rate: 4.0000e-04
# Epoch 13/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0040 - loss: 2.7315e-05 - val_MAE: 0.0041 - val_loss: 2.9197e-05 - learning_rate: 4.0000e-04
# SGD Optimizer - Loss (MSE): 0.000028, Mean Absolute Error: 0.004030
#
# Running for activation function: swish
#
# Training with Adamax optimizer and swish activation function...
# Epoch 1/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - MAE: 0.0167 - loss: 5.1422e-04 - val_MAE: 0.0033 - val_loss: 1.7569e-05 - learning_rate: 0.0020
# Epoch 2/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0079 - loss: 1.0440e-04 - val_MAE: 0.0030 - val_loss: 1.4239e-05 - learning_rate: 0.0020
# Epoch 3/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0065 - loss: 7.2215e-05 - val_MAE: 0.0026 - val_loss: 1.1385e-05 - learning_rate: 0.0020
# Epoch 4/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0056 - loss: 5.1470e-05 - val_MAE: 0.0025 - val_loss: 1.0628e-05 - learning_rate: 0.0020
# Epoch 5/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0049 - loss: 4.1165e-05 - val_MAE: 0.0024 - val_loss: 1.0273e-05 - learning_rate: 0.0020
# Epoch 6/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0044 - loss: 3.2116e-05 - val_MAE: 0.0024 - val_loss: 9.9140e-06 - learning_rate: 0.0020
# Epoch 7/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0041 - loss: 2.8186e-05 - val_MAE: 0.0024 - val_loss: 9.7473e-06 - learning_rate: 4.0000e-04
# Epoch 8/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0040 - loss: 2.7916e-05 - val_MAE: 0.0024 - val_loss: 9.6074e-06 - learning_rate: 4.0000e-04
# Epoch 9/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0039 - loss: 2.5663e-05 - val_MAE: 0.0024 - val_loss: 9.5481e-06 - learning_rate: 4.0000e-04
# Epoch 10/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0038 - loss: 2.4817e-05 - val_MAE: 0.0024 - val_loss: 9.7961e-06 - learning_rate: 4.0000e-04
# Epoch 11/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0038 - loss: 2.4646e-05 - val_MAE: 0.0023 - val_loss: 9.4414e-06 - learning_rate: 4.0000e-04
# Epoch 12/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0038 - loss: 2.4078e-05 - val_MAE: 0.0023 - val_loss: 9.5227e-06 - learning_rate: 8.0000e-05
# Epoch 13/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0037 - loss: 2.3031e-05 - val_MAE: 0.0023 - val_loss: 9.3987e-06 - learning_rate: 8.0000e-05
# Epoch 14/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0038 - loss: 2.5152e-05 - val_MAE: 0.0023 - val_loss: 9.4077e-06 - learning_rate: 8.0000e-05
# Epoch 15/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0036 - loss: 2.2284e-05 - val_MAE: 0.0023 - val_loss: 9.4003e-06 - learning_rate: 8.0000e-05
# Epoch 16/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0038 - loss: 2.4738e-05 - val_MAE: 0.0023 - val_loss: 9.3841e-06 - learning_rate: 8.0000e-05
# Epoch 17/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0039 - loss: 2.5375e-05 - val_MAE: 0.0023 - val_loss: 9.3538e-06 - learning_rate: 1.6000e-05
# Epoch 18/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0038 - loss: 2.4234e-05 - val_MAE: 0.0023 - val_loss: 9.3563e-06 - learning_rate: 1.6000e-05
# Epoch 19/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0038 - loss: 2.5190e-05 - val_MAE: 0.0023 - val_loss: 9.3508e-06 - learning_rate: 1.6000e-05
# Epoch 20/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0038 - loss: 2.4799e-05 - val_MAE: 0.0023 - val_loss: 9.3590e-06 - learning_rate: 1.6000e-05
# Epoch 21/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0037 - loss: 2.2406e-05 - val_MAE: 0.0023 - val_loss: 9.3505e-06 - learning_rate: 1.6000e-05
# Epoch 22/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0038 - loss: 2.5089e-05 - val_MAE: 0.0023 - val_loss: 9.3500e-06 - learning_rate: 1.0000e-05
# Epoch 23/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0038 - loss: 2.5158e-05 - val_MAE: 0.0023 - val_loss: 9.3485e-06 - learning_rate: 1.0000e-05
# Epoch 24/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0038 - loss: 2.4721e-05 - val_MAE: 0.0023 - val_loss: 9.3505e-06 - learning_rate: 1.0000e-05
# Epoch 25/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0038 - loss: 2.4813e-05 - val_MAE: 0.0023 - val_loss: 9.3500e-06 - learning_rate: 1.0000e-05
# Epoch 26/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0037 - loss: 2.3194e-05 - val_MAE: 0.0023 - val_loss: 9.3532e-06 - learning_rate: 1.0000e-05
# Epoch 27/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0040 - loss: 2.6664e-05 - val_MAE: 0.0023 - val_loss: 9.3519e-06 - learning_rate: 1.0000e-05
# Epoch 28/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0038 - loss: 2.3890e-05 - val_MAE: 0.0023 - val_loss: 9.3577e-06 - learning_rate: 1.0000e-05
# Epoch 29/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0038 - loss: 2.4867e-05 - val_MAE: 0.0023 - val_loss: 9.3596e-06 - learning_rate: 1.0000e-05
# Epoch 30/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0038 - loss: 2.3366e-05 - val_MAE: 0.0023 - val_loss: 9.3730e-06 - learning_rate: 1.0000e-05
# Epoch 31/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0039 - loss: 2.4253e-05 - val_MAE: 0.0023 - val_loss: 9.3886e-06 - learning_rate: 1.0000e-05
# Epoch 32/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0039 - loss: 2.6517e-05 - val_MAE: 0.0023 - val_loss: 9.3668e-06 - learning_rate: 1.0000e-05
# Epoch 33/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0038 - loss: 2.5136e-05 - val_MAE: 0.0023 - val_loss: 9.3731e-06 - learning_rate: 1.0000e-05
# Adamax Optimizer - Loss (MSE): 0.000009, Mean Absolute Error: 0.002326
#
# Training with RMSprop optimizer and swish activation function...
# Epoch 1/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - MAE: 0.0042 - loss: 2.9576e-05 - val_MAE: 0.0036 - val_loss: 1.8294e-05 - learning_rate: 0.0010
# Epoch 2/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0041 - loss: 2.6795e-05 - val_MAE: 0.0025 - val_loss: 1.0538e-05 - learning_rate: 0.0010
# Epoch 3/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0040 - loss: 2.7604e-05 - val_MAE: 0.0024 - val_loss: 9.6924e-06 - learning_rate: 0.0010
# Epoch 4/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0037 - loss: 2.2629e-05 - val_MAE: 0.0025 - val_loss: 1.0038e-05 - learning_rate: 0.0010
# Epoch 5/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0038 - loss: 2.4215e-05 - val_MAE: 0.0025 - val_loss: 1.0401e-05 - learning_rate: 0.0010
# Epoch 6/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0038 - loss: 2.4224e-05 - val_MAE: 0.0024 - val_loss: 9.6068e-06 - learning_rate: 0.0010
# Epoch 7/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0035 - loss: 2.0512e-05 - val_MAE: 0.0024 - val_loss: 9.7657e-06 - learning_rate: 2.0000e-04
# Epoch 8/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0034 - loss: 2.0128e-05 - val_MAE: 0.0024 - val_loss: 9.8325e-06 - learning_rate: 2.0000e-04
# Epoch 9/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0034 - loss: 1.9856e-05 - val_MAE: 0.0024 - val_loss: 9.9294e-06 - learning_rate: 2.0000e-04
# Epoch 10/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0033 - loss: 1.8626e-05 - val_MAE: 0.0023 - val_loss: 9.4693e-06 - learning_rate: 2.0000e-04
# Epoch 11/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0033 - loss: 1.8758e-05 - val_MAE: 0.0024 - val_loss: 9.8434e-06 - learning_rate: 2.0000e-04
# Epoch 12/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0035 - loss: 2.1225e-05 - val_MAE: 0.0023 - val_loss: 9.4669e-06 - learning_rate: 4.0000e-05
# Epoch 13/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0034 - loss: 1.9966e-05 - val_MAE: 0.0024 - val_loss: 9.5133e-06 - learning_rate: 4.0000e-05
# Epoch 14/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0032 - loss: 1.7179e-05 - val_MAE: 0.0024 - val_loss: 9.5839e-06 - learning_rate: 4.0000e-05
# Epoch 15/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0033 - loss: 1.9659e-05 - val_MAE: 0.0023 - val_loss: 9.4697e-06 - learning_rate: 4.0000e-05
# Epoch 16/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0033 - loss: 1.9933e-05 - val_MAE: 0.0023 - val_loss: 9.4804e-06 - learning_rate: 4.0000e-05
# Epoch 17/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0033 - loss: 1.8316e-05 - val_MAE: 0.0023 - val_loss: 9.4688e-06 - learning_rate: 1.0000e-05
# Epoch 18/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0033 - loss: 1.9286e-05 - val_MAE: 0.0023 - val_loss: 9.4671e-06 - learning_rate: 1.0000e-05
# Epoch 19/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0034 - loss: 2.1101e-05 - val_MAE: 0.0023 - val_loss: 9.4686e-06 - learning_rate: 1.0000e-05
# Epoch 20/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0032 - loss: 1.7033e-05 - val_MAE: 0.0023 - val_loss: 9.4615e-06 - learning_rate: 1.0000e-05
# Epoch 21/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0035 - loss: 1.9904e-05 - val_MAE: 0.0023 - val_loss: 9.4627e-06 - learning_rate: 1.0000e-05
# Epoch 22/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0035 - loss: 2.0654e-05 - val_MAE: 0.0023 - val_loss: 9.4622e-06 - learning_rate: 1.0000e-05
# Epoch 23/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0033 - loss: 1.8184e-05 - val_MAE: 0.0023 - val_loss: 9.4738e-06 - learning_rate: 1.0000e-05
# Epoch 24/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0034 - loss: 1.9405e-05 - val_MAE: 0.0023 - val_loss: 9.4641e-06 - learning_rate: 1.0000e-05
# Epoch 25/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0033 - loss: 1.8807e-05 - val_MAE: 0.0024 - val_loss: 9.4991e-06 - learning_rate: 1.0000e-05
# Epoch 26/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0034 - loss: 1.9472e-05 - val_MAE: 0.0023 - val_loss: 9.4640e-06 - learning_rate: 1.0000e-05
# Epoch 27/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0033 - loss: 1.9286e-05 - val_MAE: 0.0023 - val_loss: 9.4595e-06 - learning_rate: 1.0000e-05
# Epoch 28/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0033 - loss: 1.7993e-05 - val_MAE: 0.0023 - val_loss: 9.4710e-06 - learning_rate: 1.0000e-05
# Epoch 29/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0033 - loss: 1.8315e-05 - val_MAE: 0.0024 - val_loss: 9.4979e-06 - learning_rate: 1.0000e-05
# Epoch 30/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0035 - loss: 1.9840e-05 - val_MAE: 0.0023 - val_loss: 9.4700e-06 - learning_rate: 1.0000e-05
# Epoch 31/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0033 - loss: 1.7400e-05 - val_MAE: 0.0023 - val_loss: 9.4731e-06 - learning_rate: 1.0000e-05
# Epoch 32/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0034 - loss: 2.0302e-05 - val_MAE: 0.0023 - val_loss: 9.4584e-06 - learning_rate: 1.0000e-05
# Epoch 33/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0033 - loss: 1.8117e-05 - val_MAE: 0.0023 - val_loss: 9.4583e-06 - learning_rate: 1.0000e-05
# Epoch 34/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0035 - loss: 2.1629e-05 - val_MAE: 0.0023 - val_loss: 9.4620e-06 - learning_rate: 1.0000e-05
# Epoch 35/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0032 - loss: 1.7746e-05 - val_MAE: 0.0023 - val_loss: 9.4783e-06 - learning_rate: 1.0000e-05
# Epoch 36/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0032 - loss: 1.7472e-05 - val_MAE: 0.0023 - val_loss: 9.4620e-06 - learning_rate: 1.0000e-05
# Epoch 37/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0034 - loss: 1.9153e-05 - val_MAE: 0.0023 - val_loss: 9.4551e-06 - learning_rate: 1.0000e-05
# Epoch 38/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0033 - loss: 1.8792e-05 - val_MAE: 0.0023 - val_loss: 9.4612e-06 - learning_rate: 1.0000e-05
# Epoch 39/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0035 - loss: 2.0705e-05 - val_MAE: 0.0023 - val_loss: 9.4593e-06 - learning_rate: 1.0000e-05
# Epoch 40/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0034 - loss: 1.9419e-05 - val_MAE: 0.0023 - val_loss: 9.4554e-06 - learning_rate: 1.0000e-05
# Epoch 41/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0033 - loss: 1.7978e-05 - val_MAE: 0.0023 - val_loss: 9.4736e-06 - learning_rate: 1.0000e-05
# Epoch 42/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0033 - loss: 1.9341e-05 - val_MAE: 0.0023 - val_loss: 9.4624e-06 - learning_rate: 1.0000e-05
# Epoch 43/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0031 - loss: 1.6411e-05 - val_MAE: 0.0024 - val_loss: 9.4972e-06 - learning_rate: 1.0000e-05
# Epoch 44/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0032 - loss: 1.9029e-05 - val_MAE: 0.0023 - val_loss: 9.4547e-06 - learning_rate: 1.0000e-05
# Epoch 45/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0032 - loss: 1.7379e-05 - val_MAE: 0.0023 - val_loss: 9.4547e-06 - learning_rate: 1.0000e-05
# Epoch 46/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0033 - loss: 1.8604e-05 - val_MAE: 0.0023 - val_loss: 9.4583e-06 - learning_rate: 1.0000e-05
# Epoch 47/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0033 - loss: 1.8492e-05 - val_MAE: 0.0023 - val_loss: 9.4540e-06 - learning_rate: 1.0000e-05
# Epoch 48/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0033 - loss: 1.8571e-05 - val_MAE: 0.0023 - val_loss: 9.4562e-06 - learning_rate: 1.0000e-05
# Epoch 49/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0035 - loss: 2.1991e-05 - val_MAE: 0.0023 - val_loss: 9.4675e-06 - learning_rate: 1.0000e-05
# Epoch 50/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0032 - loss: 1.7160e-05 - val_MAE: 0.0023 - val_loss: 9.4555e-06 - learning_rate: 1.0000e-05
# Epoch 51/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0033 - loss: 1.9438e-05 - val_MAE: 0.0023 - val_loss: 9.4787e-06 - learning_rate: 1.0000e-05
# Epoch 52/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0035 - loss: 2.2765e-05 - val_MAE: 0.0023 - val_loss: 9.4861e-06 - learning_rate: 1.0000e-05
# Epoch 53/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0034 - loss: 2.0361e-05 - val_MAE: 0.0023 - val_loss: 9.4523e-06 - learning_rate: 1.0000e-05
# Epoch 54/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0034 - loss: 1.9243e-05 - val_MAE: 0.0023 - val_loss: 9.4632e-06 - learning_rate: 1.0000e-05
# Epoch 55/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0033 - loss: 1.7908e-05 - val_MAE: 0.0023 - val_loss: 9.4896e-06 - learning_rate: 1.0000e-05
# Epoch 56/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0035 - loss: 2.1170e-05 - val_MAE: 0.0023 - val_loss: 9.4595e-06 - learning_rate: 1.0000e-05
# Epoch 57/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0033 - loss: 1.9141e-05 - val_MAE: 0.0023 - val_loss: 9.4519e-06 - learning_rate: 1.0000e-05
# Epoch 58/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0034 - loss: 2.0018e-05 - val_MAE: 0.0023 - val_loss: 9.4555e-06 - learning_rate: 1.0000e-05
# Epoch 59/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0033 - loss: 1.8627e-05 - val_MAE: 0.0023 - val_loss: 9.4517e-06 - learning_rate: 1.0000e-05
# Epoch 60/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0033 - loss: 1.7771e-05 - val_MAE: 0.0023 - val_loss: 9.4505e-06 - learning_rate: 1.0000e-05
# Epoch 61/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0033 - loss: 1.9158e-05 - val_MAE: 0.0023 - val_loss: 9.4547e-06 - learning_rate: 1.0000e-05
# Epoch 62/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0034 - loss: 1.8890e-05 - val_MAE: 0.0023 - val_loss: 9.4545e-06 - learning_rate: 1.0000e-05
# Epoch 63/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0033 - loss: 1.8565e-05 - val_MAE: 0.0023 - val_loss: 9.4570e-06 - learning_rate: 1.0000e-05
# Epoch 64/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0033 - loss: 1.7950e-05 - val_MAE: 0.0023 - val_loss: 9.4518e-06 - learning_rate: 1.0000e-05
# Epoch 65/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0032 - loss: 1.7492e-05 - val_MAE: 0.0023 - val_loss: 9.4524e-06 - learning_rate: 1.0000e-05
# Epoch 66/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0034 - loss: 1.9054e-05 - val_MAE: 0.0023 - val_loss: 9.4530e-06 - learning_rate: 1.0000e-05
# Epoch 67/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0032 - loss: 1.7370e-05 - val_MAE: 0.0023 - val_loss: 9.4538e-06 - learning_rate: 1.0000e-05
# Epoch 68/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0033 - loss: 1.9149e-05 - val_MAE: 0.0023 - val_loss: 9.4524e-06 - learning_rate: 1.0000e-05
# Epoch 69/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0034 - loss: 1.9401e-05 - val_MAE: 0.0023 - val_loss: 9.4528e-06 - learning_rate: 1.0000e-05
# Epoch 70/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0033 - loss: 1.8575e-05 - val_MAE: 0.0023 - val_loss: 9.4625e-06 - learning_rate: 1.0000e-05
# RMSprop Optimizer - Loss (MSE): 0.000009, Mean Absolute Error: 0.002338
#
# Training with SGD optimizer and swish activation function...
# Epoch 1/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - MAE: 0.0032 - loss: 1.7322e-05 - val_MAE: 0.0024 - val_loss: 9.5102e-06 - learning_rate: 0.0100
# Epoch 2/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0034 - loss: 1.8957e-05 - val_MAE: 0.0023 - val_loss: 9.4489e-06 - learning_rate: 0.0100
# Epoch 3/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0032 - loss: 1.8330e-05 - val_MAE: 0.0023 - val_loss: 9.4454e-06 - learning_rate: 0.0100
# Epoch 4/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0032 - loss: 1.8524e-05 - val_MAE: 0.0023 - val_loss: 9.4563e-06 - learning_rate: 0.0100
# Epoch 5/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0033 - loss: 1.8604e-05 - val_MAE: 0.0023 - val_loss: 9.4628e-06 - learning_rate: 0.0100
# Epoch 6/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0034 - loss: 2.0190e-05 - val_MAE: 0.0023 - val_loss: 9.4891e-06 - learning_rate: 0.0100
# Epoch 7/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0033 - loss: 1.8883e-05 - val_MAE: 0.0023 - val_loss: 9.4497e-06 - learning_rate: 0.0020
# Epoch 8/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0033 - loss: 1.7893e-05 - val_MAE: 0.0023 - val_loss: 9.4781e-06 - learning_rate: 0.0020
# Epoch 9/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0033 - loss: 1.8523e-05 - val_MAE: 0.0023 - val_loss: 9.4541e-06 - learning_rate: 0.0020
# Epoch 10/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0034 - loss: 1.8922e-05 - val_MAE: 0.0023 - val_loss: 9.4535e-06 - learning_rate: 0.0020
# Epoch 11/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0033 - loss: 1.8062e-05 - val_MAE: 0.0023 - val_loss: 9.4494e-06 - learning_rate: 0.0020
# Epoch 12/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0033 - loss: 1.8669e-05 - val_MAE: 0.0023 - val_loss: 9.4564e-06 - learning_rate: 4.0000e-04
# Epoch 13/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0034 - loss: 2.1116e-05 - val_MAE: 0.0023 - val_loss: 9.4492e-06 - learning_rate: 4.0000e-04
# SGD Optimizer - Loss (MSE): 0.000009, Mean Absolute Error: 0.002338

# %%
print(all_mae_values)
print(all_loss_values)
print(all_labels)
# Out:
# [0.004594596102833748, 0.003275633091107011, 0.003543304977938533, 0.0042879325337708, 0.00323124835267663, 0.003926132805645466, 0.002938583493232727, 0.0025109080597758293, 0.002518885536119342, 0.005350043531507254, 0.00396988820284605, 0.004029629752039909, 0.0023262372706085443, 0.0023384448140859604, 0.002337715355679393]
# [3.586525053833611e-05, 1.860016527643893e-05, 2.205418422818184e-05, 2.9342869311221875e-05, 1.7225109331775457e-05, 2.4727842173888348e-05, 1.448420516680926e-05, 1.1598154742387123e-05, 1.1469650416984223e-05, 4.791285391547717e-05, 2.673183371371124e-05, 2.804720679705497e-05, 9.348487765237223e-06, 9.450480320083443e-06, 9.445426258025691e-06]
# ['relu, Adamax', 'relu, RMSprop', 'relu, SGD', 'leaky_relu, Adamax', 'leaky_relu, RMSprop', 'leaky_relu, SGD', 'elu, Adamax', 'elu, RMSprop', 'elu, SGD', 'prelu, Adamax', 'prelu, RMSprop', 'prelu, SGD', 'swish, Adamax', 'swish, RMSprop', 'swish, SGD']

# %%
# Create a DataFrame
chd_models_df = pd.DataFrame({
    'Model': all_labels, 
    'Activation_Function': all_activation_functions , 
    'Optimizer': all_optimizers, 
    'MAE': all_mae_values, 
    'Loss': all_loss_values
})

chd_models_df
# Out:
#                   Model Activation_Function Optimizer       MAE      Loss
# 0          relu, Adamax                relu    Adamax  0.004595  0.000036
# 1         relu, RMSprop                relu   RMSprop  0.003276  0.000019
# 2             relu, SGD                relu       SGD  0.003543  0.000022
# 3    leaky_relu, Adamax          leaky_relu    Adamax  0.004288  0.000029
# 4   leaky_relu, RMSprop          leaky_relu   RMSprop  0.003231  0.000017
# 5       leaky_relu, SGD          leaky_relu       SGD  0.003926  0.000025
# 6           elu, Adamax                 elu    Adamax  0.002939  0.000014
# 7          elu, RMSprop                 elu   RMSprop  0.002511  0.000012
# 8              elu, SGD                 elu       SGD  0.002519  0.000011
# 9         prelu, Adamax               prelu    Adamax  0.005350  0.000048
# 10       prelu, RMSprop               prelu   RMSprop  0.003970  0.000027
# 11           prelu, SGD               prelu       SGD  0.004030  0.000028
# 12        swish, Adamax               swish    Adamax  0.002326  0.000009
# 13       swish, RMSprop               swish   RMSprop  0.002338  0.000009
# 14           swish, SGD               swish       SGD  0.002338  0.000009

# %%
# Plotting
fig, ax1 = plt.subplots(figsize=(14, 8))

# Bar plot for Accuracy
color = 'tab:blue'
ax1.set_xlabel('Model')
ax1.set_ylabel('Mean Absolute Error', color=color)
ax1.bar(chd_models_df['Model'], chd_models_df['MAE'], color=color, alpha=0.6, label='MAE')
ax1.tick_params(axis='y', labelcolor=color)
ax1.set_xticks(range(len(chd_models_df['Model'])))
ax1.set_xticklabels(chd_models_df['Model'], rotation=90)

# Create a second y-axis for Loss
ax2 = ax1.twinx()
color = 'tab:red'
ax2.set_ylabel('Loss (MSE)', color=color)
ax2.plot(chd_models_df['Model'], chd_models_df['Loss'], color=color, marker='o', linestyle='-', linewidth=2, markersize=8, label='Loss')
ax2.tick_params(axis='y', labelcolor=color)

# Title and layout
plt.title('MAE and Loss for Chronic Heart Disease Models')
fig.tight_layout()
plt.show()

# %%
# Rank the models based on MAE (lower is better)
chd_models_df['MAE_Rank'] = chd_models_df['MAE'].rank()

# Rank the models based on Loss (lower is better)
chd_models_df['Loss_Rank'] = chd_models_df['Loss'].rank()

# Calculate the average rank
chd_models_df['Average_Rank'] = (chd_models_df['MAE_Rank'] + chd_models_df['Loss_Rank']) / 2

# Find the top two ranked models
best_model_avg_rank = chd_models_df.sort_values('Average_Rank').iloc[0]
print(best_model_avg_rank)
# Out:
# Model                  swish, Adamax
# Activation_Function            swish
# Optimizer                     Adamax
# MAE                         0.002326
# Loss                        0.000009
# MAE_Rank                         1.0
# Loss_Rank                        1.0
# Average_Rank                     1.0
# Name: 12, dtype: object

# %%
# Initialize train and get predictions with the random forest regressor
chd_rf = RandomForestRegressor(n_estimators=500, random_state=78)
chd_rf.fit(X_train, y_train)
predictions = chd_rf.predict(X_test)

# Evaluate using MAE MSE RMSE and R2 metrics
mae = mean_absolute_error(y_test, predictions)
mse = mean_squared_error(y_test, predictions)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, predictions)

# Print Evaluation Metrics
print(f"MAE: {mae}")
print(f"MSE: {mse}")
print(f"RMSE: {rmse}")
print(f"R²: {r2}")
# Out:
# MAE: 0.00226032769830949
# MSE: 9.15610218985695e-06
# RMSE: 0.003025905185206065
# R²: 0.881870567942117

# %%
# Get Feature Importance
importances = chd_rf.feature_importances_

# Extract feature names
feature_names = chd_df.drop(columns=['target_chd', 'county_index']).columns

# Visualize the features by importance
importances_df = pd.DataFrame(sorted(zip(chd_rf.feature_importances_, feature_names), reverse=True))
importances_df.set_index(importances_df[1], inplace=True)
importances_df.drop(columns=1, inplace=True)
importances_df.rename(columns={0: 'Feature Importances'}, inplace=True)
importances_sorted = importances_df.sort_values(by='Feature Importances')
importances_sorted.plot(kind='barh', color='lightgreen', title= 'CHD Features Importances', legend=False)
# Out:
# <Axes: title={'center': 'CHD Features Importances'}, ylabel='1'>
