# %%
import warnings
from pathlib import Path
import pandas as pd
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Dense, Dropout, Input, Activation
from keras.optimizers import Adamax, RMSprop, SGD
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from keras.layers import LeakyReLU, ELU, PReLU
import tensorflow as tf
from tensorflow.keras.callbacks import EarlyStopping
import matplotlib.pyplot as plt

# %%
# File Path
chd_data_to_load = Path("../Outputs/CHD_sdoh_access.csv")

# Read shcool metrics into Pandas DataFrames
chd_df = pd.read_csv(chd_data_to_load)

chd_df.head()
# Out:
#    county_index  target_chd  AGE65  BROAD  CROWD  HCOST  NOHSDP  POV150  \
# 0          1001         5.7   15.1   14.5    1.5   21.5    10.4    21.7
# 1          1011         7.9   16.2   40.6    0.8   23.9    22.4    46.0
# 2          1021         6.5   16.4   21.7    2.9   16.1    18.2    26.5
# 3          1029         6.5   19.2   27.2    2.1   18.1    16.9    27.3
# 4          1049         7.1   16.9   20.1    3.3   20.9    21.8    35.4
#
#    REMNRTY  SNGPNT  UNEMP  No_Vehicle_10_Miles  No_Vehicle_1_Mile  \
# 0     26.9     7.1    2.8             0.406809           1.528284
# 1     79.6    14.5    3.0             0.733003           3.060290
# 2     20.7     4.5    6.4             0.025205           1.416035
# 3      7.6     4.5    4.5             0.073470           1.302431
# 4     20.4     5.8    4.3             0.000000           1.492076
#
#    No_Vehicle_Half_Mile
# 0              1.914937
# 1              3.967381
# 2              1.718489
# 3              1.436014
# 4              1.816929

# %%
# Divide the percentage values by 100 to prepare for Neural Network
columns_to_scale = chd_df.dtypes[chd_df.dtypes == "float64"].index.tolist()
chd_df[columns_to_scale] = chd_df[columns_to_scale] / 100
chd_df.head()
# Out:
#    county_index  target_chd  AGE65  BROAD  CROWD  HCOST  NOHSDP  POV150  \
# 0          1001       0.057  0.151  0.145  0.015  0.215   0.104   0.217
# 1          1011       0.079  0.162  0.406  0.008  0.239   0.224   0.460
# 2          1021       0.065  0.164  0.217  0.029  0.161   0.182   0.265
# 3          1029       0.065  0.192  0.272  0.021  0.181   0.169   0.273
# 4          1049       0.071  0.169  0.201  0.033  0.209   0.218   0.354
#
#    REMNRTY  SNGPNT  UNEMP  No_Vehicle_10_Miles  No_Vehicle_1_Mile  \
# 0    0.269   0.071  0.028             0.004068           0.015283
# 1    0.796   0.145  0.030             0.007330           0.030603
# 2    0.207   0.045  0.064             0.000252           0.014160
# 3    0.076   0.045  0.045             0.000735           0.013024
# 4    0.204   0.058  0.043             0.000000           0.014921
#
#    No_Vehicle_Half_Mile
# 0              0.019149
# 1              0.039674
# 2              0.017185
# 3              0.014360
# 4              0.018169

# %%
# Split data into our features and target arrays
y = chd_df['target_chd'].values
X = chd_df.drop(columns = ['target_chd', 'county_index']).values

# Split the arrays into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=12)

# Data was prescaled manually so set values to work with the train_model function
X_train_scaled = X_train
X_test_scaled = X_test

# Set the values for input shape and hidden nodes for each layer
input_shape = len(X_train[0])
hidden_nodes_layer1 =  128
hidden_nodes_layer2 = 64
hidden_nodes_layer3 = 32

# %%
def train_model(X_train_scaled, y_train, X_test_scaled, y_test, activation_func='relu'):
    """
    Train a neural network with specified activation function and multiple optimizers.

    Args:
    - X_train_scaled: Scaled training data
    - y_train: Labels for training data
    - X_test_scaled: Scaled test data
    - y_test: Labels for test data
    - activation_func: Activation function to use (e.g., 'relu', 'leaky_relu', 'elu', 'prelu', 'swish')

    Returns:
    - mae_list2: List of mean absolute error for each optimizer
    - loss_list2: List of losses (MSE) for each optimizer
    """
    
    # Custom activation handling
    def get_activation(activation):
        if activation == 'leaky_relu':
            return LeakyReLU(alpha=0.1)  # Custom activation layer
        elif activation == 'elu':
            return ELU(alpha=1.0)  # Custom activation layer
        elif activation == 'prelu':
            return PReLU()  # Custom activation layer
        elif activation == 'swish':  # Or silu
            return Activation(tf.keras.activations.swish)  # Wrap as Activation layer
        else:
            return activation  # For standard activations like 'relu', 'sigmoid', etc.
    
    # Build model
    nn = tf.keras.models.Sequential()

    # Add the input layer
    nn.add(tf.keras.layers.Input(shape=(input_shape,)))
    
    # First hidden layer
    if isinstance(get_activation(activation_func), str):  # If it's a standard activation
        nn.add(tf.keras.layers.Dense(units=128, activation=get_activation(activation_func)))  # Use activation as string
    else:  # If it's a custom activation layer
        nn.add(tf.keras.layers.Dense(units=128))
        nn.add(get_activation(activation_func))  # Add custom activation layer
    
    # Dropout and subsequent layers
    nn.add(Dropout(0.3))
    if isinstance(get_activation(activation_func), str):
        nn.add(tf.keras.layers.Dense(units=64, activation=get_activation(activation_func)))
    else:
        nn.add(tf.keras.layers.Dense(units=64))
        nn.add(get_activation(activation_func))
    
    nn.add(Dropout(0.3))
    if isinstance(get_activation(activation_func), str):
        nn.add(tf.keras.layers.Dense(units=32, activation=get_activation(activation_func)))
    else:
        nn.add(tf.keras.layers.Dense(units=32))
        nn.add(get_activation(activation_func))
    
    # Output layer (for continuous data)
    nn.add(tf.keras.layers.Dense(units=1, activation="linear"))

    # Experiment with different optimizers
    optimizers = {
        'Adamax': Adamax(learning_rate=0.002),
        'RMSprop': RMSprop(learning_rate=0.001),
        'SGD': SGD(learning_rate=0.01, momentum=0.9)
    }

    mae_list2 = []
    loss_list2 = []

    # Iterate through each optimizer
    for name, optimizer in optimizers.items():
        print(f"\nTraining with {name} optimizer and {activation_func} activation function...")
        nn.compile(optimizer=optimizer, loss="mean_squared_error", metrics=["MAE"])

        # Callbacks
        early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
        reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=0.00001)

        # Train the model
        nn.fit(X_train_scaled, y_train, epochs=100, validation_data=(X_test_scaled, y_test),
               callbacks=[early_stopping, reduce_lr], verbose=1)

        # Evaluate the model
        loss, mae = nn.evaluate(X_test_scaled, y_test, verbose=0)
        print(f"{name} Optimizer - Loss (MSE): {loss:.6f}, Mean Absolute Error: {mae:.6f}")
        mae_list2.append(mae)
        loss_list2.append(loss)
    
    return mae_list2, loss_list2

# %%
all_mae_values = []
all_loss_values = []
all_labels = []
all_activation_functions = []
all_optimizers = []

activation_functions = ['relu', 'leaky_relu', 'elu', 'prelu', 'swish']
optimizers = ['Adamax', 'RMSprop', 'SGD']

for activation in activation_functions:
    print(f"\nRunning for activation function: {activation}")
    mae_list, loss_list = train_model(X_train_scaled, y_train, X_test_scaled, y_test, activation_func=activation)
    
    # Append the Mean Absolute Error, loss values and labels for this activation function
    all_mae_values.extend(mae_list)
    all_loss_values.extend(loss_list)
    
    # Create labels combining activation function and optimizer
    for optimizer in optimizers:
        all_labels.append(f"{activation}, {optimizer}")
        all_activation_functions.append(activation)
        all_optimizers.append(optimizer)
# Out:
# Running for activation function: relu
#
# Training with Adamax optimizer and relu activation function...
# Epoch 1/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - MAE: 0.0201 - loss: 7.8001e-04 - val_MAE: 0.0072 - val_loss: 7.5118e-05 - learning_rate: 0.0020
# Epoch 2/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0083 - loss: 1.1716e-04 - val_MAE: 0.0096 - val_loss: 1.2061e-04 - learning_rate: 0.0020
# Epoch 3/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0069 - loss: 8.2083e-05 - val_MAE: 0.0067 - val_loss: 6.4826e-05 - learning_rate: 0.0020
# Epoch 4/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0057 - loss: 5.8242e-05 - val_MAE: 0.0079 - val_loss: 8.9134e-05 - learning_rate: 0.0020
# Epoch 5/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0054 - loss: 4.8342e-05 - val_MAE: 0.0065 - val_loss: 6.4007e-05 - learning_rate: 0.0020
# Epoch 6/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0049 - loss: 4.0894e-05 - val_MAE: 0.0064 - val_loss: 6.2026e-05 - learning_rate: 0.0020
# Epoch 7/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0046 - loss: 3.7564e-05 - val_MAE: 0.0060 - val_loss: 5.5603e-05 - learning_rate: 4.0000e-04
# Epoch 8/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0046 - loss: 3.7321e-05 - val_MAE: 0.0060 - val_loss: 5.6239e-05 - learning_rate: 4.0000e-04
# Epoch 9/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0048 - loss: 4.0592e-05 - val_MAE: 0.0060 - val_loss: 5.5921e-05 - learning_rate: 4.0000e-04
# Epoch 10/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0044 - loss: 3.5201e-05 - val_MAE: 0.0056 - val_loss: 4.9256e-05 - learning_rate: 4.0000e-04
# Epoch 11/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0045 - loss: 3.4479e-05 - val_MAE: 0.0059 - val_loss: 5.2986e-05 - learning_rate: 4.0000e-04
# Epoch 12/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0046 - loss: 3.5247e-05 - val_MAE: 0.0057 - val_loss: 5.0432e-05 - learning_rate: 8.0000e-05
# Epoch 13/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0044 - loss: 3.3882e-05 - val_MAE: 0.0055 - val_loss: 4.7852e-05 - learning_rate: 8.0000e-05
# Epoch 14/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0044 - loss: 3.3778e-05 - val_MAE: 0.0056 - val_loss: 4.9111e-05 - learning_rate: 8.0000e-05
# Epoch 15/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0042 - loss: 3.5054e-05 - val_MAE: 0.0057 - val_loss: 4.9810e-05 - learning_rate: 8.0000e-05
# Epoch 16/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0044 - loss: 3.3312e-05 - val_MAE: 0.0057 - val_loss: 5.1113e-05 - learning_rate: 8.0000e-05
# Epoch 17/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0045 - loss: 3.4027e-05 - val_MAE: 0.0057 - val_loss: 5.1120e-05 - learning_rate: 1.6000e-05
# Epoch 18/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0043 - loss: 3.2979e-05 - val_MAE: 0.0057 - val_loss: 5.0356e-05 - learning_rate: 1.6000e-05
# Epoch 19/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0043 - loss: 3.2932e-05 - val_MAE: 0.0056 - val_loss: 4.9441e-05 - learning_rate: 1.6000e-05
# Epoch 20/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0041 - loss: 2.9669e-05 - val_MAE: 0.0056 - val_loss: 4.8812e-05 - learning_rate: 1.6000e-05
# Epoch 21/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0045 - loss: 3.3865e-05 - val_MAE: 0.0055 - val_loss: 4.8285e-05 - learning_rate: 1.6000e-05
# Epoch 22/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0042 - loss: 3.2182e-05 - val_MAE: 0.0056 - val_loss: 4.8643e-05 - learning_rate: 1.0000e-05
# Epoch 23/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0044 - loss: 3.3787e-05 - val_MAE: 0.0056 - val_loss: 4.8419e-05 - learning_rate: 1.0000e-05
# Adamax Optimizer - Loss (MSE): 0.000048, Mean Absolute Error: 0.005525
#
# Training with RMSprop optimizer and relu activation function...
# Epoch 1/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - MAE: 0.0046 - loss: 3.5397e-05 - val_MAE: 0.0061 - val_loss: 5.7176e-05 - learning_rate: 0.0010
# Epoch 2/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0042 - loss: 3.0022e-05 - val_MAE: 0.0056 - val_loss: 4.8148e-05 - learning_rate: 0.0010
# Epoch 3/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0041 - loss: 3.0244e-05 - val_MAE: 0.0067 - val_loss: 6.6540e-05 - learning_rate: 0.0010
# Epoch 4/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0041 - loss: 2.8593e-05 - val_MAE: 0.0038 - val_loss: 2.3690e-05 - learning_rate: 0.0010
# Epoch 5/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0042 - loss: 3.0425e-05 - val_MAE: 0.0044 - val_loss: 3.1558e-05 - learning_rate: 0.0010
# Epoch 6/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0040 - loss: 2.7383e-05 - val_MAE: 0.0044 - val_loss: 3.2685e-05 - learning_rate: 0.0010
# Epoch 7/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0038 - loss: 2.4675e-05 - val_MAE: 0.0049 - val_loss: 3.9641e-05 - learning_rate: 2.0000e-04
# Epoch 8/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0037 - loss: 2.3681e-05 - val_MAE: 0.0042 - val_loss: 2.9328e-05 - learning_rate: 2.0000e-04
# Epoch 9/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0040 - loss: 3.0709e-05 - val_MAE: 0.0053 - val_loss: 4.4181e-05 - learning_rate: 2.0000e-04
# Epoch 10/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0037 - loss: 2.4821e-05 - val_MAE: 0.0044 - val_loss: 3.2101e-05 - learning_rate: 2.0000e-04
# Epoch 11/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0039 - loss: 2.5597e-05 - val_MAE: 0.0048 - val_loss: 3.8215e-05 - learning_rate: 2.0000e-04
# Epoch 12/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0037 - loss: 2.5624e-05 - val_MAE: 0.0046 - val_loss: 3.5660e-05 - learning_rate: 4.0000e-05
# Epoch 13/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0038 - loss: 2.4930e-05 - val_MAE: 0.0048 - val_loss: 3.7085e-05 - learning_rate: 4.0000e-05
# Epoch 14/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0037 - loss: 2.3959e-05 - val_MAE: 0.0047 - val_loss: 3.5971e-05 - learning_rate: 4.0000e-05
# RMSprop Optimizer - Loss (MSE): 0.000024, Mean Absolute Error: 0.003764
#
# Training with SGD optimizer and relu activation function...
# Epoch 1/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - MAE: 0.0040 - loss: 2.8164e-05 - val_MAE: 0.0050 - val_loss: 3.9213e-05 - learning_rate: 0.0100
# Epoch 2/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0039 - loss: 2.6504e-05 - val_MAE: 0.0052 - val_loss: 4.1567e-05 - learning_rate: 0.0100
# Epoch 3/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0038 - loss: 2.6674e-05 - val_MAE: 0.0049 - val_loss: 3.7920e-05 - learning_rate: 0.0100
# Epoch 4/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0039 - loss: 2.6460e-05 - val_MAE: 0.0046 - val_loss: 3.4447e-05 - learning_rate: 0.0100
# Epoch 5/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0039 - loss: 2.5961e-05 - val_MAE: 0.0049 - val_loss: 3.7776e-05 - learning_rate: 0.0100
# Epoch 6/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0040 - loss: 2.8590e-05 - val_MAE: 0.0047 - val_loss: 3.5320e-05 - learning_rate: 0.0100
# Epoch 7/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0038 - loss: 2.5539e-05 - val_MAE: 0.0049 - val_loss: 3.7662e-05 - learning_rate: 0.0020
# Epoch 8/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0038 - loss: 2.4895e-05 - val_MAE: 0.0048 - val_loss: 3.6982e-05 - learning_rate: 0.0020
# Epoch 9/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0039 - loss: 2.6939e-05 - val_MAE: 0.0049 - val_loss: 3.7706e-05 - learning_rate: 0.0020
# Epoch 10/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0039 - loss: 2.5575e-05 - val_MAE: 0.0048 - val_loss: 3.7453e-05 - learning_rate: 0.0020
# Epoch 11/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0039 - loss: 2.5994e-05 - val_MAE: 0.0046 - val_loss: 3.4604e-05 - learning_rate: 0.0020
# Epoch 12/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0040 - loss: 2.9968e-05 - val_MAE: 0.0046 - val_loss: 3.4928e-05 - learning_rate: 4.0000e-04
# Epoch 13/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0039 - loss: 2.5966e-05 - val_MAE: 0.0047 - val_loss: 3.6170e-05 - learning_rate: 4.0000e-04
# Epoch 14/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0040 - loss: 2.7951e-05 - val_MAE: 0.0048 - val_loss: 3.6888e-05 - learning_rate: 4.0000e-04
# SGD Optimizer - Loss (MSE): 0.000034, Mean Absolute Error: 0.004608
#
# Running for activation function: leaky_relu
#
# Training with Adamax optimizer and leaky_relu activation function...
# Epoch 1/100
# C:\Users\ecros\anaconda3\envs\dev\lib\site-packages\keras\src\layers\activations\leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - MAE: 0.0255 - loss: 0.0017 - val_MAE: 0.0144 - val_loss: 2.5300e-04 - learning_rate: 0.0020
# Epoch 2/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0106 - loss: 2.0597e-04 - val_MAE: 0.0096 - val_loss: 1.3297e-04 - learning_rate: 0.0020
# Epoch 3/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0086 - loss: 1.3666e-04 - val_MAE: 0.0080 - val_loss: 9.8293e-05 - learning_rate: 0.0020
# Epoch 4/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0073 - loss: 9.9903e-05 - val_MAE: 0.0076 - val_loss: 9.0719e-05 - learning_rate: 0.0020
# Epoch 5/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0069 - loss: 1.0572e-04 - val_MAE: 0.0073 - val_loss: 8.2627e-05 - learning_rate: 0.0020
# Epoch 6/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0061 - loss: 6.6982e-05 - val_MAE: 0.0074 - val_loss: 8.3962e-05 - learning_rate: 0.0020
# Epoch 7/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0061 - loss: 6.9538e-05 - val_MAE: 0.0057 - val_loss: 5.2892e-05 - learning_rate: 0.0020
# Epoch 8/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0058 - loss: 6.2718e-05 - val_MAE: 0.0062 - val_loss: 6.1765e-05 - learning_rate: 4.0000e-04
# Epoch 9/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0056 - loss: 5.5630e-05 - val_MAE: 0.0057 - val_loss: 5.3091e-05 - learning_rate: 4.0000e-04
# Epoch 10/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0057 - loss: 5.5773e-05 - val_MAE: 0.0062 - val_loss: 6.0300e-05 - learning_rate: 4.0000e-04
# Epoch 11/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0053 - loss: 5.1798e-05 - val_MAE: 0.0059 - val_loss: 5.5276e-05 - learning_rate: 4.0000e-04
# Epoch 12/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0055 - loss: 5.3271e-05 - val_MAE: 0.0062 - val_loss: 5.9739e-05 - learning_rate: 4.0000e-04
# Epoch 13/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0051 - loss: 4.5449e-05 - val_MAE: 0.0058 - val_loss: 5.4416e-05 - learning_rate: 8.0000e-05
# Epoch 14/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0056 - loss: 5.7043e-05 - val_MAE: 0.0058 - val_loss: 5.3480e-05 - learning_rate: 8.0000e-05
# Epoch 15/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0052 - loss: 4.7448e-05 - val_MAE: 0.0057 - val_loss: 5.2214e-05 - learning_rate: 8.0000e-05
# Epoch 16/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0052 - loss: 4.7657e-05 - val_MAE: 0.0057 - val_loss: 5.2956e-05 - learning_rate: 8.0000e-05
# Epoch 17/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0052 - loss: 5.1456e-05 - val_MAE: 0.0056 - val_loss: 5.0744e-05 - learning_rate: 8.0000e-05
# Epoch 18/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0049 - loss: 4.4129e-05 - val_MAE: 0.0057 - val_loss: 5.1470e-05 - learning_rate: 1.6000e-05
# Epoch 19/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0054 - loss: 5.0757e-05 - val_MAE: 0.0057 - val_loss: 5.1859e-05 - learning_rate: 1.6000e-05
# Epoch 20/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0051 - loss: 4.6288e-05 - val_MAE: 0.0057 - val_loss: 5.2519e-05 - learning_rate: 1.6000e-05
# Epoch 21/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0054 - loss: 5.1393e-05 - val_MAE: 0.0058 - val_loss: 5.3131e-05 - learning_rate: 1.6000e-05
# Epoch 22/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0054 - loss: 5.3211e-05 - val_MAE: 0.0058 - val_loss: 5.2842e-05 - learning_rate: 1.6000e-05
# Epoch 23/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0055 - loss: 5.9539e-05 - val_MAE: 0.0057 - val_loss: 5.2534e-05 - learning_rate: 1.0000e-05
# Epoch 24/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0051 - loss: 4.7095e-05 - val_MAE: 0.0057 - val_loss: 5.2615e-05 - learning_rate: 1.0000e-05
# Epoch 25/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0054 - loss: 5.3673e-05 - val_MAE: 0.0058 - val_loss: 5.2834e-05 - learning_rate: 1.0000e-05
# Epoch 26/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0050 - loss: 4.5996e-05 - val_MAE: 0.0057 - val_loss: 5.2481e-05 - learning_rate: 1.0000e-05
# Epoch 27/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0056 - loss: 6.4341e-05 - val_MAE: 0.0058 - val_loss: 5.2951e-05 - learning_rate: 1.0000e-05
# Adamax Optimizer - Loss (MSE): 0.000051, Mean Absolute Error: 0.005605
#
# Training with RMSprop optimizer and leaky_relu activation function...
# Epoch 1/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - MAE: 0.0057 - loss: 5.7908e-05 - val_MAE: 0.0038 - val_loss: 2.5603e-05 - learning_rate: 0.0010
# Epoch 2/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0053 - loss: 5.3569e-05 - val_MAE: 0.0072 - val_loss: 7.4797e-05 - learning_rate: 0.0010
# Epoch 3/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0047 - loss: 3.7573e-05 - val_MAE: 0.0063 - val_loss: 5.7928e-05 - learning_rate: 0.0010
# Epoch 4/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0047 - loss: 4.0034e-05 - val_MAE: 0.0036 - val_loss: 2.1899e-05 - learning_rate: 0.0010
# Epoch 5/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0046 - loss: 3.7404e-05 - val_MAE: 0.0039 - val_loss: 2.5567e-05 - learning_rate: 0.0010
# Epoch 6/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0046 - loss: 3.7882e-05 - val_MAE: 0.0036 - val_loss: 2.2029e-05 - learning_rate: 0.0010
# Epoch 7/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0043 - loss: 3.1483e-05 - val_MAE: 0.0046 - val_loss: 3.5056e-05 - learning_rate: 2.0000e-04
# Epoch 8/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0040 - loss: 2.8363e-05 - val_MAE: 0.0045 - val_loss: 3.3495e-05 - learning_rate: 2.0000e-04
# Epoch 9/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0043 - loss: 3.1460e-05 - val_MAE: 0.0041 - val_loss: 2.7828e-05 - learning_rate: 2.0000e-04
# Epoch 10/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0041 - loss: 2.9223e-05 - val_MAE: 0.0041 - val_loss: 2.9005e-05 - learning_rate: 2.0000e-04
# Epoch 11/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0041 - loss: 2.9515e-05 - val_MAE: 0.0039 - val_loss: 2.6422e-05 - learning_rate: 2.0000e-04
# Epoch 12/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0042 - loss: 3.0549e-05 - val_MAE: 0.0041 - val_loss: 2.8793e-05 - learning_rate: 4.0000e-05
# Epoch 13/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0041 - loss: 3.1114e-05 - val_MAE: 0.0042 - val_loss: 2.9867e-05 - learning_rate: 4.0000e-05
# Epoch 14/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0040 - loss: 2.8197e-05 - val_MAE: 0.0042 - val_loss: 2.9960e-05 - learning_rate: 4.0000e-05
# RMSprop Optimizer - Loss (MSE): 0.000022, Mean Absolute Error: 0.003604
#
# Training with SGD optimizer and leaky_relu activation function...
# Epoch 1/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - MAE: 0.0044 - loss: 3.3138e-05 - val_MAE: 0.0045 - val_loss: 3.3840e-05 - learning_rate: 0.0100
# Epoch 2/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0045 - loss: 3.3826e-05 - val_MAE: 0.0046 - val_loss: 3.4859e-05 - learning_rate: 0.0100
# Epoch 3/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0046 - loss: 4.0712e-05 - val_MAE: 0.0047 - val_loss: 3.6298e-05 - learning_rate: 0.0100
# Epoch 4/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0044 - loss: 3.2827e-05 - val_MAE: 0.0044 - val_loss: 3.2715e-05 - learning_rate: 0.0100
# Epoch 5/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0043 - loss: 3.1770e-05 - val_MAE: 0.0042 - val_loss: 3.0026e-05 - learning_rate: 0.0100
# Epoch 6/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0042 - loss: 2.9888e-05 - val_MAE: 0.0049 - val_loss: 3.8833e-05 - learning_rate: 0.0100
# Epoch 7/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0045 - loss: 3.6070e-05 - val_MAE: 0.0044 - val_loss: 3.1962e-05 - learning_rate: 0.0020
# Epoch 8/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0044 - loss: 3.7865e-05 - val_MAE: 0.0047 - val_loss: 3.5748e-05 - learning_rate: 0.0020
# Epoch 9/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0041 - loss: 3.0450e-05 - val_MAE: 0.0045 - val_loss: 3.3998e-05 - learning_rate: 0.0020
# Epoch 10/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0045 - loss: 3.5652e-05 - val_MAE: 0.0046 - val_loss: 3.4460e-05 - learning_rate: 0.0020
# Epoch 11/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0043 - loss: 3.2571e-05 - val_MAE: 0.0045 - val_loss: 3.3449e-05 - learning_rate: 0.0020
# Epoch 12/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0044 - loss: 3.4110e-05 - val_MAE: 0.0046 - val_loss: 3.4381e-05 - learning_rate: 4.0000e-04
# Epoch 13/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0044 - loss: 3.3507e-05 - val_MAE: 0.0046 - val_loss: 3.4192e-05 - learning_rate: 4.0000e-04
# Epoch 14/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0045 - loss: 3.7220e-05 - val_MAE: 0.0045 - val_loss: 3.4016e-05 - learning_rate: 4.0000e-04
# Epoch 15/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0045 - loss: 3.7539e-05 - val_MAE: 0.0046 - val_loss: 3.4553e-05 - learning_rate: 4.0000e-04
# SGD Optimizer - Loss (MSE): 0.000030, Mean Absolute Error: 0.004237
#
# Running for activation function: elu
#
# Training with Adamax optimizer and elu activation function...
# Epoch 1/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - MAE: 0.0894 - loss: 0.0153 - val_MAE: 0.0065 - val_loss: 6.9846e-05 - learning_rate: 0.0020
# Epoch 2/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0365 - loss: 0.0024 - val_MAE: 0.0040 - val_loss: 2.6200e-05 - learning_rate: 0.0020
# Epoch 3/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0264 - loss: 0.0012 - val_MAE: 0.0040 - val_loss: 2.6030e-05 - learning_rate: 0.0020
# Epoch 4/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0220 - loss: 8.0996e-04 - val_MAE: 0.0031 - val_loss: 1.6969e-05 - learning_rate: 0.0020
# Epoch 5/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0172 - loss: 5.3167e-04 - val_MAE: 0.0043 - val_loss: 2.7262e-05 - learning_rate: 0.0020
# Epoch 6/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0145 - loss: 3.6477e-04 - val_MAE: 0.0042 - val_loss: 2.9168e-05 - learning_rate: 0.0020
# Epoch 7/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0130 - loss: 2.9095e-04 - val_MAE: 0.0029 - val_loss: 1.5725e-05 - learning_rate: 4.0000e-04
# Epoch 8/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0130 - loss: 2.9247e-04 - val_MAE: 0.0029 - val_loss: 1.6084e-05 - learning_rate: 4.0000e-04
# Epoch 9/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0120 - loss: 2.5633e-04 - val_MAE: 0.0028 - val_loss: 1.3566e-05 - learning_rate: 4.0000e-04
# Epoch 10/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0116 - loss: 2.3639e-04 - val_MAE: 0.0030 - val_loss: 1.5048e-05 - learning_rate: 4.0000e-04
# Epoch 11/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0114 - loss: 2.2900e-04 - val_MAE: 0.0030 - val_loss: 1.4672e-05 - learning_rate: 4.0000e-04
# Epoch 12/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0104 - loss: 1.8477e-04 - val_MAE: 0.0028 - val_loss: 1.3514e-05 - learning_rate: 8.0000e-05
# Epoch 13/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0107 - loss: 2.0027e-04 - val_MAE: 0.0029 - val_loss: 1.4008e-05 - learning_rate: 8.0000e-05
# Epoch 14/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0106 - loss: 2.0050e-04 - val_MAE: 0.0029 - val_loss: 1.3977e-05 - learning_rate: 8.0000e-05
# Epoch 15/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0100 - loss: 1.8299e-04 - val_MAE: 0.0028 - val_loss: 1.3570e-05 - learning_rate: 8.0000e-05
# Epoch 16/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0104 - loss: 1.9553e-04 - val_MAE: 0.0027 - val_loss: 1.3645e-05 - learning_rate: 8.0000e-05
# Epoch 17/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0101 - loss: 1.7547e-04 - val_MAE: 0.0028 - val_loss: 1.3769e-05 - learning_rate: 1.6000e-05
# Epoch 18/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0102 - loss: 1.8011e-04 - val_MAE: 0.0028 - val_loss: 1.3756e-05 - learning_rate: 1.6000e-05
# Epoch 19/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0100 - loss: 1.6856e-04 - val_MAE: 0.0028 - val_loss: 1.3923e-05 - learning_rate: 1.6000e-05
# Epoch 20/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0099 - loss: 1.7583e-04 - val_MAE: 0.0028 - val_loss: 1.3885e-05 - learning_rate: 1.6000e-05
# Epoch 21/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0101 - loss: 1.8123e-04 - val_MAE: 0.0028 - val_loss: 1.3965e-05 - learning_rate: 1.6000e-05
# Epoch 22/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0106 - loss: 1.9654e-04 - val_MAE: 0.0028 - val_loss: 1.3806e-05 - learning_rate: 1.0000e-05
# Adamax Optimizer - Loss (MSE): 0.000014, Mean Absolute Error: 0.002757
#
# Training with RMSprop optimizer and elu activation function...
# Epoch 1/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - MAE: 0.0140 - loss: 3.5885e-04 - val_MAE: 0.0065 - val_loss: 5.6886e-05 - learning_rate: 0.0010
# Epoch 2/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0082 - loss: 1.0951e-04 - val_MAE: 0.0058 - val_loss: 4.6430e-05 - learning_rate: 0.0010
# Epoch 3/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0069 - loss: 7.4446e-05 - val_MAE: 0.0035 - val_loss: 2.2275e-05 - learning_rate: 0.0010
# Epoch 4/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0063 - loss: 6.3616e-05 - val_MAE: 0.0046 - val_loss: 3.1628e-05 - learning_rate: 0.0010
# Epoch 5/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0057 - loss: 5.2406e-05 - val_MAE: 0.0050 - val_loss: 3.7482e-05 - learning_rate: 0.0010
# Epoch 6/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0058 - loss: 5.3000e-05 - val_MAE: 0.0034 - val_loss: 1.7631e-05 - learning_rate: 0.0010
# Epoch 7/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0037 - loss: 2.4960e-05 - val_MAE: 0.0026 - val_loss: 1.1529e-05 - learning_rate: 2.0000e-04
# Epoch 8/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0037 - loss: 2.4016e-05 - val_MAE: 0.0026 - val_loss: 1.1740e-05 - learning_rate: 2.0000e-04
# Epoch 9/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0036 - loss: 2.1623e-05 - val_MAE: 0.0028 - val_loss: 1.2928e-05 - learning_rate: 2.0000e-04
# Epoch 10/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0038 - loss: 2.5579e-05 - val_MAE: 0.0026 - val_loss: 1.1593e-05 - learning_rate: 2.0000e-04
# Epoch 11/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0037 - loss: 2.3414e-05 - val_MAE: 0.0028 - val_loss: 1.2960e-05 - learning_rate: 2.0000e-04
# Epoch 12/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0037 - loss: 2.4408e-05 - val_MAE: 0.0025 - val_loss: 1.1256e-05 - learning_rate: 4.0000e-05
# Epoch 13/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0035 - loss: 2.0673e-05 - val_MAE: 0.0025 - val_loss: 1.1287e-05 - learning_rate: 4.0000e-05
# Epoch 14/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0035 - loss: 2.3271e-05 - val_MAE: 0.0025 - val_loss: 1.1297e-05 - learning_rate: 4.0000e-05
# Epoch 15/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0036 - loss: 2.3147e-05 - val_MAE: 0.0026 - val_loss: 1.1589e-05 - learning_rate: 4.0000e-05
# Epoch 16/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0036 - loss: 2.3645e-05 - val_MAE: 0.0025 - val_loss: 1.1138e-05 - learning_rate: 4.0000e-05
# Epoch 17/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0036 - loss: 2.1767e-05 - val_MAE: 0.0026 - val_loss: 1.1661e-05 - learning_rate: 1.0000e-05
# Epoch 18/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0034 - loss: 2.0889e-05 - val_MAE: 0.0025 - val_loss: 1.1170e-05 - learning_rate: 1.0000e-05
# Epoch 19/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0035 - loss: 2.2067e-05 - val_MAE: 0.0025 - val_loss: 1.1164e-05 - learning_rate: 1.0000e-05
# Epoch 20/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0035 - loss: 2.2271e-05 - val_MAE: 0.0025 - val_loss: 1.1187e-05 - learning_rate: 1.0000e-05
# Epoch 21/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0035 - loss: 2.2296e-05 - val_MAE: 0.0026 - val_loss: 1.1766e-05 - learning_rate: 1.0000e-05
# Epoch 22/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0036 - loss: 2.2692e-05 - val_MAE: 0.0026 - val_loss: 1.1522e-05 - learning_rate: 1.0000e-05
# Epoch 23/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0036 - loss: 2.2455e-05 - val_MAE: 0.0026 - val_loss: 1.1764e-05 - learning_rate: 1.0000e-05
# Epoch 24/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0033 - loss: 1.9341e-05 - val_MAE: 0.0026 - val_loss: 1.1359e-05 - learning_rate: 1.0000e-05
# Epoch 25/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0035 - loss: 2.2450e-05 - val_MAE: 0.0025 - val_loss: 1.1142e-05 - learning_rate: 1.0000e-05
# Epoch 26/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0036 - loss: 2.3054e-05 - val_MAE: 0.0026 - val_loss: 1.1414e-05 - learning_rate: 1.0000e-05
# RMSprop Optimizer - Loss (MSE): 0.000011, Mean Absolute Error: 0.002508
#
# Training with SGD optimizer and elu activation function...
# Epoch 1/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - MAE: 0.0038 - loss: 2.9632e-05 - val_MAE: 0.0026 - val_loss: 1.1297e-05 - learning_rate: 0.0100
# Epoch 2/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0037 - loss: 2.3428e-05 - val_MAE: 0.0025 - val_loss: 1.1070e-05 - learning_rate: 0.0100
# Epoch 3/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0035 - loss: 2.1886e-05 - val_MAE: 0.0028 - val_loss: 1.2987e-05 - learning_rate: 0.0100
# Epoch 4/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0036 - loss: 2.1842e-05 - val_MAE: 0.0025 - val_loss: 1.0952e-05 - learning_rate: 0.0100
# Epoch 5/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0035 - loss: 2.1846e-05 - val_MAE: 0.0026 - val_loss: 1.1747e-05 - learning_rate: 0.0100
# Epoch 6/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0034 - loss: 2.1044e-05 - val_MAE: 0.0025 - val_loss: 1.1037e-05 - learning_rate: 0.0100
# Epoch 7/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0035 - loss: 1.9705e-05 - val_MAE: 0.0026 - val_loss: 1.1365e-05 - learning_rate: 0.0020
# Epoch 8/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0036 - loss: 2.3112e-05 - val_MAE: 0.0026 - val_loss: 1.1273e-05 - learning_rate: 0.0020
# Epoch 9/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0037 - loss: 2.4431e-05 - val_MAE: 0.0026 - val_loss: 1.1251e-05 - learning_rate: 0.0020
# Epoch 10/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0035 - loss: 2.1447e-05 - val_MAE: 0.0025 - val_loss: 1.1096e-05 - learning_rate: 0.0020
# Epoch 11/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0033 - loss: 2.0222e-05 - val_MAE: 0.0025 - val_loss: 1.1104e-05 - learning_rate: 0.0020
# Epoch 12/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0035 - loss: 2.2937e-05 - val_MAE: 0.0026 - val_loss: 1.1394e-05 - learning_rate: 4.0000e-04
# Epoch 13/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0036 - loss: 2.3118e-05 - val_MAE: 0.0026 - val_loss: 1.1233e-05 - learning_rate: 4.0000e-04
# Epoch 14/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0035 - loss: 2.0881e-05 - val_MAE: 0.0026 - val_loss: 1.1315e-05 - learning_rate: 4.0000e-04
# SGD Optimizer - Loss (MSE): 0.000011, Mean Absolute Error: 0.002485
#
# Running for activation function: prelu
#
# Training with Adamax optimizer and prelu activation function...
# Epoch 1/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - MAE: 0.0266 - loss: 0.0014 - val_MAE: 0.0067 - val_loss: 6.2894e-05 - learning_rate: 0.0020
# Epoch 2/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0095 - loss: 1.6251e-04 - val_MAE: 0.0057 - val_loss: 5.1005e-05 - learning_rate: 0.0020
# Epoch 3/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0075 - loss: 1.0210e-04 - val_MAE: 0.0065 - val_loss: 6.9343e-05 - learning_rate: 0.0020
# Epoch 4/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0067 - loss: 8.0350e-05 - val_MAE: 0.0059 - val_loss: 5.6726e-05 - learning_rate: 0.0020
# Epoch 5/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0059 - loss: 5.8840e-05 - val_MAE: 0.0054 - val_loss: 4.8291e-05 - learning_rate: 0.0020
# Epoch 6/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0056 - loss: 5.4589e-05 - val_MAE: 0.0046 - val_loss: 3.5310e-05 - learning_rate: 0.0020
# Epoch 7/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0054 - loss: 5.0714e-05 - val_MAE: 0.0047 - val_loss: 3.6035e-05 - learning_rate: 4.0000e-04
# Epoch 8/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0055 - loss: 5.3086e-05 - val_MAE: 0.0045 - val_loss: 3.3707e-05 - learning_rate: 4.0000e-04
# Epoch 9/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0051 - loss: 4.4052e-05 - val_MAE: 0.0045 - val_loss: 3.4327e-05 - learning_rate: 4.0000e-04
# Epoch 10/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0048 - loss: 4.1409e-05 - val_MAE: 0.0045 - val_loss: 3.4354e-05 - learning_rate: 4.0000e-04
# Epoch 11/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0050 - loss: 4.5668e-05 - val_MAE: 0.0042 - val_loss: 2.9565e-05 - learning_rate: 4.0000e-04
# Epoch 12/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0052 - loss: 4.8336e-05 - val_MAE: 0.0044 - val_loss: 3.2451e-05 - learning_rate: 8.0000e-05
# Epoch 13/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0050 - loss: 4.5489e-05 - val_MAE: 0.0044 - val_loss: 3.2610e-05 - learning_rate: 8.0000e-05
# Epoch 14/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0052 - loss: 4.9810e-05 - val_MAE: 0.0044 - val_loss: 3.1787e-05 - learning_rate: 8.0000e-05
# Epoch 15/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0052 - loss: 5.1317e-05 - val_MAE: 0.0045 - val_loss: 3.3884e-05 - learning_rate: 8.0000e-05
# Epoch 16/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0051 - loss: 4.7027e-05 - val_MAE: 0.0044 - val_loss: 3.2782e-05 - learning_rate: 8.0000e-05
# Epoch 17/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0050 - loss: 4.3351e-05 - val_MAE: 0.0044 - val_loss: 3.2774e-05 - learning_rate: 1.6000e-05
# Epoch 18/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0051 - loss: 4.7836e-05 - val_MAE: 0.0044 - val_loss: 3.2355e-05 - learning_rate: 1.6000e-05
# Epoch 19/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0050 - loss: 4.3610e-05 - val_MAE: 0.0044 - val_loss: 3.2254e-05 - learning_rate: 1.6000e-05
# Epoch 20/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0050 - loss: 4.3359e-05 - val_MAE: 0.0044 - val_loss: 3.2621e-05 - learning_rate: 1.6000e-05
# Epoch 21/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0048 - loss: 3.9234e-05 - val_MAE: 0.0044 - val_loss: 3.2572e-05 - learning_rate: 1.6000e-05
# Adamax Optimizer - Loss (MSE): 0.000030, Mean Absolute Error: 0.004214
#
# Training with RMSprop optimizer and prelu activation function...
# Epoch 1/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - MAE: 0.0055 - loss: 5.1143e-05 - val_MAE: 0.0044 - val_loss: 3.0567e-05 - learning_rate: 0.0010
# Epoch 2/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0050 - loss: 4.3502e-05 - val_MAE: 0.0047 - val_loss: 3.6017e-05 - learning_rate: 0.0010
# Epoch 3/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0046 - loss: 3.5739e-05 - val_MAE: 0.0040 - val_loss: 2.5598e-05 - learning_rate: 0.0010
# Epoch 4/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0048 - loss: 3.9444e-05 - val_MAE: 0.0041 - val_loss: 2.7498e-05 - learning_rate: 0.0010
# Epoch 5/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0046 - loss: 3.9463e-05 - val_MAE: 0.0042 - val_loss: 2.8370e-05 - learning_rate: 0.0010
# Epoch 6/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0045 - loss: 3.3430e-05 - val_MAE: 0.0037 - val_loss: 2.3038e-05 - learning_rate: 0.0010
# Epoch 7/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0040 - loss: 2.8568e-05 - val_MAE: 0.0037 - val_loss: 2.2501e-05 - learning_rate: 2.0000e-04
# Epoch 8/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0041 - loss: 2.9458e-05 - val_MAE: 0.0038 - val_loss: 2.4475e-05 - learning_rate: 2.0000e-04
# Epoch 9/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0041 - loss: 2.8261e-05 - val_MAE: 0.0038 - val_loss: 2.3445e-05 - learning_rate: 2.0000e-04
# Epoch 10/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0041 - loss: 2.8380e-05 - val_MAE: 0.0038 - val_loss: 2.3644e-05 - learning_rate: 2.0000e-04
# Epoch 11/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0039 - loss: 2.6172e-05 - val_MAE: 0.0038 - val_loss: 2.3689e-05 - learning_rate: 2.0000e-04
# Epoch 12/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0040 - loss: 2.8415e-05 - val_MAE: 0.0037 - val_loss: 2.2224e-05 - learning_rate: 4.0000e-05
# Epoch 13/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0039 - loss: 2.6152e-05 - val_MAE: 0.0037 - val_loss: 2.2843e-05 - learning_rate: 4.0000e-05
# Epoch 14/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0039 - loss: 2.5876e-05 - val_MAE: 0.0037 - val_loss: 2.2840e-05 - learning_rate: 4.0000e-05
# Epoch 15/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0038 - loss: 2.6651e-05 - val_MAE: 0.0037 - val_loss: 2.3148e-05 - learning_rate: 4.0000e-05
# Epoch 16/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0040 - loss: 2.7451e-05 - val_MAE: 0.0037 - val_loss: 2.1981e-05 - learning_rate: 4.0000e-05
# Epoch 17/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0039 - loss: 2.6548e-05 - val_MAE: 0.0038 - val_loss: 2.3455e-05 - learning_rate: 1.0000e-05
# Epoch 18/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0040 - loss: 2.7470e-05 - val_MAE: 0.0037 - val_loss: 2.3116e-05 - learning_rate: 1.0000e-05
# Epoch 19/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0040 - loss: 2.7783e-05 - val_MAE: 0.0038 - val_loss: 2.3580e-05 - learning_rate: 1.0000e-05
# Epoch 20/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0037 - loss: 2.4587e-05 - val_MAE: 0.0037 - val_loss: 2.3059e-05 - learning_rate: 1.0000e-05
# Epoch 21/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0038 - loss: 2.4099e-05 - val_MAE: 0.0037 - val_loss: 2.3044e-05 - learning_rate: 1.0000e-05
# Epoch 22/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0040 - loss: 2.6950e-05 - val_MAE: 0.0037 - val_loss: 2.2926e-05 - learning_rate: 1.0000e-05
# Epoch 23/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0040 - loss: 2.7538e-05 - val_MAE: 0.0037 - val_loss: 2.2172e-05 - learning_rate: 1.0000e-05
# Epoch 24/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0040 - loss: 2.6978e-05 - val_MAE: 0.0037 - val_loss: 2.2488e-05 - learning_rate: 1.0000e-05
# Epoch 25/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0038 - loss: 2.5569e-05 - val_MAE: 0.0037 - val_loss: 2.2559e-05 - learning_rate: 1.0000e-05
# Epoch 26/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0039 - loss: 2.7757e-05 - val_MAE: 0.0037 - val_loss: 2.2688e-05 - learning_rate: 1.0000e-05
# RMSprop Optimizer - Loss (MSE): 0.000022, Mean Absolute Error: 0.003656
#
# Training with SGD optimizer and prelu activation function...
# Epoch 1/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - MAE: 0.0039 - loss: 2.7363e-05 - val_MAE: 0.0036 - val_loss: 2.1203e-05 - learning_rate: 0.0100
# Epoch 2/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0039 - loss: 2.5068e-05 - val_MAE: 0.0037 - val_loss: 2.2843e-05 - learning_rate: 0.0100
# Epoch 3/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0039 - loss: 2.5218e-05 - val_MAE: 0.0037 - val_loss: 2.2992e-05 - learning_rate: 0.0100
# Epoch 4/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0040 - loss: 2.7564e-05 - val_MAE: 0.0037 - val_loss: 2.2425e-05 - learning_rate: 0.0100
# Epoch 5/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0044 - loss: 3.2744e-05 - val_MAE: 0.0038 - val_loss: 2.3451e-05 - learning_rate: 0.0100
# Epoch 6/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0041 - loss: 2.8927e-05 - val_MAE: 0.0037 - val_loss: 2.2335e-05 - learning_rate: 0.0100
# Epoch 7/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0039 - loss: 2.5966e-05 - val_MAE: 0.0036 - val_loss: 2.1509e-05 - learning_rate: 0.0020
# Epoch 8/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0039 - loss: 2.7325e-05 - val_MAE: 0.0037 - val_loss: 2.2353e-05 - learning_rate: 0.0020
# Epoch 9/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0040 - loss: 2.6016e-05 - val_MAE: 0.0037 - val_loss: 2.2377e-05 - learning_rate: 0.0020
# Epoch 10/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0039 - loss: 2.6854e-05 - val_MAE: 0.0037 - val_loss: 2.2783e-05 - learning_rate: 0.0020
# Epoch 11/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0040 - loss: 2.7999e-05 - val_MAE: 0.0037 - val_loss: 2.2424e-05 - learning_rate: 0.0020
# SGD Optimizer - Loss (MSE): 0.000021, Mean Absolute Error: 0.003607
#
# Running for activation function: swish
#
# Training with Adamax optimizer and swish activation function...
# Epoch 1/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - MAE: 0.0136 - loss: 3.3926e-04 - val_MAE: 0.0036 - val_loss: 2.0698e-05 - learning_rate: 0.0020
# Epoch 2/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0071 - loss: 8.2421e-05 - val_MAE: 0.0027 - val_loss: 1.2127e-05 - learning_rate: 0.0020
# Epoch 3/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0052 - loss: 4.6610e-05 - val_MAE: 0.0026 - val_loss: 1.1735e-05 - learning_rate: 0.0020
# Epoch 4/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0046 - loss: 3.6793e-05 - val_MAE: 0.0025 - val_loss: 1.0637e-05 - learning_rate: 0.0020
# Epoch 5/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAE: 0.0042 - loss: 2.9030e-05 - val_MAE: 0.0029 - val_loss: 1.4127e-05 - learning_rate: 0.0020
# Epoch 6/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0040 - loss: 2.8443e-05 - val_MAE: 0.0024 - val_loss: 9.8652e-06 - learning_rate: 0.0020
# Epoch 7/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0036 - loss: 2.2681e-05 - val_MAE: 0.0023 - val_loss: 9.3935e-06 - learning_rate: 4.0000e-04
# Epoch 8/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0036 - loss: 2.1457e-05 - val_MAE: 0.0023 - val_loss: 9.3254e-06 - learning_rate: 4.0000e-04
# Epoch 9/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0036 - loss: 2.3247e-05 - val_MAE: 0.0023 - val_loss: 9.3410e-06 - learning_rate: 4.0000e-04
# Epoch 10/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0035 - loss: 2.0109e-05 - val_MAE: 0.0024 - val_loss: 9.9480e-06 - learning_rate: 4.0000e-04
# Epoch 11/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0035 - loss: 1.9839e-05 - val_MAE: 0.0023 - val_loss: 9.2526e-06 - learning_rate: 4.0000e-04
# Epoch 12/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0035 - loss: 2.0506e-05 - val_MAE: 0.0023 - val_loss: 9.3249e-06 - learning_rate: 8.0000e-05
# Epoch 13/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0036 - loss: 2.2248e-05 - val_MAE: 0.0023 - val_loss: 9.2001e-06 - learning_rate: 8.0000e-05
# Epoch 14/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0033 - loss: 1.8581e-05 - val_MAE: 0.0023 - val_loss: 9.1967e-06 - learning_rate: 8.0000e-05
# Epoch 15/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0035 - loss: 2.1589e-05 - val_MAE: 0.0023 - val_loss: 9.2374e-06 - learning_rate: 8.0000e-05
# Epoch 16/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0033 - loss: 1.7899e-05 - val_MAE: 0.0023 - val_loss: 9.3123e-06 - learning_rate: 8.0000e-05
# Epoch 17/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0034 - loss: 1.9141e-05 - val_MAE: 0.0023 - val_loss: 9.2580e-06 - learning_rate: 1.6000e-05
# Epoch 18/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0034 - loss: 1.9234e-05 - val_MAE: 0.0023 - val_loss: 9.2409e-06 - learning_rate: 1.6000e-05
# Epoch 19/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0032 - loss: 1.7618e-05 - val_MAE: 0.0023 - val_loss: 9.2452e-06 - learning_rate: 1.6000e-05
# Epoch 20/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0034 - loss: 2.0621e-05 - val_MAE: 0.0023 - val_loss: 9.2600e-06 - learning_rate: 1.6000e-05
# Epoch 21/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0031 - loss: 1.6679e-05 - val_MAE: 0.0023 - val_loss: 9.2723e-06 - learning_rate: 1.6000e-05
# Epoch 22/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0034 - loss: 2.2037e-05 - val_MAE: 0.0023 - val_loss: 9.2800e-06 - learning_rate: 1.0000e-05
# Epoch 23/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0034 - loss: 2.0494e-05 - val_MAE: 0.0023 - val_loss: 9.2493e-06 - learning_rate: 1.0000e-05
# Epoch 24/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0032 - loss: 1.7954e-05 - val_MAE: 0.0023 - val_loss: 9.2616e-06 - learning_rate: 1.0000e-05
# Adamax Optimizer - Loss (MSE): 0.000009, Mean Absolute Error: 0.002304
#
# Training with RMSprop optimizer and swish activation function...
# Epoch 1/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - MAE: 0.0039 - loss: 2.5603e-05 - val_MAE: 0.0026 - val_loss: 1.0607e-05 - learning_rate: 0.0010
# Epoch 2/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0038 - loss: 2.3048e-05 - val_MAE: 0.0027 - val_loss: 1.2055e-05 - learning_rate: 0.0010
# Epoch 3/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0039 - loss: 2.3616e-05 - val_MAE: 0.0032 - val_loss: 1.5314e-05 - learning_rate: 0.0010
# Epoch 4/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0036 - loss: 2.1703e-05 - val_MAE: 0.0025 - val_loss: 1.0307e-05 - learning_rate: 0.0010
# Epoch 5/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0036 - loss: 2.0553e-05 - val_MAE: 0.0024 - val_loss: 9.7859e-06 - learning_rate: 0.0010
# Epoch 6/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0035 - loss: 2.0766e-05 - val_MAE: 0.0025 - val_loss: 1.0343e-05 - learning_rate: 0.0010
# Epoch 7/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0031 - loss: 1.6941e-05 - val_MAE: 0.0024 - val_loss: 9.7085e-06 - learning_rate: 2.0000e-04
# Epoch 8/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0033 - loss: 1.9538e-05 - val_MAE: 0.0023 - val_loss: 9.4247e-06 - learning_rate: 2.0000e-04
# Epoch 9/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0031 - loss: 1.5807e-05 - val_MAE: 0.0024 - val_loss: 9.5077e-06 - learning_rate: 2.0000e-04
# Epoch 10/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0032 - loss: 1.7533e-05 - val_MAE: 0.0024 - val_loss: 9.6301e-06 - learning_rate: 2.0000e-04
# Epoch 11/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0032 - loss: 1.7469e-05 - val_MAE: 0.0023 - val_loss: 9.4120e-06 - learning_rate: 2.0000e-04
# Epoch 12/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0031 - loss: 1.6523e-05 - val_MAE: 0.0023 - val_loss: 9.4330e-06 - learning_rate: 4.0000e-05
# Epoch 13/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0031 - loss: 1.6911e-05 - val_MAE: 0.0023 - val_loss: 9.4337e-06 - learning_rate: 4.0000e-05
# Epoch 14/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0031 - loss: 1.6907e-05 - val_MAE: 0.0023 - val_loss: 9.3705e-06 - learning_rate: 4.0000e-05
# Epoch 15/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0032 - loss: 1.7397e-05 - val_MAE: 0.0023 - val_loss: 9.3708e-06 - learning_rate: 4.0000e-05
# Epoch 16/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0032 - loss: 1.8201e-05 - val_MAE: 0.0023 - val_loss: 9.3825e-06 - learning_rate: 4.0000e-05
# Epoch 17/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0031 - loss: 1.6427e-05 - val_MAE: 0.0023 - val_loss: 9.3689e-06 - learning_rate: 1.0000e-05
# Epoch 18/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0033 - loss: 1.9291e-05 - val_MAE: 0.0023 - val_loss: 9.3727e-06 - learning_rate: 1.0000e-05
# Epoch 19/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0031 - loss: 1.6407e-05 - val_MAE: 0.0023 - val_loss: 9.3685e-06 - learning_rate: 1.0000e-05
# Epoch 20/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0031 - loss: 1.6577e-05 - val_MAE: 0.0023 - val_loss: 9.3707e-06 - learning_rate: 1.0000e-05
# Epoch 21/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0031 - loss: 1.6503e-05 - val_MAE: 0.0023 - val_loss: 9.3683e-06 - learning_rate: 1.0000e-05
# Epoch 22/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0032 - loss: 1.7280e-05 - val_MAE: 0.0023 - val_loss: 9.3700e-06 - learning_rate: 1.0000e-05
# Epoch 23/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0032 - loss: 1.7027e-05 - val_MAE: 0.0023 - val_loss: 9.3697e-06 - learning_rate: 1.0000e-05
# Epoch 24/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0031 - loss: 1.6235e-05 - val_MAE: 0.0023 - val_loss: 9.3713e-06 - learning_rate: 1.0000e-05
# Epoch 25/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0032 - loss: 1.6729e-05 - val_MAE: 0.0023 - val_loss: 9.3680e-06 - learning_rate: 1.0000e-05
# Epoch 26/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0032 - loss: 1.7128e-05 - val_MAE: 0.0023 - val_loss: 9.3828e-06 - learning_rate: 1.0000e-05
# Epoch 27/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0031 - loss: 1.5758e-05 - val_MAE: 0.0023 - val_loss: 9.3667e-06 - learning_rate: 1.0000e-05
# Epoch 28/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0031 - loss: 1.6198e-05 - val_MAE: 0.0023 - val_loss: 9.3873e-06 - learning_rate: 1.0000e-05
# Epoch 29/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0032 - loss: 1.7012e-05 - val_MAE: 0.0023 - val_loss: 9.3661e-06 - learning_rate: 1.0000e-05
# Epoch 30/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0030 - loss: 1.5590e-05 - val_MAE: 0.0023 - val_loss: 9.3710e-06 - learning_rate: 1.0000e-05
# Epoch 31/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0031 - loss: 1.5801e-05 - val_MAE: 0.0023 - val_loss: 9.3681e-06 - learning_rate: 1.0000e-05
# Epoch 32/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0031 - loss: 1.6045e-05 - val_MAE: 0.0023 - val_loss: 9.3648e-06 - learning_rate: 1.0000e-05
# Epoch 33/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0031 - loss: 1.5816e-05 - val_MAE: 0.0023 - val_loss: 9.3673e-06 - learning_rate: 1.0000e-05
# Epoch 34/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0031 - loss: 1.6332e-05 - val_MAE: 0.0023 - val_loss: 9.3689e-06 - learning_rate: 1.0000e-05
# Epoch 35/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0032 - loss: 1.7144e-05 - val_MAE: 0.0023 - val_loss: 9.3627e-06 - learning_rate: 1.0000e-05
# Epoch 36/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0031 - loss: 1.5854e-05 - val_MAE: 0.0023 - val_loss: 9.3699e-06 - learning_rate: 1.0000e-05
# Epoch 37/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0033 - loss: 1.7707e-05 - val_MAE: 0.0023 - val_loss: 9.4057e-06 - learning_rate: 1.0000e-05
# Epoch 38/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0032 - loss: 1.6891e-05 - val_MAE: 0.0023 - val_loss: 9.3707e-06 - learning_rate: 1.0000e-05
# Epoch 39/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0032 - loss: 1.7343e-05 - val_MAE: 0.0023 - val_loss: 9.3635e-06 - learning_rate: 1.0000e-05
# Epoch 40/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0032 - loss: 1.7467e-05 - val_MAE: 0.0023 - val_loss: 9.3752e-06 - learning_rate: 1.0000e-05
# Epoch 41/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0031 - loss: 1.6379e-05 - val_MAE: 0.0023 - val_loss: 9.3689e-06 - learning_rate: 1.0000e-05
# Epoch 42/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0032 - loss: 1.7075e-05 - val_MAE: 0.0023 - val_loss: 9.3895e-06 - learning_rate: 1.0000e-05
# Epoch 43/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0033 - loss: 1.7995e-05 - val_MAE: 0.0023 - val_loss: 9.3685e-06 - learning_rate: 1.0000e-05
# Epoch 44/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0032 - loss: 1.8458e-05 - val_MAE: 0.0023 - val_loss: 9.3684e-06 - learning_rate: 1.0000e-05
# Epoch 45/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0032 - loss: 1.7532e-05 - val_MAE: 0.0023 - val_loss: 9.3642e-06 - learning_rate: 1.0000e-05
# RMSprop Optimizer - Loss (MSE): 0.000009, Mean Absolute Error: 0.002328
#
# Training with SGD optimizer and swish activation function...
# Epoch 1/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - MAE: 0.0032 - loss: 1.7015e-05 - val_MAE: 0.0023 - val_loss: 9.3642e-06 - learning_rate: 0.0100
# Epoch 2/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0032 - loss: 1.7048e-05 - val_MAE: 0.0024 - val_loss: 9.4871e-06 - learning_rate: 0.0100
# Epoch 3/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0031 - loss: 1.6376e-05 - val_MAE: 0.0023 - val_loss: 9.5288e-06 - learning_rate: 0.0100
# Epoch 4/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0030 - loss: 1.5607e-05 - val_MAE: 0.0023 - val_loss: 9.4046e-06 - learning_rate: 0.0100
# Epoch 5/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0031 - loss: 1.6333e-05 - val_MAE: 0.0024 - val_loss: 9.9397e-06 - learning_rate: 0.0100
# Epoch 6/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0033 - loss: 1.7543e-05 - val_MAE: 0.0023 - val_loss: 9.3574e-06 - learning_rate: 0.0100
# Epoch 7/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0032 - loss: 1.6983e-05 - val_MAE: 0.0023 - val_loss: 9.3636e-06 - learning_rate: 0.0020
# Epoch 8/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAE: 0.0030 - loss: 1.5678e-05 - val_MAE: 0.0023 - val_loss: 9.3571e-06 - learning_rate: 0.0020
# Epoch 9/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0031 - loss: 1.6534e-05 - val_MAE: 0.0023 - val_loss: 9.3708e-06 - learning_rate: 0.0020
# Epoch 10/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0031 - loss: 1.5393e-05 - val_MAE: 0.0023 - val_loss: 9.3772e-06 - learning_rate: 0.0020
# Epoch 11/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0031 - loss: 1.5574e-05 - val_MAE: 0.0023 - val_loss: 9.3650e-06 - learning_rate: 0.0020
# Epoch 12/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0031 - loss: 1.6120e-05 - val_MAE: 0.0023 - val_loss: 9.3641e-06 - learning_rate: 4.0000e-04
# Epoch 13/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0033 - loss: 1.7884e-05 - val_MAE: 0.0023 - val_loss: 9.3623e-06 - learning_rate: 4.0000e-04
# Epoch 14/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0032 - loss: 1.6890e-05 - val_MAE: 0.0023 - val_loss: 9.3603e-06 - learning_rate: 4.0000e-04
# Epoch 15/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0031 - loss: 1.6088e-05 - val_MAE: 0.0023 - val_loss: 9.3579e-06 - learning_rate: 4.0000e-04
# Epoch 16/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0032 - loss: 1.6720e-05 - val_MAE: 0.0023 - val_loss: 9.3575e-06 - learning_rate: 4.0000e-04
# Epoch 17/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0031 - loss: 1.5986e-05 - val_MAE: 0.0023 - val_loss: 9.3579e-06 - learning_rate: 8.0000e-05
# Epoch 18/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0033 - loss: 1.7973e-05 - val_MAE: 0.0023 - val_loss: 9.3576e-06 - learning_rate: 8.0000e-05
# SGD Optimizer - Loss (MSE): 0.000009, Mean Absolute Error: 0.002327

# %%
print(all_mae_values)
print(all_loss_values)
print(all_labels)
# Out:
# [0.005525414831936359, 0.003764432854950428, 0.004607540555298328, 0.005604826845228672, 0.003604203462600708, 0.0042372290045022964, 0.002757125534117222, 0.0025084211956709623, 0.00248542707413435, 0.004213961772620678, 0.0036562669556587934, 0.0036069375928491354, 0.0023044731933623552, 0.0023276228457689285, 0.0023270819801837206]
# [4.785191049450077e-05, 2.369025423831772e-05, 3.444681715336628e-05, 5.074350701761432e-05, 2.189856968470849e-05, 3.0026239983271807e-05, 1.3514356396626681e-05, 1.1138413356093224e-05, 1.0951838703476824e-05, 2.9564789656433277e-05, 2.1980578821967356e-05, 2.1202991774771363e-05, 9.196745850204024e-06, 9.362688615510706e-06, 9.357093404105399e-06]
# ['relu, Adamax', 'relu, RMSprop', 'relu, SGD', 'leaky_relu, Adamax', 'leaky_relu, RMSprop', 'leaky_relu, SGD', 'elu, Adamax', 'elu, RMSprop', 'elu, SGD', 'prelu, Adamax', 'prelu, RMSprop', 'prelu, SGD', 'swish, Adamax', 'swish, RMSprop', 'swish, SGD']

# %%
# Create a DataFrame
chd_models_df = pd.DataFrame({
    'Model': all_labels, 
    'Activation_Function': all_activation_functions , 
    'Optimizer': all_optimizers, 
    'MAE': all_mae_values, 
    'Loss': all_loss_values
})

chd_models_df
# Out:
#                   Model Activation_Function Optimizer       MAE      Loss
# 0          relu, Adamax                relu    Adamax  0.005525  0.000048
# 1         relu, RMSprop                relu   RMSprop  0.003764  0.000024
# 2             relu, SGD                relu       SGD  0.004608  0.000034
# 3    leaky_relu, Adamax          leaky_relu    Adamax  0.005605  0.000051
# 4   leaky_relu, RMSprop          leaky_relu   RMSprop  0.003604  0.000022
# 5       leaky_relu, SGD          leaky_relu       SGD  0.004237  0.000030
# 6           elu, Adamax                 elu    Adamax  0.002757  0.000014
# 7          elu, RMSprop                 elu   RMSprop  0.002508  0.000011
# 8              elu, SGD                 elu       SGD  0.002485  0.000011
# 9         prelu, Adamax               prelu    Adamax  0.004214  0.000030
# 10       prelu, RMSprop               prelu   RMSprop  0.003656  0.000022
# 11           prelu, SGD               prelu       SGD  0.003607  0.000021
# 12        swish, Adamax               swish    Adamax  0.002304  0.000009
# 13       swish, RMSprop               swish   RMSprop  0.002328  0.000009
# 14           swish, SGD               swish       SGD  0.002327  0.000009

# %%
# Plotting
fig, ax1 = plt.subplots(figsize=(14, 8))

# Bar plot for Accuracy
color = 'tab:blue'
ax1.set_xlabel('Model')
ax1.set_ylabel('Mean Absolute Error', color=color)
ax1.bar(chd_models_df['Model'], chd_models_df['MAE'], color=color, alpha=0.6, label='MAE')
ax1.tick_params(axis='y', labelcolor=color)
ax1.set_xticks(range(len(chd_models_df['Model'])))
ax1.set_xticklabels(chd_models_df['Model'], rotation=90)

# Create a second y-axis for Loss
ax2 = ax1.twinx()
color = 'tab:red'
ax2.set_ylabel('Loss (MSE)', color=color)
ax2.plot(chd_models_df['Model'], chd_models_df['Loss'], color=color, marker='o', linestyle='-', linewidth=2, markersize=8, label='Loss')
ax2.tick_params(axis='y', labelcolor=color)

# Title and layout
plt.title('MAE and Loss for Chronic Heart Disease Models')
fig.tight_layout()
plt.show()

# %%
# Rank the models based on MAE (lower is better)
chd_models_df['MAE_Rank'] = chd_models_df['MAE'].rank()

# Rank the models based on Loss (lower is better)
chd_models_df['Loss_Rank'] = chd_models_df['Loss'].rank()

# Calculate the average rank
chd_models_df['Average_Rank'] = (chd_models_df['MAE_Rank'] + chd_models_df['Loss_Rank']) / 2

# Find the top two ranked models
best_model_avg_rank = chd_models_df.sort_values('Average_Rank').iloc[0]
print(best_model_avg_rank)
# Out:
# Model                  swish, Adamax
# Activation_Function            swish
# Optimizer                     Adamax
# MAE                         0.002304
# Loss                        0.000009
# MAE_Rank                         1.0
# Loss_Rank                        1.0
# Average_Rank                     1.0
# Name: 12, dtype: object
