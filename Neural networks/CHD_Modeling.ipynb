# %%
import warnings
from pathlib import Path
import pandas as pd
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Dense, Dropout, Input, Activation
from keras.optimizers import Adamax, RMSprop, SGD
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from keras.layers import LeakyReLU, ELU, PReLU
import tensorflow as tf
from tensorflow.keras.callbacks import EarlyStopping
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

# %%
# File Path
chd_data_to_load = Path("../Outputs/CHD_sdoh_access.csv")

# Read shcool metrics into Pandas DataFrames
chd_df = pd.read_csv(chd_data_to_load)

chd_df.head()
# Out:
#    county_index  target_chd  AGE65  BROAD  CROWD  HCOST  NOHSDP  POV150  \
# 0          1001         5.7   15.1   14.5    1.5   21.5    10.4    21.7
# 1          1011         7.9   16.2   40.6    0.8   23.9    22.4    46.0
# 2          1021         6.5   16.4   21.7    2.9   16.1    18.2    26.5
# 3          1029         6.5   19.2   27.2    2.1   18.1    16.9    27.3
# 4          1049         7.1   16.9   20.1    3.3   20.9    21.8    35.4
#
#    REMNRTY  SNGPNT  UNEMP  No_Vehicle_10_Miles  No_Vehicle_1_Mile  \
# 0     26.9     7.1    2.8             0.406809           1.528284
# 1     79.6    14.5    3.0             0.733003           3.060290
# 2     20.7     4.5    6.4             0.025205           1.416035
# 3      7.6     4.5    4.5             0.073470           1.302431
# 4     20.4     5.8    4.3             0.000000           1.492076
#
#    No_Vehicle_Half_Mile
# 0              1.914937
# 1              3.967381
# 2              1.718489
# 3              1.436014
# 4              1.816929

# %%
# Divide the percentage values by 100 to prepare for Neural Network
columns_to_scale = chd_df.dtypes[chd_df.dtypes == "float64"].index.tolist()
chd_df[columns_to_scale] = chd_df[columns_to_scale] / 100
chd_df.head()
# Out:
#    county_index  target_chd  AGE65  BROAD  CROWD  HCOST  NOHSDP  POV150  \
# 0          1001       0.057  0.151  0.145  0.015  0.215   0.104   0.217
# 1          1011       0.079  0.162  0.406  0.008  0.239   0.224   0.460
# 2          1021       0.065  0.164  0.217  0.029  0.161   0.182   0.265
# 3          1029       0.065  0.192  0.272  0.021  0.181   0.169   0.273
# 4          1049       0.071  0.169  0.201  0.033  0.209   0.218   0.354
#
#    REMNRTY  SNGPNT  UNEMP  No_Vehicle_10_Miles  No_Vehicle_1_Mile  \
# 0    0.269   0.071  0.028             0.004068           0.015283
# 1    0.796   0.145  0.030             0.007330           0.030603
# 2    0.207   0.045  0.064             0.000252           0.014160
# 3    0.076   0.045  0.045             0.000735           0.013024
# 4    0.204   0.058  0.043             0.000000           0.014921
#
#    No_Vehicle_Half_Mile
# 0              0.019149
# 1              0.039674
# 2              0.017185
# 3              0.014360
# 4              0.018169

# %%
# Split data into our features and target arrays
y = chd_df['target_chd'].values
X = chd_df.drop(columns = ['target_chd', 'county_index']).values

# Split the arrays into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=12)

# Data was prescaled manually so set values to work with the train_model function
X_train_scaled = X_train
X_test_scaled = X_test

# Set the values for input shape and hidden nodes for each layer
input_shape = len(X_train[0])
hidden_nodes_layer1 =  128
hidden_nodes_layer2 = 64
hidden_nodes_layer3 = 32

# %%
def train_model(X_train_scaled, y_train, X_test_scaled, y_test, activation_func='relu'):
    """
    Train a neural network with specified activation function and multiple optimizers.

    Args:
    - X_train_scaled: Scaled training data
    - y_train: Labels for training data
    - X_test_scaled: Scaled test data
    - y_test: Labels for test data
    - activation_func: Activation function to use (e.g., 'relu', 'leaky_relu', 'elu', 'prelu', 'swish')

    Returns:
    - mae_list2: List of mean absolute error for each optimizer
    - loss_list2: List of losses (MSE) for each optimizer
    """
    
    # Custom activation handling
    def get_activation(activation):
        if activation == 'leaky_relu':
            return LeakyReLU(alpha=0.1)  # Custom activation layer
        elif activation == 'elu':
            return ELU(alpha=1.0)  # Custom activation layer
        elif activation == 'prelu':
            return PReLU()  # Custom activation layer
        elif activation == 'swish':  # Or silu
            return Activation(tf.keras.activations.swish)  # Wrap as Activation layer
        else:
            return activation  # For standard activations like 'relu', 'sigmoid', etc.
    
    # Build model
    nn = tf.keras.models.Sequential()

    # Add the input layer
    nn.add(tf.keras.layers.Input(shape=(input_shape,)))
    
    # First hidden layer
    if isinstance(get_activation(activation_func), str):  # If it's a standard activation
        nn.add(tf.keras.layers.Dense(units=128, activation=get_activation(activation_func)))  # Use activation as string
    else:  # If it's a custom activation layer
        nn.add(tf.keras.layers.Dense(units=128))
        nn.add(get_activation(activation_func))  # Add custom activation layer
    
    # Dropout and subsequent layers
    nn.add(Dropout(0.3))
    if isinstance(get_activation(activation_func), str):
        nn.add(tf.keras.layers.Dense(units=64, activation=get_activation(activation_func)))
    else:
        nn.add(tf.keras.layers.Dense(units=64))
        nn.add(get_activation(activation_func))
    
    nn.add(Dropout(0.3))
    if isinstance(get_activation(activation_func), str):
        nn.add(tf.keras.layers.Dense(units=32, activation=get_activation(activation_func)))
    else:
        nn.add(tf.keras.layers.Dense(units=32))
        nn.add(get_activation(activation_func))
    
    # Output layer (for continuous data)
    nn.add(tf.keras.layers.Dense(units=1, activation="linear"))

    # Experiment with different optimizers
    optimizers = {
        'Adamax': Adamax(learning_rate=0.002),
        'RMSprop': RMSprop(learning_rate=0.001),
        'SGD': SGD(learning_rate=0.01, momentum=0.9)
    }

    mae_list2 = []
    loss_list2 = []

    # Iterate through each optimizer
    for name, optimizer in optimizers.items():
        print(f"\nTraining with {name} optimizer and {activation_func} activation function...")
        nn.compile(optimizer=optimizer, loss="mean_squared_error", metrics=["MAE"])

        # Callbacks
        early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
        reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=0.00001)

        # Train the model
        nn.fit(X_train_scaled, y_train, epochs=100, validation_data=(X_test_scaled, y_test),
               callbacks=[early_stopping, reduce_lr], verbose=1)

        # Evaluate the model
        loss, mae = nn.evaluate(X_test_scaled, y_test, verbose=0)
        print(f"{name} Optimizer - Loss (MSE): {loss:.6f}, Mean Absolute Error: {mae:.6f}")
        mae_list2.append(mae)
        loss_list2.append(loss)
    
    return mae_list2, loss_list2

# %%
all_mae_values = []
all_loss_values = []
all_labels = []
all_activation_functions = []
all_optimizers = []

activation_functions = ['relu', 'leaky_relu', 'elu', 'prelu', 'swish']
optimizers = ['Adamax', 'RMSprop', 'SGD']

for activation in activation_functions:
    print(f"\nRunning for activation function: {activation}")
    mae_list, loss_list = train_model(X_train_scaled, y_train, X_test_scaled, y_test, activation_func=activation)
    
    # Append the Mean Absolute Error, loss values and labels for this activation function
    all_mae_values.extend(mae_list)
    all_loss_values.extend(loss_list)
    
    # Create labels combining activation function and optimizer
    for optimizer in optimizers:
        all_labels.append(f"{activation}, {optimizer}")
        all_activation_functions.append(activation)
        all_optimizers.append(optimizer)
# Out:
# Running for activation function: relu
#
# Training with Adamax optimizer and relu activation function...
# Epoch 1/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - MAE: 0.0301 - loss: 0.0018 - val_MAE: 0.0112 - val_loss: 1.8890e-04 - learning_rate: 0.0020
# Epoch 2/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - MAE: 0.0118 - loss: 2.4664e-04 - val_MAE: 0.0096 - val_loss: 1.5355e-04 - learning_rate: 0.0020
# Epoch 3/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAE: 0.0087 - loss: 1.3577e-04 - val_MAE: 0.0088 - val_loss: 1.1718e-04 - learning_rate: 0.0020
# Epoch 4/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - MAE: 0.0077 - loss: 1.0434e-04 - val_MAE: 0.0086 - val_loss: 1.1153e-04 - learning_rate: 0.0020
# Epoch 5/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - MAE: 0.0067 - loss: 8.0056e-05 - val_MAE: 0.0065 - val_loss: 6.5666e-05 - learning_rate: 0.0020
# Epoch 6/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAE: 0.0063 - loss: 7.9560e-05 - val_MAE: 0.0066 - val_loss: 6.9656e-05 - learning_rate: 0.0020
# Epoch 7/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAE: 0.0057 - loss: 5.8659e-05 - val_MAE: 0.0056 - val_loss: 5.2055e-05 - learning_rate: 0.0020
# Epoch 8/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAE: 0.0053 - loss: 5.3965e-05 - val_MAE: 0.0052 - val_loss: 4.3904e-05 - learning_rate: 0.0020
# Epoch 9/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - MAE: 0.0053 - loss: 4.8746e-05 - val_MAE: 0.0046 - val_loss: 3.5160e-05 - learning_rate: 0.0020
# Epoch 10/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - MAE: 0.0053 - loss: 5.0358e-05 - val_MAE: 0.0051 - val_loss: 4.3793e-05 - learning_rate: 0.0020
# Epoch 11/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - MAE: 0.0050 - loss: 4.7709e-05 - val_MAE: 0.0047 - val_loss: 3.7452e-05 - learning_rate: 4.0000e-04
# Epoch 12/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAE: 0.0049 - loss: 4.2975e-05 - val_MAE: 0.0047 - val_loss: 3.6754e-05 - learning_rate: 4.0000e-04
# Epoch 13/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAE: 0.0049 - loss: 4.2989e-05 - val_MAE: 0.0044 - val_loss: 3.3085e-05 - learning_rate: 4.0000e-04
# Epoch 14/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAE: 0.0047 - loss: 3.8853e-05 - val_MAE: 0.0045 - val_loss: 3.4402e-05 - learning_rate: 4.0000e-04
# Epoch 15/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAE: 0.0049 - loss: 4.0723e-05 - val_MAE: 0.0044 - val_loss: 3.2948e-05 - learning_rate: 4.0000e-04
# Epoch 16/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - MAE: 0.0048 - loss: 4.3850e-05 - val_MAE: 0.0044 - val_loss: 3.2316e-05 - learning_rate: 8.0000e-05
# Epoch 17/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - MAE: 0.0046 - loss: 3.9498e-05 - val_MAE: 0.0044 - val_loss: 3.2430e-05 - learning_rate: 8.0000e-05
# Epoch 18/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - MAE: 0.0045 - loss: 3.6774e-05 - val_MAE: 0.0044 - val_loss: 3.2229e-05 - learning_rate: 8.0000e-05
# Epoch 19/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAE: 0.0047 - loss: 3.9170e-05 - val_MAE: 0.0043 - val_loss: 3.1225e-05 - learning_rate: 8.0000e-05
# Epoch 20/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAE: 0.0045 - loss: 3.6988e-05 - val_MAE: 0.0045 - val_loss: 3.3426e-05 - learning_rate: 8.0000e-05
# Epoch 21/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAE: 0.0047 - loss: 4.0426e-05 - val_MAE: 0.0044 - val_loss: 3.2238e-05 - learning_rate: 1.6000e-05
# Epoch 22/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAE: 0.0046 - loss: 4.3866e-05 - val_MAE: 0.0043 - val_loss: 3.1811e-05 - learning_rate: 1.6000e-05
# Epoch 23/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - MAE: 0.0045 - loss: 4.0757e-05 - val_MAE: 0.0043 - val_loss: 3.1807e-05 - learning_rate: 1.6000e-05
# Epoch 24/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - MAE: 0.0045 - loss: 3.6827e-05 - val_MAE: 0.0043 - val_loss: 3.1786e-05 - learning_rate: 1.6000e-05
# Epoch 25/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - MAE: 0.0046 - loss: 3.6781e-05 - val_MAE: 0.0044 - val_loss: 3.2005e-05 - learning_rate: 1.6000e-05
# Epoch 26/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - MAE: 0.0045 - loss: 3.7903e-05 - val_MAE: 0.0043 - val_loss: 3.1544e-05 - learning_rate: 1.0000e-05
# Epoch 27/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - MAE: 0.0047 - loss: 3.9822e-05 - val_MAE: 0.0043 - val_loss: 3.1458e-05 - learning_rate: 1.0000e-05
# Epoch 28/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAE: 0.0043 - loss: 3.2701e-05 - val_MAE: 0.0043 - val_loss: 3.1812e-05 - learning_rate: 1.0000e-05
# Epoch 29/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAE: 0.0045 - loss: 3.8006e-05 - val_MAE: 0.0043 - val_loss: 3.1878e-05 - learning_rate: 1.0000e-05
# Adamax Optimizer - Loss (MSE): 0.000031, Mean Absolute Error: 0.004301
#
# Training with RMSprop optimizer and relu activation function...
# Epoch 1/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - MAE: 0.0049 - loss: 4.0987e-05 - val_MAE: 0.0042 - val_loss: 2.9024e-05 - learning_rate: 0.0010
# Epoch 2/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAE: 0.0045 - loss: 3.5374e-05 - val_MAE: 0.0045 - val_loss: 3.3141e-05 - learning_rate: 0.0010
# Epoch 3/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAE: 0.0046 - loss: 3.6311e-05 - val_MAE: 0.0061 - val_loss: 5.6508e-05 - learning_rate: 0.0010
# Epoch 4/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0047 - loss: 4.0802e-05 - val_MAE: 0.0045 - val_loss: 3.3227e-05 - learning_rate: 0.0010
# Epoch 5/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0044 - loss: 3.3096e-05 - val_MAE: 0.0036 - val_loss: 2.1940e-05 - learning_rate: 0.0010
# Epoch 6/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0044 - loss: 3.1526e-05 - val_MAE: 0.0038 - val_loss: 2.4679e-05 - learning_rate: 0.0010
# Epoch 7/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0040 - loss: 2.7868e-05 - val_MAE: 0.0035 - val_loss: 2.0797e-05 - learning_rate: 2.0000e-04
# Epoch 8/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0041 - loss: 3.0213e-05 - val_MAE: 0.0035 - val_loss: 2.1086e-05 - learning_rate: 2.0000e-04
# Epoch 9/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0040 - loss: 2.8519e-05 - val_MAE: 0.0035 - val_loss: 2.0394e-05 - learning_rate: 2.0000e-04
# Epoch 10/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0041 - loss: 3.1694e-05 - val_MAE: 0.0036 - val_loss: 2.1579e-05 - learning_rate: 2.0000e-04
# Epoch 11/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0038 - loss: 2.7074e-05 - val_MAE: 0.0036 - val_loss: 2.1768e-05 - learning_rate: 2.0000e-04
# Epoch 12/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0039 - loss: 2.8345e-05 - val_MAE: 0.0037 - val_loss: 2.3785e-05 - learning_rate: 4.0000e-05
# Epoch 13/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0038 - loss: 2.6345e-05 - val_MAE: 0.0037 - val_loss: 2.3074e-05 - learning_rate: 4.0000e-05
# Epoch 14/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAE: 0.0039 - loss: 2.6442e-05 - val_MAE: 0.0037 - val_loss: 2.3576e-05 - learning_rate: 4.0000e-05
# Epoch 15/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0038 - loss: 2.5212e-05 - val_MAE: 0.0036 - val_loss: 2.1474e-05 - learning_rate: 4.0000e-05
# Epoch 16/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0039 - loss: 2.7476e-05 - val_MAE: 0.0037 - val_loss: 2.2880e-05 - learning_rate: 4.0000e-05
# Epoch 17/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - MAE: 0.0039 - loss: 2.6789e-05 - val_MAE: 0.0036 - val_loss: 2.2328e-05 - learning_rate: 1.0000e-05
# Epoch 18/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAE: 0.0039 - loss: 2.8893e-05 - val_MAE: 0.0035 - val_loss: 2.1332e-05 - learning_rate: 1.0000e-05
# Epoch 19/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - MAE: 0.0040 - loss: 2.9940e-05 - val_MAE: 0.0036 - val_loss: 2.2668e-05 - learning_rate: 1.0000e-05
# RMSprop Optimizer - Loss (MSE): 0.000020, Mean Absolute Error: 0.003488
#
# Training with SGD optimizer and relu activation function...
# Epoch 1/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - MAE: 0.0038 - loss: 2.6663e-05 - val_MAE: 0.0035 - val_loss: 2.1248e-05 - learning_rate: 0.0100
# Epoch 2/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0039 - loss: 2.7836e-05 - val_MAE: 0.0035 - val_loss: 2.1157e-05 - learning_rate: 0.0100
# Epoch 3/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0038 - loss: 2.6233e-05 - val_MAE: 0.0035 - val_loss: 2.0325e-05 - learning_rate: 0.0100
# Epoch 4/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAE: 0.0039 - loss: 2.6312e-05 - val_MAE: 0.0036 - val_loss: 2.2026e-05 - learning_rate: 0.0100
# Epoch 5/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - MAE: 0.0038 - loss: 2.5617e-05 - val_MAE: 0.0036 - val_loss: 2.1670e-05 - learning_rate: 0.0100
# Epoch 6/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0040 - loss: 2.7516e-05 - val_MAE: 0.0037 - val_loss: 2.3861e-05 - learning_rate: 0.0100
# Epoch 7/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0039 - loss: 2.5065e-05 - val_MAE: 0.0036 - val_loss: 2.1885e-05 - learning_rate: 0.0020
# Epoch 8/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0039 - loss: 2.9857e-05 - val_MAE: 0.0036 - val_loss: 2.1988e-05 - learning_rate: 0.0020
# Epoch 9/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0039 - loss: 2.8861e-05 - val_MAE: 0.0037 - val_loss: 2.3042e-05 - learning_rate: 0.0020
# Epoch 10/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0039 - loss: 2.8229e-05 - val_MAE: 0.0036 - val_loss: 2.1876e-05 - learning_rate: 0.0020
# Epoch 11/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0038 - loss: 2.6042e-05 - val_MAE: 0.0036 - val_loss: 2.1836e-05 - learning_rate: 0.0020
# Epoch 12/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAE: 0.0040 - loss: 3.0289e-05 - val_MAE: 0.0036 - val_loss: 2.1574e-05 - learning_rate: 4.0000e-04
# Epoch 13/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0040 - loss: 2.8759e-05 - val_MAE: 0.0036 - val_loss: 2.1718e-05 - learning_rate: 4.0000e-04
# SGD Optimizer - Loss (MSE): 0.000020, Mean Absolute Error: 0.003475
#
# Running for activation function: leaky_relu
# C:\Users\ecros\anaconda3\envs\dev\lib\site-packages\keras\src\layers\activations\leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(
# Training with Adamax optimizer and leaky_relu activation function...
# Epoch 1/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - MAE: 0.0178 - loss: 6.0174e-04 - val_MAE: 0.0054 - val_loss: 4.4377e-05 - learning_rate: 0.0020
# Epoch 2/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAE: 0.0072 - loss: 9.2025e-05 - val_MAE: 0.0050 - val_loss: 4.0636e-05 - learning_rate: 0.0020
# Epoch 3/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAE: 0.0059 - loss: 6.1636e-05 - val_MAE: 0.0040 - val_loss: 2.6191e-05 - learning_rate: 0.0020
# Epoch 4/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAE: 0.0054 - loss: 4.9953e-05 - val_MAE: 0.0049 - val_loss: 3.7891e-05 - learning_rate: 0.0020
# Epoch 5/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAE: 0.0049 - loss: 4.1397e-05 - val_MAE: 0.0052 - val_loss: 4.3492e-05 - learning_rate: 0.0020
# Epoch 6/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAE: 0.0049 - loss: 4.0138e-05 - val_MAE: 0.0036 - val_loss: 2.2142e-05 - learning_rate: 0.0020
# Epoch 7/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - MAE: 0.0045 - loss: 3.6136e-05 - val_MAE: 0.0041 - val_loss: 2.8091e-05 - learning_rate: 4.0000e-04
# Epoch 8/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAE: 0.0043 - loss: 3.2365e-05 - val_MAE: 0.0041 - val_loss: 2.8400e-05 - learning_rate: 4.0000e-04
# Epoch 9/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAE: 0.0043 - loss: 3.4456e-05 - val_MAE: 0.0041 - val_loss: 2.7726e-05 - learning_rate: 4.0000e-04
# Epoch 10/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - MAE: 0.0044 - loss: 3.2181e-05 - val_MAE: 0.0035 - val_loss: 2.1137e-05 - learning_rate: 4.0000e-04
# Epoch 11/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAE: 0.0042 - loss: 3.1920e-05 - val_MAE: 0.0039 - val_loss: 2.5264e-05 - learning_rate: 4.0000e-04
# Epoch 12/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - MAE: 0.0043 - loss: 3.5309e-05 - val_MAE: 0.0039 - val_loss: 2.5686e-05 - learning_rate: 8.0000e-05
# Epoch 13/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAE: 0.0042 - loss: 3.1298e-05 - val_MAE: 0.0038 - val_loss: 2.3930e-05 - learning_rate: 8.0000e-05
# Epoch 14/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAE: 0.0042 - loss: 3.1066e-05 - val_MAE: 0.0037 - val_loss: 2.3233e-05 - learning_rate: 8.0000e-05
# Epoch 15/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAE: 0.0042 - loss: 3.0551e-05 - val_MAE: 0.0040 - val_loss: 2.6277e-05 - learning_rate: 8.0000e-05
# Epoch 16/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - MAE: 0.0043 - loss: 3.0787e-05 - val_MAE: 0.0038 - val_loss: 2.4032e-05 - learning_rate: 8.0000e-05
# Epoch 17/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAE: 0.0043 - loss: 3.1011e-05 - val_MAE: 0.0038 - val_loss: 2.4556e-05 - learning_rate: 1.6000e-05
# Epoch 18/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAE: 0.0041 - loss: 3.1408e-05 - val_MAE: 0.0038 - val_loss: 2.4327e-05 - learning_rate: 1.6000e-05
# Epoch 19/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAE: 0.0043 - loss: 3.1701e-05 - val_MAE: 0.0038 - val_loss: 2.4614e-05 - learning_rate: 1.6000e-05
# Epoch 20/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - MAE: 0.0041 - loss: 3.0282e-05 - val_MAE: 0.0038 - val_loss: 2.4611e-05 - learning_rate: 1.6000e-05
# Adamax Optimizer - Loss (MSE): 0.000021, Mean Absolute Error: 0.003537
#
# Training with RMSprop optimizer and leaky_relu activation function...
# Epoch 1/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - MAE: 0.0047 - loss: 3.7117e-05 - val_MAE: 0.0037 - val_loss: 2.2534e-05 - learning_rate: 0.0010
# Epoch 2/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0047 - loss: 4.3255e-05 - val_MAE: 0.0033 - val_loss: 1.7747e-05 - learning_rate: 0.0010
# Epoch 3/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0044 - loss: 3.2424e-05 - val_MAE: 0.0034 - val_loss: 1.9983e-05 - learning_rate: 0.0010
# Epoch 4/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0043 - loss: 3.1505e-05 - val_MAE: 0.0047 - val_loss: 3.5140e-05 - learning_rate: 0.0010
# Epoch 5/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0042 - loss: 2.9962e-05 - val_MAE: 0.0040 - val_loss: 2.7504e-05 - learning_rate: 0.0010
# Epoch 6/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0042 - loss: 2.8938e-05 - val_MAE: 0.0030 - val_loss: 1.5154e-05 - learning_rate: 0.0010
# Epoch 7/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0040 - loss: 2.7153e-05 - val_MAE: 0.0032 - val_loss: 1.7303e-05 - learning_rate: 2.0000e-04
# Epoch 8/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAE: 0.0038 - loss: 2.6609e-05 - val_MAE: 0.0036 - val_loss: 2.2509e-05 - learning_rate: 2.0000e-04
# Epoch 9/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAE: 0.0037 - loss: 2.4289e-05 - val_MAE: 0.0033 - val_loss: 1.8639e-05 - learning_rate: 2.0000e-04
# Epoch 10/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAE: 0.0036 - loss: 2.2401e-05 - val_MAE: 0.0034 - val_loss: 1.9809e-05 - learning_rate: 2.0000e-04
# Epoch 11/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAE: 0.0037 - loss: 2.4425e-05 - val_MAE: 0.0032 - val_loss: 1.7514e-05 - learning_rate: 2.0000e-04
# Epoch 12/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAE: 0.0038 - loss: 2.6438e-05 - val_MAE: 0.0033 - val_loss: 1.9088e-05 - learning_rate: 4.0000e-05
# Epoch 13/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAE: 0.0035 - loss: 2.3152e-05 - val_MAE: 0.0033 - val_loss: 1.8601e-05 - learning_rate: 4.0000e-05
# Epoch 14/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - MAE: 0.0036 - loss: 2.1929e-05 - val_MAE: 0.0033 - val_loss: 1.8601e-05 - learning_rate: 4.0000e-05
# Epoch 15/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAE: 0.0037 - loss: 2.3891e-05 - val_MAE: 0.0031 - val_loss: 1.6675e-05 - learning_rate: 4.0000e-05
# Epoch 16/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAE: 0.0036 - loss: 2.3143e-05 - val_MAE: 0.0032 - val_loss: 1.8041e-05 - learning_rate: 4.0000e-05
# RMSprop Optimizer - Loss (MSE): 0.000015, Mean Absolute Error: 0.003041
#
# Training with SGD optimizer and leaky_relu activation function...
# Epoch 1/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - MAE: 0.0039 - loss: 2.6162e-05 - val_MAE: 0.0035 - val_loss: 2.1259e-05 - learning_rate: 0.0100
# Epoch 2/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAE: 0.0037 - loss: 2.3954e-05 - val_MAE: 0.0032 - val_loss: 1.8283e-05 - learning_rate: 0.0100
# Epoch 3/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAE: 0.0038 - loss: 2.4524e-05 - val_MAE: 0.0034 - val_loss: 2.0366e-05 - learning_rate: 0.0100
# Epoch 4/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAE: 0.0037 - loss: 2.3796e-05 - val_MAE: 0.0035 - val_loss: 2.1761e-05 - learning_rate: 0.0100
# Epoch 5/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - MAE: 0.0037 - loss: 2.4340e-05 - val_MAE: 0.0034 - val_loss: 1.9575e-05 - learning_rate: 0.0100
# Epoch 6/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAE: 0.0037 - loss: 2.3564e-05 - val_MAE: 0.0032 - val_loss: 1.7986e-05 - learning_rate: 0.0100
# Epoch 7/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - MAE: 0.0037 - loss: 2.4501e-05 - val_MAE: 0.0033 - val_loss: 1.9390e-05 - learning_rate: 0.0020
# Epoch 8/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAE: 0.0036 - loss: 2.3506e-05 - val_MAE: 0.0034 - val_loss: 1.9811e-05 - learning_rate: 0.0020
# Epoch 9/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAE: 0.0037 - loss: 2.3489e-05 - val_MAE: 0.0034 - val_loss: 1.9819e-05 - learning_rate: 0.0020
# Epoch 10/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAE: 0.0036 - loss: 2.5530e-05 - val_MAE: 0.0034 - val_loss: 2.0095e-05 - learning_rate: 0.0020
# Epoch 11/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - MAE: 0.0038 - loss: 2.5745e-05 - val_MAE: 0.0033 - val_loss: 1.9085e-05 - learning_rate: 0.0020
# Epoch 12/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAE: 0.0038 - loss: 2.4855e-05 - val_MAE: 0.0033 - val_loss: 1.8955e-05 - learning_rate: 4.0000e-04
# Epoch 13/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAE: 0.0036 - loss: 2.2560e-05 - val_MAE: 0.0033 - val_loss: 1.8852e-05 - learning_rate: 4.0000e-04
# Epoch 14/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAE: 0.0037 - loss: 2.5795e-05 - val_MAE: 0.0033 - val_loss: 1.8988e-05 - learning_rate: 4.0000e-04
# Epoch 15/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAE: 0.0035 - loss: 2.2805e-05 - val_MAE: 0.0033 - val_loss: 1.8818e-05 - learning_rate: 4.0000e-04
# Epoch 16/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAE: 0.0037 - loss: 2.5095e-05 - val_MAE: 0.0033 - val_loss: 1.8951e-05 - learning_rate: 4.0000e-04
# SGD Optimizer - Loss (MSE): 0.000018, Mean Absolute Error: 0.003209
#
# Running for activation function: elu
#
# Training with Adamax optimizer and elu activation function...
# Epoch 1/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - MAE: 0.0854 - loss: 0.0151 - val_MAE: 0.0082 - val_loss: 1.0000e-04 - learning_rate: 0.0020
# Epoch 2/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - MAE: 0.0376 - loss: 0.0024 - val_MAE: 0.0057 - val_loss: 5.9170e-05 - learning_rate: 0.0020
# Epoch 3/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAE: 0.0298 - loss: 0.0015 - val_MAE: 0.0035 - val_loss: 1.9855e-05 - learning_rate: 0.0020
# Epoch 4/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAE: 0.0231 - loss: 9.8625e-04 - val_MAE: 0.0034 - val_loss: 1.9611e-05 - learning_rate: 0.0020
# Epoch 5/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAE: 0.0209 - loss: 7.2464e-04 - val_MAE: 0.0049 - val_loss: 3.5147e-05 - learning_rate: 0.0020
# Epoch 6/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - MAE: 0.0185 - loss: 6.1834e-04 - val_MAE: 0.0055 - val_loss: 5.2918e-05 - learning_rate: 0.0020
# Epoch 7/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - MAE: 0.0174 - loss: 5.6260e-04 - val_MAE: 0.0032 - val_loss: 1.6873e-05 - learning_rate: 4.0000e-04
# Epoch 8/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - MAE: 0.0169 - loss: 5.2018e-04 - val_MAE: 0.0025 - val_loss: 1.1119e-05 - learning_rate: 4.0000e-04
# Epoch 9/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAE: 0.0166 - loss: 4.9491e-04 - val_MAE: 0.0028 - val_loss: 1.3166e-05 - learning_rate: 4.0000e-04
# Epoch 10/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAE: 0.0151 - loss: 4.0623e-04 - val_MAE: 0.0024 - val_loss: 1.0521e-05 - learning_rate: 4.0000e-04
# Epoch 11/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAE: 0.0159 - loss: 4.4114e-04 - val_MAE: 0.0026 - val_loss: 1.1172e-05 - learning_rate: 4.0000e-04
# Epoch 12/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAE: 0.0153 - loss: 3.9577e-04 - val_MAE: 0.0028 - val_loss: 1.2744e-05 - learning_rate: 8.0000e-05
# Epoch 13/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAE: 0.0150 - loss: 4.0581e-04 - val_MAE: 0.0030 - val_loss: 1.4376e-05 - learning_rate: 8.0000e-05
# Epoch 14/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAE: 0.0147 - loss: 3.8305e-04 - val_MAE: 0.0027 - val_loss: 1.1974e-05 - learning_rate: 8.0000e-05
# Epoch 15/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - MAE: 0.0153 - loss: 4.1121e-04 - val_MAE: 0.0029 - val_loss: 1.3192e-05 - learning_rate: 8.0000e-05
# Epoch 16/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAE: 0.0151 - loss: 4.0847e-04 - val_MAE: 0.0033 - val_loss: 1.6812e-05 - learning_rate: 8.0000e-05
# Epoch 17/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAE: 0.0148 - loss: 3.9543e-04 - val_MAE: 0.0031 - val_loss: 1.5400e-05 - learning_rate: 1.6000e-05
# Epoch 18/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - MAE: 0.0149 - loss: 4.0587e-04 - val_MAE: 0.0030 - val_loss: 1.4290e-05 - learning_rate: 1.6000e-05
# Epoch 19/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAE: 0.0148 - loss: 3.8904e-04 - val_MAE: 0.0029 - val_loss: 1.3329e-05 - learning_rate: 1.6000e-05
# Epoch 20/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAE: 0.0145 - loss: 3.7886e-04 - val_MAE: 0.0029 - val_loss: 1.3343e-05 - learning_rate: 1.6000e-05
# Adamax Optimizer - Loss (MSE): 0.000011, Mean Absolute Error: 0.002441
#
# Training with RMSprop optimizer and elu activation function...
# Epoch 1/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - MAE: 0.0182 - loss: 6.1181e-04 - val_MAE: 0.0029 - val_loss: 1.3912e-05 - learning_rate: 0.0010
# Epoch 2/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - MAE: 0.0091 - loss: 1.4349e-04 - val_MAE: 0.0111 - val_loss: 1.3733e-04 - learning_rate: 0.0010
# Epoch 3/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - MAE: 0.0075 - loss: 1.0049e-04 - val_MAE: 0.0041 - val_loss: 2.3478e-05 - learning_rate: 0.0010
# Epoch 4/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - MAE: 0.0062 - loss: 6.3905e-05 - val_MAE: 0.0030 - val_loss: 1.5009e-05 - learning_rate: 0.0010
# Epoch 5/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAE: 0.0052 - loss: 4.7002e-05 - val_MAE: 0.0030 - val_loss: 1.3462e-05 - learning_rate: 0.0010
# Epoch 6/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - MAE: 0.0049 - loss: 4.0825e-05 - val_MAE: 0.0034 - val_loss: 1.6717e-05 - learning_rate: 0.0010
# Epoch 7/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAE: 0.0037 - loss: 2.4133e-05 - val_MAE: 0.0025 - val_loss: 1.0184e-05 - learning_rate: 2.0000e-04
# Epoch 8/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAE: 0.0038 - loss: 2.5619e-05 - val_MAE: 0.0030 - val_loss: 1.3842e-05 - learning_rate: 2.0000e-04
# Epoch 9/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAE: 0.0036 - loss: 2.2537e-05 - val_MAE: 0.0026 - val_loss: 1.0874e-05 - learning_rate: 2.0000e-04
# Epoch 10/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAE: 0.0036 - loss: 2.3223e-05 - val_MAE: 0.0026 - val_loss: 1.0798e-05 - learning_rate: 2.0000e-04
# Epoch 11/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAE: 0.0035 - loss: 2.1772e-05 - val_MAE: 0.0027 - val_loss: 1.1877e-05 - learning_rate: 2.0000e-04
# Epoch 12/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAE: 0.0035 - loss: 2.1878e-05 - val_MAE: 0.0025 - val_loss: 1.0639e-05 - learning_rate: 4.0000e-05
# Epoch 13/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAE: 0.0035 - loss: 2.2479e-05 - val_MAE: 0.0025 - val_loss: 1.0464e-05 - learning_rate: 4.0000e-05
# Epoch 14/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - MAE: 0.0036 - loss: 2.3366e-05 - val_MAE: 0.0025 - val_loss: 1.0567e-05 - learning_rate: 4.0000e-05
# Epoch 15/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0034 - loss: 2.0795e-05 - val_MAE: 0.0027 - val_loss: 1.1663e-05 - learning_rate: 4.0000e-05
# Epoch 16/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAE: 0.0036 - loss: 2.3896e-05 - val_MAE: 0.0025 - val_loss: 1.0191e-05 - learning_rate: 4.0000e-05
# Epoch 17/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAE: 0.0035 - loss: 2.0814e-05 - val_MAE: 0.0025 - val_loss: 1.0632e-05 - learning_rate: 1.0000e-05
# RMSprop Optimizer - Loss (MSE): 0.000010, Mean Absolute Error: 0.002453
#
# Training with SGD optimizer and elu activation function...
# Epoch 1/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - MAE: 0.0035 - loss: 2.0640e-05 - val_MAE: 0.0025 - val_loss: 1.0282e-05 - learning_rate: 0.0100
# Epoch 2/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0036 - loss: 2.3926e-05 - val_MAE: 0.0029 - val_loss: 1.3431e-05 - learning_rate: 0.0100
# Epoch 3/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0036 - loss: 2.5170e-05 - val_MAE: 0.0024 - val_loss: 1.0077e-05 - learning_rate: 0.0100
# Epoch 4/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAE: 0.0035 - loss: 2.1828e-05 - val_MAE: 0.0026 - val_loss: 1.0889e-05 - learning_rate: 0.0100
# Epoch 5/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0037 - loss: 2.4205e-05 - val_MAE: 0.0025 - val_loss: 1.0166e-05 - learning_rate: 0.0100
# Epoch 6/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0037 - loss: 2.4837e-05 - val_MAE: 0.0025 - val_loss: 1.0311e-05 - learning_rate: 0.0100
# Epoch 7/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0035 - loss: 2.1331e-05 - val_MAE: 0.0025 - val_loss: 1.0407e-05 - learning_rate: 0.0020
# Epoch 8/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0036 - loss: 2.3294e-05 - val_MAE: 0.0025 - val_loss: 1.0616e-05 - learning_rate: 0.0020
# Epoch 9/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0036 - loss: 2.4014e-05 - val_MAE: 0.0027 - val_loss: 1.1401e-05 - learning_rate: 0.0020
# Epoch 10/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0035 - loss: 2.0661e-05 - val_MAE: 0.0026 - val_loss: 1.1003e-05 - learning_rate: 0.0020
# Epoch 11/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAE: 0.0036 - loss: 2.3515e-05 - val_MAE: 0.0025 - val_loss: 1.0482e-05 - learning_rate: 0.0020
# Epoch 12/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0036 - loss: 2.2606e-05 - val_MAE: 0.0025 - val_loss: 1.0588e-05 - learning_rate: 4.0000e-04
# Epoch 13/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0036 - loss: 2.2349e-05 - val_MAE: 0.0025 - val_loss: 1.0650e-05 - learning_rate: 4.0000e-04
# SGD Optimizer - Loss (MSE): 0.000010, Mean Absolute Error: 0.002431
#
# Running for activation function: prelu
#
# Training with Adamax optimizer and prelu activation function...
# Epoch 1/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - MAE: 0.0205 - loss: 8.3660e-04 - val_MAE: 0.0076 - val_loss: 9.4456e-05 - learning_rate: 0.0020
# Epoch 2/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAE: 0.0089 - loss: 1.4145e-04 - val_MAE: 0.0057 - val_loss: 5.2739e-05 - learning_rate: 0.0020
# Epoch 3/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0066 - loss: 7.8723e-05 - val_MAE: 0.0056 - val_loss: 4.8607e-05 - learning_rate: 0.0020
# Epoch 4/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0060 - loss: 6.8088e-05 - val_MAE: 0.0049 - val_loss: 4.0187e-05 - learning_rate: 0.0020
# Epoch 5/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAE: 0.0053 - loss: 5.0606e-05 - val_MAE: 0.0043 - val_loss: 3.0524e-05 - learning_rate: 0.0020
# Epoch 6/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0050 - loss: 4.4506e-05 - val_MAE: 0.0048 - val_loss: 3.8603e-05 - learning_rate: 0.0020
# Epoch 7/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAE: 0.0049 - loss: 4.2563e-05 - val_MAE: 0.0044 - val_loss: 3.2877e-05 - learning_rate: 4.0000e-04
# Epoch 8/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0047 - loss: 4.1907e-05 - val_MAE: 0.0045 - val_loss: 3.3686e-05 - learning_rate: 4.0000e-04
# Epoch 9/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAE: 0.0047 - loss: 4.0026e-05 - val_MAE: 0.0042 - val_loss: 2.9980e-05 - learning_rate: 4.0000e-04
# Epoch 10/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0045 - loss: 3.5803e-05 - val_MAE: 0.0043 - val_loss: 3.1237e-05 - learning_rate: 4.0000e-04
# Epoch 11/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - MAE: 0.0045 - loss: 3.5398e-05 - val_MAE: 0.0042 - val_loss: 2.9289e-05 - learning_rate: 4.0000e-04
# Epoch 12/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAE: 0.0046 - loss: 3.7706e-05 - val_MAE: 0.0042 - val_loss: 3.0399e-05 - learning_rate: 8.0000e-05
# Epoch 13/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAE: 0.0043 - loss: 3.2189e-05 - val_MAE: 0.0042 - val_loss: 3.0290e-05 - learning_rate: 8.0000e-05
# Epoch 14/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAE: 0.0045 - loss: 3.6318e-05 - val_MAE: 0.0042 - val_loss: 2.9145e-05 - learning_rate: 8.0000e-05
# Epoch 15/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - MAE: 0.0043 - loss: 3.1303e-05 - val_MAE: 0.0042 - val_loss: 2.9375e-05 - learning_rate: 8.0000e-05
# Epoch 16/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - MAE: 0.0043 - loss: 3.2101e-05 - val_MAE: 0.0042 - val_loss: 3.0198e-05 - learning_rate: 8.0000e-05
# Epoch 17/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAE: 0.0044 - loss: 3.4457e-05 - val_MAE: 0.0042 - val_loss: 3.0092e-05 - learning_rate: 1.6000e-05
# Epoch 18/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAE: 0.0043 - loss: 3.4478e-05 - val_MAE: 0.0042 - val_loss: 2.9495e-05 - learning_rate: 1.6000e-05
# Epoch 19/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAE: 0.0045 - loss: 3.5860e-05 - val_MAE: 0.0042 - val_loss: 2.9253e-05 - learning_rate: 1.6000e-05
# Epoch 20/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAE: 0.0045 - loss: 3.6456e-05 - val_MAE: 0.0042 - val_loss: 2.9246e-05 - learning_rate: 1.6000e-05
# Epoch 21/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - MAE: 0.0046 - loss: 3.8588e-05 - val_MAE: 0.0041 - val_loss: 2.8957e-05 - learning_rate: 1.6000e-05
# Epoch 22/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - MAE: 0.0045 - loss: 3.6482e-05 - val_MAE: 0.0041 - val_loss: 2.8819e-05 - learning_rate: 1.0000e-05
# Epoch 23/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAE: 0.0045 - loss: 3.5843e-05 - val_MAE: 0.0041 - val_loss: 2.8635e-05 - learning_rate: 1.0000e-05
# Epoch 24/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - MAE: 0.0043 - loss: 3.3682e-05 - val_MAE: 0.0041 - val_loss: 2.8512e-05 - learning_rate: 1.0000e-05
# Epoch 25/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAE: 0.0045 - loss: 3.5284e-05 - val_MAE: 0.0041 - val_loss: 2.8372e-05 - learning_rate: 1.0000e-05
# Epoch 26/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAE: 0.0045 - loss: 3.7280e-05 - val_MAE: 0.0041 - val_loss: 2.8339e-05 - learning_rate: 1.0000e-05
# Epoch 27/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAE: 0.0043 - loss: 3.2675e-05 - val_MAE: 0.0042 - val_loss: 2.9169e-05 - learning_rate: 1.0000e-05
# Epoch 28/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAE: 0.0044 - loss: 3.3690e-05 - val_MAE: 0.0041 - val_loss: 2.9072e-05 - learning_rate: 1.0000e-05
# Epoch 29/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAE: 0.0044 - loss: 3.3697e-05 - val_MAE: 0.0041 - val_loss: 2.9121e-05 - learning_rate: 1.0000e-05
# Epoch 30/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0043 - loss: 3.2410e-05 - val_MAE: 0.0041 - val_loss: 2.8446e-05 - learning_rate: 1.0000e-05
# Epoch 31/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0044 - loss: 3.4553e-05 - val_MAE: 0.0041 - val_loss: 2.8773e-05 - learning_rate: 1.0000e-05
# Epoch 32/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0043 - loss: 3.6207e-05 - val_MAE: 0.0041 - val_loss: 2.8493e-05 - learning_rate: 1.0000e-05
# Epoch 33/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAE: 0.0045 - loss: 3.4624e-05 - val_MAE: 0.0041 - val_loss: 2.8172e-05 - learning_rate: 1.0000e-05
# Epoch 34/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - MAE: 0.0045 - loss: 3.6109e-05 - val_MAE: 0.0041 - val_loss: 2.8482e-05 - learning_rate: 1.0000e-05
# Epoch 35/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0044 - loss: 3.2834e-05 - val_MAE: 0.0041 - val_loss: 2.8673e-05 - learning_rate: 1.0000e-05
# Epoch 36/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAE: 0.0044 - loss: 3.3099e-05 - val_MAE: 0.0041 - val_loss: 2.8190e-05 - learning_rate: 1.0000e-05
# Epoch 37/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAE: 0.0043 - loss: 3.1796e-05 - val_MAE: 0.0041 - val_loss: 2.8465e-05 - learning_rate: 1.0000e-05
# Epoch 38/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAE: 0.0043 - loss: 3.2525e-05 - val_MAE: 0.0041 - val_loss: 2.8619e-05 - learning_rate: 1.0000e-05
# Epoch 39/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0044 - loss: 3.3509e-05 - val_MAE: 0.0041 - val_loss: 2.8638e-05 - learning_rate: 1.0000e-05
# Epoch 40/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAE: 0.0043 - loss: 3.1948e-05 - val_MAE: 0.0041 - val_loss: 2.8057e-05 - learning_rate: 1.0000e-05
# Epoch 41/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0042 - loss: 3.1513e-05 - val_MAE: 0.0041 - val_loss: 2.8399e-05 - learning_rate: 1.0000e-05
# Epoch 42/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0045 - loss: 3.6219e-05 - val_MAE: 0.0041 - val_loss: 2.8770e-05 - learning_rate: 1.0000e-05
# Epoch 43/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0043 - loss: 3.2171e-05 - val_MAE: 0.0041 - val_loss: 2.8550e-05 - learning_rate: 1.0000e-05
# Epoch 44/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0043 - loss: 3.4135e-05 - val_MAE: 0.0041 - val_loss: 2.8143e-05 - learning_rate: 1.0000e-05
# Epoch 45/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0042 - loss: 3.1535e-05 - val_MAE: 0.0041 - val_loss: 2.8237e-05 - learning_rate: 1.0000e-05
# Epoch 46/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0042 - loss: 3.0602e-05 - val_MAE: 0.0041 - val_loss: 2.8769e-05 - learning_rate: 1.0000e-05
# Epoch 47/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0045 - loss: 3.6014e-05 - val_MAE: 0.0041 - val_loss: 2.8887e-05 - learning_rate: 1.0000e-05
# Epoch 48/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0042 - loss: 3.1599e-05 - val_MAE: 0.0041 - val_loss: 2.8748e-05 - learning_rate: 1.0000e-05
# Epoch 49/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0043 - loss: 3.1990e-05 - val_MAE: 0.0041 - val_loss: 2.8004e-05 - learning_rate: 1.0000e-05
# Epoch 50/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0044 - loss: 3.4415e-05 - val_MAE: 0.0041 - val_loss: 2.8088e-05 - learning_rate: 1.0000e-05
# Epoch 51/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAE: 0.0043 - loss: 3.1327e-05 - val_MAE: 0.0041 - val_loss: 2.7861e-05 - learning_rate: 1.0000e-05
# Epoch 52/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0043 - loss: 3.0822e-05 - val_MAE: 0.0041 - val_loss: 2.8115e-05 - learning_rate: 1.0000e-05
# Epoch 53/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAE: 0.0043 - loss: 3.4678e-05 - val_MAE: 0.0041 - val_loss: 2.8099e-05 - learning_rate: 1.0000e-05
# Epoch 54/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - MAE: 0.0044 - loss: 3.2719e-05 - val_MAE: 0.0041 - val_loss: 2.7789e-05 - learning_rate: 1.0000e-05
# Epoch 55/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAE: 0.0043 - loss: 3.1869e-05 - val_MAE: 0.0041 - val_loss: 2.7987e-05 - learning_rate: 1.0000e-05
# Epoch 56/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAE: 0.0043 - loss: 3.2526e-05 - val_MAE: 0.0040 - val_loss: 2.7431e-05 - learning_rate: 1.0000e-05
# Epoch 57/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAE: 0.0044 - loss: 3.3113e-05 - val_MAE: 0.0041 - val_loss: 2.8051e-05 - learning_rate: 1.0000e-05
# Epoch 58/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAE: 0.0043 - loss: 3.2032e-05 - val_MAE: 0.0041 - val_loss: 2.7811e-05 - learning_rate: 1.0000e-05
# Epoch 59/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAE: 0.0041 - loss: 3.0870e-05 - val_MAE: 0.0040 - val_loss: 2.7737e-05 - learning_rate: 1.0000e-05
# Epoch 60/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAE: 0.0042 - loss: 3.3119e-05 - val_MAE: 0.0040 - val_loss: 2.7463e-05 - learning_rate: 1.0000e-05
# Epoch 61/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAE: 0.0044 - loss: 3.2690e-05 - val_MAE: 0.0040 - val_loss: 2.7754e-05 - learning_rate: 1.0000e-05
# Epoch 62/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAE: 0.0042 - loss: 3.1697e-05 - val_MAE: 0.0040 - val_loss: 2.7405e-05 - learning_rate: 1.0000e-05
# Epoch 63/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAE: 0.0042 - loss: 3.1258e-05 - val_MAE: 0.0040 - val_loss: 2.7681e-05 - learning_rate: 1.0000e-05
# Epoch 64/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAE: 0.0041 - loss: 2.8653e-05 - val_MAE: 0.0041 - val_loss: 2.7861e-05 - learning_rate: 1.0000e-05
# Epoch 65/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAE: 0.0042 - loss: 3.1159e-05 - val_MAE: 0.0040 - val_loss: 2.7025e-05 - learning_rate: 1.0000e-05
# Epoch 66/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0043 - loss: 3.2178e-05 - val_MAE: 0.0040 - val_loss: 2.7206e-05 - learning_rate: 1.0000e-05
# Epoch 67/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAE: 0.0045 - loss: 3.7331e-05 - val_MAE: 0.0041 - val_loss: 2.7808e-05 - learning_rate: 1.0000e-05
# Epoch 68/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAE: 0.0045 - loss: 3.6113e-05 - val_MAE: 0.0040 - val_loss: 2.7236e-05 - learning_rate: 1.0000e-05
# Epoch 69/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0043 - loss: 3.1477e-05 - val_MAE: 0.0040 - val_loss: 2.7262e-05 - learning_rate: 1.0000e-05
# Epoch 70/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0042 - loss: 2.9855e-05 - val_MAE: 0.0040 - val_loss: 2.7425e-05 - learning_rate: 1.0000e-05
# Epoch 71/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0043 - loss: 3.1560e-05 - val_MAE: 0.0040 - val_loss: 2.7268e-05 - learning_rate: 1.0000e-05
# Epoch 72/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0043 - loss: 3.2743e-05 - val_MAE: 0.0040 - val_loss: 2.7598e-05 - learning_rate: 1.0000e-05
# Epoch 73/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0042 - loss: 3.0890e-05 - val_MAE: 0.0040 - val_loss: 2.7371e-05 - learning_rate: 1.0000e-05
# Epoch 74/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0043 - loss: 3.3212e-05 - val_MAE: 0.0040 - val_loss: 2.7064e-05 - learning_rate: 1.0000e-05
# Epoch 75/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0043 - loss: 3.1096e-05 - val_MAE: 0.0040 - val_loss: 2.7501e-05 - learning_rate: 1.0000e-05
# Adamax Optimizer - Loss (MSE): 0.000027, Mean Absolute Error: 0.003997
#
# Training with RMSprop optimizer and prelu activation function...
# Epoch 1/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - MAE: 0.0047 - loss: 3.7656e-05 - val_MAE: 0.0038 - val_loss: 2.5079e-05 - learning_rate: 0.0010
# Epoch 2/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0044 - loss: 3.2596e-05 - val_MAE: 0.0038 - val_loss: 2.3869e-05 - learning_rate: 0.0010
# Epoch 3/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0045 - loss: 3.5457e-05 - val_MAE: 0.0037 - val_loss: 2.2694e-05 - learning_rate: 0.0010
# Epoch 4/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0042 - loss: 3.0189e-05 - val_MAE: 0.0036 - val_loss: 2.0812e-05 - learning_rate: 0.0010
# Epoch 5/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAE: 0.0043 - loss: 3.2037e-05 - val_MAE: 0.0038 - val_loss: 2.4656e-05 - learning_rate: 0.0010
# Epoch 6/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAE: 0.0042 - loss: 2.9237e-05 - val_MAE: 0.0034 - val_loss: 1.9055e-05 - learning_rate: 0.0010
# Epoch 7/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0038 - loss: 2.4177e-05 - val_MAE: 0.0033 - val_loss: 1.7966e-05 - learning_rate: 2.0000e-04
# Epoch 8/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAE: 0.0038 - loss: 2.4231e-05 - val_MAE: 0.0035 - val_loss: 2.0550e-05 - learning_rate: 2.0000e-04
# Epoch 9/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0040 - loss: 2.8609e-05 - val_MAE: 0.0032 - val_loss: 1.7696e-05 - learning_rate: 2.0000e-04
# Epoch 10/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0038 - loss: 2.4424e-05 - val_MAE: 0.0033 - val_loss: 1.8387e-05 - learning_rate: 2.0000e-04
# Epoch 11/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0038 - loss: 2.6640e-05 - val_MAE: 0.0034 - val_loss: 1.9466e-05 - learning_rate: 2.0000e-04
# Epoch 12/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0037 - loss: 2.4615e-05 - val_MAE: 0.0032 - val_loss: 1.7778e-05 - learning_rate: 4.0000e-05
# Epoch 13/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0037 - loss: 2.2984e-05 - val_MAE: 0.0033 - val_loss: 1.8607e-05 - learning_rate: 4.0000e-05
# Epoch 14/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0037 - loss: 2.3777e-05 - val_MAE: 0.0032 - val_loss: 1.7529e-05 - learning_rate: 4.0000e-05
# Epoch 15/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0037 - loss: 2.3525e-05 - val_MAE: 0.0032 - val_loss: 1.7650e-05 - learning_rate: 4.0000e-05
# Epoch 16/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0038 - loss: 2.3791e-05 - val_MAE: 0.0033 - val_loss: 1.8176e-05 - learning_rate: 4.0000e-05
# Epoch 17/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0038 - loss: 2.4008e-05 - val_MAE: 0.0032 - val_loss: 1.7865e-05 - learning_rate: 1.0000e-05
# Epoch 18/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0039 - loss: 2.4591e-05 - val_MAE: 0.0032 - val_loss: 1.8018e-05 - learning_rate: 1.0000e-05
# Epoch 19/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0037 - loss: 2.3434e-05 - val_MAE: 0.0032 - val_loss: 1.7993e-05 - learning_rate: 1.0000e-05
# Epoch 20/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0035 - loss: 2.0981e-05 - val_MAE: 0.0032 - val_loss: 1.7876e-05 - learning_rate: 1.0000e-05
# Epoch 21/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0038 - loss: 2.4808e-05 - val_MAE: 0.0032 - val_loss: 1.7798e-05 - learning_rate: 1.0000e-05
# Epoch 22/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0038 - loss: 2.3276e-05 - val_MAE: 0.0032 - val_loss: 1.8067e-05 - learning_rate: 1.0000e-05
# Epoch 23/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0036 - loss: 2.3365e-05 - val_MAE: 0.0032 - val_loss: 1.7963e-05 - learning_rate: 1.0000e-05
# Epoch 24/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0037 - loss: 2.4316e-05 - val_MAE: 0.0032 - val_loss: 1.7868e-05 - learning_rate: 1.0000e-05
# RMSprop Optimizer - Loss (MSE): 0.000018, Mean Absolute Error: 0.003215
#
# Training with SGD optimizer and prelu activation function...
# Epoch 1/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - MAE: 0.0038 - loss: 2.6162e-05 - val_MAE: 0.0033 - val_loss: 1.9207e-05 - learning_rate: 0.0100
# Epoch 2/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0037 - loss: 2.4608e-05 - val_MAE: 0.0032 - val_loss: 1.7639e-05 - learning_rate: 0.0100
# Epoch 3/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0036 - loss: 2.2799e-05 - val_MAE: 0.0033 - val_loss: 1.8397e-05 - learning_rate: 0.0100
# Epoch 4/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0037 - loss: 2.3737e-05 - val_MAE: 0.0033 - val_loss: 1.8812e-05 - learning_rate: 0.0100
# Epoch 5/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0038 - loss: 2.4283e-05 - val_MAE: 0.0033 - val_loss: 1.8213e-05 - learning_rate: 0.0100
# Epoch 6/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0035 - loss: 2.0628e-05 - val_MAE: 0.0033 - val_loss: 1.8296e-05 - learning_rate: 0.0100
# Epoch 7/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0039 - loss: 2.6057e-05 - val_MAE: 0.0032 - val_loss: 1.7776e-05 - learning_rate: 0.0020
# Epoch 8/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0036 - loss: 2.3316e-05 - val_MAE: 0.0033 - val_loss: 1.8464e-05 - learning_rate: 0.0020
# Epoch 9/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0037 - loss: 2.4787e-05 - val_MAE: 0.0032 - val_loss: 1.7836e-05 - learning_rate: 0.0020
# Epoch 10/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAE: 0.0038 - loss: 2.5431e-05 - val_MAE: 0.0032 - val_loss: 1.7752e-05 - learning_rate: 0.0020
# Epoch 11/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0037 - loss: 2.3793e-05 - val_MAE: 0.0032 - val_loss: 1.8035e-05 - learning_rate: 0.0020
# Epoch 12/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAE: 0.0036 - loss: 2.2053e-05 - val_MAE: 0.0032 - val_loss: 1.8125e-05 - learning_rate: 4.0000e-04
# SGD Optimizer - Loss (MSE): 0.000018, Mean Absolute Error: 0.003214
#
# Running for activation function: swish
#
# Training with Adamax optimizer and swish activation function...
# Epoch 1/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - MAE: 0.0173 - loss: 5.9929e-04 - val_MAE: 0.0034 - val_loss: 1.9914e-05 - learning_rate: 0.0020
# Epoch 2/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAE: 0.0070 - loss: 8.5850e-05 - val_MAE: 0.0027 - val_loss: 1.2269e-05 - learning_rate: 0.0020
# Epoch 3/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAE: 0.0062 - loss: 6.4494e-05 - val_MAE: 0.0025 - val_loss: 1.0902e-05 - learning_rate: 0.0020
# Epoch 4/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAE: 0.0051 - loss: 4.4644e-05 - val_MAE: 0.0026 - val_loss: 1.1304e-05 - learning_rate: 0.0020
# Epoch 5/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAE: 0.0047 - loss: 3.5806e-05 - val_MAE: 0.0025 - val_loss: 1.0344e-05 - learning_rate: 0.0020
# Epoch 6/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAE: 0.0043 - loss: 3.0427e-05 - val_MAE: 0.0024 - val_loss: 1.0219e-05 - learning_rate: 0.0020
# Epoch 7/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAE: 0.0042 - loss: 2.9067e-05 - val_MAE: 0.0024 - val_loss: 9.6464e-06 - learning_rate: 4.0000e-04
# Epoch 8/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAE: 0.0040 - loss: 2.6704e-05 - val_MAE: 0.0024 - val_loss: 9.8704e-06 - learning_rate: 4.0000e-04
# Epoch 9/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0040 - loss: 2.6769e-05 - val_MAE: 0.0024 - val_loss: 9.7747e-06 - learning_rate: 4.0000e-04
# Epoch 10/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0038 - loss: 2.5132e-05 - val_MAE: 0.0024 - val_loss: 9.7386e-06 - learning_rate: 4.0000e-04
# Epoch 11/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0038 - loss: 2.4586e-05 - val_MAE: 0.0024 - val_loss: 9.6262e-06 - learning_rate: 4.0000e-04
# Epoch 12/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAE: 0.0037 - loss: 2.4224e-05 - val_MAE: 0.0024 - val_loss: 9.7132e-06 - learning_rate: 8.0000e-05
# Epoch 13/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - MAE: 0.0037 - loss: 2.4961e-05 - val_MAE: 0.0024 - val_loss: 9.6734e-06 - learning_rate: 8.0000e-05
# Epoch 14/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0036 - loss: 2.2175e-05 - val_MAE: 0.0024 - val_loss: 9.6744e-06 - learning_rate: 8.0000e-05
# Epoch 15/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0037 - loss: 2.2115e-05 - val_MAE: 0.0024 - val_loss: 9.6646e-06 - learning_rate: 8.0000e-05
# Epoch 16/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0038 - loss: 2.4638e-05 - val_MAE: 0.0024 - val_loss: 9.7278e-06 - learning_rate: 8.0000e-05
# Epoch 17/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0038 - loss: 2.4474e-05 - val_MAE: 0.0024 - val_loss: 9.7036e-06 - learning_rate: 1.6000e-05
# Epoch 18/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0037 - loss: 2.2234e-05 - val_MAE: 0.0024 - val_loss: 9.6728e-06 - learning_rate: 1.6000e-05
# Epoch 19/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0037 - loss: 2.4271e-05 - val_MAE: 0.0024 - val_loss: 9.7000e-06 - learning_rate: 1.6000e-05
# Epoch 20/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0038 - loss: 2.3835e-05 - val_MAE: 0.0024 - val_loss: 9.6748e-06 - learning_rate: 1.6000e-05
# Epoch 21/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0036 - loss: 2.2991e-05 - val_MAE: 0.0024 - val_loss: 9.7032e-06 - learning_rate: 1.6000e-05
# Adamax Optimizer - Loss (MSE): 0.000010, Mean Absolute Error: 0.002372
#
# Training with RMSprop optimizer and swish activation function...
# Epoch 1/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - MAE: 0.0045 - loss: 3.2116e-05 - val_MAE: 0.0067 - val_loss: 5.5078e-05 - learning_rate: 0.0010
# Epoch 2/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0043 - loss: 3.0186e-05 - val_MAE: 0.0024 - val_loss: 9.9910e-06 - learning_rate: 0.0010
# Epoch 3/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0040 - loss: 2.6965e-05 - val_MAE: 0.0024 - val_loss: 9.9692e-06 - learning_rate: 0.0010
# Epoch 4/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0041 - loss: 2.7535e-05 - val_MAE: 0.0027 - val_loss: 1.1340e-05 - learning_rate: 0.0010
# Epoch 5/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0039 - loss: 2.4807e-05 - val_MAE: 0.0030 - val_loss: 1.3585e-05 - learning_rate: 0.0010
# Epoch 6/100
# ...
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0035 - loss: 2.0607e-05 - val_MAE: 0.0024 - val_loss: 9.7957e-06 - learning_rate: 4.0000e-05
# Epoch 15/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0033 - loss: 1.9661e-05 - val_MAE: 0.0024 - val_loss: 9.8050e-06 - learning_rate: 4.0000e-05
# Epoch 16/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0032 - loss: 1.7545e-05 - val_MAE: 0.0024 - val_loss: 9.8314e-06 - learning_rate: 4.0000e-05
# Epoch 17/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0033 - loss: 1.8174e-05 - val_MAE: 0.0024 - val_loss: 9.7908e-06 - learning_rate: 1.0000e-05
# Epoch 18/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0035 - loss: 2.0410e-05 - val_MAE: 0.0024 - val_loss: 9.7885e-06 - learning_rate: 1.0000e-05
# Epoch 19/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0033 - loss: 1.8355e-05 - val_MAE: 0.0024 - val_loss: 9.8167e-06 - learning_rate: 1.0000e-05
# Epoch 20/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0033 - loss: 1.8609e-05 - val_MAE: 0.0024 - val_loss: 9.7913e-06 - learning_rate: 1.0000e-05
# Epoch 21/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0034 - loss: 1.9144e-05 - val_MAE: 0.0024 - val_loss: 9.7875e-06 - learning_rate: 1.0000e-05
# Epoch 22/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0034 - loss: 1.9143e-05 - val_MAE: 0.0024 - val_loss: 9.7966e-06 - learning_rate: 1.0000e-05
# Epoch 23/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0032 - loss: 1.7380e-05 - val_MAE: 0.0024 - val_loss: 9.8287e-06 - learning_rate: 1.0000e-05
# Epoch 24/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0033 - loss: 1.8625e-05 - val_MAE: 0.0024 - val_loss: 9.8072e-06 - learning_rate: 1.0000e-05
# Epoch 25/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0035 - loss: 2.0526e-05 - val_MAE: 0.0024 - val_loss: 9.7892e-06 - learning_rate: 1.0000e-05
# Epoch 26/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0034 - loss: 1.8884e-05 - val_MAE: 0.0024 - val_loss: 9.8131e-06 - learning_rate: 1.0000e-05
# Epoch 27/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0034 - loss: 1.9347e-05 - val_MAE: 0.0024 - val_loss: 9.7864e-06 - learning_rate: 1.0000e-05
# Epoch 28/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0032 - loss: 1.8132e-05 - val_MAE: 0.0024 - val_loss: 9.7945e-06 - learning_rate: 1.0000e-05
# Epoch 29/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0034 - loss: 1.9666e-05 - val_MAE: 0.0024 - val_loss: 9.7911e-06 - learning_rate: 1.0000e-05
# Epoch 30/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0033 - loss: 1.7855e-05 - val_MAE: 0.0024 - val_loss: 9.7838e-06 - learning_rate: 1.0000e-05
# Epoch 31/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0033 - loss: 1.8384e-05 - val_MAE: 0.0024 - val_loss: 9.7903e-06 - learning_rate: 1.0000e-05
# Epoch 32/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0034 - loss: 2.1897e-05 - val_MAE: 0.0024 - val_loss: 9.7832e-06 - learning_rate: 1.0000e-05
# Epoch 33/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0033 - loss: 1.8329e-05 - val_MAE: 0.0024 - val_loss: 9.7828e-06 - learning_rate: 1.0000e-05
# Epoch 34/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0034 - loss: 1.8567e-05 - val_MAE: 0.0024 - val_loss: 9.7872e-06 - learning_rate: 1.0000e-05
# Epoch 35/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0033 - loss: 1.9210e-05 - val_MAE: 0.0024 - val_loss: 9.7807e-06 - learning_rate: 1.0000e-05
# Epoch 36/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0033 - loss: 1.8884e-05 - val_MAE: 0.0024 - val_loss: 9.7801e-06 - learning_rate: 1.0000e-05
# Epoch 37/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0034 - loss: 1.8166e-05 - val_MAE: 0.0024 - val_loss: 9.7963e-06 - learning_rate: 1.0000e-05
# Epoch 38/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0033 - loss: 1.7807e-05 - val_MAE: 0.0024 - val_loss: 9.7945e-06 - learning_rate: 1.0000e-05
# Epoch 39/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0031 - loss: 1.6566e-05 - val_MAE: 0.0024 - val_loss: 9.7869e-06 - learning_rate: 1.0000e-05
# Epoch 40/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0034 - loss: 1.9889e-05 - val_MAE: 0.0024 - val_loss: 9.7889e-06 - learning_rate: 1.0000e-05
# Epoch 41/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0034 - loss: 1.9806e-05 - val_MAE: 0.0024 - val_loss: 9.7906e-06 - learning_rate: 1.0000e-05
# Epoch 42/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0034 - loss: 1.9805e-05 - val_MAE: 0.0024 - val_loss: 9.7800e-06 - learning_rate: 1.0000e-05
# Epoch 43/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0031 - loss: 1.6299e-05 - val_MAE: 0.0024 - val_loss: 9.7842e-06 - learning_rate: 1.0000e-05
# Epoch 44/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0032 - loss: 1.7586e-05 - val_MAE: 0.0024 - val_loss: 9.7906e-06 - learning_rate: 1.0000e-05
# Epoch 45/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0032 - loss: 1.7187e-05 - val_MAE: 0.0024 - val_loss: 9.7752e-06 - learning_rate: 1.0000e-05
# Epoch 46/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0033 - loss: 1.8686e-05 - val_MAE: 0.0024 - val_loss: 9.7748e-06 - learning_rate: 1.0000e-05
# Epoch 47/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0032 - loss: 1.6351e-05 - val_MAE: 0.0024 - val_loss: 9.7803e-06 - learning_rate: 1.0000e-05
# Epoch 48/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0031 - loss: 1.6952e-05 - val_MAE: 0.0024 - val_loss: 9.7905e-06 - learning_rate: 1.0000e-05
# Epoch 49/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0033 - loss: 1.8874e-05 - val_MAE: 0.0024 - val_loss: 9.7743e-06 - learning_rate: 1.0000e-05
# Epoch 50/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0033 - loss: 1.8771e-05 - val_MAE: 0.0024 - val_loss: 9.7756e-06 - learning_rate: 1.0000e-05
# Epoch 51/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0033 - loss: 1.7790e-05 - val_MAE: 0.0024 - val_loss: 9.7753e-06 - learning_rate: 1.0000e-05
# Epoch 52/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0032 - loss: 1.7811e-05 - val_MAE: 0.0024 - val_loss: 9.7731e-06 - learning_rate: 1.0000e-05
# Epoch 53/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0032 - loss: 1.7568e-05 - val_MAE: 0.0024 - val_loss: 9.7733e-06 - learning_rate: 1.0000e-05
# Epoch 54/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0033 - loss: 1.7910e-05 - val_MAE: 0.0024 - val_loss: 9.7716e-06 - learning_rate: 1.0000e-05
# Epoch 55/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0032 - loss: 1.7592e-05 - val_MAE: 0.0024 - val_loss: 9.7728e-06 - learning_rate: 1.0000e-05
# Epoch 56/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0033 - loss: 1.8063e-05 - val_MAE: 0.0024 - val_loss: 9.7911e-06 - learning_rate: 1.0000e-05
# Epoch 57/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0032 - loss: 1.7865e-05 - val_MAE: 0.0024 - val_loss: 9.7817e-06 - learning_rate: 1.0000e-05
# Epoch 58/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0033 - loss: 1.8394e-05 - val_MAE: 0.0024 - val_loss: 9.7711e-06 - learning_rate: 1.0000e-05
# Epoch 59/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0033 - loss: 1.8881e-05 - val_MAE: 0.0024 - val_loss: 9.7769e-06 - learning_rate: 1.0000e-05
# Epoch 60/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0033 - loss: 1.8439e-05 - val_MAE: 0.0024 - val_loss: 9.7681e-06 - learning_rate: 1.0000e-05
# Epoch 61/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0033 - loss: 1.8783e-05 - val_MAE: 0.0024 - val_loss: 9.7834e-06 - learning_rate: 1.0000e-05
# Epoch 62/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAE: 0.0033 - loss: 1.8092e-05 - val_MAE: 0.0024 - val_loss: 9.7724e-06 - learning_rate: 1.0000e-05
# Epoch 63/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0032 - loss: 1.7507e-05 - val_MAE: 0.0024 - val_loss: 9.7725e-06 - learning_rate: 1.0000e-05
# Epoch 64/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0033 - loss: 1.9425e-05 - val_MAE: 0.0024 - val_loss: 9.7978e-06 - learning_rate: 1.0000e-05
# Epoch 65/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0033 - loss: 1.8679e-05 - val_MAE: 0.0024 - val_loss: 9.7665e-06 - learning_rate: 1.0000e-05
# Epoch 66/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0033 - loss: 1.9124e-05 - val_MAE: 0.0024 - val_loss: 9.7702e-06 - learning_rate: 1.0000e-05
# Epoch 67/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAE: 0.0033 - loss: 1.8738e-05 - val_MAE: 0.0024 - val_loss: 9.7816e-06 - learning_rate: 1.0000e-05
# Epoch 68/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAE: 0.0033 - loss: 1.8098e-05 - val_MAE: 0.0024 - val_loss: 9.7691e-06 - learning_rate: 1.0000e-05
# Epoch 69/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAE: 0.0033 - loss: 1.9304e-05 - val_MAE: 0.0024 - val_loss: 9.7616e-06 - learning_rate: 1.0000e-05
# Epoch 70/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0034 - loss: 1.9229e-05 - val_MAE: 0.0024 - val_loss: 9.7622e-06 - learning_rate: 1.0000e-05
# Epoch 71/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAE: 0.0033 - loss: 1.8676e-05 - val_MAE: 0.0024 - val_loss: 9.7805e-06 - learning_rate: 1.0000e-05
# Epoch 72/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0032 - loss: 1.8540e-05 - val_MAE: 0.0024 - val_loss: 9.7647e-06 - learning_rate: 1.0000e-05
# Epoch 73/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0031 - loss: 1.7076e-05 - val_MAE: 0.0024 - val_loss: 9.7785e-06 - learning_rate: 1.0000e-05
# Epoch 74/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0034 - loss: 2.1675e-05 - val_MAE: 0.0024 - val_loss: 9.7596e-06 - learning_rate: 1.0000e-05
# Epoch 75/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0033 - loss: 1.7504e-05 - val_MAE: 0.0024 - val_loss: 9.7683e-06 - learning_rate: 1.0000e-05
# Epoch 76/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAE: 0.0033 - loss: 1.7558e-05 - val_MAE: 0.0024 - val_loss: 9.7609e-06 - learning_rate: 1.0000e-05
# Epoch 77/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0033 - loss: 1.8403e-05 - val_MAE: 0.0024 - val_loss: 9.7579e-06 - learning_rate: 1.0000e-05
# Epoch 78/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAE: 0.0033 - loss: 1.8327e-05 - val_MAE: 0.0024 - val_loss: 9.7715e-06 - learning_rate: 1.0000e-05
# Epoch 79/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0033 - loss: 1.9253e-05 - val_MAE: 0.0024 - val_loss: 9.7579e-06 - learning_rate: 1.0000e-05
# Epoch 80/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0033 - loss: 1.8635e-05 - val_MAE: 0.0024 - val_loss: 9.7714e-06 - learning_rate: 1.0000e-05
# Epoch 81/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0033 - loss: 1.8713e-05 - val_MAE: 0.0024 - val_loss: 9.7709e-06 - learning_rate: 1.0000e-05
# Epoch 82/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAE: 0.0033 - loss: 1.8653e-05 - val_MAE: 0.0024 - val_loss: 9.7555e-06 - learning_rate: 1.0000e-05
# Epoch 83/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0033 - loss: 1.8652e-05 - val_MAE: 0.0024 - val_loss: 9.7557e-06 - learning_rate: 1.0000e-05
# Epoch 84/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAE: 0.0032 - loss: 1.7183e-05 - val_MAE: 0.0024 - val_loss: 9.7576e-06 - learning_rate: 1.0000e-05
# Epoch 85/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0032 - loss: 1.7690e-05 - val_MAE: 0.0024 - val_loss: 9.7551e-06 - learning_rate: 1.0000e-05
# Epoch 86/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0033 - loss: 1.8849e-05 - val_MAE: 0.0024 - val_loss: 9.7526e-06 - learning_rate: 1.0000e-05
# Epoch 87/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0032 - loss: 1.7823e-05 - val_MAE: 0.0024 - val_loss: 9.7563e-06 - learning_rate: 1.0000e-05
# Epoch 88/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0033 - loss: 1.8294e-05 - val_MAE: 0.0024 - val_loss: 9.7698e-06 - learning_rate: 1.0000e-05
# Epoch 89/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - MAE: 0.0033 - loss: 1.8171e-05 - val_MAE: 0.0024 - val_loss: 9.7712e-06 - learning_rate: 1.0000e-05
# Epoch 90/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAE: 0.0033 - loss: 1.8361e-05 - val_MAE: 0.0024 - val_loss: 9.7523e-06 - learning_rate: 1.0000e-05
# Epoch 91/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAE: 0.0033 - loss: 1.8605e-05 - val_MAE: 0.0024 - val_loss: 9.7521e-06 - learning_rate: 1.0000e-05
# Epoch 92/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0034 - loss: 1.9040e-05 - val_MAE: 0.0024 - val_loss: 9.7646e-06 - learning_rate: 1.0000e-05
# Epoch 93/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0032 - loss: 1.7321e-05 - val_MAE: 0.0024 - val_loss: 9.7504e-06 - learning_rate: 1.0000e-05
# Epoch 94/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0032 - loss: 1.7686e-05 - val_MAE: 0.0024 - val_loss: 9.7519e-06 - learning_rate: 1.0000e-05
# Epoch 95/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0034 - loss: 2.0437e-05 - val_MAE: 0.0024 - val_loss: 9.7491e-06 - learning_rate: 1.0000e-05
# Epoch 96/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0034 - loss: 2.0297e-05 - val_MAE: 0.0024 - val_loss: 9.7494e-06 - learning_rate: 1.0000e-05
# Epoch 97/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0033 - loss: 1.8967e-05 - val_MAE: 0.0024 - val_loss: 9.7492e-06 - learning_rate: 1.0000e-05
# Epoch 98/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAE: 0.0033 - loss: 2.0199e-05 - val_MAE: 0.0024 - val_loss: 9.7990e-06 - learning_rate: 1.0000e-05
# Epoch 99/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0033 - loss: 1.9094e-05 - val_MAE: 0.0024 - val_loss: 9.7491e-06 - learning_rate: 1.0000e-05
# Epoch 100/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0033 - loss: 1.8764e-05 - val_MAE: 0.0024 - val_loss: 9.7514e-06 - learning_rate: 1.0000e-05
# RMSprop Optimizer - Loss (MSE): 0.000010, Mean Absolute Error: 0.002391
#
# Training with SGD optimizer and swish activation function...
# Epoch 1/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - MAE: 0.0032 - loss: 1.7444e-05 - val_MAE: 0.0024 - val_loss: 9.7484e-06 - learning_rate: 0.0100
# Epoch 2/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0032 - loss: 1.7714e-05 - val_MAE: 0.0024 - val_loss: 9.7691e-06 - learning_rate: 0.0100
# Epoch 3/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0032 - loss: 1.6955e-05 - val_MAE: 0.0024 - val_loss: 9.7703e-06 - learning_rate: 0.0100
# Epoch 4/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAE: 0.0032 - loss: 1.7969e-05 - val_MAE: 0.0024 - val_loss: 9.7694e-06 - learning_rate: 0.0100
# Epoch 5/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0033 - loss: 1.8318e-05 - val_MAE: 0.0024 - val_loss: 9.7870e-06 - learning_rate: 0.0100
# Epoch 6/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0033 - loss: 1.8837e-05 - val_MAE: 0.0024 - val_loss: 9.7451e-06 - learning_rate: 0.0100
# Epoch 7/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAE: 0.0034 - loss: 2.0271e-05 - val_MAE: 0.0024 - val_loss: 9.8622e-06 - learning_rate: 0.0020
# Epoch 8/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0032 - loss: 1.7370e-05 - val_MAE: 0.0024 - val_loss: 9.7458e-06 - learning_rate: 0.0020
# Epoch 9/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0034 - loss: 1.9928e-05 - val_MAE: 0.0024 - val_loss: 9.7600e-06 - learning_rate: 0.0020
# Epoch 10/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0033 - loss: 1.9817e-05 - val_MAE: 0.0024 - val_loss: 9.7465e-06 - learning_rate: 0.0020
# Epoch 11/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0034 - loss: 1.9807e-05 - val_MAE: 0.0024 - val_loss: 9.7572e-06 - learning_rate: 0.0020
# Epoch 12/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0034 - loss: 1.9564e-05 - val_MAE: 0.0024 - val_loss: 9.7910e-06 - learning_rate: 4.0000e-04
# Epoch 13/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0032 - loss: 1.7967e-05 - val_MAE: 0.0024 - val_loss: 9.7620e-06 - learning_rate: 4.0000e-04
# Epoch 14/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0033 - loss: 1.9940e-05 - val_MAE: 0.0024 - val_loss: 9.7468e-06 - learning_rate: 4.0000e-04
# Epoch 15/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0032 - loss: 1.7085e-05 - val_MAE: 0.0024 - val_loss: 9.7533e-06 - learning_rate: 4.0000e-04
# Epoch 16/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0033 - loss: 1.8960e-05 - val_MAE: 0.0024 - val_loss: 9.7475e-06 - learning_rate: 4.0000e-04
# SGD Optimizer - Loss (MSE): 0.000010, Mean Absolute Error: 0.002390

# %%
print(all_mae_values)
print(all_loss_values)
print(all_labels)
# Out:
# [0.0043005249463021755, 0.003487584413960576, 0.0034749547485262156, 0.0035370353143662214, 0.0030411635525524616, 0.003209215123206377, 0.002441342221572995, 0.0024525574408471584, 0.002431383589282632, 0.003997279331088066, 0.003215201897546649, 0.0032139599788933992, 0.0023718802258372307, 0.002390744397416711, 0.002390356035903096]
# [3.1224870326695964e-05, 2.0394396415213123e-05, 2.032488555414602e-05, 2.113662048941478e-05, 1.5154093489400111e-05, 1.7985703379963525e-05, 1.0521250260353554e-05, 1.0183507583860774e-05, 1.0077435945277102e-05, 2.7024974770029075e-05, 1.752887874317821e-05, 1.763896580087021e-05, 9.62617286859313e-06, 9.749097444000654e-06, 9.745136594574433e-06]
# ['relu, Adamax', 'relu, RMSprop', 'relu, SGD', 'leaky_relu, Adamax', 'leaky_relu, RMSprop', 'leaky_relu, SGD', 'elu, Adamax', 'elu, RMSprop', 'elu, SGD', 'prelu, Adamax', 'prelu, RMSprop', 'prelu, SGD', 'swish, Adamax', 'swish, RMSprop', 'swish, SGD']

# %%
# Create a DataFrame
chd_models_df = pd.DataFrame({
    'Model': all_labels, 
    'Activation_Function': all_activation_functions , 
    'Optimizer': all_optimizers, 
    'MAE': all_mae_values, 
    'Loss': all_loss_values
})

chd_models_df
# Out:
#                   Model Activation_Function Optimizer       MAE      Loss
# 0          relu, Adamax                relu    Adamax  0.004301  0.000031
# 1         relu, RMSprop                relu   RMSprop  0.003488  0.000020
# 2             relu, SGD                relu       SGD  0.003475  0.000020
# 3    leaky_relu, Adamax          leaky_relu    Adamax  0.003537  0.000021
# 4   leaky_relu, RMSprop          leaky_relu   RMSprop  0.003041  0.000015
# 5       leaky_relu, SGD          leaky_relu       SGD  0.003209  0.000018
# 6           elu, Adamax                 elu    Adamax  0.002441  0.000011
# 7          elu, RMSprop                 elu   RMSprop  0.002453  0.000010
# 8              elu, SGD                 elu       SGD  0.002431  0.000010
# 9         prelu, Adamax               prelu    Adamax  0.003997  0.000027
# 10       prelu, RMSprop               prelu   RMSprop  0.003215  0.000018
# 11           prelu, SGD               prelu       SGD  0.003214  0.000018
# 12        swish, Adamax               swish    Adamax  0.002372  0.000010
# 13       swish, RMSprop               swish   RMSprop  0.002391  0.000010
# 14           swish, SGD               swish       SGD  0.002390  0.000010

# %%
# Plotting
fig, ax1 = plt.subplots(figsize=(14, 8))

# Bar plot for Accuracy
color = 'tab:blue'
ax1.set_xlabel('Model')
ax1.set_ylabel('Mean Absolute Error', color=color)
ax1.bar(chd_models_df['Model'], chd_models_df['MAE'], color=color, alpha=0.6, label='MAE')
ax1.tick_params(axis='y', labelcolor=color)
ax1.set_xticks(range(len(chd_models_df['Model'])))
ax1.set_xticklabels(chd_models_df['Model'], rotation=90)

# Create a second y-axis for Loss
ax2 = ax1.twinx()
color = 'tab:red'
ax2.set_ylabel('Loss (MSE)', color=color)
ax2.plot(chd_models_df['Model'], chd_models_df['Loss'], color=color, marker='o', linestyle='-', linewidth=2, markersize=8, label='Loss')
ax2.tick_params(axis='y', labelcolor=color)

# Title and layout
plt.title('MAE and Loss for Chronic Heart Disease Models')
fig.tight_layout()
plt.show()

# %%
# Rank the models based on MAE (lower is better)
chd_models_df['MAE_Rank'] = chd_models_df['MAE'].rank()

# Rank the models based on Loss (lower is better)
chd_models_df['Loss_Rank'] = chd_models_df['Loss'].rank()

# Calculate the average rank
chd_models_df['Average_Rank'] = (chd_models_df['MAE_Rank'] + chd_models_df['Loss_Rank']) / 2

# Find the top two ranked models
best_model_avg_rank = chd_models_df.sort_values('Average_Rank').iloc[0]
print(best_model_avg_rank)
# Out:
# Model                  swish, Adamax
# Activation_Function            swish
# Optimizer                     Adamax
# MAE                         0.002372
# Loss                         0.00001
# MAE_Rank                         1.0
# Loss_Rank                        1.0
# Average_Rank                     1.0
# Name: 12, dtype: object

# %%
# Initialize train and get predictions with the random forest regressor
chd_rf = RandomForestRegressor(n_estimators=500, random_state=78)
chd_rf.fit(X_train, y_train)
predictions = chd_rf.predict(X_test)

# Evaluate using MAE MSE RMSE and R2 metrics
mae = mean_absolute_error(y_test, predictions)
mse = mean_squared_error(y_test, predictions)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, predictions)

# Print Evaluation Metrics
print(f"MAE: {mae}")
print(f"MSE: {mse}")
print(f"RMSE: {rmse}")
print(f"R²: {r2}")
# Out:
# MAE: 0.00226032769830949
# MSE: 9.15610218985695e-06
# RMSE: 0.003025905185206065
# R²: 0.881870567942117

# %%
# Get Feature Importance
importances = chd_rf.feature_importances_

# Extract feature names
feature_names = chd_df.drop(columns=['target_chd', 'county_index']).columns

# Visualize the features by importance
importances_df = pd.DataFrame(sorted(zip(chd_rf.feature_importances_, feature_names), reverse=True))
importances_df.set_index(importances_df[1], inplace=True)
importances_df.drop(columns=1, inplace=True)
importances_df.rename(columns={0: 'Feature Importances'}, inplace=True)
importances_sorted = importances_df.sort_values(by='Feature Importances')
importances_sorted.plot(kind='barh', color='lightgreen', title= 'CHD Features Importances', legend=False)
# Out:
# <Axes: title={'center': 'CHD Features Importances'}, ylabel='1'>
