# %%
import warnings
from pathlib import Path
import pandas as pd
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Dense, Dropout, Input, Activation
from keras.optimizers import Adamax, RMSprop, SGD
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from keras.layers import LeakyReLU, ELU, PReLU
import tensorflow as tf
from tensorflow.keras.callbacks import EarlyStopping
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

# %%
# File Path
cancer_data_to_load = Path("../Outputs/CANCER_sdoh_access.csv")

# Read shcool metrics into Pandas DataFrames
cancer_df = pd.read_csv(cancer_data_to_load)

cancer_df.head()
# Out:
#    county_index  target_cancer  AGE65  BROAD  CROWD  HCOST  NOHSDP  POV150  \
# 0          1001            6.3   15.1   14.5    1.5   21.5    10.4    21.7
# 1          1011            5.5   16.2   40.6    0.8   23.9    22.4    46.0
# 2          1021            6.3   16.4   21.7    2.9   16.1    18.2    26.5
# 3          1029            6.4   19.2   27.2    2.1   18.1    16.9    27.3
# 4          1049            6.3   16.9   20.1    3.3   20.9    21.8    35.4
#
#    REMNRTY  SNGPNT  UNEMP  No_Vehicle_10_Miles  No_Vehicle_1_Mile  \
# 0     26.9     7.1    2.8             0.406809           1.528284
# 1     79.6    14.5    3.0             0.733003           3.060290
# 2     20.7     4.5    6.4             0.025205           1.416035
# 3      7.6     4.5    4.5             0.073470           1.302431
# 4     20.4     5.8    4.3             0.000000           1.492076
#
#    No_Vehicle_Half_Mile
# 0              1.914937
# 1              3.967381
# 2              1.718489
# 3              1.436014
# 4              1.816929

# %%
# Divide the percentage values by 100 to prepare for Neural Network
columns_to_scale = cancer_df.dtypes[cancer_df.dtypes == "float64"].index.tolist()
cancer_df[columns_to_scale] = cancer_df[columns_to_scale] / 100
cancer_df.head()
# Out:
#    county_index  target_cancer  AGE65  BROAD  CROWD  HCOST  NOHSDP  POV150  \
# 0          1001          0.063  0.151  0.145  0.015  0.215   0.104   0.217
# 1          1011          0.055  0.162  0.406  0.008  0.239   0.224   0.460
# 2          1021          0.063  0.164  0.217  0.029  0.161   0.182   0.265
# 3          1029          0.064  0.192  0.272  0.021  0.181   0.169   0.273
# 4          1049          0.063  0.169  0.201  0.033  0.209   0.218   0.354
#
#    REMNRTY  SNGPNT  UNEMP  No_Vehicle_10_Miles  No_Vehicle_1_Mile  \
# 0    0.269   0.071  0.028             0.004068           0.015283
# 1    0.796   0.145  0.030             0.007330           0.030603
# 2    0.207   0.045  0.064             0.000252           0.014160
# 3    0.076   0.045  0.045             0.000735           0.013024
# 4    0.204   0.058  0.043             0.000000           0.014921
#
#    No_Vehicle_Half_Mile
# 0              0.019149
# 1              0.039674
# 2              0.017185
# 3              0.014360
# 4              0.018169

# %%
# Split data into our features and target arrays
y = cancer_df['target_cancer'].values
X = cancer_df.drop(columns = ['target_cancer', 'county_index']).values

# Split the arrays into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=12)

# Data was prescaled manually so set values to work with the train_model function
X_train_scaled = X_train
X_test_scaled = X_test

input_shape = len(X_train[0])

# %% [markdown]
# ## Neural Network Optimization Function

# %%
def train_model(X_train_scaled, y_train, X_test_scaled, y_test, activation_func='relu'):
    """
    Train a neural network with specified activation function and multiple optimizers.

    Args:
    - X_train_scaled: Scaled training data
    - y_train: Labels for training data
    - X_test_scaled: Scaled test data
    - y_test: Labels for test data
    - activation_func: Activation function to use (e.g., 'relu', 'leaky_relu', 'elu', 'prelu', 'swish')

    Returns:
    - mae_list2: List of mean absolute error for each optimizer
    - loss_list2: List of losses (MSE) for each optimizer
    """
    
    # Custom activation handling
    def get_activation(activation):
        if activation == 'leaky_relu':
            return LeakyReLU(alpha=0.1)  # Custom activation layer
        elif activation == 'elu':
            return ELU(alpha=1.0)  # Custom activation layer
        elif activation == 'prelu':
            return PReLU()  # Custom activation layer
        elif activation == 'swish':  # Or silu
            return Activation(tf.keras.activations.swish)  # Wrap as Activation layer
        else:
            return activation  # For standard activations like 'relu', 'sigmoid', etc.
    
    # Build model
    nn = tf.keras.models.Sequential()

    # Add the input layer
    nn.add(tf.keras.layers.Input(shape=(input_shape,)))
    
    # First hidden layer
    if isinstance(get_activation(activation_func), str):  # If it's a standard activation
        nn.add(tf.keras.layers.Dense(units=128, activation=get_activation(activation_func)))  # Use activation as string
    else:  # If it's a custom activation layer
        nn.add(tf.keras.layers.Dense(units=128))
        nn.add(get_activation(activation_func))  # Add custom activation layer
    
    # Dropout and subsequent layers
    nn.add(Dropout(0.3))
    if isinstance(get_activation(activation_func), str):
        nn.add(tf.keras.layers.Dense(units=64, activation=get_activation(activation_func)))
    else:
        nn.add(tf.keras.layers.Dense(units=64))
        nn.add(get_activation(activation_func))
    
    nn.add(Dropout(0.3))
    if isinstance(get_activation(activation_func), str):
        nn.add(tf.keras.layers.Dense(units=32, activation=get_activation(activation_func)))
    else:
        nn.add(tf.keras.layers.Dense(units=32))
        nn.add(get_activation(activation_func))
    
    # Output layer (for continuous data)
    nn.add(tf.keras.layers.Dense(units=1, activation="linear"))

    # Experiment with different optimizers
    optimizers = {
        'Adamax': Adamax(learning_rate=0.002),
        'RMSprop': RMSprop(learning_rate=0.001),
        'SGD': SGD(learning_rate=0.01, momentum=0.9)
    }

    mae_list2 = []
    loss_list2 = []

    # Iterate through each optimizer
    for name, optimizer in optimizers.items():
        print(f"\nTraining with {name} optimizer and {activation_func} activation function...")
        nn.compile(optimizer=optimizer, loss="mean_squared_error", metrics=["MAE"])

        # Callbacks
        early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
        reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=0.00001)

        # Train the model
        nn.fit(X_train_scaled, y_train, epochs=100, validation_data=(X_test_scaled, y_test),
               callbacks=[early_stopping, reduce_lr], verbose=1)

        # Evaluate the model
        loss, mae = nn.evaluate(X_test_scaled, y_test, verbose=0)
        print(f"{name} Optimizer - Loss (MSE): {loss:.6f}, Mean Absolute Error: {mae:.6f}")
        mae_list2.append(mae)
        loss_list2.append(loss)
    
    return mae_list2, loss_list2

# %%
all_mae_values = []
all_loss_values = []
all_labels = []
all_activation_functions = []
all_optimizers = []

activation_functions = ['relu', 'leaky_relu', 'elu', 'prelu', 'swish']
optimizers = ['Adamax', 'RMSprop', 'SGD']

for activation in activation_functions:
    print(f"\nRunning for activation function: {activation}")
    mae_list, loss_list = train_model(X_train_scaled, y_train, X_test_scaled, y_test, activation_func=activation)
    
    # Append the Mean Absolute Error, loss values and labels for this activation function
    all_mae_values.extend(mae_list)
    all_loss_values.extend(loss_list)
    
    # Create labels combining activation function and optimizer
    for optimizer in optimizers:
        all_labels.append(f"{activation}, {optimizer}")
        all_activation_functions.append(activation)
        all_optimizers.append(optimizer)
# Out:
# Running for activation function: relu
#
# Training with Adamax optimizer and relu activation function...
# Epoch 1/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - MAE: 0.0260 - loss: 0.0013 - val_MAE: 0.0113 - val_loss: 1.6442e-04 - learning_rate: 0.0020
# Epoch 2/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0104 - loss: 1.9687e-04 - val_MAE: 0.0059 - val_loss: 5.0824e-05 - learning_rate: 0.0020
# Epoch 3/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0073 - loss: 1.0594e-04 - val_MAE: 0.0033 - val_loss: 2.0218e-05 - learning_rate: 0.0020
# Epoch 4/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0055 - loss: 6.7724e-05 - val_MAE: 0.0036 - val_loss: 2.0045e-05 - learning_rate: 0.0020
# Epoch 5/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0046 - loss: 4.3523e-05 - val_MAE: 0.0030 - val_loss: 1.3775e-05 - learning_rate: 0.0020
# Epoch 6/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0038 - loss: 2.9935e-05 - val_MAE: 0.0029 - val_loss: 1.1937e-05 - learning_rate: 0.0020
# Epoch 7/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0034 - loss: 2.6214e-05 - val_MAE: 0.0025 - val_loss: 1.0693e-05 - learning_rate: 0.0020
# Epoch 8/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0034 - loss: 2.5697e-05 - val_MAE: 0.0026 - val_loss: 1.0474e-05 - learning_rate: 4.0000e-04
# Epoch 9/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0031 - loss: 2.0009e-05 - val_MAE: 0.0026 - val_loss: 1.0280e-05 - learning_rate: 4.0000e-04
# Epoch 10/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0029 - loss: 1.9238e-05 - val_MAE: 0.0026 - val_loss: 1.0481e-05 - learning_rate: 4.0000e-04
# Epoch 11/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0031 - loss: 2.3281e-05 - val_MAE: 0.0025 - val_loss: 1.0991e-05 - learning_rate: 4.0000e-04
# Epoch 12/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0030 - loss: 1.9402e-05 - val_MAE: 0.0025 - val_loss: 1.0345e-05 - learning_rate: 4.0000e-04
# Epoch 13/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0030 - loss: 2.1980e-05 - val_MAE: 0.0025 - val_loss: 1.0356e-05 - learning_rate: 8.0000e-05
# Epoch 14/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0029 - loss: 1.9628e-05 - val_MAE: 0.0025 - val_loss: 1.0280e-05 - learning_rate: 8.0000e-05
# Epoch 15/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0028 - loss: 1.6143e-05 - val_MAE: 0.0025 - val_loss: 1.0228e-05 - learning_rate: 8.0000e-05
# Epoch 16/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0028 - loss: 1.7948e-05 - val_MAE: 0.0025 - val_loss: 1.0085e-05 - learning_rate: 8.0000e-05
# Epoch 17/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0029 - loss: 1.7034e-05 - val_MAE: 0.0025 - val_loss: 1.0171e-05 - learning_rate: 8.0000e-05
# Epoch 18/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0029 - loss: 2.3122e-05 - val_MAE: 0.0025 - val_loss: 1.0204e-05 - learning_rate: 1.6000e-05
# Epoch 19/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0029 - loss: 1.9220e-05 - val_MAE: 0.0025 - val_loss: 1.0166e-05 - learning_rate: 1.6000e-05
# Epoch 20/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0029 - loss: 2.0210e-05 - val_MAE: 0.0025 - val_loss: 1.0138e-05 - learning_rate: 1.6000e-05
# Epoch 21/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0029 - loss: 1.8972e-05 - val_MAE: 0.0025 - val_loss: 1.0160e-05 - learning_rate: 1.6000e-05
# Epoch 22/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0029 - loss: 1.9953e-05 - val_MAE: 0.0025 - val_loss: 1.0143e-05 - learning_rate: 1.6000e-05
# Epoch 23/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0029 - loss: 1.8123e-05 - val_MAE: 0.0025 - val_loss: 1.0218e-05 - learning_rate: 1.0000e-05
# Epoch 24/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0027 - loss: 1.6632e-05 - val_MAE: 0.0025 - val_loss: 1.0150e-05 - learning_rate: 1.0000e-05
# Epoch 25/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0027 - loss: 1.6630e-05 - val_MAE: 0.0025 - val_loss: 1.0188e-05 - learning_rate: 1.0000e-05
# Epoch 26/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0028 - loss: 1.8271e-05 - val_MAE: 0.0025 - val_loss: 1.0249e-05 - learning_rate: 1.0000e-05
# Adamax Optimizer - Loss (MSE): 0.000010, Mean Absolute Error: 0.002511
#
# Training with RMSprop optimizer and relu activation function...
# Epoch 1/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - MAE: 0.0036 - loss: 2.4441e-05 - val_MAE: 0.0038 - val_loss: 2.2195e-05 - learning_rate: 0.0010
# Epoch 2/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0028 - loss: 1.7295e-05 - val_MAE: 0.0021 - val_loss: 9.1170e-06 - learning_rate: 0.0010
# Epoch 3/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0029 - loss: 1.7023e-05 - val_MAE: 0.0020 - val_loss: 6.0847e-06 - learning_rate: 0.0010
# Epoch 4/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0027 - loss: 1.3305e-05 - val_MAE: 0.0019 - val_loss: 6.2612e-06 - learning_rate: 0.0010
# Epoch 5/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0026 - loss: 1.2883e-05 - val_MAE: 0.0036 - val_loss: 1.9315e-05 - learning_rate: 0.0010
# Epoch 6/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0027 - loss: 1.1697e-05 - val_MAE: 0.0019 - val_loss: 6.4638e-06 - learning_rate: 0.0010
# Epoch 7/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0018 - loss: 8.1568e-06 - val_MAE: 0.0021 - val_loss: 9.1959e-06 - learning_rate: 2.0000e-04
# Epoch 8/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0018 - loss: 8.2266e-06 - val_MAE: 0.0020 - val_loss: 8.4290e-06 - learning_rate: 2.0000e-04
# Epoch 9/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0018 - loss: 8.1447e-06 - val_MAE: 0.0019 - val_loss: 7.7778e-06 - learning_rate: 2.0000e-04
# Epoch 10/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0018 - loss: 7.5034e-06 - val_MAE: 0.0018 - val_loss: 5.9518e-06 - learning_rate: 2.0000e-04
# Epoch 11/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0018 - loss: 7.3853e-06 - val_MAE: 0.0019 - val_loss: 7.3283e-06 - learning_rate: 2.0000e-04
# Epoch 12/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0017 - loss: 6.9570e-06 - val_MAE: 0.0018 - val_loss: 7.0229e-06 - learning_rate: 4.0000e-05
# Epoch 13/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0017 - loss: 6.5759e-06 - val_MAE: 0.0019 - val_loss: 7.4571e-06 - learning_rate: 4.0000e-05
# Epoch 14/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0016 - loss: 5.5209e-06 - val_MAE: 0.0018 - val_loss: 6.2911e-06 - learning_rate: 4.0000e-05
# Epoch 15/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0018 - loss: 8.3836e-06 - val_MAE: 0.0019 - val_loss: 7.2910e-06 - learning_rate: 4.0000e-05
# Epoch 16/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0017 - loss: 6.8707e-06 - val_MAE: 0.0019 - val_loss: 7.8295e-06 - learning_rate: 4.0000e-05
# Epoch 17/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0017 - loss: 7.2186e-06 - val_MAE: 0.0019 - val_loss: 7.2654e-06 - learning_rate: 1.0000e-05
# Epoch 18/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0017 - loss: 6.6806e-06 - val_MAE: 0.0018 - val_loss: 7.0950e-06 - learning_rate: 1.0000e-05
# Epoch 19/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0017 - loss: 7.0921e-06 - val_MAE: 0.0018 - val_loss: 7.1731e-06 - learning_rate: 1.0000e-05
# Epoch 20/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0016 - loss: 6.5727e-06 - val_MAE: 0.0019 - val_loss: 7.3778e-06 - learning_rate: 1.0000e-05
# RMSprop Optimizer - Loss (MSE): 0.000006, Mean Absolute Error: 0.001758
#
# Training with SGD optimizer and relu activation function...
# Epoch 1/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - MAE: 0.0017 - loss: 6.8643e-06 - val_MAE: 0.0020 - val_loss: 8.4149e-06 - learning_rate: 0.0100
# Epoch 2/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0017 - loss: 8.0751e-06 - val_MAE: 0.0019 - val_loss: 7.2382e-06 - learning_rate: 0.0100
# Epoch 3/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0017 - loss: 6.3341e-06 - val_MAE: 0.0019 - val_loss: 7.8882e-06 - learning_rate: 0.0100
# Epoch 4/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0017 - loss: 7.0849e-06 - val_MAE: 0.0018 - val_loss: 7.0991e-06 - learning_rate: 0.0100
# Epoch 5/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0017 - loss: 6.4915e-06 - val_MAE: 0.0020 - val_loss: 8.1105e-06 - learning_rate: 0.0100
# Epoch 6/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0017 - loss: 7.1579e-06 - val_MAE: 0.0020 - val_loss: 8.3542e-06 - learning_rate: 0.0100
# Epoch 7/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0017 - loss: 6.7468e-06 - val_MAE: 0.0019 - val_loss: 7.3420e-06 - learning_rate: 0.0020
# Epoch 8/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0018 - loss: 7.7713e-06 - val_MAE: 0.0019 - val_loss: 7.3537e-06 - learning_rate: 0.0020
# Epoch 9/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0017 - loss: 7.7663e-06 - val_MAE: 0.0018 - val_loss: 6.8766e-06 - learning_rate: 0.0020
# Epoch 10/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0018 - loss: 8.1915e-06 - val_MAE: 0.0019 - val_loss: 7.3476e-06 - learning_rate: 0.0020
# Epoch 11/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0017 - loss: 6.3988e-06 - val_MAE: 0.0018 - val_loss: 7.1460e-06 - learning_rate: 0.0020
# Epoch 12/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0016 - loss: 6.5493e-06 - val_MAE: 0.0019 - val_loss: 7.3718e-06 - learning_rate: 4.0000e-04
# Epoch 13/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0017 - loss: 6.7069e-06 - val_MAE: 0.0019 - val_loss: 7.3157e-06 - learning_rate: 4.0000e-04
# Epoch 14/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0016 - loss: 6.7333e-06 - val_MAE: 0.0019 - val_loss: 7.3370e-06 - learning_rate: 4.0000e-04
# Epoch 15/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0016 - loss: 6.2865e-06 - val_MAE: 0.0019 - val_loss: 7.2887e-06 - learning_rate: 4.0000e-04
# Epoch 16/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0017 - loss: 7.5458e-06 - val_MAE: 0.0019 - val_loss: 7.2134e-06 - learning_rate: 4.0000e-04
# Epoch 17/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0017 - loss: 7.3357e-06 - val_MAE: 0.0018 - val_loss: 7.1873e-06 - learning_rate: 8.0000e-05
# Epoch 18/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0017 - loss: 7.6180e-06 - val_MAE: 0.0019 - val_loss: 7.1985e-06 - learning_rate: 8.0000e-05
# Epoch 19/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0017 - loss: 6.9366e-06 - val_MAE: 0.0018 - val_loss: 7.1974e-06 - learning_rate: 8.0000e-05
# SGD Optimizer - Loss (MSE): 0.000007, Mean Absolute Error: 0.001826
#
# Running for activation function: leaky_relu
#
# Training with Adamax optimizer and leaky_relu activation function...
# Epoch 1/100
# C:\Users\ecros\anaconda3\envs\dev\lib\site-packages\keras\src\layers\activations\leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - MAE: 0.0210 - loss: 8.9792e-04 - val_MAE: 0.0123 - val_loss: 1.6172e-04 - learning_rate: 0.0020
# Epoch 2/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0077 - loss: 1.0321e-04 - val_MAE: 0.0037 - val_loss: 1.7723e-05 - learning_rate: 0.0020
# Epoch 3/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0057 - loss: 6.0657e-05 - val_MAE: 0.0030 - val_loss: 1.1949e-05 - learning_rate: 0.0020
# Epoch 4/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0044 - loss: 3.6228e-05 - val_MAE: 0.0022 - val_loss: 6.7886e-06 - learning_rate: 0.0020
# Epoch 5/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0039 - loss: 3.0122e-05 - val_MAE: 0.0020 - val_loss: 5.6129e-06 - learning_rate: 0.0020
# Epoch 6/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0034 - loss: 2.1516e-05 - val_MAE: 0.0017 - val_loss: 4.4981e-06 - learning_rate: 0.0020
# Epoch 7/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0029 - loss: 1.5853e-05 - val_MAE: 0.0015 - val_loss: 3.8382e-06 - learning_rate: 0.0020
# Epoch 8/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0029 - loss: 1.7210e-05 - val_MAE: 0.0014 - val_loss: 3.6736e-06 - learning_rate: 4.0000e-04
# Epoch 9/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0027 - loss: 1.5115e-05 - val_MAE: 0.0014 - val_loss: 3.4749e-06 - learning_rate: 4.0000e-04
# Epoch 10/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0027 - loss: 1.4061e-05 - val_MAE: 0.0014 - val_loss: 3.5107e-06 - learning_rate: 4.0000e-04
# Epoch 11/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0025 - loss: 1.3044e-05 - val_MAE: 0.0014 - val_loss: 3.4315e-06 - learning_rate: 4.0000e-04
# Epoch 12/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0025 - loss: 1.3473e-05 - val_MAE: 0.0014 - val_loss: 3.4028e-06 - learning_rate: 4.0000e-04
# Epoch 13/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0026 - loss: 1.2994e-05 - val_MAE: 0.0014 - val_loss: 3.3844e-06 - learning_rate: 8.0000e-05
# Epoch 14/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0024 - loss: 1.1888e-05 - val_MAE: 0.0013 - val_loss: 3.3984e-06 - learning_rate: 8.0000e-05
# Epoch 15/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0025 - loss: 1.2000e-05 - val_MAE: 0.0013 - val_loss: 3.3499e-06 - learning_rate: 8.0000e-05
# Epoch 16/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0026 - loss: 1.4352e-05 - val_MAE: 0.0013 - val_loss: 3.4036e-06 - learning_rate: 8.0000e-05
# Epoch 17/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0025 - loss: 1.4475e-05 - val_MAE: 0.0013 - val_loss: 3.2695e-06 - learning_rate: 8.0000e-05
# Epoch 18/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0025 - loss: 1.3263e-05 - val_MAE: 0.0013 - val_loss: 3.2781e-06 - learning_rate: 1.6000e-05
# Epoch 19/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0026 - loss: 1.4500e-05 - val_MAE: 0.0013 - val_loss: 3.3358e-06 - learning_rate: 1.6000e-05
# Epoch 20/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0024 - loss: 1.2989e-05 - val_MAE: 0.0013 - val_loss: 3.2862e-06 - learning_rate: 1.6000e-05
# Epoch 21/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0025 - loss: 1.4093e-05 - val_MAE: 0.0013 - val_loss: 3.3191e-06 - learning_rate: 1.6000e-05
# Epoch 22/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0024 - loss: 1.0821e-05 - val_MAE: 0.0013 - val_loss: 3.3615e-06 - learning_rate: 1.6000e-05
# Epoch 23/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0025 - loss: 1.2404e-05 - val_MAE: 0.0013 - val_loss: 3.3379e-06 - learning_rate: 1.0000e-05
# Epoch 24/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0025 - loss: 1.3511e-05 - val_MAE: 0.0013 - val_loss: 3.3006e-06 - learning_rate: 1.0000e-05
# Epoch 25/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0025 - loss: 1.3283e-05 - val_MAE: 0.0013 - val_loss: 3.3527e-06 - learning_rate: 1.0000e-05
# Epoch 26/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0024 - loss: 1.1914e-05 - val_MAE: 0.0013 - val_loss: 3.3403e-06 - learning_rate: 1.0000e-05
# Epoch 27/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0026 - loss: 1.4553e-05 - val_MAE: 0.0013 - val_loss: 3.2460e-06 - learning_rate: 1.0000e-05
# Epoch 28/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0025 - loss: 1.3556e-05 - val_MAE: 0.0013 - val_loss: 3.2582e-06 - learning_rate: 1.0000e-05
# Epoch 29/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0024 - loss: 1.1851e-05 - val_MAE: 0.0013 - val_loss: 3.2591e-06 - learning_rate: 1.0000e-05
# Epoch 30/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0026 - loss: 1.3741e-05 - val_MAE: 0.0013 - val_loss: 3.3007e-06 - learning_rate: 1.0000e-05
# Epoch 31/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0025 - loss: 1.3185e-05 - val_MAE: 0.0013 - val_loss: 3.2486e-06 - learning_rate: 1.0000e-05
# Epoch 32/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0025 - loss: 1.2721e-05 - val_MAE: 0.0013 - val_loss: 3.2714e-06 - learning_rate: 1.0000e-05
# Epoch 33/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0024 - loss: 1.4464e-05 - val_MAE: 0.0013 - val_loss: 3.3018e-06 - learning_rate: 1.0000e-05
# Epoch 34/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0024 - loss: 1.1348e-05 - val_MAE: 0.0013 - val_loss: 3.2782e-06 - learning_rate: 1.0000e-05
# Epoch 35/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0023 - loss: 1.0225e-05 - val_MAE: 0.0013 - val_loss: 3.3084e-06 - learning_rate: 1.0000e-05
# Epoch 36/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0024 - loss: 1.2037e-05 - val_MAE: 0.0013 - val_loss: 3.2263e-06 - learning_rate: 1.0000e-05
# Epoch 37/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0025 - loss: 1.0970e-05 - val_MAE: 0.0013 - val_loss: 3.2303e-06 - learning_rate: 1.0000e-05
# Epoch 38/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0024 - loss: 1.1769e-05 - val_MAE: 0.0013 - val_loss: 3.3129e-06 - learning_rate: 1.0000e-05
# Epoch 39/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0024 - loss: 1.1937e-05 - val_MAE: 0.0013 - val_loss: 3.2450e-06 - learning_rate: 1.0000e-05
# Epoch 40/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0025 - loss: 1.3353e-05 - val_MAE: 0.0013 - val_loss: 3.3228e-06 - learning_rate: 1.0000e-05
# Epoch 41/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0024 - loss: 1.2404e-05 - val_MAE: 0.0013 - val_loss: 3.3186e-06 - learning_rate: 1.0000e-05
# Epoch 42/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0024 - loss: 1.1479e-05 - val_MAE: 0.0013 - val_loss: 3.2759e-06 - learning_rate: 1.0000e-05
# Epoch 43/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0024 - loss: 1.1628e-05 - val_MAE: 0.0013 - val_loss: 3.3162e-06 - learning_rate: 1.0000e-05
# Epoch 44/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0024 - loss: 1.0977e-05 - val_MAE: 0.0013 - val_loss: 3.2580e-06 - learning_rate: 1.0000e-05
# Epoch 45/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0023 - loss: 1.0707e-05 - val_MAE: 0.0013 - val_loss: 3.3582e-06 - learning_rate: 1.0000e-05
# Epoch 46/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0023 - loss: 1.1308e-05 - val_MAE: 0.0013 - val_loss: 3.2857e-06 - learning_rate: 1.0000e-05
# Adamax Optimizer - Loss (MSE): 0.000003, Mean Absolute Error: 0.001295
#
# Training with RMSprop optimizer and leaky_relu activation function...
# Epoch 1/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - MAE: 0.0031 - loss: 1.7249e-05 - val_MAE: 0.0015 - val_loss: 3.7467e-06 - learning_rate: 0.0010
# Epoch 2/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0027 - loss: 1.3220e-05 - val_MAE: 0.0013 - val_loss: 3.3666e-06 - learning_rate: 0.0010
# Epoch 3/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0025 - loss: 1.1322e-05 - val_MAE: 0.0014 - val_loss: 3.1832e-06 - learning_rate: 0.0010
# Epoch 4/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0025 - loss: 1.1296e-05 - val_MAE: 0.0014 - val_loss: 3.3222e-06 - learning_rate: 0.0010
# Epoch 5/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0024 - loss: 1.0867e-05 - val_MAE: 0.0014 - val_loss: 4.1263e-06 - learning_rate: 0.0010
# Epoch 6/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0024 - loss: 1.1667e-05 - val_MAE: 0.0031 - val_loss: 1.2588e-05 - learning_rate: 0.0010
# Epoch 7/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0021 - loss: 9.8966e-06 - val_MAE: 0.0012 - val_loss: 3.0219e-06 - learning_rate: 2.0000e-04
# Epoch 8/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0019 - loss: 6.6229e-06 - val_MAE: 0.0012 - val_loss: 2.9539e-06 - learning_rate: 2.0000e-04
# Epoch 9/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0020 - loss: 8.4179e-06 - val_MAE: 0.0013 - val_loss: 3.8070e-06 - learning_rate: 2.0000e-04
# Epoch 10/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0020 - loss: 7.9665e-06 - val_MAE: 0.0012 - val_loss: 3.0701e-06 - learning_rate: 2.0000e-04
# Epoch 11/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0020 - loss: 7.4815e-06 - val_MAE: 0.0013 - val_loss: 3.7995e-06 - learning_rate: 2.0000e-04
# Epoch 12/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0019 - loss: 8.1085e-06 - val_MAE: 0.0013 - val_loss: 3.6321e-06 - learning_rate: 4.0000e-05
# Epoch 13/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0020 - loss: 8.8016e-06 - val_MAE: 0.0012 - val_loss: 3.0583e-06 - learning_rate: 4.0000e-05
# Epoch 14/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0019 - loss: 6.7525e-06 - val_MAE: 0.0012 - val_loss: 3.3282e-06 - learning_rate: 4.0000e-05
# Epoch 15/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0019 - loss: 6.4453e-06 - val_MAE: 0.0012 - val_loss: 3.1163e-06 - learning_rate: 4.0000e-05
# Epoch 16/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0020 - loss: 8.4561e-06 - val_MAE: 0.0013 - val_loss: 3.4787e-06 - learning_rate: 4.0000e-05
# Epoch 17/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0019 - loss: 7.0274e-06 - val_MAE: 0.0012 - val_loss: 3.1946e-06 - learning_rate: 1.0000e-05
# Epoch 18/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0019 - loss: 7.3003e-06 - val_MAE: 0.0012 - val_loss: 3.2519e-06 - learning_rate: 1.0000e-05
# RMSprop Optimizer - Loss (MSE): 0.000003, Mean Absolute Error: 0.001212
#
# Training with SGD optimizer and leaky_relu activation function...
# Epoch 1/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - MAE: 0.0020 - loss: 7.9806e-06 - val_MAE: 0.0012 - val_loss: 3.0572e-06 - learning_rate: 0.0100
# Epoch 2/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0020 - loss: 8.2756e-06 - val_MAE: 0.0012 - val_loss: 3.0137e-06 - learning_rate: 0.0100
# Epoch 3/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0020 - loss: 7.5437e-06 - val_MAE: 0.0012 - val_loss: 3.1271e-06 - learning_rate: 0.0100
# Epoch 4/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0019 - loss: 7.5263e-06 - val_MAE: 0.0012 - val_loss: 3.3460e-06 - learning_rate: 0.0100
# Epoch 5/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0019 - loss: 7.0753e-06 - val_MAE: 0.0012 - val_loss: 3.2692e-06 - learning_rate: 0.0100
# Epoch 6/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0018 - loss: 6.4709e-06 - val_MAE: 0.0012 - val_loss: 2.9990e-06 - learning_rate: 0.0100
# Epoch 7/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0019 - loss: 7.0978e-06 - val_MAE: 0.0012 - val_loss: 3.1796e-06 - learning_rate: 0.0020
# Epoch 8/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0019 - loss: 7.2955e-06 - val_MAE: 0.0012 - val_loss: 3.0195e-06 - learning_rate: 0.0020
# Epoch 9/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0019 - loss: 7.4721e-06 - val_MAE: 0.0012 - val_loss: 3.1463e-06 - learning_rate: 0.0020
# Epoch 10/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0019 - loss: 6.9546e-06 - val_MAE: 0.0012 - val_loss: 3.2120e-06 - learning_rate: 0.0020
# Epoch 11/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0019 - loss: 7.0697e-06 - val_MAE: 0.0012 - val_loss: 3.2233e-06 - learning_rate: 0.0020
# Epoch 12/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0018 - loss: 6.6056e-06 - val_MAE: 0.0012 - val_loss: 3.2031e-06 - learning_rate: 4.0000e-04
# Epoch 13/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0019 - loss: 7.2944e-06 - val_MAE: 0.0012 - val_loss: 3.1522e-06 - learning_rate: 4.0000e-04
# Epoch 14/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0019 - loss: 7.1940e-06 - val_MAE: 0.0012 - val_loss: 3.1884e-06 - learning_rate: 4.0000e-04
# Epoch 15/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0019 - loss: 7.7509e-06 - val_MAE: 0.0012 - val_loss: 3.1261e-06 - learning_rate: 4.0000e-04
# Epoch 16/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0019 - loss: 7.9826e-06 - val_MAE: 0.0012 - val_loss: 3.1962e-06 - learning_rate: 4.0000e-04
# SGD Optimizer - Loss (MSE): 0.000003, Mean Absolute Error: 0.001195
#
# Running for activation function: elu
#
# Training with Adamax optimizer and elu activation function...
# Epoch 1/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - MAE: 0.0856 - loss: 0.0137 - val_MAE: 0.0073 - val_loss: 8.5616e-05 - learning_rate: 0.0020
# Epoch 2/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0328 - loss: 0.0019 - val_MAE: 0.0044 - val_loss: 3.0439e-05 - learning_rate: 0.0020
# Epoch 3/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0249 - loss: 0.0010 - val_MAE: 0.0035 - val_loss: 1.9630e-05 - learning_rate: 0.0020
# Epoch 4/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0191 - loss: 6.2073e-04 - val_MAE: 0.0030 - val_loss: 1.5795e-05 - learning_rate: 0.0020
# Epoch 5/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0158 - loss: 4.3413e-04 - val_MAE: 0.0037 - val_loss: 2.6685e-05 - learning_rate: 0.0020
# Epoch 6/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0138 - loss: 3.3549e-04 - val_MAE: 0.0026 - val_loss: 1.3444e-05 - learning_rate: 0.0020
# Epoch 7/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0121 - loss: 2.5145e-04 - val_MAE: 0.0019 - val_loss: 7.2756e-06 - learning_rate: 4.0000e-04
# Epoch 8/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0115 - loss: 2.4743e-04 - val_MAE: 0.0023 - val_loss: 9.8091e-06 - learning_rate: 4.0000e-04
# Epoch 9/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0117 - loss: 2.4894e-04 - val_MAE: 0.0020 - val_loss: 7.3321e-06 - learning_rate: 4.0000e-04
# Epoch 10/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0106 - loss: 1.9595e-04 - val_MAE: 0.0024 - val_loss: 1.1415e-05 - learning_rate: 4.0000e-04
# Epoch 11/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0105 - loss: 1.9633e-04 - val_MAE: 0.0019 - val_loss: 6.9981e-06 - learning_rate: 4.0000e-04
# Epoch 12/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0101 - loss: 1.7595e-04 - val_MAE: 0.0020 - val_loss: 7.7224e-06 - learning_rate: 8.0000e-05
# Epoch 13/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0101 - loss: 1.7913e-04 - val_MAE: 0.0021 - val_loss: 8.6904e-06 - learning_rate: 8.0000e-05
# Epoch 14/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0101 - loss: 1.7938e-04 - val_MAE: 0.0020 - val_loss: 7.9200e-06 - learning_rate: 8.0000e-05
# Epoch 15/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0102 - loss: 1.8371e-04 - val_MAE: 0.0022 - val_loss: 9.5477e-06 - learning_rate: 8.0000e-05
# Epoch 16/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0101 - loss: 1.8792e-04 - val_MAE: 0.0021 - val_loss: 8.6314e-06 - learning_rate: 8.0000e-05
# Epoch 17/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0103 - loss: 1.8333e-04 - val_MAE: 0.0020 - val_loss: 8.0337e-06 - learning_rate: 1.6000e-05
# Epoch 18/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0100 - loss: 1.6875e-04 - val_MAE: 0.0020 - val_loss: 8.1149e-06 - learning_rate: 1.6000e-05
# Epoch 19/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0098 - loss: 1.6607e-04 - val_MAE: 0.0020 - val_loss: 8.1707e-06 - learning_rate: 1.6000e-05
# Epoch 20/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0102 - loss: 1.8597e-04 - val_MAE: 0.0021 - val_loss: 8.4421e-06 - learning_rate: 1.6000e-05
# Epoch 21/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0098 - loss: 1.7212e-04 - val_MAE: 0.0020 - val_loss: 8.3112e-06 - learning_rate: 1.6000e-05
# Adamax Optimizer - Loss (MSE): 0.000007, Mean Absolute Error: 0.001857
#
# Training with RMSprop optimizer and elu activation function...
# Epoch 1/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - MAE: 0.0133 - loss: 3.3845e-04 - val_MAE: 0.0024 - val_loss: 9.7752e-06 - learning_rate: 0.0010
# Epoch 2/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0070 - loss: 7.8517e-05 - val_MAE: 0.0024 - val_loss: 8.6727e-06 - learning_rate: 0.0010
# Epoch 3/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0053 - loss: 4.4834e-05 - val_MAE: 0.0018 - val_loss: 6.6024e-06 - learning_rate: 0.0010
# Epoch 4/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0051 - loss: 4.1074e-05 - val_MAE: 0.0015 - val_loss: 5.0937e-06 - learning_rate: 0.0010
# Epoch 5/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0044 - loss: 3.1058e-05 - val_MAE: 0.0051 - val_loss: 2.8323e-05 - learning_rate: 0.0010
# Epoch 6/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0044 - loss: 3.1368e-05 - val_MAE: 0.0022 - val_loss: 7.4184e-06 - learning_rate: 0.0010
# Epoch 7/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0021 - loss: 9.8913e-06 - val_MAE: 0.0016 - val_loss: 4.9382e-06 - learning_rate: 2.0000e-04
# Epoch 8/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0021 - loss: 1.0716e-05 - val_MAE: 0.0020 - val_loss: 6.7874e-06 - learning_rate: 2.0000e-04
# Epoch 9/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0021 - loss: 1.1266e-05 - val_MAE: 0.0012 - val_loss: 2.8978e-06 - learning_rate: 2.0000e-04
# Epoch 10/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0021 - loss: 9.9081e-06 - val_MAE: 0.0031 - val_loss: 1.3303e-05 - learning_rate: 2.0000e-04
# Epoch 11/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0021 - loss: 1.0618e-05 - val_MAE: 0.0014 - val_loss: 4.4943e-06 - learning_rate: 2.0000e-04
# Epoch 12/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0019 - loss: 8.3192e-06 - val_MAE: 0.0017 - val_loss: 5.3581e-06 - learning_rate: 4.0000e-05
# Epoch 13/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0018 - loss: 7.8360e-06 - val_MAE: 0.0017 - val_loss: 5.2199e-06 - learning_rate: 4.0000e-05
# Epoch 14/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0018 - loss: 8.0473e-06 - val_MAE: 0.0015 - val_loss: 4.3150e-06 - learning_rate: 4.0000e-05
# Epoch 15/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0019 - loss: 7.4400e-06 - val_MAE: 0.0018 - val_loss: 5.6157e-06 - learning_rate: 4.0000e-05
# Epoch 16/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0019 - loss: 1.0940e-05 - val_MAE: 0.0016 - val_loss: 4.7391e-06 - learning_rate: 4.0000e-05
# Epoch 17/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0019 - loss: 8.6726e-06 - val_MAE: 0.0018 - val_loss: 5.4077e-06 - learning_rate: 1.0000e-05
# Epoch 18/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0019 - loss: 8.1554e-06 - val_MAE: 0.0016 - val_loss: 4.6637e-06 - learning_rate: 1.0000e-05
# Epoch 19/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0018 - loss: 7.5980e-06 - val_MAE: 0.0016 - val_loss: 4.7942e-06 - learning_rate: 1.0000e-05
# RMSprop Optimizer - Loss (MSE): 0.000003, Mean Absolute Error: 0.001188
#
# Training with SGD optimizer and elu activation function...
# Epoch 1/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - MAE: 0.0021 - loss: 1.1368e-05 - val_MAE: 0.0018 - val_loss: 5.8414e-06 - learning_rate: 0.0100
# Epoch 2/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0021 - loss: 1.0217e-05 - val_MAE: 0.0015 - val_loss: 4.4079e-06 - learning_rate: 0.0100
# Epoch 3/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0019 - loss: 8.6744e-06 - val_MAE: 0.0018 - val_loss: 5.5692e-06 - learning_rate: 0.0100
# Epoch 4/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0019 - loss: 8.3846e-06 - val_MAE: 0.0015 - val_loss: 4.5614e-06 - learning_rate: 0.0100
# Epoch 5/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0019 - loss: 8.1353e-06 - val_MAE: 0.0017 - val_loss: 5.5677e-06 - learning_rate: 0.0100
# Epoch 6/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0020 - loss: 1.0133e-05 - val_MAE: 0.0015 - val_loss: 4.4273e-06 - learning_rate: 0.0100
# Epoch 7/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0020 - loss: 8.5982e-06 - val_MAE: 0.0017 - val_loss: 5.1268e-06 - learning_rate: 0.0020
# Epoch 8/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0020 - loss: 1.4032e-05 - val_MAE: 0.0015 - val_loss: 4.6459e-06 - learning_rate: 0.0020
# Epoch 9/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0019 - loss: 8.9890e-06 - val_MAE: 0.0016 - val_loss: 4.8234e-06 - learning_rate: 0.0020
# Epoch 10/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0019 - loss: 9.1350e-06 - val_MAE: 0.0015 - val_loss: 4.6364e-06 - learning_rate: 0.0020
# Epoch 11/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0018 - loss: 7.6646e-06 - val_MAE: 0.0016 - val_loss: 4.9428e-06 - learning_rate: 0.0020
# Epoch 12/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0019 - loss: 8.7945e-06 - val_MAE: 0.0016 - val_loss: 4.8494e-06 - learning_rate: 4.0000e-04
# SGD Optimizer - Loss (MSE): 0.000004, Mean Absolute Error: 0.001498
#
# Running for activation function: prelu
#
# Training with Adamax optimizer and prelu activation function...
# Epoch 1/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - MAE: 0.0192 - loss: 6.3498e-04 - val_MAE: 0.0098 - val_loss: 1.1326e-04 - learning_rate: 0.0020
# Epoch 2/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0084 - loss: 1.1259e-04 - val_MAE: 0.0074 - val_loss: 6.2548e-05 - learning_rate: 0.0020
# Epoch 3/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0062 - loss: 6.7464e-05 - val_MAE: 0.0050 - val_loss: 2.9791e-05 - learning_rate: 0.0020
# Epoch 4/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0048 - loss: 4.1364e-05 - val_MAE: 0.0031 - val_loss: 1.2372e-05 - learning_rate: 0.0020
# Epoch 5/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0036 - loss: 2.3223e-05 - val_MAE: 0.0027 - val_loss: 9.8850e-06 - learning_rate: 0.0020
# Epoch 6/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0031 - loss: 1.7529e-05 - val_MAE: 0.0022 - val_loss: 7.0432e-06 - learning_rate: 0.0020
# Epoch 7/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0030 - loss: 1.6286e-05 - val_MAE: 0.0021 - val_loss: 7.0630e-06 - learning_rate: 0.0020
# Epoch 8/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0027 - loss: 1.3956e-05 - val_MAE: 0.0017 - val_loss: 6.0535e-06 - learning_rate: 0.0020
# Epoch 9/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0024 - loss: 1.1440e-05 - val_MAE: 0.0017 - val_loss: 6.0341e-06 - learning_rate: 0.0020
# Epoch 10/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0022 - loss: 9.6924e-06 - val_MAE: 0.0016 - val_loss: 5.8800e-06 - learning_rate: 4.0000e-04
# Epoch 11/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0021 - loss: 8.7321e-06 - val_MAE: 0.0017 - val_loss: 5.9063e-06 - learning_rate: 4.0000e-04
# Epoch 12/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0022 - loss: 1.0290e-05 - val_MAE: 0.0017 - val_loss: 5.6503e-06 - learning_rate: 4.0000e-04
# Epoch 13/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0020 - loss: 7.9303e-06 - val_MAE: 0.0016 - val_loss: 5.3261e-06 - learning_rate: 4.0000e-04
# Epoch 14/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0021 - loss: 8.7126e-06 - val_MAE: 0.0016 - val_loss: 5.2938e-06 - learning_rate: 4.0000e-04
# Epoch 15/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0020 - loss: 8.4067e-06 - val_MAE: 0.0016 - val_loss: 5.3696e-06 - learning_rate: 8.0000e-05
# Epoch 16/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0021 - loss: 8.6586e-06 - val_MAE: 0.0016 - val_loss: 5.2687e-06 - learning_rate: 8.0000e-05
# Epoch 17/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0021 - loss: 1.0124e-05 - val_MAE: 0.0016 - val_loss: 5.1546e-06 - learning_rate: 8.0000e-05
# Epoch 18/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0020 - loss: 8.0611e-06 - val_MAE: 0.0016 - val_loss: 5.0995e-06 - learning_rate: 8.0000e-05
# Epoch 19/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0020 - loss: 8.3807e-06 - val_MAE: 0.0016 - val_loss: 5.1392e-06 - learning_rate: 8.0000e-05
# Epoch 20/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0019 - loss: 6.5931e-06 - val_MAE: 0.0016 - val_loss: 5.1321e-06 - learning_rate: 1.6000e-05
# Epoch 21/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0020 - loss: 7.4643e-06 - val_MAE: 0.0015 - val_loss: 5.1286e-06 - learning_rate: 1.6000e-05
# Epoch 22/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0020 - loss: 7.7990e-06 - val_MAE: 0.0015 - val_loss: 5.1286e-06 - learning_rate: 1.6000e-05
# Epoch 23/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0020 - loss: 7.7355e-06 - val_MAE: 0.0016 - val_loss: 5.1024e-06 - learning_rate: 1.6000e-05
# Epoch 24/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0020 - loss: 7.6088e-06 - val_MAE: 0.0015 - val_loss: 5.0999e-06 - learning_rate: 1.6000e-05
# Epoch 25/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0020 - loss: 7.7126e-06 - val_MAE: 0.0016 - val_loss: 5.0988e-06 - learning_rate: 1.0000e-05
# Epoch 26/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0020 - loss: 8.1589e-06 - val_MAE: 0.0015 - val_loss: 5.1009e-06 - learning_rate: 1.0000e-05
# Epoch 27/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0020 - loss: 7.4317e-06 - val_MAE: 0.0016 - val_loss: 5.0817e-06 - learning_rate: 1.0000e-05
# Epoch 28/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0020 - loss: 6.9689e-06 - val_MAE: 0.0015 - val_loss: 5.0832e-06 - learning_rate: 1.0000e-05
# Epoch 29/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0020 - loss: 9.1239e-06 - val_MAE: 0.0015 - val_loss: 5.0626e-06 - learning_rate: 1.0000e-05
# Epoch 30/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0020 - loss: 8.7046e-06 - val_MAE: 0.0016 - val_loss: 5.0446e-06 - learning_rate: 1.0000e-05
# Epoch 31/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0018 - loss: 6.1558e-06 - val_MAE: 0.0015 - val_loss: 5.0260e-06 - learning_rate: 1.0000e-05
# Epoch 32/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0020 - loss: 7.3995e-06 - val_MAE: 0.0015 - val_loss: 4.9954e-06 - learning_rate: 1.0000e-05
# Epoch 33/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0019 - loss: 7.1491e-06 - val_MAE: 0.0015 - val_loss: 4.9853e-06 - learning_rate: 1.0000e-05
# Epoch 34/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0019 - loss: 7.1369e-06 - val_MAE: 0.0015 - val_loss: 4.9608e-06 - learning_rate: 1.0000e-05
# Epoch 35/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0019 - loss: 7.0469e-06 - val_MAE: 0.0015 - val_loss: 4.9609e-06 - learning_rate: 1.0000e-05
# Epoch 36/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0019 - loss: 7.4819e-06 - val_MAE: 0.0015 - val_loss: 4.9719e-06 - learning_rate: 1.0000e-05
# Epoch 37/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0019 - loss: 7.4536e-06 - val_MAE: 0.0015 - val_loss: 5.0021e-06 - learning_rate: 1.0000e-05
# Epoch 38/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0020 - loss: 8.6212e-06 - val_MAE: 0.0015 - val_loss: 4.9969e-06 - learning_rate: 1.0000e-05
# Epoch 39/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0020 - loss: 9.4810e-06 - val_MAE: 0.0015 - val_loss: 5.0009e-06 - learning_rate: 1.0000e-05
# Epoch 40/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0019 - loss: 7.3582e-06 - val_MAE: 0.0015 - val_loss: 4.9962e-06 - learning_rate: 1.0000e-05
# Epoch 41/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0019 - loss: 6.9131e-06 - val_MAE: 0.0015 - val_loss: 4.9957e-06 - learning_rate: 1.0000e-05
# Epoch 42/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0019 - loss: 6.4824e-06 - val_MAE: 0.0015 - val_loss: 4.9739e-06 - learning_rate: 1.0000e-05
# Epoch 43/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0020 - loss: 7.8920e-06 - val_MAE: 0.0015 - val_loss: 4.9426e-06 - learning_rate: 1.0000e-05
# Epoch 44/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0020 - loss: 8.2939e-06 - val_MAE: 0.0015 - val_loss: 4.9275e-06 - learning_rate: 1.0000e-05
# Epoch 45/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0019 - loss: 6.5739e-06 - val_MAE: 0.0015 - val_loss: 4.9659e-06 - learning_rate: 1.0000e-05
# Epoch 46/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0019 - loss: 6.8082e-06 - val_MAE: 0.0015 - val_loss: 4.9575e-06 - learning_rate: 1.0000e-05
# Epoch 47/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0020 - loss: 8.2738e-06 - val_MAE: 0.0015 - val_loss: 4.9470e-06 - learning_rate: 1.0000e-05
# Epoch 48/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0019 - loss: 6.5571e-06 - val_MAE: 0.0015 - val_loss: 4.9402e-06 - learning_rate: 1.0000e-05
# Epoch 49/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0019 - loss: 7.1766e-06 - val_MAE: 0.0015 - val_loss: 4.9272e-06 - learning_rate: 1.0000e-05
# Epoch 50/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0019 - loss: 8.6991e-06 - val_MAE: 0.0015 - val_loss: 4.8741e-06 - learning_rate: 1.0000e-05
# Epoch 51/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0019 - loss: 9.0824e-06 - val_MAE: 0.0015 - val_loss: 4.8586e-06 - learning_rate: 1.0000e-05
# Epoch 52/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0019 - loss: 7.4238e-06 - val_MAE: 0.0015 - val_loss: 4.9108e-06 - learning_rate: 1.0000e-05
# Epoch 53/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0018 - loss: 6.6073e-06 - val_MAE: 0.0015 - val_loss: 4.8666e-06 - learning_rate: 1.0000e-05
# Epoch 54/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0019 - loss: 6.6638e-06 - val_MAE: 0.0015 - val_loss: 4.8306e-06 - learning_rate: 1.0000e-05
# Epoch 55/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0019 - loss: 7.4338e-06 - val_MAE: 0.0015 - val_loss: 4.8445e-06 - learning_rate: 1.0000e-05
# Epoch 56/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0018 - loss: 6.2607e-06 - val_MAE: 0.0015 - val_loss: 4.8169e-06 - learning_rate: 1.0000e-05
# Epoch 57/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0020 - loss: 7.7228e-06 - val_MAE: 0.0015 - val_loss: 4.8174e-06 - learning_rate: 1.0000e-05
# Epoch 58/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0019 - loss: 7.7085e-06 - val_MAE: 0.0015 - val_loss: 4.7668e-06 - learning_rate: 1.0000e-05
# Epoch 59/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0019 - loss: 7.3143e-06 - val_MAE: 0.0015 - val_loss: 4.8156e-06 - learning_rate: 1.0000e-05
# Epoch 60/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0018 - loss: 5.9860e-06 - val_MAE: 0.0015 - val_loss: 4.8116e-06 - learning_rate: 1.0000e-05
# Epoch 61/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0018 - loss: 6.2490e-06 - val_MAE: 0.0015 - val_loss: 4.8229e-06 - learning_rate: 1.0000e-05
# Epoch 62/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0019 - loss: 6.9384e-06 - val_MAE: 0.0015 - val_loss: 4.7509e-06 - learning_rate: 1.0000e-05
# Epoch 63/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0018 - loss: 6.8176e-06 - val_MAE: 0.0015 - val_loss: 4.7333e-06 - learning_rate: 1.0000e-05
# Epoch 64/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0019 - loss: 7.3437e-06 - val_MAE: 0.0015 - val_loss: 4.7594e-06 - learning_rate: 1.0000e-05
# Epoch 65/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0018 - loss: 6.5472e-06 - val_MAE: 0.0014 - val_loss: 4.7624e-06 - learning_rate: 1.0000e-05
# Epoch 66/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0018 - loss: 7.7545e-06 - val_MAE: 0.0015 - val_loss: 4.7671e-06 - learning_rate: 1.0000e-05
# Epoch 67/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0018 - loss: 6.1775e-06 - val_MAE: 0.0015 - val_loss: 4.7545e-06 - learning_rate: 1.0000e-05
# Epoch 68/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0018 - loss: 6.6415e-06 - val_MAE: 0.0014 - val_loss: 4.7829e-06 - learning_rate: 1.0000e-05
# Epoch 69/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0018 - loss: 5.8763e-06 - val_MAE: 0.0014 - val_loss: 4.7872e-06 - learning_rate: 1.0000e-05
# Epoch 70/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0017 - loss: 6.1252e-06 - val_MAE: 0.0015 - val_loss: 4.7548e-06 - learning_rate: 1.0000e-05
# Epoch 71/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0018 - loss: 5.7668e-06 - val_MAE: 0.0015 - val_loss: 4.7875e-06 - learning_rate: 1.0000e-05
# Epoch 72/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0018 - loss: 6.1982e-06 - val_MAE: 0.0015 - val_loss: 4.7679e-06 - learning_rate: 1.0000e-05
# Epoch 73/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0019 - loss: 7.3230e-06 - val_MAE: 0.0015 - val_loss: 4.7990e-06 - learning_rate: 1.0000e-05
# Adamax Optimizer - Loss (MSE): 0.000005, Mean Absolute Error: 0.001465
#
# Training with RMSprop optimizer and prelu activation function...
# Epoch 1/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - MAE: 0.0023 - loss: 9.7512e-06 - val_MAE: 0.0015 - val_loss: 4.8629e-06 - learning_rate: 0.0010
# Epoch 2/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0020 - loss: 7.8054e-06 - val_MAE: 0.0021 - val_loss: 8.4286e-06 - learning_rate: 0.0010
# Epoch 3/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0019 - loss: 7.0411e-06 - val_MAE: 0.0017 - val_loss: 6.1727e-06 - learning_rate: 0.0010
# Epoch 4/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0020 - loss: 8.0504e-06 - val_MAE: 0.0015 - val_loss: 4.2405e-06 - learning_rate: 0.0010
# Epoch 5/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0019 - loss: 7.3246e-06 - val_MAE: 0.0024 - val_loss: 9.1545e-06 - learning_rate: 0.0010
# Epoch 6/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0019 - loss: 7.0220e-06 - val_MAE: 0.0020 - val_loss: 5.5561e-06 - learning_rate: 0.0010
# Epoch 7/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0016 - loss: 5.2685e-06 - val_MAE: 0.0014 - val_loss: 4.1483e-06 - learning_rate: 2.0000e-04
# Epoch 8/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0016 - loss: 4.9171e-06 - val_MAE: 0.0014 - val_loss: 4.2614e-06 - learning_rate: 2.0000e-04
# Epoch 9/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0016 - loss: 5.5741e-06 - val_MAE: 0.0014 - val_loss: 4.2660e-06 - learning_rate: 2.0000e-04
# Epoch 10/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0015 - loss: 4.8469e-06 - val_MAE: 0.0014 - val_loss: 4.0221e-06 - learning_rate: 2.0000e-04
# Epoch 11/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0016 - loss: 5.3486e-06 - val_MAE: 0.0014 - val_loss: 4.0128e-06 - learning_rate: 2.0000e-04
# Epoch 12/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0016 - loss: 5.2149e-06 - val_MAE: 0.0014 - val_loss: 4.0886e-06 - learning_rate: 4.0000e-05
# Epoch 13/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0016 - loss: 5.3191e-06 - val_MAE: 0.0014 - val_loss: 4.1679e-06 - learning_rate: 4.0000e-05
# Epoch 14/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0015 - loss: 4.6624e-06 - val_MAE: 0.0014 - val_loss: 4.1732e-06 - learning_rate: 4.0000e-05
# Epoch 15/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0014 - loss: 4.2923e-06 - val_MAE: 0.0014 - val_loss: 4.3465e-06 - learning_rate: 4.0000e-05
# Epoch 16/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0016 - loss: 4.8512e-06 - val_MAE: 0.0014 - val_loss: 4.0410e-06 - learning_rate: 4.0000e-05
# Epoch 17/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0015 - loss: 4.6646e-06 - val_MAE: 0.0014 - val_loss: 4.1377e-06 - learning_rate: 1.0000e-05
# Epoch 18/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0016 - loss: 5.4205e-06 - val_MAE: 0.0014 - val_loss: 4.2117e-06 - learning_rate: 1.0000e-05
# Epoch 19/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0016 - loss: 5.0708e-06 - val_MAE: 0.0014 - val_loss: 4.1297e-06 - learning_rate: 1.0000e-05
# Epoch 20/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0015 - loss: 4.6915e-06 - val_MAE: 0.0014 - val_loss: 4.1173e-06 - learning_rate: 1.0000e-05
# Epoch 21/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0015 - loss: 5.0300e-06 - val_MAE: 0.0014 - val_loss: 4.2077e-06 - learning_rate: 1.0000e-05
# RMSprop Optimizer - Loss (MSE): 0.000004, Mean Absolute Error: 0.001427
#
# Training with SGD optimizer and prelu activation function...
# Epoch 1/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - MAE: 0.0015 - loss: 4.3403e-06 - val_MAE: 0.0014 - val_loss: 4.0604e-06 - learning_rate: 0.0100
# Epoch 2/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0015 - loss: 4.4933e-06 - val_MAE: 0.0014 - val_loss: 4.1199e-06 - learning_rate: 0.0100
# Epoch 3/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0015 - loss: 4.6457e-06 - val_MAE: 0.0014 - val_loss: 4.2199e-06 - learning_rate: 0.0100
# Epoch 4/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0015 - loss: 5.6171e-06 - val_MAE: 0.0014 - val_loss: 4.1045e-06 - learning_rate: 0.0100
# Epoch 5/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0016 - loss: 5.5595e-06 - val_MAE: 0.0014 - val_loss: 4.2769e-06 - learning_rate: 0.0100
# Epoch 6/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0016 - loss: 5.4454e-06 - val_MAE: 0.0014 - val_loss: 4.1615e-06 - learning_rate: 0.0100
# Epoch 7/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0015 - loss: 4.5410e-06 - val_MAE: 0.0014 - val_loss: 4.1537e-06 - learning_rate: 0.0020
# Epoch 8/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0015 - loss: 5.0187e-06 - val_MAE: 0.0014 - val_loss: 4.1523e-06 - learning_rate: 0.0020
# Epoch 9/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0015 - loss: 4.5462e-06 - val_MAE: 0.0014 - val_loss: 4.1713e-06 - learning_rate: 0.0020
# Epoch 10/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0016 - loss: 5.2584e-06 - val_MAE: 0.0014 - val_loss: 4.2019e-06 - learning_rate: 0.0020
# Epoch 11/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0015 - loss: 5.0203e-06 - val_MAE: 0.0014 - val_loss: 4.1039e-06 - learning_rate: 0.0020
# SGD Optimizer - Loss (MSE): 0.000004, Mean Absolute Error: 0.001421
#
# ...
# Epoch 37/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0025 - loss: 1.1257e-05 - val_MAE: 0.0010 - val_loss: 2.3011e-06 - learning_rate: 1.0000e-05
# Epoch 38/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0026 - loss: 1.1429e-05 - val_MAE: 0.0010 - val_loss: 2.2990e-06 - learning_rate: 1.0000e-05
# Epoch 39/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0026 - loss: 1.1430e-05 - val_MAE: 0.0010 - val_loss: 2.2879e-06 - learning_rate: 1.0000e-05
# Epoch 40/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0025 - loss: 1.1151e-05 - val_MAE: 0.0010 - val_loss: 2.2700e-06 - learning_rate: 1.0000e-05
# Epoch 41/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAE: 0.0024 - loss: 1.1174e-05 - val_MAE: 0.0010 - val_loss: 2.2763e-06 - learning_rate: 1.0000e-05
# Epoch 42/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0024 - loss: 1.0815e-05 - val_MAE: 0.0010 - val_loss: 2.2793e-06 - learning_rate: 1.0000e-05
# Epoch 43/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0025 - loss: 1.0776e-05 - val_MAE: 0.0010 - val_loss: 2.2801e-06 - learning_rate: 1.0000e-05
# Epoch 44/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0024 - loss: 9.8458e-06 - val_MAE: 0.0010 - val_loss: 2.2645e-06 - learning_rate: 1.0000e-05
# Epoch 45/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0025 - loss: 1.1635e-05 - val_MAE: 0.0010 - val_loss: 2.2581e-06 - learning_rate: 1.0000e-05
# Epoch 46/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0024 - loss: 1.0279e-05 - val_MAE: 0.0010 - val_loss: 2.2534e-06 - learning_rate: 1.0000e-05
# Epoch 47/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0024 - loss: 9.5709e-06 - val_MAE: 0.0010 - val_loss: 2.2789e-06 - learning_rate: 1.0000e-05
# Epoch 48/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0024 - loss: 1.0949e-05 - val_MAE: 0.0010 - val_loss: 2.2622e-06 - learning_rate: 1.0000e-05
# Epoch 49/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAE: 0.0023 - loss: 9.4018e-06 - val_MAE: 0.0010 - val_loss: 2.2292e-06 - learning_rate: 1.0000e-05
# Epoch 50/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0024 - loss: 9.8686e-06 - val_MAE: 0.0010 - val_loss: 2.2380e-06 - learning_rate: 1.0000e-05
# Epoch 51/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0023 - loss: 9.4005e-06 - val_MAE: 0.0010 - val_loss: 2.2320e-06 - learning_rate: 1.0000e-05
# Epoch 52/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0024 - loss: 1.0621e-05 - val_MAE: 0.0010 - val_loss: 2.2483e-06 - learning_rate: 1.0000e-05
# Epoch 53/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0024 - loss: 1.1408e-05 - val_MAE: 0.0010 - val_loss: 2.2337e-06 - learning_rate: 1.0000e-05
# Epoch 54/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0023 - loss: 9.6344e-06 - val_MAE: 9.9871e-04 - val_loss: 2.2002e-06 - learning_rate: 1.0000e-05
# Epoch 55/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0023 - loss: 9.0088e-06 - val_MAE: 9.9744e-04 - val_loss: 2.1948e-06 - learning_rate: 1.0000e-05
# Epoch 56/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0022 - loss: 9.0989e-06 - val_MAE: 9.9671e-04 - val_loss: 2.1994e-06 - learning_rate: 1.0000e-05
# Epoch 57/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0023 - loss: 9.3727e-06 - val_MAE: 9.9467e-04 - val_loss: 2.1929e-06 - learning_rate: 1.0000e-05
# Epoch 58/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAE: 0.0023 - loss: 9.5211e-06 - val_MAE: 9.9243e-04 - val_loss: 2.1819e-06 - learning_rate: 1.0000e-05
# Epoch 59/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0023 - loss: 9.0459e-06 - val_MAE: 9.9655e-04 - val_loss: 2.2058e-06 - learning_rate: 1.0000e-05
# Epoch 60/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0023 - loss: 9.1150e-06 - val_MAE: 9.8992e-04 - val_loss: 2.1786e-06 - learning_rate: 1.0000e-05
# Epoch 61/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0023 - loss: 9.7086e-06 - val_MAE: 9.9272e-04 - val_loss: 2.1912e-06 - learning_rate: 1.0000e-05
# Epoch 62/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0022 - loss: 8.5857e-06 - val_MAE: 9.9840e-04 - val_loss: 2.2095e-06 - learning_rate: 1.0000e-05
# Epoch 63/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0023 - loss: 9.0833e-06 - val_MAE: 9.8596e-04 - val_loss: 2.1646e-06 - learning_rate: 1.0000e-05
# Epoch 64/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAE: 0.0022 - loss: 9.1732e-06 - val_MAE: 0.0010 - val_loss: 2.2286e-06 - learning_rate: 1.0000e-05
# Epoch 65/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0022 - loss: 8.4763e-06 - val_MAE: 9.9296e-04 - val_loss: 2.1938e-06 - learning_rate: 1.0000e-05
# Epoch 66/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0022 - loss: 8.8126e-06 - val_MAE: 9.8352e-04 - val_loss: 2.1595e-06 - learning_rate: 1.0000e-05
# Epoch 67/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0022 - loss: 8.8286e-06 - val_MAE: 9.9711e-04 - val_loss: 2.2050e-06 - learning_rate: 1.0000e-05
# Epoch 68/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0022 - loss: 8.5468e-06 - val_MAE: 9.8163e-04 - val_loss: 2.1462e-06 - learning_rate: 1.0000e-05
# Epoch 69/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0022 - loss: 8.8340e-06 - val_MAE: 9.8373e-04 - val_loss: 2.1645e-06 - learning_rate: 1.0000e-05
# Epoch 70/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0023 - loss: 9.8791e-06 - val_MAE: 9.7841e-04 - val_loss: 2.1465e-06 - learning_rate: 1.0000e-05
# Epoch 71/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0021 - loss: 8.8910e-06 - val_MAE: 9.7760e-04 - val_loss: 2.1419e-06 - learning_rate: 1.0000e-05
# Epoch 72/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0022 - loss: 8.6642e-06 - val_MAE: 9.7903e-04 - val_loss: 2.1492e-06 - learning_rate: 1.0000e-05
# Epoch 73/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0020 - loss: 7.9195e-06 - val_MAE: 9.7637e-04 - val_loss: 2.1229e-06 - learning_rate: 1.0000e-05
# Epoch 74/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0021 - loss: 7.5816e-06 - val_MAE: 9.7577e-04 - val_loss: 2.1193e-06 - learning_rate: 1.0000e-05
# Epoch 75/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAE: 0.0021 - loss: 8.4150e-06 - val_MAE: 9.7488e-04 - val_loss: 2.1331e-06 - learning_rate: 1.0000e-05
# Epoch 76/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0021 - loss: 7.9181e-06 - val_MAE: 9.7138e-04 - val_loss: 2.1157e-06 - learning_rate: 1.0000e-05
# Epoch 77/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAE: 0.0021 - loss: 8.1437e-06 - val_MAE: 9.7066e-04 - val_loss: 2.1146e-06 - learning_rate: 1.0000e-05
# Epoch 78/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0021 - loss: 7.6595e-06 - val_MAE: 9.7063e-04 - val_loss: 2.1187e-06 - learning_rate: 1.0000e-05
# Epoch 79/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0021 - loss: 7.3891e-06 - val_MAE: 9.7072e-04 - val_loss: 2.1186e-06 - learning_rate: 1.0000e-05
# Epoch 80/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0021 - loss: 8.0140e-06 - val_MAE: 9.6997e-04 - val_loss: 2.1054e-06 - learning_rate: 1.0000e-05
# Epoch 81/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0020 - loss: 7.1674e-06 - val_MAE: 9.7008e-04 - val_loss: 2.1036e-06 - learning_rate: 1.0000e-05
# Epoch 82/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0020 - loss: 7.8014e-06 - val_MAE: 9.6643e-04 - val_loss: 2.0967e-06 - learning_rate: 1.0000e-05
# Epoch 83/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0020 - loss: 7.2009e-06 - val_MAE: 9.6835e-04 - val_loss: 2.1079e-06 - learning_rate: 1.0000e-05
# Epoch 84/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0021 - loss: 7.8457e-06 - val_MAE: 9.6693e-04 - val_loss: 2.1041e-06 - learning_rate: 1.0000e-05
# Epoch 85/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0021 - loss: 8.0031e-06 - val_MAE: 9.6400e-04 - val_loss: 2.0907e-06 - learning_rate: 1.0000e-05
# Epoch 86/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0020 - loss: 7.5021e-06 - val_MAE: 9.6217e-04 - val_loss: 2.0873e-06 - learning_rate: 1.0000e-05
# Epoch 87/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0020 - loss: 7.2885e-06 - val_MAE: 9.6258e-04 - val_loss: 2.0909e-06 - learning_rate: 1.0000e-05
# Epoch 88/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAE: 0.0019 - loss: 7.1368e-06 - val_MAE: 9.6203e-04 - val_loss: 2.0866e-06 - learning_rate: 1.0000e-05
# Epoch 89/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0019 - loss: 6.6989e-06 - val_MAE: 9.6319e-04 - val_loss: 2.0906e-06 - learning_rate: 1.0000e-05
# Epoch 90/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0019 - loss: 7.5484e-06 - val_MAE: 9.6359e-04 - val_loss: 2.0786e-06 - learning_rate: 1.0000e-05
# Epoch 91/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0019 - loss: 6.7768e-06 - val_MAE: 9.5910e-04 - val_loss: 2.0722e-06 - learning_rate: 1.0000e-05
# Epoch 92/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0019 - loss: 6.4945e-06 - val_MAE: 9.6370e-04 - val_loss: 2.0910e-06 - learning_rate: 1.0000e-05
# Epoch 93/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0020 - loss: 8.1267e-06 - val_MAE: 9.6399e-04 - val_loss: 2.0902e-06 - learning_rate: 1.0000e-05
# Epoch 94/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0019 - loss: 6.0453e-06 - val_MAE: 9.5809e-04 - val_loss: 2.0747e-06 - learning_rate: 1.0000e-05
# Epoch 95/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0020 - loss: 6.7669e-06 - val_MAE: 9.5927e-04 - val_loss: 2.0793e-06 - learning_rate: 1.0000e-05
# Epoch 96/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0019 - loss: 6.7300e-06 - val_MAE: 9.5703e-04 - val_loss: 2.0718e-06 - learning_rate: 1.0000e-05
# Epoch 97/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAE: 0.0019 - loss: 6.8262e-06 - val_MAE: 9.5631e-04 - val_loss: 2.0686e-06 - learning_rate: 1.0000e-05
# Epoch 98/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0019 - loss: 6.9290e-06 - val_MAE: 9.5701e-04 - val_loss: 2.0701e-06 - learning_rate: 1.0000e-05
# Epoch 99/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0018 - loss: 5.6305e-06 - val_MAE: 9.5407e-04 - val_loss: 2.0590e-06 - learning_rate: 1.0000e-05
# Epoch 100/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0019 - loss: 7.4544e-06 - val_MAE: 9.5271e-04 - val_loss: 2.0532e-06 - learning_rate: 1.0000e-05
# Adamax Optimizer - Loss (MSE): 0.000002, Mean Absolute Error: 0.000953
#
# Training with RMSprop optimizer and swish activation function...
# Epoch 1/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - MAE: 0.0027 - loss: 1.2580e-05 - val_MAE: 0.0011 - val_loss: 2.4503e-06 - learning_rate: 0.0010
# Epoch 2/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0026 - loss: 1.0881e-05 - val_MAE: 9.5762e-04 - val_loss: 2.0706e-06 - learning_rate: 0.0010
# Epoch 3/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0024 - loss: 9.2590e-06 - val_MAE: 0.0024 - val_loss: 6.9343e-06 - learning_rate: 0.0010
# Epoch 4/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0026 - loss: 1.0630e-05 - val_MAE: 0.0025 - val_loss: 7.5446e-06 - learning_rate: 0.0010
# Epoch 5/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0026 - loss: 1.0817e-05 - val_MAE: 0.0018 - val_loss: 4.7765e-06 - learning_rate: 0.0010
# Epoch 6/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0024 - loss: 9.5099e-06 - val_MAE: 0.0036 - val_loss: 1.4848e-05 - learning_rate: 0.0010
# Epoch 7/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0019 - loss: 6.5185e-06 - val_MAE: 0.0010 - val_loss: 2.1980e-06 - learning_rate: 2.0000e-04
# Epoch 8/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0017 - loss: 5.7026e-06 - val_MAE: 9.5839e-04 - val_loss: 2.0720e-06 - learning_rate: 2.0000e-04
# Epoch 9/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0017 - loss: 5.5640e-06 - val_MAE: 9.4759e-04 - val_loss: 2.0407e-06 - learning_rate: 2.0000e-04
# Epoch 10/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0017 - loss: 5.7924e-06 - val_MAE: 9.9567e-04 - val_loss: 2.1429e-06 - learning_rate: 2.0000e-04
# Epoch 11/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0017 - loss: 5.2777e-06 - val_MAE: 0.0011 - val_loss: 2.3151e-06 - learning_rate: 2.0000e-04
# Epoch 12/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0016 - loss: 5.3793e-06 - val_MAE: 9.4813e-04 - val_loss: 2.0432e-06 - learning_rate: 4.0000e-05
# Epoch 13/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0016 - loss: 4.7248e-06 - val_MAE: 9.8403e-04 - val_loss: 2.1175e-06 - learning_rate: 4.0000e-05
# Epoch 14/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0017 - loss: 5.1985e-06 - val_MAE: 9.4875e-04 - val_loss: 2.0464e-06 - learning_rate: 4.0000e-05
# Epoch 15/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0017 - loss: 5.2781e-06 - val_MAE: 9.6690e-04 - val_loss: 2.0923e-06 - learning_rate: 4.0000e-05
# Epoch 16/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0017 - loss: 5.2298e-06 - val_MAE: 9.5887e-04 - val_loss: 2.0625e-06 - learning_rate: 4.0000e-05
# Epoch 17/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0017 - loss: 5.5576e-06 - val_MAE: 9.4817e-04 - val_loss: 2.0435e-06 - learning_rate: 1.0000e-05
# Epoch 18/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0017 - loss: 5.4022e-06 - val_MAE: 9.4904e-04 - val_loss: 2.0473e-06 - learning_rate: 1.0000e-05
# Epoch 19/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0016 - loss: 5.0162e-06 - val_MAE: 9.4879e-04 - val_loss: 2.0423e-06 - learning_rate: 1.0000e-05
# RMSprop Optimizer - Loss (MSE): 0.000002, Mean Absolute Error: 0.000948
#
# Training with SGD optimizer and swish activation function...
# Epoch 1/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - MAE: 0.0017 - loss: 5.1952e-06 - val_MAE: 9.6183e-04 - val_loss: 2.0803e-06 - learning_rate: 0.0100
# Epoch 2/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0017 - loss: 5.5165e-06 - val_MAE: 9.6825e-04 - val_loss: 2.0966e-06 - learning_rate: 0.0100
# Epoch 3/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0017 - loss: 5.1664e-06 - val_MAE: 9.4783e-04 - val_loss: 2.0434e-06 - learning_rate: 0.0100
# Epoch 4/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0017 - loss: 5.3791e-06 - val_MAE: 9.5347e-04 - val_loss: 2.0497e-06 - learning_rate: 0.0100
# Epoch 5/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0016 - loss: 5.3701e-06 - val_MAE: 9.4851e-04 - val_loss: 2.0460e-06 - learning_rate: 0.0100
# Epoch 6/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0016 - loss: 5.0927e-06 - val_MAE: 9.4852e-04 - val_loss: 2.0460e-06 - learning_rate: 0.0100
# Epoch 7/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0017 - loss: 5.7201e-06 - val_MAE: 9.4841e-04 - val_loss: 2.0411e-06 - learning_rate: 0.0020
# Epoch 8/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0017 - loss: 5.1742e-06 - val_MAE: 9.4833e-04 - val_loss: 2.0454e-06 - learning_rate: 0.0020
# Epoch 9/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0017 - loss: 5.6172e-06 - val_MAE: 9.4790e-04 - val_loss: 2.0436e-06 - learning_rate: 0.0020
# Epoch 10/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0017 - loss: 5.3414e-06 - val_MAE: 9.4807e-04 - val_loss: 2.0444e-06 - learning_rate: 0.0020
# Epoch 11/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0016 - loss: 4.9996e-06 - val_MAE: 9.4951e-04 - val_loss: 2.0493e-06 - learning_rate: 0.0020
# Epoch 12/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0017 - loss: 5.4149e-06 - val_MAE: 9.4830e-04 - val_loss: 2.0454e-06 - learning_rate: 4.0000e-04
# Epoch 13/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0017 - loss: 5.3642e-06 - val_MAE: 9.4778e-04 - val_loss: 2.0430e-06 - learning_rate: 4.0000e-04
# Epoch 14/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0017 - loss: 5.1314e-06 - val_MAE: 9.4767e-04 - val_loss: 2.0418e-06 - learning_rate: 4.0000e-04
# Epoch 15/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0017 - loss: 5.8916e-06 - val_MAE: 9.4772e-04 - val_loss: 2.0426e-06 - learning_rate: 4.0000e-04
# Epoch 16/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0017 - loss: 5.5539e-06 - val_MAE: 9.4770e-04 - val_loss: 2.0416e-06 - learning_rate: 4.0000e-04
# Epoch 17/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0017 - loss: 5.6357e-06 - val_MAE: 9.4767e-04 - val_loss: 2.0420e-06 - learning_rate: 8.0000e-05
# SGD Optimizer - Loss (MSE): 0.000002, Mean Absolute Error: 0.000948

# %%
print(all_mae_values)
print(all_loss_values)
print(all_labels)
# Out:
# [0.002510863821953535, 0.0017580266576260328, 0.0018255927134305239, 0.0012952359393239021, 0.0012124978238716722, 0.0011952491477131844, 0.001856882474385202, 0.001187648274935782, 0.0014978076796978712, 0.0014648273354396224, 0.0014269594103097916, 0.001421403489075601, 0.0009527141810394824, 0.0009475930710323155, 0.0009484061738476157]
# [1.0085218491440173e-05, 5.951817456661956e-06, 6.876603492855793e-06, 3.2263349112326978e-06, 2.9538980470533716e-06, 2.9989626000315184e-06, 6.9980824264348485e-06, 2.897835656767711e-06, 4.407930646266323e-06, 4.733280093205394e-06, 4.0128102227754425e-06, 4.0603895286039915e-06, 2.0531945210677804e-06, 2.040664412561455e-06, 2.0411373498063767e-06]
# ['relu, Adamax', 'relu, RMSprop', 'relu, SGD', 'leaky_relu, Adamax', 'leaky_relu, RMSprop', 'leaky_relu, SGD', 'elu, Adamax', 'elu, RMSprop', 'elu, SGD', 'prelu, Adamax', 'prelu, RMSprop', 'prelu, SGD', 'swish, Adamax', 'swish, RMSprop', 'swish, SGD']

# %%
# Create a DataFrame
cancer_models_df = pd.DataFrame({
    'Model': all_labels,
    'Activation_Function': all_activation_functions, 
    'Optimizer': all_optimizers, 
    'MAE': all_mae_values,
    'Loss': all_loss_values
})

cancer_models_df
# Out:
#                   Model Activation_Function Optimizer       MAE      Loss
# 0          relu, Adamax                relu    Adamax  0.002511  0.000010
# 1         relu, RMSprop                relu   RMSprop  0.001758  0.000006
# 2             relu, SGD                relu       SGD  0.001826  0.000007
# 3    leaky_relu, Adamax          leaky_relu    Adamax  0.001295  0.000003
# 4   leaky_relu, RMSprop          leaky_relu   RMSprop  0.001212  0.000003
# 5       leaky_relu, SGD          leaky_relu       SGD  0.001195  0.000003
# 6           elu, Adamax                 elu    Adamax  0.001857  0.000007
# 7          elu, RMSprop                 elu   RMSprop  0.001188  0.000003
# 8              elu, SGD                 elu       SGD  0.001498  0.000004
# 9         prelu, Adamax               prelu    Adamax  0.001465  0.000005
# 10       prelu, RMSprop               prelu   RMSprop  0.001427  0.000004
# 11           prelu, SGD               prelu       SGD  0.001421  0.000004
# 12        swish, Adamax               swish    Adamax  0.000953  0.000002
# 13       swish, RMSprop               swish   RMSprop  0.000948  0.000002
# 14           swish, SGD               swish       SGD  0.000948  0.000002

# %%
# Plotting
fig, ax1 = plt.subplots(figsize=(14, 8))

# Bar plot for Accuracy
color = 'tab:blue'
ax1.set_xlabel('Model')
ax1.set_ylabel('Mean Absolute Error', color=color)
ax1.bar(cancer_models_df['Model'], cancer_models_df['MAE'], color=color, alpha=0.6, label='MAE')
ax1.tick_params(axis='y', labelcolor=color)
ax1.set_xticks(range(len(cancer_models_df['Model'])))
ax1.set_xticklabels(cancer_models_df['Model'], rotation=90)

# Create a second y-axis for Loss
ax2 = ax1.twinx()
color = 'tab:red'
ax2.set_ylabel('Loss (MSE)', color=color)
ax2.plot(cancer_models_df['Model'], cancer_models_df['Loss'], color=color, marker='o', linestyle='-', linewidth=2, markersize=8, label='Loss')
ax2.tick_params(axis='y', labelcolor=color)

# Title and layout
plt.title('MAE and Loss for Cancer Models')
fig.tight_layout()
plt.show()

# %%
# Rank the models based on MAE (lower is better)
cancer_models_df['MAE_Rank'] = cancer_models_df['MAE'].rank()

# Rank the models based on Loss (lower is better)
cancer_models_df['Loss_Rank'] = cancer_models_df['Loss'].rank()

# Calculate the average rank
cancer_models_df['Average_Rank'] = (cancer_models_df['MAE_Rank'] + cancer_models_df['Loss_Rank']) / 2

# Find the top two ranked models
best_model_avg_rank = cancer_models_df.sort_values('Average_Rank').iloc[0]
print(best_model_avg_rank)
# Out:
# Model                  swish, RMSprop
# Activation_Function             swish
# Optimizer                     RMSprop
# MAE                          0.000948
# Loss                         0.000002
# MAE_Rank                          1.0
# Loss_Rank                         1.0
# Average_Rank                      1.0
# Name: 13, dtype: object

# %%
# Initialize train and get predictions with the random forest regressor
cancer_rf = RandomForestRegressor(n_estimators=500, random_state=78)
cancer_rf.fit(X_train, y_train)
predictions = cancer_rf.predict(X_test)

# Evaluate using MAE MSE RMSE and R2 metrics
mae = mean_absolute_error(y_test, predictions)
mse = mean_squared_error(y_test, predictions)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, predictions)

# Print Evaluation Metrics
print(f"MAE: {mae}")
print(f"MSE: {mse}")
print(f"RMSE: {rmse}")
print(f"R²: {r2}")
# Out:
# MAE: 0.0008245149544863479
# MSE: 1.4317078699609826e-06
# RMSE: 0.0011965399575279475
# R²: 0.848404630408665

# %%
# Get Feature Importance
importances = cancer_rf.feature_importances_

# Extract feature names
feature_names = cancer_df.drop(columns=['target_cancer', 'county_index']).columns

# Visualize the features by importance
importances_df = pd.DataFrame(sorted(zip(cancer_rf.feature_importances_, feature_names), reverse=True))
importances_df.set_index(importances_df[1], inplace=True)
importances_df.drop(columns=1, inplace=True)
importances_df.rename(columns={0: 'Feature Importances'}, inplace=True)
importances_sorted = importances_df.sort_values(by='Feature Importances')
importances_sorted.plot(kind='barh', color='lightgreen', title= 'Cancer Features Importances', legend=False)
# Out:
# <Axes: title={'center': 'Cancer Features Importances'}, ylabel='1'>
