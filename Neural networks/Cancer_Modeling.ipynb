# %%
import warnings
from pathlib import Path
import pandas as pd
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Dense, Dropout, Input, Activation
from keras.optimizers import Adamax, RMSprop, SGD
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from keras.layers import LeakyReLU, ELU, PReLU
import tensorflow as tf
from tensorflow.keras.callbacks import EarlyStopping
import matplotlib.pyplot as plt

# %%
# File Path
cancer_data_to_load = Path("../Outputs/CANCER_sdoh_access.csv")

# Read shcool metrics into Pandas DataFrames
cancer_df = pd.read_csv(cancer_data_to_load)

cancer_df.head()
# Out:
#    county_index  target_cancer  AGE65  BROAD  CROWD  HCOST  NOHSDP  POV150  \
# 0          1001            6.3   15.1   14.5    1.5   21.5    10.4    21.7
# 1          1011            5.5   16.2   40.6    0.8   23.9    22.4    46.0
# 2          1021            6.3   16.4   21.7    2.9   16.1    18.2    26.5
# 3          1029            6.4   19.2   27.2    2.1   18.1    16.9    27.3
# 4          1049            6.3   16.9   20.1    3.3   20.9    21.8    35.4
#
#    REMNRTY  SNGPNT  UNEMP  No_Vehicle_10_Miles  No_Vehicle_1_Mile  \
# 0     26.9     7.1    2.8             0.406809           1.528284
# 1     79.6    14.5    3.0             0.733003           3.060290
# 2     20.7     4.5    6.4             0.025205           1.416035
# 3      7.6     4.5    4.5             0.073470           1.302431
# 4     20.4     5.8    4.3             0.000000           1.492076
#
#    No_Vehicle_Half_Mile
# 0              1.914937
# 1              3.967381
# 2              1.718489
# 3              1.436014
# 4              1.816929

# %%
# Divide the percentage values by 100 to prepare for Neural Network
columns_to_scale = cancer_df.dtypes[cancer_df.dtypes == "float64"].index.tolist()
cancer_df[columns_to_scale] = cancer_df[columns_to_scale] / 100
cancer_df.head()
# Out:
#    county_index  target_cancer  AGE65  BROAD  CROWD  HCOST  NOHSDP  POV150  \
# 0          1001          0.063  0.151  0.145  0.015  0.215   0.104   0.217
# 1          1011          0.055  0.162  0.406  0.008  0.239   0.224   0.460
# 2          1021          0.063  0.164  0.217  0.029  0.161   0.182   0.265
# 3          1029          0.064  0.192  0.272  0.021  0.181   0.169   0.273
# 4          1049          0.063  0.169  0.201  0.033  0.209   0.218   0.354
#
#    REMNRTY  SNGPNT  UNEMP  No_Vehicle_10_Miles  No_Vehicle_1_Mile  \
# 0    0.269   0.071  0.028             0.004068           0.015283
# 1    0.796   0.145  0.030             0.007330           0.030603
# 2    0.207   0.045  0.064             0.000252           0.014160
# 3    0.076   0.045  0.045             0.000735           0.013024
# 4    0.204   0.058  0.043             0.000000           0.014921
#
#    No_Vehicle_Half_Mile
# 0              0.019149
# 1              0.039674
# 2              0.017185
# 3              0.014360
# 4              0.018169

# %%
# Split data into our features and target arrays
y = cancer_df['target_cancer'].values
X = cancer_df.drop(columns = ['target_cancer', 'county_index']).values

# Split the arrays into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=12)

# Data was prescaled manually so set values to work with the train_model function
X_train_scaled = X_train
X_test_scaled = X_test

input_shape = len(X_train[0])

# %%
def train_model(X_train_scaled, y_train, X_test_scaled, y_test, activation_func='relu'):
    """
    Train a neural network with specified activation function and multiple optimizers.

    Args:
    - X_train_scaled: Scaled training data
    - y_train: Labels for training data
    - X_test_scaled: Scaled test data
    - y_test: Labels for test data
    - activation_func: Activation function to use (e.g., 'relu', 'leaky_relu', 'elu', 'prelu', 'swish')

    Returns:
    - mae_list2: List of mean absolute error for each optimizer
    - loss_list2: List of losses (MSE) for each optimizer
    """
    
    # Custom activation handling
    def get_activation(activation):
        if activation == 'leaky_relu':
            return LeakyReLU(alpha=0.1)  # Custom activation layer
        elif activation == 'elu':
            return ELU(alpha=1.0)  # Custom activation layer
        elif activation == 'prelu':
            return PReLU()  # Custom activation layer
        elif activation == 'swish':  # Or silu
            return Activation(tf.keras.activations.swish)  # Wrap as Activation layer
        else:
            return activation  # For standard activations like 'relu', 'sigmoid', etc.
    
    # Build model
    nn = tf.keras.models.Sequential()

    # Add the input layer
    nn.add(tf.keras.layers.Input(shape=(input_shape,)))
    
    # First hidden layer
    if isinstance(get_activation(activation_func), str):  # If it's a standard activation
        nn.add(tf.keras.layers.Dense(units=128, activation=get_activation(activation_func)))  # Use activation as string
    else:  # If it's a custom activation layer
        nn.add(tf.keras.layers.Dense(units=128))
        nn.add(get_activation(activation_func))  # Add custom activation layer
    
    # Dropout and subsequent layers
    nn.add(Dropout(0.3))
    if isinstance(get_activation(activation_func), str):
        nn.add(tf.keras.layers.Dense(units=64, activation=get_activation(activation_func)))
    else:
        nn.add(tf.keras.layers.Dense(units=64))
        nn.add(get_activation(activation_func))
    
    nn.add(Dropout(0.3))
    if isinstance(get_activation(activation_func), str):
        nn.add(tf.keras.layers.Dense(units=32, activation=get_activation(activation_func)))
    else:
        nn.add(tf.keras.layers.Dense(units=32))
        nn.add(get_activation(activation_func))
    
    # Output layer (for continuous data)
    nn.add(tf.keras.layers.Dense(units=1, activation="linear"))

    # Experiment with different optimizers
    optimizers = {
        'Adamax': Adamax(learning_rate=0.002),
        'RMSprop': RMSprop(learning_rate=0.001),
        'SGD': SGD(learning_rate=0.01, momentum=0.9)
    }

    mae_list2 = []
    loss_list2 = []

    # Iterate through each optimizer
    for name, optimizer in optimizers.items():
        print(f"\nTraining with {name} optimizer and {activation_func} activation function...")
        nn.compile(optimizer=optimizer, loss="mean_squared_error", metrics=["MAE"])

        # Callbacks
        early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
        reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=0.00001)

        # Train the model
        nn.fit(X_train_scaled, y_train, epochs=100, validation_data=(X_test_scaled, y_test),
               callbacks=[early_stopping, reduce_lr], verbose=1)

        # Evaluate the model
        loss, mae = nn.evaluate(X_test_scaled, y_test, verbose=0)
        print(f"{name} Optimizer - Loss (MSE): {loss:.6f}, Mean Absolute Error: {mae:.6f}")
        mae_list2.append(mae)
        loss_list2.append(loss)
    
    return mae_list2, loss_list2

# %%
all_mae_values = []
all_loss_values = []
all_labels = []
all_activation_functions = []
all_optimizers = []

activation_functions = ['relu', 'leaky_relu', 'elu', 'prelu', 'swish']
optimizers = ['Adamax', 'RMSprop', 'SGD']

for activation in activation_functions:
    print(f"\nRunning for activation function: {activation}")
    mae_list, loss_list = train_model(X_train_scaled, y_train, X_test_scaled, y_test, activation_func=activation)
    
    # Append the Mean Absolute Error, loss values and labels for this activation function
    all_mae_values.extend(mae_list)
    all_loss_values.extend(loss_list)
    
    # Create labels combining activation function and optimizer
    for optimizer in optimizers:
        all_labels.append(f"{activation}, {optimizer}")
        all_activation_functions.append(activation)
        all_optimizers.append(optimizer)
# Out:
# Running for activation function: relu
#
# Training with Adamax optimizer and relu activation function...
# Epoch 1/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - MAE: 0.0289 - loss: 0.0018 - val_MAE: 0.0069 - val_loss: 6.8908e-05 - learning_rate: 0.0020
# Epoch 2/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0119 - loss: 2.2388e-04 - val_MAE: 0.0057 - val_loss: 4.3753e-05 - learning_rate: 0.0020
# Epoch 3/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0085 - loss: 1.2979e-04 - val_MAE: 0.0036 - val_loss: 1.8948e-05 - learning_rate: 0.0020
# Epoch 4/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0069 - loss: 8.2925e-05 - val_MAE: 0.0017 - val_loss: 5.8055e-06 - learning_rate: 0.0020
# Epoch 5/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0054 - loss: 5.4174e-05 - val_MAE: 0.0016 - val_loss: 4.9929e-06 - learning_rate: 0.0020
# Epoch 6/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0045 - loss: 4.0214e-05 - val_MAE: 0.0016 - val_loss: 5.7193e-06 - learning_rate: 0.0020
# Epoch 7/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0043 - loss: 3.5231e-05 - val_MAE: 0.0016 - val_loss: 5.2056e-06 - learning_rate: 4.0000e-04
# Epoch 8/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0040 - loss: 3.2086e-05 - val_MAE: 0.0016 - val_loss: 4.8799e-06 - learning_rate: 4.0000e-04
# Epoch 9/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0041 - loss: 3.2894e-05 - val_MAE: 0.0015 - val_loss: 4.6726e-06 - learning_rate: 4.0000e-04
# Epoch 10/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0039 - loss: 2.9682e-05 - val_MAE: 0.0015 - val_loss: 4.6609e-06 - learning_rate: 4.0000e-04
# Epoch 11/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0038 - loss: 2.8220e-05 - val_MAE: 0.0015 - val_loss: 4.6344e-06 - learning_rate: 4.0000e-04
# Epoch 12/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0036 - loss: 2.3994e-05 - val_MAE: 0.0015 - val_loss: 4.5740e-06 - learning_rate: 8.0000e-05
# Epoch 13/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0037 - loss: 2.6250e-05 - val_MAE: 0.0016 - val_loss: 4.6508e-06 - learning_rate: 8.0000e-05
# Epoch 14/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0036 - loss: 2.8024e-05 - val_MAE: 0.0015 - val_loss: 4.3725e-06 - learning_rate: 8.0000e-05
# Epoch 15/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0035 - loss: 2.3828e-05 - val_MAE: 0.0015 - val_loss: 4.4550e-06 - learning_rate: 8.0000e-05
# Epoch 16/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0035 - loss: 2.3705e-05 - val_MAE: 0.0015 - val_loss: 4.4158e-06 - learning_rate: 8.0000e-05
# Epoch 17/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0036 - loss: 2.5903e-05 - val_MAE: 0.0015 - val_loss: 4.4483e-06 - learning_rate: 1.6000e-05
# Epoch 18/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0036 - loss: 2.5441e-05 - val_MAE: 0.0015 - val_loss: 4.4524e-06 - learning_rate: 1.6000e-05
# Epoch 19/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0034 - loss: 2.2303e-05 - val_MAE: 0.0015 - val_loss: 4.4410e-06 - learning_rate: 1.6000e-05
# Epoch 20/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0035 - loss: 2.2404e-05 - val_MAE: 0.0015 - val_loss: 4.4662e-06 - learning_rate: 1.6000e-05
# Epoch 21/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0036 - loss: 2.5895e-05 - val_MAE: 0.0015 - val_loss: 4.4524e-06 - learning_rate: 1.6000e-05
# Epoch 22/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0035 - loss: 2.4264e-05 - val_MAE: 0.0015 - val_loss: 4.4323e-06 - learning_rate: 1.0000e-05
# Epoch 23/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0036 - loss: 2.6017e-05 - val_MAE: 0.0015 - val_loss: 4.4069e-06 - learning_rate: 1.0000e-05
# Epoch 24/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0035 - loss: 2.6197e-05 - val_MAE: 0.0015 - val_loss: 4.4387e-06 - learning_rate: 1.0000e-05
# Adamax Optimizer - Loss (MSE): 0.000004, Mean Absolute Error: 0.001508
#
# Training with RMSprop optimizer and relu activation function...
# Epoch 1/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - MAE: 0.0040 - loss: 2.8507e-05 - val_MAE: 0.0041 - val_loss: 1.9693e-05 - learning_rate: 0.0010
# Epoch 2/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0034 - loss: 2.2550e-05 - val_MAE: 0.0023 - val_loss: 8.4904e-06 - learning_rate: 0.0010
# Epoch 3/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0029 - loss: 1.5429e-05 - val_MAE: 0.0015 - val_loss: 4.0386e-06 - learning_rate: 0.0010
# Epoch 4/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0026 - loss: 1.3424e-05 - val_MAE: 0.0016 - val_loss: 4.1196e-06 - learning_rate: 0.0010
# Epoch 5/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0024 - loss: 1.0579e-05 - val_MAE: 0.0029 - val_loss: 1.2361e-05 - learning_rate: 0.0010
# Epoch 6/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0024 - loss: 1.1370e-05 - val_MAE: 0.0037 - val_loss: 1.7234e-05 - learning_rate: 0.0010
# Epoch 7/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0020 - loss: 8.2183e-06 - val_MAE: 0.0015 - val_loss: 4.6745e-06 - learning_rate: 2.0000e-04
# Epoch 8/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0018 - loss: 6.6199e-06 - val_MAE: 0.0015 - val_loss: 4.4525e-06 - learning_rate: 2.0000e-04
# Epoch 9/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0017 - loss: 7.1572e-06 - val_MAE: 0.0014 - val_loss: 3.8548e-06 - learning_rate: 2.0000e-04
# Epoch 10/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0018 - loss: 7.1723e-06 - val_MAE: 0.0014 - val_loss: 4.1010e-06 - learning_rate: 2.0000e-04
# Epoch 11/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0018 - loss: 7.8389e-06 - val_MAE: 0.0014 - val_loss: 4.1674e-06 - learning_rate: 2.0000e-04
# Epoch 12/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0017 - loss: 6.9488e-06 - val_MAE: 0.0014 - val_loss: 3.8351e-06 - learning_rate: 4.0000e-05
# Epoch 13/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0017 - loss: 6.0492e-06 - val_MAE: 0.0015 - val_loss: 4.7211e-06 - learning_rate: 4.0000e-05
# Epoch 14/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0017 - loss: 6.3529e-06 - val_MAE: 0.0014 - val_loss: 4.3899e-06 - learning_rate: 4.0000e-05
# Epoch 15/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0016 - loss: 6.1509e-06 - val_MAE: 0.0014 - val_loss: 4.3176e-06 - learning_rate: 4.0000e-05
# Epoch 16/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0018 - loss: 8.1898e-06 - val_MAE: 0.0014 - val_loss: 4.1274e-06 - learning_rate: 4.0000e-05
# Epoch 17/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0018 - loss: 8.0282e-06 - val_MAE: 0.0014 - val_loss: 4.2439e-06 - learning_rate: 1.0000e-05
# Epoch 18/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0017 - loss: 6.9540e-06 - val_MAE: 0.0014 - val_loss: 4.2033e-06 - learning_rate: 1.0000e-05
# Epoch 19/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0017 - loss: 5.9483e-06 - val_MAE: 0.0014 - val_loss: 4.4636e-06 - learning_rate: 1.0000e-05
# Epoch 20/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0016 - loss: 5.6261e-06 - val_MAE: 0.0014 - val_loss: 4.2588e-06 - learning_rate: 1.0000e-05
# Epoch 21/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0016 - loss: 5.9088e-06 - val_MAE: 0.0014 - val_loss: 4.4122e-06 - learning_rate: 1.0000e-05
# Epoch 22/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0017 - loss: 7.7245e-06 - val_MAE: 0.0014 - val_loss: 4.2811e-06 - learning_rate: 1.0000e-05
# RMSprop Optimizer - Loss (MSE): 0.000004, Mean Absolute Error: 0.001364
#
# Training with SGD optimizer and relu activation function...
# Epoch 1/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - MAE: 0.0017 - loss: 6.6500e-06 - val_MAE: 0.0015 - val_loss: 4.6036e-06 - learning_rate: 0.0100
# Epoch 2/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0017 - loss: 6.4240e-06 - val_MAE: 0.0015 - val_loss: 4.5914e-06 - learning_rate: 0.0100
# Epoch 3/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0017 - loss: 6.9288e-06 - val_MAE: 0.0014 - val_loss: 4.3595e-06 - learning_rate: 0.0100
# Epoch 4/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0017 - loss: 6.6804e-06 - val_MAE: 0.0014 - val_loss: 4.2381e-06 - learning_rate: 0.0100
# Epoch 5/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0017 - loss: 6.7977e-06 - val_MAE: 0.0015 - val_loss: 4.5427e-06 - learning_rate: 0.0100
# Epoch 6/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0017 - loss: 7.2028e-06 - val_MAE: 0.0016 - val_loss: 5.1098e-06 - learning_rate: 0.0100
# Epoch 7/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0018 - loss: 8.3026e-06 - val_MAE: 0.0014 - val_loss: 4.3322e-06 - learning_rate: 0.0020
# Epoch 8/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0017 - loss: 6.5102e-06 - val_MAE: 0.0014 - val_loss: 4.4299e-06 - learning_rate: 0.0020
# Epoch 9/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0016 - loss: 5.9201e-06 - val_MAE: 0.0014 - val_loss: 4.4250e-06 - learning_rate: 0.0020
# Epoch 10/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0016 - loss: 6.9793e-06 - val_MAE: 0.0015 - val_loss: 4.5771e-06 - learning_rate: 0.0020
# Epoch 11/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0017 - loss: 8.8760e-06 - val_MAE: 0.0015 - val_loss: 4.5029e-06 - learning_rate: 0.0020
# Epoch 12/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0017 - loss: 6.3038e-06 - val_MAE: 0.0014 - val_loss: 4.4069e-06 - learning_rate: 4.0000e-04
# Epoch 13/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0017 - loss: 7.7533e-06 - val_MAE: 0.0015 - val_loss: 4.4920e-06 - learning_rate: 4.0000e-04
# Epoch 14/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0016 - loss: 6.2860e-06 - val_MAE: 0.0014 - val_loss: 4.4842e-06 - learning_rate: 4.0000e-04
# SGD Optimizer - Loss (MSE): 0.000004, Mean Absolute Error: 0.001409
#
# Running for activation function: leaky_relu
#
# Training with Adamax optimizer and leaky_relu activation function...
# Epoch 1/100
# C:\Users\ecros\anaconda3\envs\dev\lib\site-packages\keras\src\layers\activations\leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - MAE: 0.0222 - loss: 0.0010 - val_MAE: 0.0123 - val_loss: 1.6644e-04 - learning_rate: 0.0020
# Epoch 2/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0079 - loss: 1.1618e-04 - val_MAE: 0.0063 - val_loss: 5.0921e-05 - learning_rate: 0.0020
# Epoch 3/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0061 - loss: 7.7548e-05 - val_MAE: 0.0025 - val_loss: 1.3484e-05 - learning_rate: 0.0020
# Epoch 4/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0050 - loss: 4.6903e-05 - val_MAE: 0.0023 - val_loss: 1.0913e-05 - learning_rate: 0.0020
# Epoch 5/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0043 - loss: 3.7441e-05 - val_MAE: 0.0017 - val_loss: 6.9039e-06 - learning_rate: 0.0020
# Epoch 6/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0037 - loss: 2.6646e-05 - val_MAE: 0.0018 - val_loss: 7.3030e-06 - learning_rate: 0.0020
# Epoch 7/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0035 - loss: 2.3913e-05 - val_MAE: 0.0015 - val_loss: 5.5700e-06 - learning_rate: 0.0020
# Epoch 8/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0032 - loss: 2.1431e-05 - val_MAE: 0.0015 - val_loss: 4.5156e-06 - learning_rate: 4.0000e-04
# Epoch 9/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0031 - loss: 2.1237e-05 - val_MAE: 0.0014 - val_loss: 4.4837e-06 - learning_rate: 4.0000e-04
# Epoch 10/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0030 - loss: 2.0172e-05 - val_MAE: 0.0014 - val_loss: 4.1377e-06 - learning_rate: 4.0000e-04
# Epoch 11/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0030 - loss: 1.7025e-05 - val_MAE: 0.0014 - val_loss: 3.9258e-06 - learning_rate: 4.0000e-04
# Epoch 12/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0030 - loss: 1.8132e-05 - val_MAE: 0.0012 - val_loss: 3.7271e-06 - learning_rate: 4.0000e-04
# Epoch 13/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0029 - loss: 1.5963e-05 - val_MAE: 0.0013 - val_loss: 3.6454e-06 - learning_rate: 8.0000e-05
# Epoch 14/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0031 - loss: 1.8855e-05 - val_MAE: 0.0014 - val_loss: 3.6095e-06 - learning_rate: 8.0000e-05
# Epoch 15/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0029 - loss: 1.7317e-05 - val_MAE: 0.0013 - val_loss: 3.5481e-06 - learning_rate: 8.0000e-05
# Epoch 16/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0029 - loss: 1.5950e-05 - val_MAE: 0.0013 - val_loss: 3.4344e-06 - learning_rate: 8.0000e-05
# Epoch 17/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0028 - loss: 1.5319e-05 - val_MAE: 0.0013 - val_loss: 3.3692e-06 - learning_rate: 8.0000e-05
# Epoch 18/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0027 - loss: 1.4419e-05 - val_MAE: 0.0013 - val_loss: 3.3695e-06 - learning_rate: 1.6000e-05
# Epoch 19/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0029 - loss: 1.6292e-05 - val_MAE: 0.0013 - val_loss: 3.4202e-06 - learning_rate: 1.6000e-05
# Epoch 20/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0028 - loss: 1.5112e-05 - val_MAE: 0.0013 - val_loss: 3.3820e-06 - learning_rate: 1.6000e-05
# Epoch 21/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0028 - loss: 1.4800e-05 - val_MAE: 0.0013 - val_loss: 3.4182e-06 - learning_rate: 1.6000e-05
# Epoch 22/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0029 - loss: 1.6816e-05 - val_MAE: 0.0013 - val_loss: 3.4290e-06 - learning_rate: 1.6000e-05
# Epoch 23/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0027 - loss: 1.5464e-05 - val_MAE: 0.0013 - val_loss: 3.4163e-06 - learning_rate: 1.0000e-05
# Epoch 24/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0028 - loss: 1.5763e-05 - val_MAE: 0.0013 - val_loss: 3.3483e-06 - learning_rate: 1.0000e-05
# Epoch 25/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0027 - loss: 1.5428e-05 - val_MAE: 0.0013 - val_loss: 3.4148e-06 - learning_rate: 1.0000e-05
# Epoch 26/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0029 - loss: 1.6300e-05 - val_MAE: 0.0013 - val_loss: 3.3829e-06 - learning_rate: 1.0000e-05
# Epoch 27/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0029 - loss: 1.5360e-05 - val_MAE: 0.0013 - val_loss: 3.2640e-06 - learning_rate: 1.0000e-05
# Epoch 28/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0028 - loss: 1.7024e-05 - val_MAE: 0.0013 - val_loss: 3.2669e-06 - learning_rate: 1.0000e-05
# Epoch 29/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0027 - loss: 1.3745e-05 - val_MAE: 0.0013 - val_loss: 3.3239e-06 - learning_rate: 1.0000e-05
# Epoch 30/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0029 - loss: 1.5159e-05 - val_MAE: 0.0014 - val_loss: 3.3948e-06 - learning_rate: 1.0000e-05
# Epoch 31/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0028 - loss: 1.6137e-05 - val_MAE: 0.0013 - val_loss: 3.3497e-06 - learning_rate: 1.0000e-05
# Epoch 32/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0027 - loss: 1.4028e-05 - val_MAE: 0.0013 - val_loss: 3.2823e-06 - learning_rate: 1.0000e-05
# Epoch 33/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0029 - loss: 1.8760e-05 - val_MAE: 0.0013 - val_loss: 3.3298e-06 - learning_rate: 1.0000e-05
# Epoch 34/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0027 - loss: 1.4818e-05 - val_MAE: 0.0014 - val_loss: 3.3682e-06 - learning_rate: 1.0000e-05
# Epoch 35/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0028 - loss: 1.5189e-05 - val_MAE: 0.0013 - val_loss: 3.3218e-06 - learning_rate: 1.0000e-05
# Epoch 36/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0028 - loss: 1.5049e-05 - val_MAE: 0.0014 - val_loss: 3.3999e-06 - learning_rate: 1.0000e-05
# Epoch 37/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0028 - loss: 1.6868e-05 - val_MAE: 0.0013 - val_loss: 3.2308e-06 - learning_rate: 1.0000e-05
# Epoch 38/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0028 - loss: 1.4894e-05 - val_MAE: 0.0013 - val_loss: 3.2315e-06 - learning_rate: 1.0000e-05
# Epoch 39/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0028 - loss: 1.6707e-05 - val_MAE: 0.0013 - val_loss: 3.2683e-06 - learning_rate: 1.0000e-05
# Epoch 40/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0026 - loss: 1.2730e-05 - val_MAE: 0.0013 - val_loss: 3.1549e-06 - learning_rate: 1.0000e-05
# Epoch 41/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0027 - loss: 1.4045e-05 - val_MAE: 0.0013 - val_loss: 3.2692e-06 - learning_rate: 1.0000e-05
# Epoch 42/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0026 - loss: 1.3475e-05 - val_MAE: 0.0013 - val_loss: 3.2062e-06 - learning_rate: 1.0000e-05
# Epoch 43/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0027 - loss: 1.4707e-05 - val_MAE: 0.0013 - val_loss: 3.2551e-06 - learning_rate: 1.0000e-05
# Epoch 44/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0028 - loss: 1.5027e-05 - val_MAE: 0.0014 - val_loss: 3.3826e-06 - learning_rate: 1.0000e-05
# Epoch 45/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0026 - loss: 1.4000e-05 - val_MAE: 0.0014 - val_loss: 3.4223e-06 - learning_rate: 1.0000e-05
# Epoch 46/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0026 - loss: 1.3013e-05 - val_MAE: 0.0013 - val_loss: 3.2211e-06 - learning_rate: 1.0000e-05
# Epoch 47/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0028 - loss: 1.5726e-05 - val_MAE: 0.0013 - val_loss: 3.2361e-06 - learning_rate: 1.0000e-05
# Epoch 48/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0026 - loss: 1.4177e-05 - val_MAE: 0.0013 - val_loss: 3.2603e-06 - learning_rate: 1.0000e-05
# Epoch 49/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0026 - loss: 1.4051e-05 - val_MAE: 0.0013 - val_loss: 3.2140e-06 - learning_rate: 1.0000e-05
# Epoch 50/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0027 - loss: 1.5038e-05 - val_MAE: 0.0013 - val_loss: 3.1407e-06 - learning_rate: 1.0000e-05
# Epoch 51/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0026 - loss: 1.3943e-05 - val_MAE: 0.0013 - val_loss: 3.0849e-06 - learning_rate: 1.0000e-05
# Epoch 52/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0027 - loss: 1.4958e-05 - val_MAE: 0.0013 - val_loss: 3.2001e-06 - learning_rate: 1.0000e-05
# Epoch 53/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0028 - loss: 1.5694e-05 - val_MAE: 0.0014 - val_loss: 3.3982e-06 - learning_rate: 1.0000e-05
# Epoch 54/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0027 - loss: 1.3971e-05 - val_MAE: 0.0013 - val_loss: 3.2405e-06 - learning_rate: 1.0000e-05
# Epoch 55/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0026 - loss: 1.3154e-05 - val_MAE: 0.0013 - val_loss: 3.1564e-06 - learning_rate: 1.0000e-05
# Epoch 56/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0026 - loss: 1.2901e-05 - val_MAE: 0.0013 - val_loss: 3.0928e-06 - learning_rate: 1.0000e-05
# Epoch 57/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0028 - loss: 1.6144e-05 - val_MAE: 0.0013 - val_loss: 3.0876e-06 - learning_rate: 1.0000e-05
# Epoch 58/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0026 - loss: 1.4010e-05 - val_MAE: 0.0014 - val_loss: 3.3572e-06 - learning_rate: 1.0000e-05
# Epoch 59/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0027 - loss: 1.5371e-05 - val_MAE: 0.0013 - val_loss: 3.1690e-06 - learning_rate: 1.0000e-05
# Epoch 60/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0025 - loss: 1.3440e-05 - val_MAE: 0.0013 - val_loss: 3.0677e-06 - learning_rate: 1.0000e-05
# Epoch 61/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0026 - loss: 1.3819e-05 - val_MAE: 0.0014 - val_loss: 3.3014e-06 - learning_rate: 1.0000e-05
# Epoch 62/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0026 - loss: 1.3331e-05 - val_MAE: 0.0014 - val_loss: 3.3431e-06 - learning_rate: 1.0000e-05
# Epoch 63/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0026 - loss: 1.4887e-05 - val_MAE: 0.0014 - val_loss: 3.2900e-06 - learning_rate: 1.0000e-05
# Epoch 64/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0026 - loss: 1.2547e-05 - val_MAE: 0.0013 - val_loss: 3.1849e-06 - learning_rate: 1.0000e-05
# Epoch 65/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0025 - loss: 1.1433e-05 - val_MAE: 0.0013 - val_loss: 3.1846e-06 - learning_rate: 1.0000e-05
# Epoch 66/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0026 - loss: 1.4552e-05 - val_MAE: 0.0013 - val_loss: 3.1351e-06 - learning_rate: 1.0000e-05
# Epoch 67/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0025 - loss: 1.5528e-05 - val_MAE: 0.0013 - val_loss: 3.2091e-06 - learning_rate: 1.0000e-05
# Epoch 68/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0026 - loss: 1.3992e-05 - val_MAE: 0.0013 - val_loss: 3.1496e-06 - learning_rate: 1.0000e-05
# Epoch 69/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0026 - loss: 1.4596e-05 - val_MAE: 0.0013 - val_loss: 3.1958e-06 - learning_rate: 1.0000e-05
# Epoch 70/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0026 - loss: 1.4004e-05 - val_MAE: 0.0013 - val_loss: 3.1487e-06 - learning_rate: 1.0000e-05
# Adamax Optimizer - Loss (MSE): 0.000003, Mean Absolute Error: 0.001274
#
# Training with RMSprop optimizer and leaky_relu activation function...
# Epoch 1/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - MAE: 0.0031 - loss: 1.8073e-05 - val_MAE: 0.0014 - val_loss: 3.7664e-06 - learning_rate: 0.0010
# Epoch 2/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0027 - loss: 1.2679e-05 - val_MAE: 0.0017 - val_loss: 4.3453e-06 - learning_rate: 0.0010
# Epoch 3/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0027 - loss: 1.3996e-05 - val_MAE: 0.0025 - val_loss: 7.6104e-06 - learning_rate: 0.0010
# Epoch 4/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0026 - loss: 1.2005e-05 - val_MAE: 0.0013 - val_loss: 3.0319e-06 - learning_rate: 0.0010
# Epoch 5/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0025 - loss: 1.1447e-05 - val_MAE: 0.0033 - val_loss: 1.2641e-05 - learning_rate: 0.0010
# Epoch 6/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0023 - loss: 9.3049e-06 - val_MAE: 0.0029 - val_loss: 1.0137e-05 - learning_rate: 0.0010
# Epoch 7/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0021 - loss: 8.7545e-06 - val_MAE: 0.0012 - val_loss: 2.8096e-06 - learning_rate: 2.0000e-04
# Epoch 8/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0020 - loss: 7.3040e-06 - val_MAE: 0.0014 - val_loss: 3.5836e-06 - learning_rate: 2.0000e-04
# Epoch 9/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0021 - loss: 8.4112e-06 - val_MAE: 0.0017 - val_loss: 4.5894e-06 - learning_rate: 2.0000e-04
# Epoch 10/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0019 - loss: 7.6532e-06 - val_MAE: 0.0011 - val_loss: 2.6311e-06 - learning_rate: 2.0000e-04
# Epoch 11/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0020 - loss: 7.9463e-06 - val_MAE: 0.0013 - val_loss: 3.2636e-06 - learning_rate: 2.0000e-04
# Epoch 12/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0020 - loss: 8.7272e-06 - val_MAE: 0.0013 - val_loss: 3.1638e-06 - learning_rate: 4.0000e-05
# Epoch 13/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0021 - loss: 8.0198e-06 - val_MAE: 0.0014 - val_loss: 3.4297e-06 - learning_rate: 4.0000e-05
# Epoch 14/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0020 - loss: 8.0437e-06 - val_MAE: 0.0014 - val_loss: 3.3054e-06 - learning_rate: 4.0000e-05
# Epoch 15/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0020 - loss: 8.0128e-06 - val_MAE: 0.0015 - val_loss: 3.6947e-06 - learning_rate: 4.0000e-05
# Epoch 16/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0019 - loss: 7.1646e-06 - val_MAE: 0.0012 - val_loss: 2.7339e-06 - learning_rate: 4.0000e-05
# Epoch 17/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0020 - loss: 8.1456e-06 - val_MAE: 0.0013 - val_loss: 3.1025e-06 - learning_rate: 1.0000e-05
# Epoch 18/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0020 - loss: 8.0609e-06 - val_MAE: 0.0012 - val_loss: 2.9889e-06 - learning_rate: 1.0000e-05
# Epoch 19/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0020 - loss: 7.7162e-06 - val_MAE: 0.0013 - val_loss: 3.1075e-06 - learning_rate: 1.0000e-05
# Epoch 20/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0020 - loss: 8.0088e-06 - val_MAE: 0.0013 - val_loss: 3.0129e-06 - learning_rate: 1.0000e-05
# RMSprop Optimizer - Loss (MSE): 0.000003, Mean Absolute Error: 0.001116
#
# Training with SGD optimizer and leaky_relu activation function...
# Epoch 1/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - MAE: 0.0020 - loss: 7.9863e-06 - val_MAE: 0.0013 - val_loss: 3.2994e-06 - learning_rate: 0.0100
# Epoch 2/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0021 - loss: 8.6642e-06 - val_MAE: 0.0013 - val_loss: 3.0499e-06 - learning_rate: 0.0100
# Epoch 3/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0019 - loss: 7.1883e-06 - val_MAE: 0.0012 - val_loss: 2.9692e-06 - learning_rate: 0.0100
# Epoch 4/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0020 - loss: 7.6756e-06 - val_MAE: 0.0014 - val_loss: 3.6085e-06 - learning_rate: 0.0100
# Epoch 5/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0020 - loss: 8.1181e-06 - val_MAE: 0.0013 - val_loss: 3.1151e-06 - learning_rate: 0.0100
# Epoch 6/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0019 - loss: 7.1748e-06 - val_MAE: 0.0015 - val_loss: 3.6629e-06 - learning_rate: 0.0100
# Epoch 7/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0019 - loss: 7.3831e-06 - val_MAE: 0.0013 - val_loss: 3.1166e-06 - learning_rate: 0.0020
# Epoch 8/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0019 - loss: 7.7992e-06 - val_MAE: 0.0013 - val_loss: 3.1165e-06 - learning_rate: 0.0020
# Epoch 9/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0019 - loss: 7.2078e-06 - val_MAE: 0.0012 - val_loss: 2.9108e-06 - learning_rate: 0.0020
# Epoch 10/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0019 - loss: 6.9962e-06 - val_MAE: 0.0013 - val_loss: 3.2002e-06 - learning_rate: 0.0020
# Epoch 11/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0019 - loss: 7.1383e-06 - val_MAE: 0.0012 - val_loss: 2.9800e-06 - learning_rate: 0.0020
# Epoch 12/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0020 - loss: 7.5549e-06 - val_MAE: 0.0012 - val_loss: 2.9902e-06 - learning_rate: 4.0000e-04
# Epoch 13/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0020 - loss: 7.9072e-06 - val_MAE: 0.0013 - val_loss: 3.0769e-06 - learning_rate: 4.0000e-04
# Epoch 14/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0020 - loss: 8.0664e-06 - val_MAE: 0.0013 - val_loss: 3.1247e-06 - learning_rate: 4.0000e-04
# Epoch 15/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0019 - loss: 7.5448e-06 - val_MAE: 0.0013 - val_loss: 3.0659e-06 - learning_rate: 4.0000e-04
# Epoch 16/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0020 - loss: 7.9116e-06 - val_MAE: 0.0013 - val_loss: 3.1433e-06 - learning_rate: 4.0000e-04
# Epoch 17/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0020 - loss: 7.7479e-06 - val_MAE: 0.0013 - val_loss: 3.1362e-06 - learning_rate: 8.0000e-05
# Epoch 18/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0020 - loss: 8.2254e-06 - val_MAE: 0.0013 - val_loss: 3.1397e-06 - learning_rate: 8.0000e-05
# Epoch 19/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0019 - loss: 7.4236e-06 - val_MAE: 0.0013 - val_loss: 3.1531e-06 - learning_rate: 8.0000e-05
# SGD Optimizer - Loss (MSE): 0.000003, Mean Absolute Error: 0.001220
#
# Running for activation function: elu
#
# Training with Adamax optimizer and elu activation function...
# Epoch 1/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - MAE: 0.0651 - loss: 0.0082 - val_MAE: 0.0089 - val_loss: 1.2175e-04 - learning_rate: 0.0020
# Epoch 2/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0254 - loss: 0.0011 - val_MAE: 0.0051 - val_loss: 4.2367e-05 - learning_rate: 0.0020
# Epoch 3/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0191 - loss: 6.3465e-04 - val_MAE: 0.0031 - val_loss: 1.6350e-05 - learning_rate: 0.0020
# Epoch 4/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0157 - loss: 4.4148e-04 - val_MAE: 0.0024 - val_loss: 9.6960e-06 - learning_rate: 0.0020
# Epoch 5/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAE: 0.0133 - loss: 3.0772e-04 - val_MAE: 0.0028 - val_loss: 1.2088e-05 - learning_rate: 0.0020
# Epoch 6/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - MAE: 0.0114 - loss: 2.2769e-04 - val_MAE: 0.0018 - val_loss: 5.8642e-06 - learning_rate: 0.0020
# Epoch 7/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0098 - loss: 1.6481e-04 - val_MAE: 0.0016 - val_loss: 4.3708e-06 - learning_rate: 0.0020
# Epoch 8/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0083 - loss: 1.2507e-04 - val_MAE: 0.0015 - val_loss: 3.7254e-06 - learning_rate: 0.0020
# Epoch 9/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0078 - loss: 1.0903e-04 - val_MAE: 0.0014 - val_loss: 3.5961e-06 - learning_rate: 4.0000e-04
# Epoch 10/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0079 - loss: 1.1153e-04 - val_MAE: 0.0015 - val_loss: 3.8250e-06 - learning_rate: 4.0000e-04
# Epoch 11/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0074 - loss: 9.5635e-05 - val_MAE: 0.0013 - val_loss: 3.1843e-06 - learning_rate: 4.0000e-04
# Epoch 12/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0070 - loss: 8.6750e-05 - val_MAE: 0.0014 - val_loss: 3.4204e-06 - learning_rate: 4.0000e-04
# Epoch 13/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0068 - loss: 8.2246e-05 - val_MAE: 0.0017 - val_loss: 5.0834e-06 - learning_rate: 4.0000e-04
# Epoch 14/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0070 - loss: 8.6243e-05 - val_MAE: 0.0015 - val_loss: 3.9618e-06 - learning_rate: 8.0000e-05
# Epoch 15/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0064 - loss: 7.4564e-05 - val_MAE: 0.0014 - val_loss: 3.6944e-06 - learning_rate: 8.0000e-05
# Epoch 16/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0066 - loss: 7.6256e-05 - val_MAE: 0.0013 - val_loss: 3.2810e-06 - learning_rate: 8.0000e-05
# Epoch 17/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0066 - loss: 8.2132e-05 - val_MAE: 0.0012 - val_loss: 2.9010e-06 - learning_rate: 8.0000e-05
# Epoch 18/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0066 - loss: 7.7457e-05 - val_MAE: 0.0014 - val_loss: 3.5689e-06 - learning_rate: 8.0000e-05
# Epoch 19/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0063 - loss: 7.0448e-05 - val_MAE: 0.0014 - val_loss: 3.5241e-06 - learning_rate: 1.6000e-05
# Epoch 20/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0064 - loss: 7.4438e-05 - val_MAE: 0.0014 - val_loss: 3.4358e-06 - learning_rate: 1.6000e-05
# Epoch 21/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0066 - loss: 7.5527e-05 - val_MAE: 0.0013 - val_loss: 3.3006e-06 - learning_rate: 1.6000e-05
# Epoch 22/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0064 - loss: 7.5794e-05 - val_MAE: 0.0013 - val_loss: 3.2759e-06 - learning_rate: 1.6000e-05
# Epoch 23/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0065 - loss: 8.1597e-05 - val_MAE: 0.0014 - val_loss: 3.4242e-06 - learning_rate: 1.6000e-05
# Epoch 24/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0063 - loss: 7.3667e-05 - val_MAE: 0.0014 - val_loss: 3.3341e-06 - learning_rate: 1.0000e-05
# Epoch 25/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0065 - loss: 7.3363e-05 - val_MAE: 0.0014 - val_loss: 3.3992e-06 - learning_rate: 1.0000e-05
# Epoch 26/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0060 - loss: 6.6234e-05 - val_MAE: 0.0014 - val_loss: 3.4506e-06 - learning_rate: 1.0000e-05
# Epoch 27/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0066 - loss: 7.7869e-05 - val_MAE: 0.0014 - val_loss: 3.5270e-06 - learning_rate: 1.0000e-05
# Adamax Optimizer - Loss (MSE): 0.000003, Mean Absolute Error: 0.001245
#
# Training with RMSprop optimizer and elu activation function...
# Epoch 1/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - MAE: 0.0075 - loss: 1.0132e-04 - val_MAE: 0.0037 - val_loss: 1.5229e-05 - learning_rate: 0.0010
# Epoch 2/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0046 - loss: 3.5129e-05 - val_MAE: 0.0047 - val_loss: 2.4151e-05 - learning_rate: 0.0010
# Epoch 3/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0036 - loss: 2.1313e-05 - val_MAE: 0.0037 - val_loss: 1.5176e-05 - learning_rate: 0.0010
# Epoch 4/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0033 - loss: 1.6961e-05 - val_MAE: 0.0057 - val_loss: 3.3738e-05 - learning_rate: 0.0010
# Epoch 5/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0035 - loss: 1.8433e-05 - val_MAE: 0.0018 - val_loss: 5.0129e-06 - learning_rate: 0.0010
# Epoch 6/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0033 - loss: 1.5787e-05 - val_MAE: 0.0050 - val_loss: 2.6969e-05 - learning_rate: 0.0010
# Epoch 7/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0019 - loss: 7.0880e-06 - val_MAE: 0.0010 - val_loss: 2.1271e-06 - learning_rate: 2.0000e-04
# Epoch 8/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0016 - loss: 6.6584e-06 - val_MAE: 0.0011 - val_loss: 2.4519e-06 - learning_rate: 2.0000e-04
# Epoch 9/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0015 - loss: 4.6487e-06 - val_MAE: 9.6649e-04 - val_loss: 1.9387e-06 - learning_rate: 2.0000e-04
# Epoch 10/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0015 - loss: 5.0122e-06 - val_MAE: 0.0011 - val_loss: 2.3932e-06 - learning_rate: 2.0000e-04
# Epoch 11/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0015 - loss: 5.3212e-06 - val_MAE: 0.0011 - val_loss: 2.3557e-06 - learning_rate: 2.0000e-04
# Epoch 12/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0014 - loss: 4.6552e-06 - val_MAE: 0.0012 - val_loss: 2.8096e-06 - learning_rate: 4.0000e-05
# Epoch 13/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0014 - loss: 5.3072e-06 - val_MAE: 0.0012 - val_loss: 2.6890e-06 - learning_rate: 4.0000e-05
# Epoch 14/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0014 - loss: 4.5716e-06 - val_MAE: 0.0012 - val_loss: 2.6498e-06 - learning_rate: 4.0000e-05
# Epoch 15/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0014 - loss: 4.5092e-06 - val_MAE: 0.0012 - val_loss: 2.5949e-06 - learning_rate: 4.0000e-05
# Epoch 16/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0014 - loss: 3.8223e-06 - val_MAE: 0.0011 - val_loss: 2.3175e-06 - learning_rate: 4.0000e-05
# Epoch 17/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0015 - loss: 4.7721e-06 - val_MAE: 0.0011 - val_loss: 2.4756e-06 - learning_rate: 1.0000e-05
# Epoch 18/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0014 - loss: 5.2797e-06 - val_MAE: 0.0011 - val_loss: 2.4728e-06 - learning_rate: 1.0000e-05
# Epoch 19/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0014 - loss: 4.1646e-06 - val_MAE: 0.0011 - val_loss: 2.3984e-06 - learning_rate: 1.0000e-05
# RMSprop Optimizer - Loss (MSE): 0.000002, Mean Absolute Error: 0.000966
#
# Training with SGD optimizer and elu activation function...
# Epoch 1/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - MAE: 0.0016 - loss: 6.1136e-06 - val_MAE: 0.0012 - val_loss: 2.7320e-06 - learning_rate: 0.0100
# Epoch 2/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0015 - loss: 4.5985e-06 - val_MAE: 0.0012 - val_loss: 2.7430e-06 - learning_rate: 0.0100
# Epoch 3/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0015 - loss: 4.7902e-06 - val_MAE: 0.0011 - val_loss: 2.4641e-06 - learning_rate: 0.0100
# Epoch 4/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0015 - loss: 5.7813e-06 - val_MAE: 0.0012 - val_loss: 2.7064e-06 - learning_rate: 0.0100
# Epoch 5/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0015 - loss: 5.9674e-06 - val_MAE: 0.0013 - val_loss: 2.9347e-06 - learning_rate: 0.0100
# Epoch 6/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0015 - loss: 4.9232e-06 - val_MAE: 0.0012 - val_loss: 2.5736e-06 - learning_rate: 0.0100
# Epoch 7/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0014 - loss: 4.1718e-06 - val_MAE: 0.0011 - val_loss: 2.3657e-06 - learning_rate: 0.0020
# Epoch 8/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0013 - loss: 3.7541e-06 - val_MAE: 0.0011 - val_loss: 2.4423e-06 - learning_rate: 0.0020
# Epoch 9/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0014 - loss: 4.4723e-06 - val_MAE: 0.0012 - val_loss: 2.7134e-06 - learning_rate: 0.0020
# Epoch 10/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0014 - loss: 4.3351e-06 - val_MAE: 0.0011 - val_loss: 2.3902e-06 - learning_rate: 0.0020
# Epoch 11/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0014 - loss: 5.1451e-06 - val_MAE: 0.0012 - val_loss: 2.5711e-06 - learning_rate: 0.0020
# Epoch 12/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0014 - loss: 4.1567e-06 - val_MAE: 0.0011 - val_loss: 2.5152e-06 - learning_rate: 4.0000e-04
# Epoch 13/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0015 - loss: 5.1152e-06 - val_MAE: 0.0011 - val_loss: 2.5186e-06 - learning_rate: 4.0000e-04
# Epoch 14/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0014 - loss: 4.3341e-06 - val_MAE: 0.0011 - val_loss: 2.4970e-06 - learning_rate: 4.0000e-04
# Epoch 15/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0014 - loss: 4.4129e-06 - val_MAE: 0.0011 - val_loss: 2.4961e-06 - learning_rate: 4.0000e-04
# Epoch 16/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0014 - loss: 5.1718e-06 - val_MAE: 0.0011 - val_loss: 2.4760e-06 - learning_rate: 4.0000e-04
# Epoch 17/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0015 - loss: 5.0143e-06 - val_MAE: 0.0011 - val_loss: 2.4703e-06 - learning_rate: 8.0000e-05
# SGD Optimizer - Loss (MSE): 0.000002, Mean Absolute Error: 0.001095
#
# Running for activation function: prelu
#
# Training with Adamax optimizer and prelu activation function...
# Epoch 1/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - MAE: 0.0161 - loss: 5.2836e-04 - val_MAE: 0.0066 - val_loss: 4.9354e-05 - learning_rate: 0.0020
# Epoch 2/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0061 - loss: 6.2540e-05 - val_MAE: 0.0029 - val_loss: 1.1610e-05 - learning_rate: 0.0020
# Epoch 3/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0039 - loss: 2.9514e-05 - val_MAE: 0.0026 - val_loss: 1.0347e-05 - learning_rate: 0.0020
# Epoch 4/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0032 - loss: 1.8840e-05 - val_MAE: 0.0018 - val_loss: 6.2964e-06 - learning_rate: 0.0020
# Epoch 5/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0028 - loss: 1.5873e-05 - val_MAE: 0.0016 - val_loss: 4.6237e-06 - learning_rate: 0.0020
# Epoch 6/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0024 - loss: 1.3766e-05 - val_MAE: 0.0017 - val_loss: 5.0157e-06 - learning_rate: 0.0020
# Epoch 7/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0021 - loss: 9.4498e-06 - val_MAE: 0.0014 - val_loss: 5.0250e-06 - learning_rate: 4.0000e-04
# Epoch 8/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0022 - loss: 9.5043e-06 - val_MAE: 0.0015 - val_loss: 4.9710e-06 - learning_rate: 4.0000e-04
# Epoch 9/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0020 - loss: 9.2095e-06 - val_MAE: 0.0015 - val_loss: 5.2743e-06 - learning_rate: 4.0000e-04
# Epoch 10/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0019 - loss: 7.9476e-06 - val_MAE: 0.0014 - val_loss: 4.9910e-06 - learning_rate: 4.0000e-04
# Epoch 11/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0020 - loss: 8.5553e-06 - val_MAE: 0.0015 - val_loss: 5.4379e-06 - learning_rate: 4.0000e-04
# Epoch 12/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0019 - loss: 7.8097e-06 - val_MAE: 0.0015 - val_loss: 5.2431e-06 - learning_rate: 8.0000e-05
# Epoch 13/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0020 - loss: 8.1210e-06 - val_MAE: 0.0015 - val_loss: 5.2175e-06 - learning_rate: 8.0000e-05
# Epoch 14/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0018 - loss: 6.7483e-06 - val_MAE: 0.0015 - val_loss: 4.9581e-06 - learning_rate: 8.0000e-05
# Epoch 15/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0020 - loss: 9.3962e-06 - val_MAE: 0.0015 - val_loss: 5.3133e-06 - learning_rate: 8.0000e-05
# Adamax Optimizer - Loss (MSE): 0.000005, Mean Absolute Error: 0.001566
#
# Training with RMSprop optimizer and prelu activation function...
# Epoch 1/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - MAE: 0.0028 - loss: 1.4397e-05 - val_MAE: 0.0016 - val_loss: 5.6749e-06 - learning_rate: 0.0010
# Epoch 2/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0024 - loss: 1.0269e-05 - val_MAE: 0.0018 - val_loss: 6.7534e-06 - learning_rate: 0.0010
# Epoch 3/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0024 - loss: 1.0806e-05 - val_MAE: 0.0024 - val_loss: 7.4649e-06 - learning_rate: 0.0010
# Epoch 4/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0024 - loss: 9.7349e-06 - val_MAE: 0.0021 - val_loss: 5.9813e-06 - learning_rate: 0.0010
# Epoch 5/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0020 - loss: 7.9364e-06 - val_MAE: 0.0020 - val_loss: 5.7190e-06 - learning_rate: 0.0010
# Epoch 6/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0022 - loss: 8.4442e-06 - val_MAE: 0.0014 - val_loss: 4.2373e-06 - learning_rate: 0.0010
# Epoch 7/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0016 - loss: 5.8394e-06 - val_MAE: 0.0015 - val_loss: 4.9309e-06 - learning_rate: 2.0000e-04
# Epoch 8/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0016 - loss: 5.9944e-06 - val_MAE: 0.0015 - val_loss: 4.4808e-06 - learning_rate: 2.0000e-04
# Epoch 9/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0016 - loss: 5.5194e-06 - val_MAE: 0.0015 - val_loss: 4.3727e-06 - learning_rate: 2.0000e-04
# Epoch 10/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0016 - loss: 4.8545e-06 - val_MAE: 0.0014 - val_loss: 4.1474e-06 - learning_rate: 2.0000e-04
# Epoch 11/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0016 - loss: 5.8414e-06 - val_MAE: 0.0015 - val_loss: 4.4406e-06 - learning_rate: 2.0000e-04
# Epoch 12/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0016 - loss: 5.3134e-06 - val_MAE: 0.0014 - val_loss: 3.9967e-06 - learning_rate: 4.0000e-05
# Epoch 13/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0015 - loss: 4.9286e-06 - val_MAE: 0.0015 - val_loss: 4.4668e-06 - learning_rate: 4.0000e-05
# Epoch 14/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0015 - loss: 4.6010e-06 - val_MAE: 0.0014 - val_loss: 4.2899e-06 - learning_rate: 4.0000e-05
# Epoch 15/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0016 - loss: 5.4298e-06 - val_MAE: 0.0013 - val_loss: 3.8522e-06 - learning_rate: 4.0000e-05
# Epoch 16/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0015 - loss: 5.5990e-06 - val_MAE: 0.0014 - val_loss: 4.2188e-06 - learning_rate: 4.0000e-05
# Epoch 17/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0015 - loss: 5.0780e-06 - val_MAE: 0.0014 - val_loss: 4.1179e-06 - learning_rate: 1.0000e-05
# Epoch 18/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0016 - loss: 5.4114e-06 - val_MAE: 0.0014 - val_loss: 4.0353e-06 - learning_rate: 1.0000e-05
# Epoch 19/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0015 - loss: 5.3634e-06 - val_MAE: 0.0014 - val_loss: 3.9715e-06 - learning_rate: 1.0000e-05
# Epoch 20/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0015 - loss: 5.1759e-06 - val_MAE: 0.0014 - val_loss: 4.0429e-06 - learning_rate: 1.0000e-05
# Epoch 21/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0015 - loss: 4.7234e-06 - val_MAE: 0.0014 - val_loss: 4.0126e-06 - learning_rate: 1.0000e-05
# Epoch 22/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0016 - loss: 5.2869e-06 - val_MAE: 0.0013 - val_loss: 3.9317e-06 - learning_rate: 1.0000e-05
# Epoch 23/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0015 - loss: 5.6844e-06 - val_MAE: 0.0014 - val_loss: 4.1149e-06 - learning_rate: 1.0000e-05
# Epoch 24/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0015 - loss: 4.6828e-06 - val_MAE: 0.0014 - val_loss: 4.3002e-06 - learning_rate: 1.0000e-05
# Epoch 25/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0015 - loss: 5.0308e-06 - val_MAE: 0.0014 - val_loss: 4.0262e-06 - learning_rate: 1.0000e-05
# RMSprop Optimizer - Loss (MSE): 0.000004, Mean Absolute Error: 0.001323
#
# Training with SGD optimizer and prelu activation function...
# Epoch 1/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - MAE: 0.0015 - loss: 5.2493e-06 - val_MAE: 0.0014 - val_loss: 4.0238e-06 - learning_rate: 0.0100
# Epoch 2/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0015 - loss: 5.5068e-06 - val_MAE: 0.0014 - val_loss: 4.1889e-06 - learning_rate: 0.0100
# Epoch 3/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0016 - loss: 6.7039e-06 - val_MAE: 0.0014 - val_loss: 4.1622e-06 - learning_rate: 0.0100
# Epoch 4/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0015 - loss: 5.4647e-06 - val_MAE: 0.0013 - val_loss: 3.7448e-06 - learning_rate: 0.0100
# Epoch 5/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0015 - loss: 4.9790e-06 - val_MAE: 0.0013 - val_loss: 3.7413e-06 - learning_rate: 0.0100
# Epoch 6/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0015 - loss: 5.2713e-06 - val_MAE: 0.0013 - val_loss: 3.6729e-06 - learning_rate: 0.0100
# Epoch 7/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0016 - loss: 6.5200e-06 - val_MAE: 0.0014 - val_loss: 4.0742e-06 - learning_rate: 0.0020
# Epoch 8/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0015 - loss: 5.3892e-06 - val_MAE: 0.0014 - val_loss: 4.0443e-06 - learning_rate: 0.0020
# Epoch 9/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0015 - loss: 5.6662e-06 - val_MAE: 0.0013 - val_loss: 3.8957e-06 - learning_rate: 0.0020
# Epoch 10/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0015 - loss: 4.7467e-06 - val_MAE: 0.0013 - val_loss: 3.9410e-06 - learning_rate: 0.0020
# Epoch 11/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0015 - loss: 5.1904e-06 - val_MAE: 0.0014 - val_loss: 4.1183e-06 - learning_rate: 0.0020
# Epoch 12/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0015 - loss: 4.5429e-06 - val_MAE: 0.0014 - val_loss: 4.0664e-06 - learning_rate: 4.0000e-04
# Epoch 13/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0016 - loss: 6.2209e-06 - val_MAE: 0.0014 - val_loss: 3.9999e-06 - learning_rate: 4.0000e-04
# Epoch 14/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0015 - loss: 5.5684e-06 - val_MAE: 0.0014 - val_loss: 4.0134e-06 - learning_rate: 4.0000e-04
# Epoch 15/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0015 - loss: 4.7559e-06 - val_MAE: 0.0014 - val_loss: 4.0513e-06 - learning_rate: 4.0000e-04
# Epoch 16/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0015 - loss: 5.6463e-06 - val_MAE: 0.0014 - val_loss: 4.1198e-06 - learning_rate: 4.0000e-04
# SGD Optimizer - Loss (MSE): 0.000004, Mean Absolute Error: 0.001296
#
# Running for activation function: swish
#
# Training with Adamax optimizer and swish activation function...
# Epoch 1/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - MAE: 0.0174 - loss: 5.7321e-04 - val_MAE: 0.0030 - val_loss: 1.5374e-05 - learning_rate: 0.0020
# Epoch 2/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0072 - loss: 9.0357e-05 - val_MAE: 0.0019 - val_loss: 6.7262e-06 - learning_rate: 0.0020
# Epoch 3/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0055 - loss: 5.2324e-05 - val_MAE: 0.0017 - val_loss: 5.1425e-06 - learning_rate: 0.0020
# Epoch 4/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAE: 0.0045 - loss: 3.3605e-05 - val_MAE: 0.0014 - val_loss: 3.8712e-06 - learning_rate: 0.0020
# Epoch 5/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0038 - loss: 2.5148e-05 - val_MAE: 0.0013 - val_loss: 3.0863e-06 - learning_rate: 0.0020
# Epoch 6/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0035 - loss: 2.0642e-05 - val_MAE: 0.0011 - val_loss: 2.6353e-06 - learning_rate: 0.0020
# Epoch 7/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0031 - loss: 1.6809e-05 - val_MAE: 0.0012 - val_loss: 2.6945e-06 - learning_rate: 4.0000e-04
# Epoch 8/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0030 - loss: 1.5567e-05 - val_MAE: 0.0011 - val_loss: 2.5070e-06 - learning_rate: 4.0000e-04
# Epoch 9/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0030 - loss: 1.6402e-05 - val_MAE: 0.0011 - val_loss: 2.4196e-06 - learning_rate: 4.0000e-04
# Epoch 10/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0031 - loss: 1.7088e-05 - val_MAE: 0.0011 - val_loss: 2.3888e-06 - learning_rate: 4.0000e-04
# Epoch 11/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0030 - loss: 1.5144e-05 - val_MAE: 0.0011 - val_loss: 2.5868e-06 - learning_rate: 4.0000e-04
# Epoch 12/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0030 - loss: 1.5194e-05 - val_MAE: 0.0011 - val_loss: 2.3690e-06 - learning_rate: 8.0000e-05
# Epoch 13/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0029 - loss: 1.4858e-05 - val_MAE: 0.0011 - val_loss: 2.3504e-06 - learning_rate: 8.0000e-05
# Epoch 14/100
# ...
# Epoch 46/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAE: 0.0026 - loss: 1.2927e-05 - val_MAE: 0.0010 - val_loss: 2.2063e-06 - learning_rate: 1.0000e-05
# Epoch 47/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0025 - loss: 1.1512e-05 - val_MAE: 0.0010 - val_loss: 2.2006e-06 - learning_rate: 1.0000e-05
# Epoch 48/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0026 - loss: 1.2883e-05 - val_MAE: 0.0010 - val_loss: 2.1788e-06 - learning_rate: 1.0000e-05
# Epoch 49/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0026 - loss: 1.2080e-05 - val_MAE: 9.9804e-04 - val_loss: 2.1398e-06 - learning_rate: 1.0000e-05
# Epoch 50/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0027 - loss: 1.3221e-05 - val_MAE: 9.9778e-04 - val_loss: 2.1370e-06 - learning_rate: 1.0000e-05
# Epoch 51/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0026 - loss: 1.2317e-05 - val_MAE: 9.9421e-04 - val_loss: 2.1254e-06 - learning_rate: 1.0000e-05
# Epoch 52/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0027 - loss: 1.2602e-05 - val_MAE: 9.9699e-04 - val_loss: 2.1354e-06 - learning_rate: 1.0000e-05
# Epoch 53/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0026 - loss: 1.3159e-05 - val_MAE: 9.9112e-04 - val_loss: 2.1179e-06 - learning_rate: 1.0000e-05
# Epoch 54/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0026 - loss: 1.2359e-05 - val_MAE: 9.9363e-04 - val_loss: 2.1246e-06 - learning_rate: 1.0000e-05
# Epoch 55/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0026 - loss: 1.2471e-05 - val_MAE: 9.9864e-04 - val_loss: 2.1353e-06 - learning_rate: 1.0000e-05
# Epoch 56/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0026 - loss: 1.2419e-05 - val_MAE: 9.8673e-04 - val_loss: 2.1026e-06 - learning_rate: 1.0000e-05
# Epoch 57/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0025 - loss: 1.1246e-05 - val_MAE: 9.8411e-04 - val_loss: 2.0959e-06 - learning_rate: 1.0000e-05
# Epoch 58/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0026 - loss: 1.1834e-05 - val_MAE: 9.9844e-04 - val_loss: 2.1321e-06 - learning_rate: 1.0000e-05
# Epoch 59/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0023 - loss: 9.2404e-06 - val_MAE: 9.8251e-04 - val_loss: 2.0834e-06 - learning_rate: 1.0000e-05
# Epoch 60/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0025 - loss: 1.0635e-05 - val_MAE: 9.8382e-04 - val_loss: 2.0789e-06 - learning_rate: 1.0000e-05
# Epoch 61/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0024 - loss: 1.0264e-05 - val_MAE: 9.7558e-04 - val_loss: 2.0719e-06 - learning_rate: 1.0000e-05
# Epoch 62/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0026 - loss: 1.2366e-05 - val_MAE: 9.7552e-04 - val_loss: 2.0709e-06 - learning_rate: 1.0000e-05
# Epoch 63/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0025 - loss: 1.1227e-05 - val_MAE: 9.7392e-04 - val_loss: 2.0678e-06 - learning_rate: 1.0000e-05
# Epoch 64/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0024 - loss: 1.0260e-05 - val_MAE: 9.7418e-04 - val_loss: 2.0676e-06 - learning_rate: 1.0000e-05
# Epoch 65/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0024 - loss: 1.0313e-05 - val_MAE: 9.7449e-04 - val_loss: 2.0714e-06 - learning_rate: 1.0000e-05
# Epoch 66/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0024 - loss: 1.0467e-05 - val_MAE: 9.7645e-04 - val_loss: 2.0732e-06 - learning_rate: 1.0000e-05
# Epoch 67/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0025 - loss: 1.0785e-05 - val_MAE: 9.6885e-04 - val_loss: 2.0502e-06 - learning_rate: 1.0000e-05
# Epoch 68/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0024 - loss: 1.1352e-05 - val_MAE: 9.6924e-04 - val_loss: 2.0466e-06 - learning_rate: 1.0000e-05
# Epoch 69/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0024 - loss: 9.8516e-06 - val_MAE: 9.6466e-04 - val_loss: 2.0377e-06 - learning_rate: 1.0000e-05
# Epoch 70/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0024 - loss: 1.0715e-05 - val_MAE: 9.6250e-04 - val_loss: 2.0353e-06 - learning_rate: 1.0000e-05
# Epoch 71/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0024 - loss: 1.0006e-05 - val_MAE: 9.6666e-04 - val_loss: 2.0409e-06 - learning_rate: 1.0000e-05
# Epoch 72/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0024 - loss: 1.0691e-05 - val_MAE: 9.5970e-04 - val_loss: 2.0215e-06 - learning_rate: 1.0000e-05
# Epoch 73/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAE: 0.0023 - loss: 9.8533e-06 - val_MAE: 9.5841e-04 - val_loss: 2.0187e-06 - learning_rate: 1.0000e-05
# Epoch 74/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0023 - loss: 1.0124e-05 - val_MAE: 9.6888e-04 - val_loss: 2.0439e-06 - learning_rate: 1.0000e-05
# Epoch 75/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0023 - loss: 1.0014e-05 - val_MAE: 9.6849e-04 - val_loss: 2.0436e-06 - learning_rate: 1.0000e-05
# Epoch 76/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0023 - loss: 9.0339e-06 - val_MAE: 9.5592e-04 - val_loss: 2.0095e-06 - learning_rate: 1.0000e-05
# Epoch 77/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0022 - loss: 9.0442e-06 - val_MAE: 9.5754e-04 - val_loss: 2.0154e-06 - learning_rate: 1.0000e-05
# Epoch 78/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0023 - loss: 1.0239e-05 - val_MAE: 9.5871e-04 - val_loss: 2.0157e-06 - learning_rate: 1.0000e-05
# Epoch 79/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0022 - loss: 8.8247e-06 - val_MAE: 9.5487e-04 - val_loss: 1.9987e-06 - learning_rate: 1.0000e-05
# Epoch 80/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0022 - loss: 9.1575e-06 - val_MAE: 9.5449e-04 - val_loss: 2.0019e-06 - learning_rate: 1.0000e-05
# Epoch 81/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0023 - loss: 8.8484e-06 - val_MAE: 9.5870e-04 - val_loss: 2.0011e-06 - learning_rate: 1.0000e-05
# Epoch 82/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0022 - loss: 8.5855e-06 - val_MAE: 9.5033e-04 - val_loss: 1.9966e-06 - learning_rate: 1.0000e-05
# Epoch 83/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0022 - loss: 9.1777e-06 - val_MAE: 9.4889e-04 - val_loss: 1.9940e-06 - learning_rate: 1.0000e-05
# Epoch 84/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0022 - loss: 8.5536e-06 - val_MAE: 9.5072e-04 - val_loss: 1.9970e-06 - learning_rate: 1.0000e-05
# Epoch 85/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0022 - loss: 9.4519e-06 - val_MAE: 9.4861e-04 - val_loss: 1.9896e-06 - learning_rate: 1.0000e-05
# Epoch 86/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0022 - loss: 8.2349e-06 - val_MAE: 9.4572e-04 - val_loss: 1.9861e-06 - learning_rate: 1.0000e-05
# Epoch 87/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0022 - loss: 8.3912e-06 - val_MAE: 9.4555e-04 - val_loss: 1.9809e-06 - learning_rate: 1.0000e-05
# Epoch 88/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0022 - loss: 9.2241e-06 - val_MAE: 9.4396e-04 - val_loss: 1.9750e-06 - learning_rate: 1.0000e-05
# Epoch 89/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0022 - loss: 8.5059e-06 - val_MAE: 9.4354e-04 - val_loss: 1.9730e-06 - learning_rate: 1.0000e-05
# Epoch 90/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0020 - loss: 7.3093e-06 - val_MAE: 9.4562e-04 - val_loss: 1.9773e-06 - learning_rate: 1.0000e-05
# Epoch 91/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0022 - loss: 8.2382e-06 - val_MAE: 9.4205e-04 - val_loss: 1.9716e-06 - learning_rate: 1.0000e-05
# Epoch 92/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0021 - loss: 8.0754e-06 - val_MAE: 9.4091e-04 - val_loss: 1.9660e-06 - learning_rate: 1.0000e-05
# Epoch 93/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0021 - loss: 7.7487e-06 - val_MAE: 9.4205e-04 - val_loss: 1.9673e-06 - learning_rate: 1.0000e-05
# Epoch 94/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0022 - loss: 8.1827e-06 - val_MAE: 9.4101e-04 - val_loss: 1.9604e-06 - learning_rate: 1.0000e-05
# Epoch 95/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0022 - loss: 8.8387e-06 - val_MAE: 9.4057e-04 - val_loss: 1.9574e-06 - learning_rate: 1.0000e-05
# Epoch 96/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0021 - loss: 7.5863e-06 - val_MAE: 9.4271e-04 - val_loss: 1.9620e-06 - learning_rate: 1.0000e-05
# Epoch 97/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0020 - loss: 7.2738e-06 - val_MAE: 9.3847e-04 - val_loss: 1.9502e-06 - learning_rate: 1.0000e-05
# Epoch 98/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0021 - loss: 8.6896e-06 - val_MAE: 9.3625e-04 - val_loss: 1.9430e-06 - learning_rate: 1.0000e-05
# Epoch 99/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0021 - loss: 8.6012e-06 - val_MAE: 9.4079e-04 - val_loss: 1.9556e-06 - learning_rate: 1.0000e-05
# Epoch 100/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0021 - loss: 8.0574e-06 - val_MAE: 9.4463e-04 - val_loss: 1.9643e-06 - learning_rate: 1.0000e-05
# Adamax Optimizer - Loss (MSE): 0.000002, Mean Absolute Error: 0.000936
#
# Training with RMSprop optimizer and swish activation function...
# Epoch 1/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - MAE: 0.0030 - loss: 1.5089e-05 - val_MAE: 9.6410e-04 - val_loss: 2.0097e-06 - learning_rate: 0.0010
# Epoch 2/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0025 - loss: 1.0407e-05 - val_MAE: 0.0037 - val_loss: 1.5128e-05 - learning_rate: 0.0010
# Epoch 3/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0026 - loss: 1.0756e-05 - val_MAE: 0.0010 - val_loss: 2.1057e-06 - learning_rate: 0.0010
# Epoch 4/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0026 - loss: 1.1549e-05 - val_MAE: 0.0032 - val_loss: 1.1741e-05 - learning_rate: 0.0010
# Epoch 5/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0025 - loss: 1.0267e-05 - val_MAE: 9.3278e-04 - val_loss: 1.9272e-06 - learning_rate: 0.0010
# Epoch 6/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0025 - loss: 1.0316e-05 - val_MAE: 0.0026 - val_loss: 8.5117e-06 - learning_rate: 0.0010
# Epoch 7/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0020 - loss: 7.7719e-06 - val_MAE: 9.8903e-04 - val_loss: 2.0554e-06 - learning_rate: 2.0000e-04
# Epoch 8/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0019 - loss: 6.1772e-06 - val_MAE: 9.4245e-04 - val_loss: 1.9504e-06 - learning_rate: 2.0000e-04
# Epoch 9/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0020 - loss: 7.0365e-06 - val_MAE: 9.4073e-04 - val_loss: 1.9461e-06 - learning_rate: 2.0000e-04
# Epoch 10/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0019 - loss: 7.0700e-06 - val_MAE: 0.0011 - val_loss: 2.2816e-06 - learning_rate: 2.0000e-04
# Epoch 11/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0019 - loss: 6.2783e-06 - val_MAE: 9.4616e-04 - val_loss: 1.9512e-06 - learning_rate: 2.0000e-04
# Epoch 12/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0018 - loss: 6.5060e-06 - val_MAE: 9.4069e-04 - val_loss: 1.9394e-06 - learning_rate: 4.0000e-05
# Epoch 13/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0019 - loss: 6.7885e-06 - val_MAE: 9.2986e-04 - val_loss: 1.9189e-06 - learning_rate: 4.0000e-05
# Epoch 14/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0019 - loss: 7.9216e-06 - val_MAE: 9.3657e-04 - val_loss: 1.9365e-06 - learning_rate: 4.0000e-05
# Epoch 15/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0019 - loss: 7.1286e-06 - val_MAE: 9.3559e-04 - val_loss: 1.9345e-06 - learning_rate: 4.0000e-05
# Epoch 16/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0019 - loss: 6.4090e-06 - val_MAE: 9.2844e-04 - val_loss: 1.9183e-06 - learning_rate: 4.0000e-05
# Epoch 17/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0019 - loss: 6.5049e-06 - val_MAE: 9.2850e-04 - val_loss: 1.9190e-06 - learning_rate: 1.0000e-05
# Epoch 18/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0018 - loss: 6.2732e-06 - val_MAE: 9.3625e-04 - val_loss: 1.9361e-06 - learning_rate: 1.0000e-05
# Epoch 19/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0019 - loss: 6.7890e-06 - val_MAE: 9.2871e-04 - val_loss: 1.9180e-06 - learning_rate: 1.0000e-05
# Epoch 20/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0019 - loss: 6.3221e-06 - val_MAE: 9.2976e-04 - val_loss: 1.9198e-06 - learning_rate: 1.0000e-05
# Epoch 21/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0019 - loss: 6.7077e-06 - val_MAE: 9.3141e-04 - val_loss: 1.9233e-06 - learning_rate: 1.0000e-05
# Epoch 22/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0018 - loss: 6.3411e-06 - val_MAE: 9.2881e-04 - val_loss: 1.9183e-06 - learning_rate: 1.0000e-05
# Epoch 23/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0019 - loss: 6.8536e-06 - val_MAE: 9.2847e-04 - val_loss: 1.9185e-06 - learning_rate: 1.0000e-05
# Epoch 24/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0018 - loss: 6.7102e-06 - val_MAE: 9.2900e-04 - val_loss: 1.9185e-06 - learning_rate: 1.0000e-05
# Epoch 25/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0019 - loss: 6.4921e-06 - val_MAE: 9.3431e-04 - val_loss: 1.9290e-06 - learning_rate: 1.0000e-05
# Epoch 26/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0018 - loss: 6.4703e-06 - val_MAE: 9.3174e-04 - val_loss: 1.9240e-06 - learning_rate: 1.0000e-05
# Epoch 27/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0018 - loss: 6.2541e-06 - val_MAE: 9.3549e-04 - val_loss: 1.9346e-06 - learning_rate: 1.0000e-05
# Epoch 28/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0019 - loss: 6.7836e-06 - val_MAE: 9.3102e-04 - val_loss: 1.9252e-06 - learning_rate: 1.0000e-05
# Epoch 29/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0019 - loss: 7.0555e-06 - val_MAE: 9.4470e-04 - val_loss: 1.9508e-06 - learning_rate: 1.0000e-05
# RMSprop Optimizer - Loss (MSE): 0.000002, Mean Absolute Error: 0.000929
#
# Training with SGD optimizer and swish activation function...
# Epoch 1/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - MAE: 0.0019 - loss: 7.0117e-06 - val_MAE: 9.5265e-04 - val_loss: 1.9691e-06 - learning_rate: 0.0100
# Epoch 2/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0019 - loss: 7.3102e-06 - val_MAE: 9.4396e-04 - val_loss: 1.9546e-06 - learning_rate: 0.0100
# Epoch 3/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0018 - loss: 6.1945e-06 - val_MAE: 9.7712e-04 - val_loss: 2.0331e-06 - learning_rate: 0.0100
# Epoch 4/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0018 - loss: 5.8701e-06 - val_MAE: 9.2836e-04 - val_loss: 1.9186e-06 - learning_rate: 0.0100
# Epoch 5/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0019 - loss: 6.7659e-06 - val_MAE: 9.2875e-04 - val_loss: 1.9179e-06 - learning_rate: 0.0100
# Epoch 6/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0019 - loss: 6.2835e-06 - val_MAE: 9.5377e-04 - val_loss: 1.9785e-06 - learning_rate: 0.0100
# Epoch 7/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0018 - loss: 5.5992e-06 - val_MAE: 9.2834e-04 - val_loss: 1.9180e-06 - learning_rate: 0.0020
# Epoch 8/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0019 - loss: 6.2795e-06 - val_MAE: 9.3423e-04 - val_loss: 1.9317e-06 - learning_rate: 0.0020
# Epoch 9/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0018 - loss: 6.0558e-06 - val_MAE: 9.2915e-04 - val_loss: 1.9208e-06 - learning_rate: 0.0020
# Epoch 10/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0019 - loss: 6.6463e-06 - val_MAE: 9.3319e-04 - val_loss: 1.9272e-06 - learning_rate: 0.0020
# Epoch 11/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0020 - loss: 8.3211e-06 - val_MAE: 9.2853e-04 - val_loss: 1.9181e-06 - learning_rate: 0.0020
# Epoch 12/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0019 - loss: 6.3913e-06 - val_MAE: 9.2839e-04 - val_loss: 1.9187e-06 - learning_rate: 4.0000e-04
# Epoch 13/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0018 - loss: 6.5381e-06 - val_MAE: 9.2850e-04 - val_loss: 1.9180e-06 - learning_rate: 4.0000e-04
# Epoch 14/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0019 - loss: 6.5450e-06 - val_MAE: 9.2836e-04 - val_loss: 1.9183e-06 - learning_rate: 4.0000e-04
# Epoch 15/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0019 - loss: 6.6571e-06 - val_MAE: 9.2836e-04 - val_loss: 1.9184e-06 - learning_rate: 4.0000e-04
# SGD Optimizer - Loss (MSE): 0.000002, Mean Absolute Error: 0.000929

# %%
print(all_mae_values)
print(all_loss_values)
print(all_labels)
# Out:
# [0.0015080288285389543, 0.001363700837828219, 0.001408647047355771, 0.0012737233191728592, 0.0011159410933032632, 0.0012201647041365504, 0.0012446881737560034, 0.0009664914105087519, 0.0010948897106572986, 0.001565909362398088, 0.0013227002928033471, 0.0012956819264218211, 0.0009362518321722746, 0.0009287112625315785, 0.0009287467109970748]
# [4.372535386210075e-06, 3.835123607132118e-06, 4.238104338583071e-06, 3.0677233553433325e-06, 2.6311461169825634e-06, 2.9108020953572122e-06, 2.901002289945609e-06, 1.9387043721508235e-06, 2.3656700705032563e-06, 4.623704626283143e-06, 3.852246663882397e-06, 3.672910452223732e-06, 1.9430381144047715e-06, 1.9180226900061825e-06, 1.9179374248778913e-06]
# ['relu, Adamax', 'relu, RMSprop', 'relu, SGD', 'leaky_relu, Adamax', 'leaky_relu, RMSprop', 'leaky_relu, SGD', 'elu, Adamax', 'elu, RMSprop', 'elu, SGD', 'prelu, Adamax', 'prelu, RMSprop', 'prelu, SGD', 'swish, Adamax', 'swish, RMSprop', 'swish, SGD']

# %%
# Create a DataFrame
cancer_models_df = pd.DataFrame({
    'Model': all_labels,
    'Activation_Function': all_activation_functions, 
    'Optimizer': all_optimizers, 
    'MAE': all_mae_values,
    'Loss': all_loss_values
})

cancer_models_df
# Out:
#                   Model Activation_Function Optimizer       MAE      Loss
# 0          relu, Adamax                relu    Adamax  0.001508  0.000004
# 1         relu, RMSprop                relu   RMSprop  0.001364  0.000004
# 2             relu, SGD                relu       SGD  0.001409  0.000004
# 3    leaky_relu, Adamax          leaky_relu    Adamax  0.001274  0.000003
# 4   leaky_relu, RMSprop          leaky_relu   RMSprop  0.001116  0.000003
# 5       leaky_relu, SGD          leaky_relu       SGD  0.001220  0.000003
# 6           elu, Adamax                 elu    Adamax  0.001245  0.000003
# 7          elu, RMSprop                 elu   RMSprop  0.000966  0.000002
# 8              elu, SGD                 elu       SGD  0.001095  0.000002
# 9         prelu, Adamax               prelu    Adamax  0.001566  0.000005
# 10       prelu, RMSprop               prelu   RMSprop  0.001323  0.000004
# 11           prelu, SGD               prelu       SGD  0.001296  0.000004
# 12        swish, Adamax               swish    Adamax  0.000936  0.000002
# 13       swish, RMSprop               swish   RMSprop  0.000929  0.000002
# 14           swish, SGD               swish       SGD  0.000929  0.000002

# %%
# Plotting
fig, ax1 = plt.subplots(figsize=(14, 8))

# Bar plot for Accuracy
color = 'tab:blue'
ax1.set_xlabel('Model')
ax1.set_ylabel('Mean Absolute Error', color=color)
ax1.bar(cancer_models_df['Model'], cancer_models_df['MAE'], color=color, alpha=0.6, label='MAE')
ax1.tick_params(axis='y', labelcolor=color)
ax1.set_xticks(range(len(cancer_models_df['Model'])))
ax1.set_xticklabels(cancer_models_df['Model'], rotation=90)

# Create a second y-axis for Loss
ax2 = ax1.twinx()
color = 'tab:red'
ax2.set_ylabel('Loss (MSE)', color=color)
ax2.plot(cancer_models_df['Model'], cancer_models_df['Loss'], color=color, marker='o', linestyle='-', linewidth=2, markersize=8, label='Loss')
ax2.tick_params(axis='y', labelcolor=color)

# Title and layout
plt.title('MAE and Loss for Cancer Models')
fig.tight_layout()
plt.show()

# %%
# Rank the models based on MAE (lower is better)
cancer_models_df['MAE_Rank'] = cancer_models_df['MAE'].rank()

# Rank the models based on Loss (lower is better)
cancer_models_df['Loss_Rank'] = cancer_models_df['Loss'].rank()

# Calculate the average rank
cancer_models_df['Average_Rank'] = (cancer_models_df['MAE_Rank'] + cancer_models_df['Loss_Rank']) / 2

# Find the top two ranked models
best_model_avg_rank = cancer_models_df.sort_values('Average_Rank').iloc[0]
print(best_model_avg_rank)
# Out:
# Model                  swish, RMSprop
# Activation_Function             swish
# Optimizer                     RMSprop
# MAE                          0.000929
# Loss                         0.000002
# MAE_Rank                          1.0
# Loss_Rank                         2.0
# Average_Rank                      1.5
# Name: 13, dtype: object
