# %%
import warnings
from pathlib import Path
import pandas as pd
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Dense, Dropout, Input, Activation
from keras.optimizers import Adamax, RMSprop, SGD
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from keras.layers import LeakyReLU, ELU, PReLU
import tensorflow as tf
from tensorflow.keras.callbacks import EarlyStopping
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

# %%
# File Path
cancer_data_to_load = Path("../Outputs/CANCER_sdoh_access.csv")

# Read shcool metrics into Pandas DataFrames
cancer_df = pd.read_csv(cancer_data_to_load)

cancer_df.head()
# Out:
#    county_index  target_cancer  AGE65  BROAD  CROWD  HCOST  NOHSDP  POV150  \
# 0          1001            6.3   15.1   14.5    1.5   21.5    10.4    21.7
# 1          1011            5.5   16.2   40.6    0.8   23.9    22.4    46.0
# 2          1021            6.3   16.4   21.7    2.9   16.1    18.2    26.5
# 3          1029            6.4   19.2   27.2    2.1   18.1    16.9    27.3
# 4          1049            6.3   16.9   20.1    3.3   20.9    21.8    35.4
#
#    REMNRTY  SNGPNT  UNEMP  No_Vehicle_10_Miles  No_Vehicle_1_Mile  \
# 0     26.9     7.1    2.8             0.406809           1.528284
# 1     79.6    14.5    3.0             0.733003           3.060290
# 2     20.7     4.5    6.4             0.025205           1.416035
# 3      7.6     4.5    4.5             0.073470           1.302431
# 4     20.4     5.8    4.3             0.000000           1.492076
#
#    No_Vehicle_Half_Mile
# 0              1.914937
# 1              3.967381
# 2              1.718489
# 3              1.436014
# 4              1.816929

# %%
# Divide the percentage values by 100 to prepare for Neural Network
columns_to_scale = cancer_df.dtypes[cancer_df.dtypes == "float64"].index.tolist()
cancer_df[columns_to_scale] = cancer_df[columns_to_scale] / 100
cancer_df.head()
# Out:
#    county_index  target_cancer  AGE65  BROAD  CROWD  HCOST  NOHSDP  POV150  \
# 0          1001          0.063  0.151  0.145  0.015  0.215   0.104   0.217
# 1          1011          0.055  0.162  0.406  0.008  0.239   0.224   0.460
# 2          1021          0.063  0.164  0.217  0.029  0.161   0.182   0.265
# 3          1029          0.064  0.192  0.272  0.021  0.181   0.169   0.273
# 4          1049          0.063  0.169  0.201  0.033  0.209   0.218   0.354
#
#    REMNRTY  SNGPNT  UNEMP  No_Vehicle_10_Miles  No_Vehicle_1_Mile  \
# 0    0.269   0.071  0.028             0.004068           0.015283
# 1    0.796   0.145  0.030             0.007330           0.030603
# 2    0.207   0.045  0.064             0.000252           0.014160
# 3    0.076   0.045  0.045             0.000735           0.013024
# 4    0.204   0.058  0.043             0.000000           0.014921
#
#    No_Vehicle_Half_Mile
# 0              0.019149
# 1              0.039674
# 2              0.017185
# 3              0.014360
# 4              0.018169

# %%
# Split data into our features and target arrays
y = cancer_df['target_cancer'].values
X = cancer_df.drop(columns = ['target_cancer', 'county_index']).values

# Split the arrays into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=12)

# Data was prescaled manually so set values to work with the train_model function
X_train_scaled = X_train
X_test_scaled = X_test

input_shape = len(X_train[0])

# %%
def train_model(X_train_scaled, y_train, X_test_scaled, y_test, activation_func='relu'):
    """
    Train a neural network with specified activation function and multiple optimizers.

    Args:
    - X_train_scaled: Scaled training data
    - y_train: Labels for training data
    - X_test_scaled: Scaled test data
    - y_test: Labels for test data
    - activation_func: Activation function to use (e.g., 'relu', 'leaky_relu', 'elu', 'prelu', 'swish')

    Returns:
    - mae_list2: List of mean absolute error for each optimizer
    - loss_list2: List of losses (MSE) for each optimizer
    """
    
    # Custom activation handling
    def get_activation(activation):
        if activation == 'leaky_relu':
            return LeakyReLU(alpha=0.1)  # Custom activation layer
        elif activation == 'elu':
            return ELU(alpha=1.0)  # Custom activation layer
        elif activation == 'prelu':
            return PReLU()  # Custom activation layer
        elif activation == 'swish':  # Or silu
            return Activation(tf.keras.activations.swish)  # Wrap as Activation layer
        else:
            return activation  # For standard activations like 'relu', 'sigmoid', etc.
    
    # Build model
    nn = tf.keras.models.Sequential()

    # Add the input layer
    nn.add(tf.keras.layers.Input(shape=(input_shape,)))
    
    # First hidden layer
    if isinstance(get_activation(activation_func), str):  # If it's a standard activation
        nn.add(tf.keras.layers.Dense(units=128, activation=get_activation(activation_func)))  # Use activation as string
    else:  # If it's a custom activation layer
        nn.add(tf.keras.layers.Dense(units=128))
        nn.add(get_activation(activation_func))  # Add custom activation layer
    
    # Dropout and subsequent layers
    nn.add(Dropout(0.3))
    if isinstance(get_activation(activation_func), str):
        nn.add(tf.keras.layers.Dense(units=64, activation=get_activation(activation_func)))
    else:
        nn.add(tf.keras.layers.Dense(units=64))
        nn.add(get_activation(activation_func))
    
    nn.add(Dropout(0.3))
    if isinstance(get_activation(activation_func), str):
        nn.add(tf.keras.layers.Dense(units=32, activation=get_activation(activation_func)))
    else:
        nn.add(tf.keras.layers.Dense(units=32))
        nn.add(get_activation(activation_func))
    
    # Output layer (for continuous data)
    nn.add(tf.keras.layers.Dense(units=1, activation="linear"))

    # Experiment with different optimizers
    optimizers = {
        'Adamax': Adamax(learning_rate=0.002),
        'RMSprop': RMSprop(learning_rate=0.001),
        'SGD': SGD(learning_rate=0.01, momentum=0.9)
    }

    mae_list2 = []
    loss_list2 = []

    # Iterate through each optimizer
    for name, optimizer in optimizers.items():
        print(f"\nTraining with {name} optimizer and {activation_func} activation function...")
        nn.compile(optimizer=optimizer, loss="mean_squared_error", metrics=["MAE"])

        # Callbacks
        early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
        reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=0.00001)

        # Train the model
        nn.fit(X_train_scaled, y_train, epochs=100, validation_data=(X_test_scaled, y_test),
               callbacks=[early_stopping, reduce_lr], verbose=1)

        # Evaluate the model
        loss, mae = nn.evaluate(X_test_scaled, y_test, verbose=0)
        print(f"{name} Optimizer - Loss (MSE): {loss:.6f}, Mean Absolute Error: {mae:.6f}")
        mae_list2.append(mae)
        loss_list2.append(loss)
    
    return mae_list2, loss_list2

# %%
all_mae_values = []
all_loss_values = []
all_labels = []
all_activation_functions = []
all_optimizers = []

activation_functions = ['relu', 'leaky_relu', 'elu', 'prelu', 'swish']
optimizers = ['Adamax', 'RMSprop', 'SGD']

for activation in activation_functions:
    print(f"\nRunning for activation function: {activation}")
    mae_list, loss_list = train_model(X_train_scaled, y_train, X_test_scaled, y_test, activation_func=activation)
    
    # Append the Mean Absolute Error, loss values and labels for this activation function
    all_mae_values.extend(mae_list)
    all_loss_values.extend(loss_list)
    
    # Create labels combining activation function and optimizer
    for optimizer in optimizers:
        all_labels.append(f"{activation}, {optimizer}")
        all_activation_functions.append(activation)
        all_optimizers.append(optimizer)
# Out:
# Running for activation function: relu
#
# Training with Adamax optimizer and relu activation function...
# Epoch 1/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - MAE: 0.0215 - loss: 8.8540e-04 - val_MAE: 0.0123 - val_loss: 1.6510e-04 - learning_rate: 0.0020
# Epoch 2/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0084 - loss: 1.2270e-04 - val_MAE: 0.0055 - val_loss: 3.6514e-05 - learning_rate: 0.0020
# Epoch 3/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0055 - loss: 5.4227e-05 - val_MAE: 0.0040 - val_loss: 2.0405e-05 - learning_rate: 0.0020
# Epoch 4/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0043 - loss: 3.6897e-05 - val_MAE: 0.0023 - val_loss: 8.7542e-06 - learning_rate: 0.0020
# Epoch 5/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0034 - loss: 2.1680e-05 - val_MAE: 0.0016 - val_loss: 5.2019e-06 - learning_rate: 0.0020
# Epoch 6/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0029 - loss: 1.8583e-05 - val_MAE: 0.0014 - val_loss: 4.0792e-06 - learning_rate: 0.0020
# Epoch 7/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0026 - loss: 1.3796e-05 - val_MAE: 0.0014 - val_loss: 3.8213e-06 - learning_rate: 0.0020
# Epoch 8/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0024 - loss: 1.2118e-05 - val_MAE: 0.0014 - val_loss: 3.8071e-06 - learning_rate: 4.0000e-04
# Epoch 9/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0024 - loss: 1.2996e-05 - val_MAE: 0.0014 - val_loss: 3.8560e-06 - learning_rate: 4.0000e-04
# Epoch 10/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0022 - loss: 1.1685e-05 - val_MAE: 0.0014 - val_loss: 3.7399e-06 - learning_rate: 4.0000e-04
# Epoch 11/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0023 - loss: 1.2442e-05 - val_MAE: 0.0014 - val_loss: 4.0105e-06 - learning_rate: 4.0000e-04
# Epoch 12/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0022 - loss: 1.0345e-05 - val_MAE: 0.0014 - val_loss: 3.8775e-06 - learning_rate: 4.0000e-04
# Epoch 13/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0021 - loss: 9.4612e-06 - val_MAE: 0.0014 - val_loss: 3.9007e-06 - learning_rate: 8.0000e-05
# Epoch 14/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0022 - loss: 1.1311e-05 - val_MAE: 0.0014 - val_loss: 3.9516e-06 - learning_rate: 8.0000e-05
# Epoch 15/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0022 - loss: 1.1583e-05 - val_MAE: 0.0014 - val_loss: 3.9418e-06 - learning_rate: 8.0000e-05
# Epoch 16/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0020 - loss: 8.9124e-06 - val_MAE: 0.0014 - val_loss: 3.9513e-06 - learning_rate: 8.0000e-05
# Epoch 17/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0020 - loss: 8.7991e-06 - val_MAE: 0.0014 - val_loss: 3.9081e-06 - learning_rate: 8.0000e-05
# Epoch 18/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0020 - loss: 8.4827e-06 - val_MAE: 0.0014 - val_loss: 3.9056e-06 - learning_rate: 1.6000e-05
# Epoch 19/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0022 - loss: 1.0792e-05 - val_MAE: 0.0014 - val_loss: 3.9634e-06 - learning_rate: 1.6000e-05
# Epoch 20/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0020 - loss: 8.0570e-06 - val_MAE: 0.0014 - val_loss: 4.0102e-06 - learning_rate: 1.6000e-05
# Adamax Optimizer - Loss (MSE): 0.000004, Mean Absolute Error: 0.001401
#
# Training with RMSprop optimizer and relu activation function...
# Epoch 1/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - MAE: 0.0025 - loss: 1.1766e-05 - val_MAE: 0.0029 - val_loss: 1.1685e-05 - learning_rate: 0.0010
# Epoch 2/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0024 - loss: 1.1033e-05 - val_MAE: 0.0017 - val_loss: 4.3831e-06 - learning_rate: 0.0010
# Epoch 3/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - MAE: 0.0022 - loss: 1.0026e-05 - val_MAE: 0.0025 - val_loss: 1.0135e-05 - learning_rate: 0.0010
# Epoch 4/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0021 - loss: 8.1634e-06 - val_MAE: 0.0016 - val_loss: 3.9242e-06 - learning_rate: 0.0010
# Epoch 5/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0021 - loss: 9.2026e-06 - val_MAE: 0.0015 - val_loss: 3.8489e-06 - learning_rate: 0.0010
# Epoch 6/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0019 - loss: 6.7489e-06 - val_MAE: 0.0014 - val_loss: 3.6929e-06 - learning_rate: 0.0010
# Epoch 7/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0016 - loss: 6.3813e-06 - val_MAE: 0.0014 - val_loss: 4.3056e-06 - learning_rate: 2.0000e-04
# Epoch 8/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0016 - loss: 6.1640e-06 - val_MAE: 0.0015 - val_loss: 4.1195e-06 - learning_rate: 2.0000e-04
# Epoch 9/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0016 - loss: 5.8509e-06 - val_MAE: 0.0014 - val_loss: 4.0419e-06 - learning_rate: 2.0000e-04
# Epoch 10/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0016 - loss: 5.6443e-06 - val_MAE: 0.0015 - val_loss: 4.0244e-06 - learning_rate: 2.0000e-04
# Epoch 11/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0015 - loss: 5.2314e-06 - val_MAE: 0.0014 - val_loss: 4.2581e-06 - learning_rate: 2.0000e-04
# Epoch 12/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - MAE: 0.0016 - loss: 5.4480e-06 - val_MAE: 0.0014 - val_loss: 4.2448e-06 - learning_rate: 4.0000e-05
# Epoch 13/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0015 - loss: 5.3232e-06 - val_MAE: 0.0014 - val_loss: 4.2830e-06 - learning_rate: 4.0000e-05
# Epoch 14/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0015 - loss: 5.0357e-06 - val_MAE: 0.0015 - val_loss: 4.7744e-06 - learning_rate: 4.0000e-05
# Epoch 15/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0014 - loss: 4.3805e-06 - val_MAE: 0.0014 - val_loss: 4.3289e-06 - learning_rate: 4.0000e-05
# Epoch 16/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0016 - loss: 6.5849e-06 - val_MAE: 0.0015 - val_loss: 4.4599e-06 - learning_rate: 4.0000e-05
# RMSprop Optimizer - Loss (MSE): 0.000004, Mean Absolute Error: 0.001423
#
# Training with SGD optimizer and relu activation function...
# Epoch 1/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - MAE: 0.0016 - loss: 6.0752e-06 - val_MAE: 0.0014 - val_loss: 3.9636e-06 - learning_rate: 0.0100
# Epoch 2/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - MAE: 0.0016 - loss: 6.6320e-06 - val_MAE: 0.0014 - val_loss: 4.4073e-06 - learning_rate: 0.0100
# Epoch 3/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0017 - loss: 6.6141e-06 - val_MAE: 0.0014 - val_loss: 4.1178e-06 - learning_rate: 0.0100
# Epoch 4/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0016 - loss: 5.5377e-06 - val_MAE: 0.0014 - val_loss: 4.1586e-06 - learning_rate: 0.0100
# Epoch 5/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - MAE: 0.0017 - loss: 6.8477e-06 - val_MAE: 0.0014 - val_loss: 4.0597e-06 - learning_rate: 0.0100
# Epoch 6/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0016 - loss: 5.4515e-06 - val_MAE: 0.0014 - val_loss: 4.3532e-06 - learning_rate: 0.0100
# Epoch 7/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - MAE: 0.0016 - loss: 6.2540e-06 - val_MAE: 0.0014 - val_loss: 4.1873e-06 - learning_rate: 0.0020
# Epoch 8/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0015 - loss: 5.4906e-06 - val_MAE: 0.0014 - val_loss: 4.2626e-06 - learning_rate: 0.0020
# Epoch 9/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0016 - loss: 6.0649e-06 - val_MAE: 0.0014 - val_loss: 4.2732e-06 - learning_rate: 0.0020
# Epoch 10/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0016 - loss: 6.1276e-06 - val_MAE: 0.0014 - val_loss: 4.2959e-06 - learning_rate: 0.0020
# Epoch 11/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0016 - loss: 5.7825e-06 - val_MAE: 0.0014 - val_loss: 4.1941e-06 - learning_rate: 0.0020
# SGD Optimizer - Loss (MSE): 0.000004, Mean Absolute Error: 0.001398
#
# Running for activation function: leaky_relu
#
# Training with Adamax optimizer and leaky_relu activation function...
# Epoch 1/100
# C:\Users\ecros\anaconda3\envs\dev\lib\site-packages\keras\src\layers\activations\leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - MAE: 0.0175 - loss: 5.2864e-04 - val_MAE: 0.0088 - val_loss: 9.1757e-05 - learning_rate: 0.0020
# Epoch 2/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0071 - loss: 8.3988e-05 - val_MAE: 0.0058 - val_loss: 3.9856e-05 - learning_rate: 0.0020
# Epoch 3/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0050 - loss: 4.3512e-05 - val_MAE: 0.0022 - val_loss: 8.3554e-06 - learning_rate: 0.0020
# Epoch 4/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0041 - loss: 3.0323e-05 - val_MAE: 0.0019 - val_loss: 5.9316e-06 - learning_rate: 0.0020
# Epoch 5/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0034 - loss: 2.0984e-05 - val_MAE: 0.0015 - val_loss: 4.1481e-06 - learning_rate: 0.0020
# Epoch 6/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0031 - loss: 1.7848e-05 - val_MAE: 0.0013 - val_loss: 3.5135e-06 - learning_rate: 0.0020
# Epoch 7/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0029 - loss: 1.7121e-05 - val_MAE: 0.0016 - val_loss: 4.7098e-06 - learning_rate: 4.0000e-04
# Epoch 8/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0028 - loss: 1.4229e-05 - val_MAE: 0.0015 - val_loss: 4.1436e-06 - learning_rate: 4.0000e-04
# Epoch 9/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0028 - loss: 1.7365e-05 - val_MAE: 0.0014 - val_loss: 3.7014e-06 - learning_rate: 4.0000e-04
# Epoch 10/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0026 - loss: 1.2826e-05 - val_MAE: 0.0016 - val_loss: 4.7864e-06 - learning_rate: 4.0000e-04
# Epoch 11/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0026 - loss: 1.2447e-05 - val_MAE: 0.0014 - val_loss: 3.7145e-06 - learning_rate: 4.0000e-04
# Epoch 12/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0026 - loss: 1.2517e-05 - val_MAE: 0.0014 - val_loss: 3.9005e-06 - learning_rate: 8.0000e-05
# Epoch 13/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0026 - loss: 1.2992e-05 - val_MAE: 0.0014 - val_loss: 3.7051e-06 - learning_rate: 8.0000e-05
# Epoch 14/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0026 - loss: 1.3415e-05 - val_MAE: 0.0013 - val_loss: 3.5959e-06 - learning_rate: 8.0000e-05
# Epoch 15/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0025 - loss: 1.3236e-05 - val_MAE: 0.0015 - val_loss: 4.0776e-06 - learning_rate: 8.0000e-05
# Epoch 16/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0025 - loss: 1.1638e-05 - val_MAE: 0.0015 - val_loss: 4.0791e-06 - learning_rate: 8.0000e-05
# Adamax Optimizer - Loss (MSE): 0.000004, Mean Absolute Error: 0.001325
#
# Training with RMSprop optimizer and leaky_relu activation function...
# Epoch 1/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - MAE: 0.0035 - loss: 2.1165e-05 - val_MAE: 0.0017 - val_loss: 4.7618e-06 - learning_rate: 0.0010
# Epoch 2/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - MAE: 0.0031 - loss: 1.6264e-05 - val_MAE: 0.0039 - val_loss: 1.8054e-05 - learning_rate: 0.0010
# Epoch 3/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - MAE: 0.0029 - loss: 1.4128e-05 - val_MAE: 0.0013 - val_loss: 3.4115e-06 - learning_rate: 0.0010
# Epoch 4/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0029 - loss: 1.4231e-05 - val_MAE: 0.0013 - val_loss: 3.3188e-06 - learning_rate: 0.0010
# Epoch 5/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0026 - loss: 1.2189e-05 - val_MAE: 0.0028 - val_loss: 1.0711e-05 - learning_rate: 0.0010
# Epoch 6/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - MAE: 0.0026 - loss: 1.3438e-05 - val_MAE: 0.0014 - val_loss: 3.6204e-06 - learning_rate: 0.0010
# Epoch 7/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0021 - loss: 8.7425e-06 - val_MAE: 0.0013 - val_loss: 3.6927e-06 - learning_rate: 2.0000e-04
# Epoch 8/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0021 - loss: 8.2245e-06 - val_MAE: 0.0014 - val_loss: 4.2311e-06 - learning_rate: 2.0000e-04
# Epoch 9/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0020 - loss: 8.6677e-06 - val_MAE: 0.0014 - val_loss: 4.0318e-06 - learning_rate: 2.0000e-04
# Epoch 10/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - MAE: 0.0020 - loss: 7.8378e-06 - val_MAE: 0.0014 - val_loss: 3.9973e-06 - learning_rate: 2.0000e-04
# Epoch 11/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - MAE: 0.0019 - loss: 7.0684e-06 - val_MAE: 0.0016 - val_loss: 4.9465e-06 - learning_rate: 2.0000e-04
# Epoch 12/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0019 - loss: 7.1765e-06 - val_MAE: 0.0015 - val_loss: 4.3196e-06 - learning_rate: 4.0000e-05
# Epoch 13/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - MAE: 0.0020 - loss: 8.8782e-06 - val_MAE: 0.0016 - val_loss: 4.6659e-06 - learning_rate: 4.0000e-05
# Epoch 14/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0020 - loss: 7.7411e-06 - val_MAE: 0.0015 - val_loss: 4.2990e-06 - learning_rate: 4.0000e-05
# RMSprop Optimizer - Loss (MSE): 0.000003, Mean Absolute Error: 0.001300
#
# Training with SGD optimizer and leaky_relu activation function...
# Epoch 1/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - MAE: 0.0021 - loss: 9.3357e-06 - val_MAE: 0.0013 - val_loss: 3.8252e-06 - learning_rate: 0.0100
# Epoch 2/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0022 - loss: 1.0338e-05 - val_MAE: 0.0015 - val_loss: 4.3321e-06 - learning_rate: 0.0100
# Epoch 3/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - MAE: 0.0022 - loss: 8.6371e-06 - val_MAE: 0.0015 - val_loss: 4.2456e-06 - learning_rate: 0.0100
# Epoch 4/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - MAE: 0.0022 - loss: 1.0455e-05 - val_MAE: 0.0015 - val_loss: 4.3838e-06 - learning_rate: 0.0100
# Epoch 5/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0022 - loss: 9.1108e-06 - val_MAE: 0.0016 - val_loss: 4.8629e-06 - learning_rate: 0.0100
# Epoch 6/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0021 - loss: 8.1806e-06 - val_MAE: 0.0016 - val_loss: 4.6700e-06 - learning_rate: 0.0100
# Epoch 7/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - MAE: 0.0021 - loss: 9.0222e-06 - val_MAE: 0.0014 - val_loss: 4.1528e-06 - learning_rate: 0.0020
# Epoch 8/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - MAE: 0.0022 - loss: 9.5484e-06 - val_MAE: 0.0015 - val_loss: 4.3094e-06 - learning_rate: 0.0020
# Epoch 9/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - MAE: 0.0021 - loss: 9.1057e-06 - val_MAE: 0.0015 - val_loss: 4.4332e-06 - learning_rate: 0.0020
# Epoch 10/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0023 - loss: 1.0329e-05 - val_MAE: 0.0015 - val_loss: 4.5464e-06 - learning_rate: 0.0020
# Epoch 11/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - MAE: 0.0021 - loss: 9.3193e-06 - val_MAE: 0.0015 - val_loss: 4.3652e-06 - learning_rate: 0.0020
# SGD Optimizer - Loss (MSE): 0.000004, Mean Absolute Error: 0.001348
#
# Running for activation function: elu
#
# Training with Adamax optimizer and elu activation function...
# Epoch 1/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - MAE: 0.0871 - loss: 0.0136 - val_MAE: 0.0053 - val_loss: 4.7647e-05 - learning_rate: 0.0020
# Epoch 2/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0344 - loss: 0.0020 - val_MAE: 0.0053 - val_loss: 4.5852e-05 - learning_rate: 0.0020
# Epoch 3/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0273 - loss: 0.0013 - val_MAE: 0.0045 - val_loss: 3.3354e-05 - learning_rate: 0.0020
# Epoch 4/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0226 - loss: 9.2867e-04 - val_MAE: 0.0037 - val_loss: 2.2823e-05 - learning_rate: 0.0020
# Epoch 5/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0184 - loss: 5.7729e-04 - val_MAE: 0.0030 - val_loss: 1.5401e-05 - learning_rate: 0.0020
# Epoch 6/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0163 - loss: 4.6379e-04 - val_MAE: 0.0033 - val_loss: 1.9265e-05 - learning_rate: 0.0020
# Epoch 7/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0147 - loss: 3.6472e-04 - val_MAE: 0.0028 - val_loss: 1.2819e-05 - learning_rate: 4.0000e-04
# Epoch 8/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0146 - loss: 3.6782e-04 - val_MAE: 0.0027 - val_loss: 1.2297e-05 - learning_rate: 4.0000e-04
# Epoch 9/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0138 - loss: 3.2515e-04 - val_MAE: 0.0026 - val_loss: 1.0898e-05 - learning_rate: 4.0000e-04
# Epoch 10/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0137 - loss: 3.1979e-04 - val_MAE: 0.0025 - val_loss: 1.0304e-05 - learning_rate: 4.0000e-04
# Epoch 11/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0132 - loss: 3.0413e-04 - val_MAE: 0.0024 - val_loss: 9.7661e-06 - learning_rate: 4.0000e-04
# Epoch 12/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0127 - loss: 2.7858e-04 - val_MAE: 0.0024 - val_loss: 9.3819e-06 - learning_rate: 8.0000e-05
# Epoch 13/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0125 - loss: 2.9579e-04 - val_MAE: 0.0024 - val_loss: 9.4550e-06 - learning_rate: 8.0000e-05
# Epoch 14/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0125 - loss: 2.7265e-04 - val_MAE: 0.0023 - val_loss: 9.2098e-06 - learning_rate: 8.0000e-05
# Epoch 15/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0130 - loss: 2.8985e-04 - val_MAE: 0.0023 - val_loss: 8.8193e-06 - learning_rate: 8.0000e-05
# Epoch 16/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0124 - loss: 2.5999e-04 - val_MAE: 0.0023 - val_loss: 8.8596e-06 - learning_rate: 8.0000e-05
# Epoch 17/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0129 - loss: 2.9136e-04 - val_MAE: 0.0023 - val_loss: 8.7249e-06 - learning_rate: 1.6000e-05
# Epoch 18/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0124 - loss: 2.6763e-04 - val_MAE: 0.0023 - val_loss: 8.7402e-06 - learning_rate: 1.6000e-05
# Epoch 19/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0125 - loss: 2.8591e-04 - val_MAE: 0.0023 - val_loss: 8.6922e-06 - learning_rate: 1.6000e-05
# Epoch 20/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0127 - loss: 2.8094e-04 - val_MAE: 0.0023 - val_loss: 8.7117e-06 - learning_rate: 1.6000e-05
# Epoch 21/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0119 - loss: 2.4566e-04 - val_MAE: 0.0023 - val_loss: 8.6344e-06 - learning_rate: 1.6000e-05
# Epoch 22/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0124 - loss: 2.6175e-04 - val_MAE: 0.0023 - val_loss: 8.5799e-06 - learning_rate: 1.0000e-05
# Epoch 23/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0123 - loss: 2.6025e-04 - val_MAE: 0.0023 - val_loss: 8.4999e-06 - learning_rate: 1.0000e-05
# Epoch 24/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0121 - loss: 2.5737e-04 - val_MAE: 0.0022 - val_loss: 8.4286e-06 - learning_rate: 1.0000e-05
# Epoch 25/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0124 - loss: 2.6405e-04 - val_MAE: 0.0023 - val_loss: 8.4907e-06 - learning_rate: 1.0000e-05
# Epoch 26/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0125 - loss: 2.5946e-04 - val_MAE: 0.0022 - val_loss: 8.4081e-06 - learning_rate: 1.0000e-05
# Epoch 27/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0123 - loss: 2.6073e-04 - val_MAE: 0.0022 - val_loss: 8.4585e-06 - learning_rate: 1.0000e-05
# Epoch 28/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0128 - loss: 2.8385e-04 - val_MAE: 0.0023 - val_loss: 8.7868e-06 - learning_rate: 1.0000e-05
# Epoch 29/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0120 - loss: 2.5056e-04 - val_MAE: 0.0023 - val_loss: 8.6347e-06 - learning_rate: 1.0000e-05
# Epoch 30/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0114 - loss: 2.2242e-04 - val_MAE: 0.0022 - val_loss: 8.4655e-06 - learning_rate: 1.0000e-05
# Epoch 31/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0124 - loss: 2.5785e-04 - val_MAE: 0.0022 - val_loss: 8.3115e-06 - learning_rate: 1.0000e-05
# Epoch 32/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0119 - loss: 2.3765e-04 - val_MAE: 0.0022 - val_loss: 8.1805e-06 - learning_rate: 1.0000e-05
# Epoch 33/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0120 - loss: 2.4032e-04 - val_MAE: 0.0022 - val_loss: 8.1960e-06 - learning_rate: 1.0000e-05
# Epoch 34/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0120 - loss: 2.3991e-04 - val_MAE: 0.0022 - val_loss: 8.0241e-06 - learning_rate: 1.0000e-05
# Epoch 35/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0121 - loss: 2.5440e-04 - val_MAE: 0.0022 - val_loss: 8.0826e-06 - learning_rate: 1.0000e-05
# Epoch 36/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0121 - loss: 2.5061e-04 - val_MAE: 0.0022 - val_loss: 8.0588e-06 - learning_rate: 1.0000e-05
# Epoch 37/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0119 - loss: 2.4666e-04 - val_MAE: 0.0022 - val_loss: 7.8841e-06 - learning_rate: 1.0000e-05
# Epoch 38/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0113 - loss: 2.2012e-04 - val_MAE: 0.0022 - val_loss: 7.9675e-06 - learning_rate: 1.0000e-05
# Epoch 39/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0116 - loss: 2.2508e-04 - val_MAE: 0.0022 - val_loss: 7.7912e-06 - learning_rate: 1.0000e-05
# Epoch 40/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0118 - loss: 2.3921e-04 - val_MAE: 0.0022 - val_loss: 7.8663e-06 - learning_rate: 1.0000e-05
# Epoch 41/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0117 - loss: 2.4183e-04 - val_MAE: 0.0021 - val_loss: 7.5687e-06 - learning_rate: 1.0000e-05
# Epoch 42/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0116 - loss: 2.3959e-04 - val_MAE: 0.0021 - val_loss: 7.6899e-06 - learning_rate: 1.0000e-05
# Epoch 43/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0119 - loss: 2.4330e-04 - val_MAE: 0.0022 - val_loss: 8.0681e-06 - learning_rate: 1.0000e-05
# Epoch 44/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0116 - loss: 2.4746e-04 - val_MAE: 0.0022 - val_loss: 8.1454e-06 - learning_rate: 1.0000e-05
# Epoch 45/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0115 - loss: 2.4156e-04 - val_MAE: 0.0020 - val_loss: 7.0690e-06 - learning_rate: 1.0000e-05
# Epoch 46/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0114 - loss: 2.2700e-04 - val_MAE: 0.0020 - val_loss: 6.9381e-06 - learning_rate: 1.0000e-05
# Epoch 47/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0114 - loss: 2.3121e-04 - val_MAE: 0.0020 - val_loss: 7.0162e-06 - learning_rate: 1.0000e-05
# Epoch 48/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0113 - loss: 2.1539e-04 - val_MAE: 0.0021 - val_loss: 7.5597e-06 - learning_rate: 1.0000e-05
# Epoch 49/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0111 - loss: 2.1818e-04 - val_MAE: 0.0020 - val_loss: 6.5627e-06 - learning_rate: 1.0000e-05
# Epoch 50/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0108 - loss: 2.0438e-04 - val_MAE: 0.0020 - val_loss: 6.5168e-06 - learning_rate: 1.0000e-05
# Epoch 51/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0114 - loss: 2.2242e-04 - val_MAE: 0.0019 - val_loss: 6.2583e-06 - learning_rate: 1.0000e-05
# Epoch 52/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0111 - loss: 2.1281e-04 - val_MAE: 0.0019 - val_loss: 6.1398e-06 - learning_rate: 1.0000e-05
# Epoch 53/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0106 - loss: 1.9486e-04 - val_MAE: 0.0019 - val_loss: 5.9284e-06 - learning_rate: 1.0000e-05
# Epoch 54/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0104 - loss: 2.0104e-04 - val_MAE: 0.0019 - val_loss: 5.9582e-06 - learning_rate: 1.0000e-05
# Epoch 55/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0104 - loss: 1.8604e-04 - val_MAE: 0.0019 - val_loss: 5.7917e-06 - learning_rate: 1.0000e-05
# Epoch 56/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0105 - loss: 1.9113e-04 - val_MAE: 0.0018 - val_loss: 5.3987e-06 - learning_rate: 1.0000e-05
# Epoch 57/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0102 - loss: 1.7859e-04 - val_MAE: 0.0018 - val_loss: 5.3333e-06 - learning_rate: 1.0000e-05
# Epoch 58/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0103 - loss: 1.8687e-04 - val_MAE: 0.0017 - val_loss: 5.1506e-06 - learning_rate: 1.0000e-05
# Epoch 59/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0104 - loss: 1.9722e-04 - val_MAE: 0.0017 - val_loss: 5.1212e-06 - learning_rate: 1.0000e-05
# Epoch 60/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0100 - loss: 1.7058e-04 - val_MAE: 0.0017 - val_loss: 4.7860e-06 - learning_rate: 1.0000e-05
# Epoch 61/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0097 - loss: 1.6650e-04 - val_MAE: 0.0016 - val_loss: 4.6767e-06 - learning_rate: 1.0000e-05
# Epoch 62/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0100 - loss: 1.7114e-04 - val_MAE: 0.0016 - val_loss: 4.5949e-06 - learning_rate: 1.0000e-05
# Epoch 63/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0098 - loss: 1.7594e-04 - val_MAE: 0.0017 - val_loss: 4.9693e-06 - learning_rate: 1.0000e-05
# Epoch 64/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0097 - loss: 1.6188e-04 - val_MAE: 0.0017 - val_loss: 4.9681e-06 - learning_rate: 1.0000e-05
# Epoch 65/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0097 - loss: 1.7435e-04 - val_MAE: 0.0016 - val_loss: 4.6159e-06 - learning_rate: 1.0000e-05
# Epoch 66/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0096 - loss: 1.5972e-04 - val_MAE: 0.0016 - val_loss: 4.5747e-06 - learning_rate: 1.0000e-05
# Epoch 67/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0097 - loss: 1.6848e-04 - val_MAE: 0.0015 - val_loss: 4.1905e-06 - learning_rate: 1.0000e-05
# Epoch 68/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0096 - loss: 1.5790e-04 - val_MAE: 0.0015 - val_loss: 4.0554e-06 - learning_rate: 1.0000e-05
# Epoch 69/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0095 - loss: 1.6094e-04 - val_MAE: 0.0015 - val_loss: 3.9809e-06 - learning_rate: 1.0000e-05
# Epoch 70/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0093 - loss: 1.5029e-04 - val_MAE: 0.0015 - val_loss: 3.8970e-06 - learning_rate: 1.0000e-05
# Epoch 71/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0090 - loss: 1.4282e-04 - val_MAE: 0.0014 - val_loss: 3.7923e-06 - learning_rate: 1.0000e-05
# Epoch 72/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0089 - loss: 1.3973e-04 - val_MAE: 0.0014 - val_loss: 3.7875e-06 - learning_rate: 1.0000e-05
# Epoch 73/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0089 - loss: 1.4624e-04 - val_MAE: 0.0014 - val_loss: 3.8206e-06 - learning_rate: 1.0000e-05
# Epoch 74/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0089 - loss: 1.3956e-04 - val_MAE: 0.0015 - val_loss: 3.9242e-06 - learning_rate: 1.0000e-05
# Epoch 75/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0089 - loss: 1.3503e-04 - val_MAE: 0.0014 - val_loss: 3.8202e-06 - learning_rate: 1.0000e-05
# Epoch 76/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0087 - loss: 1.2963e-04 - val_MAE: 0.0014 - val_loss: 3.5378e-06 - learning_rate: 1.0000e-05
# Epoch 77/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0084 - loss: 1.2510e-04 - val_MAE: 0.0014 - val_loss: 3.6272e-06 - learning_rate: 1.0000e-05
# Epoch 78/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0087 - loss: 1.3429e-04 - val_MAE: 0.0014 - val_loss: 3.5578e-06 - learning_rate: 1.0000e-05
# Epoch 79/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0083 - loss: 1.2070e-04 - val_MAE: 0.0014 - val_loss: 3.3921e-06 - learning_rate: 1.0000e-05
# Epoch 80/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0088 - loss: 1.3366e-04 - val_MAE: 0.0013 - val_loss: 3.3850e-06 - learning_rate: 1.0000e-05
# Epoch 81/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0085 - loss: 1.2284e-04 - val_MAE: 0.0014 - val_loss: 3.4047e-06 - learning_rate: 1.0000e-05
# Epoch 82/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0087 - loss: 1.3259e-04 - val_MAE: 0.0013 - val_loss: 3.2021e-06 - learning_rate: 1.0000e-05
# Epoch 83/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0082 - loss: 1.1696e-04 - val_MAE: 0.0014 - val_loss: 3.4284e-06 - learning_rate: 1.0000e-05
# Epoch 84/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0088 - loss: 1.3868e-04 - val_MAE: 0.0013 - val_loss: 3.2083e-06 - learning_rate: 1.0000e-05
# Epoch 85/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0082 - loss: 1.2288e-04 - val_MAE: 0.0013 - val_loss: 3.2303e-06 - learning_rate: 1.0000e-05
# Epoch 86/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0082 - loss: 1.1662e-04 - val_MAE: 0.0013 - val_loss: 3.2001e-06 - learning_rate: 1.0000e-05
# Epoch 87/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0080 - loss: 1.1515e-04 - val_MAE: 0.0014 - val_loss: 3.4533e-06 - learning_rate: 1.0000e-05
# Epoch 88/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0082 - loss: 1.2206e-04 - val_MAE: 0.0013 - val_loss: 3.0284e-06 - learning_rate: 1.0000e-05
# Epoch 89/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0079 - loss: 1.0573e-04 - val_MAE: 0.0012 - val_loss: 2.9253e-06 - learning_rate: 1.0000e-05
# Epoch 90/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0079 - loss: 1.0971e-04 - val_MAE: 0.0012 - val_loss: 2.8845e-06 - learning_rate: 1.0000e-05
# Epoch 91/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0078 - loss: 1.0431e-04 - val_MAE: 0.0012 - val_loss: 2.8630e-06 - learning_rate: 1.0000e-05
# Epoch 92/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0076 - loss: 9.9592e-05 - val_MAE: 0.0014 - val_loss: 3.4191e-06 - learning_rate: 1.0000e-05
# Epoch 93/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0080 - loss: 1.1017e-04 - val_MAE: 0.0012 - val_loss: 2.9246e-06 - learning_rate: 1.0000e-05
# Epoch 94/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0077 - loss: 1.0738e-04 - val_MAE: 0.0012 - val_loss: 2.8028e-06 - learning_rate: 1.0000e-05
# Epoch 95/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0075 - loss: 9.9474e-05 - val_MAE: 0.0012 - val_loss: 2.7213e-06 - learning_rate: 1.0000e-05
# Epoch 96/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0077 - loss: 1.0812e-04 - val_MAE: 0.0012 - val_loss: 2.7461e-06 - learning_rate: 1.0000e-05
# Epoch 97/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0075 - loss: 9.6209e-05 - val_MAE: 0.0012 - val_loss: 2.7383e-06 - learning_rate: 1.0000e-05
# Epoch 98/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0075 - loss: 1.0017e-04 - val_MAE: 0.0012 - val_loss: 2.6935e-06 - learning_rate: 1.0000e-05
# Epoch 99/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0075 - loss: 9.6316e-05 - val_MAE: 0.0013 - val_loss: 3.0341e-06 - learning_rate: 1.0000e-05
# Epoch 100/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0073 - loss: 9.7735e-05 - val_MAE: 0.0012 - val_loss: 2.7054e-06 - learning_rate: 1.0000e-05
# Adamax Optimizer - Loss (MSE): 0.000003, Mean Absolute Error: 0.001185
#
# Training with RMSprop optimizer and elu activation function...
# Epoch 1/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - MAE: 0.0100 - loss: 1.8336e-04 - val_MAE: 0.0060 - val_loss: 3.8857e-05 - learning_rate: 0.0010
# Epoch 2/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0063 - loss: 6.1487e-05 - val_MAE: 0.0055 - val_loss: 3.2347e-05 - learning_rate: 0.0010
# Epoch 3/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0044 - loss: 3.1284e-05 - val_MAE: 0.0026 - val_loss: 8.5838e-06 - learning_rate: 0.0010
# Epoch 4/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0047 - loss: 3.5215e-05 - val_MAE: 0.0027 - val_loss: 8.5714e-06 - learning_rate: 0.0010
# Epoch 5/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0041 - loss: 2.5624e-05 - val_MAE: 0.0011 - val_loss: 2.4418e-06 - learning_rate: 0.0010
# Epoch 6/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0036 - loss: 2.1706e-05 - val_MAE: 0.0013 - val_loss: 3.2479e-06 - learning_rate: 0.0010
# Epoch 7/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0017 - loss: 6.1619e-06 - val_MAE: 9.9387e-04 - val_loss: 2.1180e-06 - learning_rate: 2.0000e-04
# Epoch 8/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0018 - loss: 7.4260e-06 - val_MAE: 9.8184e-04 - val_loss: 2.0990e-06 - learning_rate: 2.0000e-04
# Epoch 9/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0018 - loss: 6.8127e-06 - val_MAE: 9.8944e-04 - val_loss: 2.1660e-06 - learning_rate: 2.0000e-04
# Epoch 10/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0017 - loss: 7.2584e-06 - val_MAE: 0.0014 - val_loss: 3.3477e-06 - learning_rate: 2.0000e-04
# Epoch 11/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0017 - loss: 6.3134e-06 - val_MAE: 0.0011 - val_loss: 2.5237e-06 - learning_rate: 2.0000e-04
# Epoch 12/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0016 - loss: 6.0737e-06 - val_MAE: 9.9254e-04 - val_loss: 2.1390e-06 - learning_rate: 4.0000e-05
# Epoch 13/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0016 - loss: 6.5090e-06 - val_MAE: 0.0010 - val_loss: 2.1696e-06 - learning_rate: 4.0000e-05
# Epoch 14/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0015 - loss: 5.6622e-06 - val_MAE: 9.4949e-04 - val_loss: 2.0697e-06 - learning_rate: 4.0000e-05
# Epoch 15/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0015 - loss: 4.9434e-06 - val_MAE: 9.3842e-04 - val_loss: 2.0475e-06 - learning_rate: 4.0000e-05
# Epoch 16/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0016 - loss: 5.6483e-06 - val_MAE: 9.3762e-04 - val_loss: 2.0459e-06 - learning_rate: 4.0000e-05
# Epoch 17/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0016 - loss: 6.1238e-06 - val_MAE: 9.7631e-04 - val_loss: 2.1232e-06 - learning_rate: 1.0000e-05
# Epoch 18/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0015 - loss: 4.9998e-06 - val_MAE: 9.7605e-04 - val_loss: 2.1237e-06 - learning_rate: 1.0000e-05
# Epoch 19/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0016 - loss: 5.6278e-06 - val_MAE: 9.3955e-04 - val_loss: 2.0468e-06 - learning_rate: 1.0000e-05
# Epoch 20/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0016 - loss: 6.1152e-06 - val_MAE: 9.7307e-04 - val_loss: 2.1108e-06 - learning_rate: 1.0000e-05
# Epoch 21/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0017 - loss: 6.5171e-06 - val_MAE: 9.3765e-04 - val_loss: 2.0443e-06 - learning_rate: 1.0000e-05
# Epoch 22/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0016 - loss: 6.1473e-06 - val_MAE: 9.6417e-04 - val_loss: 2.0888e-06 - learning_rate: 1.0000e-05
# Epoch 23/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0017 - loss: 7.2158e-06 - val_MAE: 9.8797e-04 - val_loss: 2.1387e-06 - learning_rate: 1.0000e-05
# Epoch 24/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0015 - loss: 5.2106e-06 - val_MAE: 9.4381e-04 - val_loss: 2.0460e-06 - learning_rate: 1.0000e-05
# Epoch 25/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0016 - loss: 5.5993e-06 - val_MAE: 9.5749e-04 - val_loss: 2.0696e-06 - learning_rate: 1.0000e-05
# Epoch 26/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0016 - loss: 6.5255e-06 - val_MAE: 9.5494e-04 - val_loss: 2.0667e-06 - learning_rate: 1.0000e-05
# Epoch 27/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0015 - loss: 4.9412e-06 - val_MAE: 9.5501e-04 - val_loss: 2.0668e-06 - learning_rate: 1.0000e-05
# Epoch 28/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0018 - loss: 9.0631e-06 - val_MAE: 9.5489e-04 - val_loss: 2.0648e-06 - learning_rate: 1.0000e-05
# Epoch 29/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0016 - loss: 6.9989e-06 - val_MAE: 9.9572e-04 - val_loss: 2.1552e-06 - learning_rate: 1.0000e-05
# Epoch 30/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0016 - loss: 6.4618e-06 - val_MAE: 9.4685e-04 - val_loss: 2.0524e-06 - learning_rate: 1.0000e-05
# Epoch 31/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0016 - loss: 5.9811e-06 - val_MAE: 9.5155e-04 - val_loss: 2.0639e-06 - learning_rate: 1.0000e-05
# RMSprop Optimizer - Loss (MSE): 0.000002, Mean Absolute Error: 0.000938
#
# Training with SGD optimizer and elu activation function...
# Epoch 1/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - MAE: 0.0016 - loss: 6.0286e-06 - val_MAE: 9.6764e-04 - val_loss: 2.0933e-06 - learning_rate: 0.0100
# Epoch 2/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0015 - loss: 5.2570e-06 - val_MAE: 0.0010 - val_loss: 2.1853e-06 - learning_rate: 0.0100
# Epoch 3/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0016 - loss: 5.3537e-06 - val_MAE: 9.8615e-04 - val_loss: 2.1413e-06 - learning_rate: 0.0100
# Epoch 4/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0015 - loss: 4.5079e-06 - val_MAE: 9.3464e-04 - val_loss: 2.0443e-06 - learning_rate: 0.0100
# Epoch 5/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0016 - loss: 5.9206e-06 - val_MAE: 0.0010 - val_loss: 2.2217e-06 - learning_rate: 0.0100
# Epoch 6/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0015 - loss: 4.7946e-06 - val_MAE: 9.5142e-04 - val_loss: 2.0676e-06 - learning_rate: 0.0100
# Epoch 7/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0017 - loss: 6.1077e-06 - val_MAE: 9.9684e-04 - val_loss: 2.1706e-06 - learning_rate: 0.0020
# Epoch 8/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0015 - loss: 5.3629e-06 - val_MAE: 9.7096e-04 - val_loss: 2.1098e-06 - learning_rate: 0.0020
# Epoch 9/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0016 - loss: 5.5642e-06 - val_MAE: 9.6854e-04 - val_loss: 2.1041e-06 - learning_rate: 0.0020
# Epoch 10/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0015 - loss: 5.2216e-06 - val_MAE: 9.9531e-04 - val_loss: 2.1636e-06 - learning_rate: 0.0020
# Epoch 11/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0015 - loss: 4.7299e-06 - val_MAE: 9.5472e-04 - val_loss: 2.0733e-06 - learning_rate: 0.0020
# Epoch 12/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0016 - loss: 5.7360e-06 - val_MAE: 9.5065e-04 - val_loss: 2.0639e-06 - learning_rate: 4.0000e-04
# Epoch 13/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0016 - loss: 6.5744e-06 - val_MAE: 9.5360e-04 - val_loss: 2.0694e-06 - learning_rate: 4.0000e-04
# Epoch 14/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0016 - loss: 5.3429e-06 - val_MAE: 9.6482e-04 - val_loss: 2.0929e-06 - learning_rate: 4.0000e-04
# SGD Optimizer - Loss (MSE): 0.000002, Mean Absolute Error: 0.000935
#
# Running for activation function: prelu
#
# Training with Adamax optimizer and prelu activation function...
# Epoch 1/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - MAE: 0.0311 - loss: 0.0021 - val_MAE: 0.0038 - val_loss: 2.2865e-05 - learning_rate: 0.0020
# Epoch 2/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0072 - loss: 9.1618e-05 - val_MAE: 0.0022 - val_loss: 1.0231e-05 - learning_rate: 0.0020
# Epoch 3/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0056 - loss: 6.3119e-05 - val_MAE: 0.0024 - val_loss: 9.1275e-06 - learning_rate: 0.0020
# Epoch 4/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0045 - loss: 3.7890e-05 - val_MAE: 0.0019 - val_loss: 6.4305e-06 - learning_rate: 0.0020
# Epoch 5/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0038 - loss: 2.8602e-05 - val_MAE: 0.0020 - val_loss: 6.5394e-06 - learning_rate: 0.0020
# Epoch 6/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0035 - loss: 2.6032e-05 - val_MAE: 0.0025 - val_loss: 9.0758e-06 - learning_rate: 0.0020
# Epoch 7/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0031 - loss: 1.9247e-05 - val_MAE: 0.0023 - val_loss: 8.3033e-06 - learning_rate: 4.0000e-04
# Epoch 8/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0028 - loss: 1.6032e-05 - val_MAE: 0.0026 - val_loss: 9.5525e-06 - learning_rate: 4.0000e-04
# Epoch 9/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0030 - loss: 1.8777e-05 - val_MAE: 0.0024 - val_loss: 8.3122e-06 - learning_rate: 4.0000e-04
# Epoch 10/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0029 - loss: 1.6969e-05 - val_MAE: 0.0027 - val_loss: 9.9273e-06 - learning_rate: 4.0000e-04
# Epoch 11/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0027 - loss: 1.4996e-05 - val_MAE: 0.0024 - val_loss: 8.4604e-06 - learning_rate: 4.0000e-04
# Epoch 12/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0028 - loss: 1.6499e-05 - val_MAE: 0.0022 - val_loss: 7.5048e-06 - learning_rate: 8.0000e-05
# Epoch 13/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0027 - loss: 1.5568e-05 - val_MAE: 0.0024 - val_loss: 8.4430e-06 - learning_rate: 8.0000e-05
# Epoch 14/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0026 - loss: 1.3487e-05 - val_MAE: 0.0025 - val_loss: 9.2877e-06 - learning_rate: 8.0000e-05
# Adamax Optimizer - Loss (MSE): 0.000006, Mean Absolute Error: 0.001867
#
# Training with RMSprop optimizer and prelu activation function...
# Epoch 1/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - MAE: 0.0043 - loss: 3.3768e-05 - val_MAE: 0.0043 - val_loss: 2.2431e-05 - learning_rate: 0.0010
# Epoch 2/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0032 - loss: 2.0175e-05 - val_MAE: 0.0020 - val_loss: 7.1679e-06 - learning_rate: 0.0010
# Epoch 3/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0028 - loss: 1.4566e-05 - val_MAE: 0.0030 - val_loss: 1.2110e-05 - learning_rate: 0.0010
# Epoch 4/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0029 - loss: 1.5543e-05 - val_MAE: 0.0018 - val_loss: 5.1938e-06 - learning_rate: 0.0010
# Epoch 5/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0025 - loss: 1.2637e-05 - val_MAE: 0.0021 - val_loss: 6.2015e-06 - learning_rate: 0.0010
# Epoch 6/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0027 - loss: 1.2326e-05 - val_MAE: 0.0026 - val_loss: 1.1224e-05 - learning_rate: 0.0010
# Epoch 7/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0019 - loss: 8.8289e-06 - val_MAE: 0.0016 - val_loss: 5.0145e-06 - learning_rate: 2.0000e-04
# Epoch 8/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0019 - loss: 8.4671e-06 - val_MAE: 0.0016 - val_loss: 5.7484e-06 - learning_rate: 2.0000e-04
# Epoch 9/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0018 - loss: 7.0149e-06 - val_MAE: 0.0017 - val_loss: 5.9584e-06 - learning_rate: 2.0000e-04
# Epoch 10/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0017 - loss: 7.0264e-06 - val_MAE: 0.0016 - val_loss: 5.4983e-06 - learning_rate: 2.0000e-04
# Epoch 11/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0017 - loss: 6.3886e-06 - val_MAE: 0.0016 - val_loss: 5.5620e-06 - learning_rate: 2.0000e-04
# Epoch 12/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0018 - loss: 7.9512e-06 - val_MAE: 0.0016 - val_loss: 5.6703e-06 - learning_rate: 4.0000e-05
# Epoch 13/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0017 - loss: 6.0349e-06 - val_MAE: 0.0016 - val_loss: 5.5766e-06 - learning_rate: 4.0000e-05
# Epoch 14/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0017 - loss: 6.8592e-06 - val_MAE: 0.0016 - val_loss: 5.5877e-06 - learning_rate: 4.0000e-05
# Epoch 15/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0017 - loss: 6.6411e-06 - val_MAE: 0.0016 - val_loss: 5.6977e-06 - learning_rate: 4.0000e-05
# Epoch 16/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0018 - loss: 7.7392e-06 - val_MAE: 0.0016 - val_loss: 5.2652e-06 - learning_rate: 4.0000e-05
# Epoch 17/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0017 - loss: 6.2879e-06 - val_MAE: 0.0016 - val_loss: 5.5948e-06 - learning_rate: 1.0000e-05
# RMSprop Optimizer - Loss (MSE): 0.000005, Mean Absolute Error: 0.001649
#
# Training with SGD optimizer and prelu activation function...
# Epoch 1/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - MAE: 0.0018 - loss: 7.8514e-06 - val_MAE: 0.0017 - val_loss: 6.2467e-06 - learning_rate: 0.0100
# Epoch 2/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0018 - loss: 7.5982e-06 - val_MAE: 0.0016 - val_loss: 5.6277e-06 - learning_rate: 0.0100
# Epoch 3/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0018 - loss: 8.0168e-06 - val_MAE: 0.0016 - val_loss: 5.2328e-06 - learning_rate: 0.0100
# Epoch 4/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0018 - loss: 7.6861e-06 - val_MAE: 0.0016 - val_loss: 5.4452e-06 - learning_rate: 0.0100
# Epoch 5/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0018 - loss: 7.4813e-06 - val_MAE: 0.0016 - val_loss: 5.6168e-06 - learning_rate: 0.0100
# Epoch 6/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0018 - loss: 8.7527e-06 - val_MAE: 0.0017 - val_loss: 6.3107e-06 - learning_rate: 0.0100
# Epoch 7/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0017 - loss: 6.6061e-06 - val_MAE: 0.0016 - val_loss: 5.4034e-06 - learning_rate: 0.0020
# Epoch 8/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0017 - loss: 7.2036e-06 - val_MAE: 0.0016 - val_loss: 5.4836e-06 - learning_rate: 0.0020
# Epoch 9/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0018 - loss: 7.5100e-06 - val_MAE: 0.0017 - val_loss: 5.8688e-06 - learning_rate: 0.0020
# Epoch 10/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0017 - loss: 6.7174e-06 - val_MAE: 0.0016 - val_loss: 5.6326e-06 - learning_rate: 0.0020
# Epoch 11/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0018 - loss: 6.6268e-06 - val_MAE: 0.0016 - val_loss: 5.4969e-06 - learning_rate: 0.0020
# Epoch 12/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0017 - loss: 6.6580e-06 - val_MAE: 0.0016 - val_loss: 5.5190e-06 - learning_rate: 4.0000e-04
# Epoch 13/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0016 - loss: 5.9956e-06 - val_MAE: 0.0016 - val_loss: 5.5243e-06 - learning_rate: 4.0000e-04
# SGD Optimizer - Loss (MSE): 0.000005, Mean Absolute Error: 0.001627
#
# Running for activation function: swish
#
# Training with Adamax optimizer and swish activation function...
# Epoch 1/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - MAE: 0.0187 - loss: 6.9894e-04 - val_MAE: 0.0038 - val_loss: 2.3426e-05 - learning_rate: 0.0020
# Epoch 2/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0078 - loss: 9.7614e-05 - val_MAE: 0.0025 - val_loss: 1.0885e-05 - learning_rate: 0.0020
# Epoch 3/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0060 - loss: 5.9149e-05 - val_MAE: 0.0021 - val_loss: 7.9448e-06 - learning_rate: 0.0020
# Epoch 4/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0052 - loss: 4.6550e-05 - val_MAE: 0.0018 - val_loss: 5.9482e-06 - learning_rate: 0.0020
# Epoch 5/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0046 - loss: 3.5096e-05 - val_MAE: 0.0015 - val_loss: 4.3737e-06 - learning_rate: 0.0020
# Epoch 6/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0040 - loss: 2.7590e-05 - val_MAE: 0.0015 - val_loss: 4.0215e-06 - learning_rate: 0.0020
# Epoch 7/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0036 - loss: 2.3177e-05 - val_MAE: 0.0014 - val_loss: 3.6022e-06 - learning_rate: 4.0000e-04
# Epoch 8/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0036 - loss: 2.1839e-05 - val_MAE: 0.0013 - val_loss: 3.2702e-06 - learning_rate: 4.0000e-04
# Epoch 9/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0036 - loss: 2.2298e-05 - val_MAE: 0.0013 - val_loss: 3.2988e-06 - learning_rate: 4.0000e-04
# Epoch 10/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0034 - loss: 2.0784e-05 - val_MAE: 0.0013 - val_loss: 3.1771e-06 - learning_rate: 4.0000e-04
# Epoch 11/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0034 - loss: 1.9261e-05 - val_MAE: 0.0012 - val_loss: 2.9264e-06 - learning_rate: 4.0000e-04
# Epoch 12/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0032 - loss: 1.7018e-05 - val_MAE: 0.0012 - val_loss: 2.9189e-06 - learning_rate: 8.0000e-05
# Epoch 13/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0033 - loss: 1.8117e-05 - val_MAE: 0.0012 - val_loss: 2.8842e-06 - learning_rate: 8.0000e-05
# Epoch 14/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0032 - loss: 1.7144e-05 - val_MAE: 0.0012 - val_loss: 2.8351e-06 - learning_rate: 8.0000e-05
# Epoch 15/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0031 - loss: 1.8196e-05 - val_MAE: 0.0012 - val_loss: 2.8246e-06 - learning_rate: 8.0000e-05
# Epoch 16/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0030 - loss: 1.5002e-05 - val_MAE: 0.0012 - val_loss: 2.8036e-06 - learning_rate: 8.0000e-05
# Epoch 17/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0031 - loss: 1.6267e-05 - val_MAE: 0.0012 - val_loss: 2.7954e-06 - learning_rate: 1.6000e-05
# Epoch 18/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0031 - loss: 1.6014e-05 - val_MAE: 0.0012 - val_loss: 2.7911e-06 - learning_rate: 1.6000e-05
# Epoch 19/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0030 - loss: 1.5295e-05 - val_MAE: 0.0012 - val_loss: 2.7849e-06 - learning_rate: 1.6000e-05
# Epoch 20/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0030 - loss: 1.5267e-05 - val_MAE: 0.0012 - val_loss: 2.7802e-06 - learning_rate: 1.6000e-05
# Epoch 21/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0032 - loss: 1.8265e-05 - val_MAE: 0.0012 - val_loss: 2.7714e-06 - learning_rate: 1.6000e-05
# Epoch 22/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0031 - loss: 1.7084e-05 - val_MAE: 0.0012 - val_loss: 2.7669e-06 - learning_rate: 1.0000e-05
# Epoch 23/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0031 - loss: 1.6589e-05 - val_MAE: 0.0012 - val_loss: 2.7603e-06 - learning_rate: 1.0000e-05
# Epoch 24/100
# ...
# Epoch 43/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0030 - loss: 1.4935e-05 - val_MAE: 0.0011 - val_loss: 2.6063e-06 - learning_rate: 1.0000e-05
# Epoch 44/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0029 - loss: 1.5887e-05 - val_MAE: 0.0011 - val_loss: 2.5937e-06 - learning_rate: 1.0000e-05
# Epoch 45/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0029 - loss: 1.4496e-05 - val_MAE: 0.0011 - val_loss: 2.5889e-06 - learning_rate: 1.0000e-05
# Epoch 46/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0030 - loss: 1.5928e-05 - val_MAE: 0.0011 - val_loss: 2.5662e-06 - learning_rate: 1.0000e-05
# Epoch 47/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0029 - loss: 1.4721e-05 - val_MAE: 0.0011 - val_loss: 2.5403e-06 - learning_rate: 1.0000e-05
# Epoch 48/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0028 - loss: 1.3196e-05 - val_MAE: 0.0011 - val_loss: 2.5801e-06 - learning_rate: 1.0000e-05
# Epoch 49/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0027 - loss: 1.2991e-05 - val_MAE: 0.0011 - val_loss: 2.5202e-06 - learning_rate: 1.0000e-05
# Epoch 50/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0028 - loss: 1.2779e-05 - val_MAE: 0.0011 - val_loss: 2.5422e-06 - learning_rate: 1.0000e-05
# Epoch 51/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0029 - loss: 1.4028e-05 - val_MAE: 0.0011 - val_loss: 2.4819e-06 - learning_rate: 1.0000e-05
# Epoch 52/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0028 - loss: 1.3441e-05 - val_MAE: 0.0011 - val_loss: 2.4782e-06 - learning_rate: 1.0000e-05
# Epoch 53/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0028 - loss: 1.3280e-05 - val_MAE: 0.0011 - val_loss: 2.4505e-06 - learning_rate: 1.0000e-05
# Epoch 54/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0026 - loss: 1.2314e-05 - val_MAE: 0.0011 - val_loss: 2.4364e-06 - learning_rate: 1.0000e-05
# Epoch 55/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0029 - loss: 1.3797e-05 - val_MAE: 0.0011 - val_loss: 2.4676e-06 - learning_rate: 1.0000e-05
# Epoch 56/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0028 - loss: 1.3073e-05 - val_MAE: 0.0011 - val_loss: 2.4325e-06 - learning_rate: 1.0000e-05
# Epoch 57/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0027 - loss: 1.3161e-05 - val_MAE: 0.0011 - val_loss: 2.4011e-06 - learning_rate: 1.0000e-05
# Epoch 58/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0028 - loss: 1.3279e-05 - val_MAE: 0.0011 - val_loss: 2.3763e-06 - learning_rate: 1.0000e-05
# Epoch 59/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0027 - loss: 1.3033e-05 - val_MAE: 0.0010 - val_loss: 2.3532e-06 - learning_rate: 1.0000e-05
# Epoch 60/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0027 - loss: 1.1830e-05 - val_MAE: 0.0010 - val_loss: 2.3487e-06 - learning_rate: 1.0000e-05
# Epoch 61/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0027 - loss: 1.2762e-05 - val_MAE: 0.0011 - val_loss: 2.4326e-06 - learning_rate: 1.0000e-05
# Epoch 62/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0026 - loss: 1.2421e-05 - val_MAE: 0.0010 - val_loss: 2.3469e-06 - learning_rate: 1.0000e-05
# Epoch 63/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0026 - loss: 1.0886e-05 - val_MAE: 0.0010 - val_loss: 2.3127e-06 - learning_rate: 1.0000e-05
# Epoch 64/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0026 - loss: 1.1679e-05 - val_MAE: 0.0010 - val_loss: 2.3111e-06 - learning_rate: 1.0000e-05
# Epoch 65/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0027 - loss: 1.3237e-05 - val_MAE: 0.0010 - val_loss: 2.3114e-06 - learning_rate: 1.0000e-05
# Epoch 66/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0026 - loss: 1.2159e-05 - val_MAE: 0.0010 - val_loss: 2.2931e-06 - learning_rate: 1.0000e-05
# Epoch 67/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0026 - loss: 1.2454e-05 - val_MAE: 0.0010 - val_loss: 2.3479e-06 - learning_rate: 1.0000e-05
# Epoch 68/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0025 - loss: 1.0684e-05 - val_MAE: 0.0010 - val_loss: 2.2773e-06 - learning_rate: 1.0000e-05
# Epoch 69/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0024 - loss: 1.0212e-05 - val_MAE: 0.0010 - val_loss: 2.2629e-06 - learning_rate: 1.0000e-05
# Epoch 70/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0025 - loss: 1.0828e-05 - val_MAE: 0.0010 - val_loss: 2.2422e-06 - learning_rate: 1.0000e-05
# Epoch 71/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0026 - loss: 1.2093e-05 - val_MAE: 0.0010 - val_loss: 2.2567e-06 - learning_rate: 1.0000e-05
# Epoch 72/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0025 - loss: 1.1529e-05 - val_MAE: 0.0010 - val_loss: 2.2275e-06 - learning_rate: 1.0000e-05
# Epoch 73/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0024 - loss: 9.8236e-06 - val_MAE: 0.0010 - val_loss: 2.2036e-06 - learning_rate: 1.0000e-05
# Epoch 74/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0024 - loss: 1.0328e-05 - val_MAE: 0.0010 - val_loss: 2.1935e-06 - learning_rate: 1.0000e-05
# Epoch 75/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0024 - loss: 1.0486e-05 - val_MAE: 0.0010 - val_loss: 2.2685e-06 - learning_rate: 1.0000e-05
# Epoch 76/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0025 - loss: 1.1269e-05 - val_MAE: 9.9870e-04 - val_loss: 2.1948e-06 - learning_rate: 1.0000e-05
# Epoch 77/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0025 - loss: 1.1550e-05 - val_MAE: 0.0010 - val_loss: 2.2546e-06 - learning_rate: 1.0000e-05
# Epoch 78/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0024 - loss: 9.8128e-06 - val_MAE: 0.0010 - val_loss: 2.2221e-06 - learning_rate: 1.0000e-05
# Epoch 79/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0024 - loss: 9.3345e-06 - val_MAE: 9.9745e-04 - val_loss: 2.1841e-06 - learning_rate: 1.0000e-05
# Epoch 80/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0024 - loss: 9.8794e-06 - val_MAE: 9.9731e-04 - val_loss: 2.1783e-06 - learning_rate: 1.0000e-05
# Epoch 81/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0023 - loss: 9.3931e-06 - val_MAE: 0.0010 - val_loss: 2.2842e-06 - learning_rate: 1.0000e-05
# Epoch 82/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0024 - loss: 9.9119e-06 - val_MAE: 9.9566e-04 - val_loss: 2.1807e-06 - learning_rate: 1.0000e-05
# Epoch 83/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0023 - loss: 9.6059e-06 - val_MAE: 0.0010 - val_loss: 2.1958e-06 - learning_rate: 1.0000e-05
# Epoch 84/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0023 - loss: 9.9800e-06 - val_MAE: 9.9011e-04 - val_loss: 2.1679e-06 - learning_rate: 1.0000e-05
# Epoch 85/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0024 - loss: 9.7415e-06 - val_MAE: 9.9494e-04 - val_loss: 2.1732e-06 - learning_rate: 1.0000e-05
# Epoch 86/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0023 - loss: 9.7756e-06 - val_MAE: 9.8334e-04 - val_loss: 2.1443e-06 - learning_rate: 1.0000e-05
# Epoch 87/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0022 - loss: 8.6527e-06 - val_MAE: 9.9019e-04 - val_loss: 2.1590e-06 - learning_rate: 1.0000e-05
# Epoch 88/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0022 - loss: 8.3478e-06 - val_MAE: 9.8501e-04 - val_loss: 2.1352e-06 - learning_rate: 1.0000e-05
# Epoch 89/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0023 - loss: 9.0605e-06 - val_MAE: 9.7643e-04 - val_loss: 2.1138e-06 - learning_rate: 1.0000e-05
# Epoch 90/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0022 - loss: 8.9784e-06 - val_MAE: 9.8328e-04 - val_loss: 2.1232e-06 - learning_rate: 1.0000e-05
# Epoch 91/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0022 - loss: 8.5816e-06 - val_MAE: 9.8026e-04 - val_loss: 2.1233e-06 - learning_rate: 1.0000e-05
# Epoch 92/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0023 - loss: 1.0557e-05 - val_MAE: 9.8089e-04 - val_loss: 2.1175e-06 - learning_rate: 1.0000e-05
# Epoch 93/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0023 - loss: 8.9954e-06 - val_MAE: 9.7606e-04 - val_loss: 2.1070e-06 - learning_rate: 1.0000e-05
# Epoch 94/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0022 - loss: 8.6224e-06 - val_MAE: 9.6718e-04 - val_loss: 2.0926e-06 - learning_rate: 1.0000e-05
# Epoch 95/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0021 - loss: 8.1282e-06 - val_MAE: 9.7268e-04 - val_loss: 2.1113e-06 - learning_rate: 1.0000e-05
# Epoch 96/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0022 - loss: 8.3571e-06 - val_MAE: 9.7343e-04 - val_loss: 2.1087e-06 - learning_rate: 1.0000e-05
# Epoch 97/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0022 - loss: 8.4039e-06 - val_MAE: 9.8877e-04 - val_loss: 2.1311e-06 - learning_rate: 1.0000e-05
# Epoch 98/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0022 - loss: 9.1979e-06 - val_MAE: 9.6608e-04 - val_loss: 2.0801e-06 - learning_rate: 1.0000e-05
# Epoch 99/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0021 - loss: 8.1264e-06 - val_MAE: 9.8730e-04 - val_loss: 2.1250e-06 - learning_rate: 1.0000e-05
# Epoch 100/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0022 - loss: 9.9464e-06 - val_MAE: 9.7237e-04 - val_loss: 2.0889e-06 - learning_rate: 1.0000e-05
# Adamax Optimizer - Loss (MSE): 0.000002, Mean Absolute Error: 0.000966
#
# Training with RMSprop optimizer and swish activation function...
# Epoch 1/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - MAE: 0.0027 - loss: 1.2219e-05 - val_MAE: 0.0013 - val_loss: 3.1330e-06 - learning_rate: 0.0010
# Epoch 2/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0023 - loss: 9.8774e-06 - val_MAE: 0.0022 - val_loss: 6.2506e-06 - learning_rate: 0.0010
# Epoch 3/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0023 - loss: 9.1389e-06 - val_MAE: 0.0011 - val_loss: 2.3518e-06 - learning_rate: 0.0010
# Epoch 4/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0024 - loss: 9.9362e-06 - val_MAE: 0.0029 - val_loss: 1.0177e-05 - learning_rate: 0.0010
# Epoch 5/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0024 - loss: 9.7824e-06 - val_MAE: 0.0013 - val_loss: 2.9900e-06 - learning_rate: 0.0010
# Epoch 6/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0023 - loss: 9.3279e-06 - val_MAE: 0.0017 - val_loss: 4.4342e-06 - learning_rate: 0.0010
# Epoch 7/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0019 - loss: 6.3053e-06 - val_MAE: 9.6360e-04 - val_loss: 2.0834e-06 - learning_rate: 2.0000e-04
# Epoch 8/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0018 - loss: 6.1788e-06 - val_MAE: 0.0013 - val_loss: 2.8883e-06 - learning_rate: 2.0000e-04
# Epoch 9/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0020 - loss: 8.3405e-06 - val_MAE: 9.6668e-04 - val_loss: 2.0815e-06 - learning_rate: 2.0000e-04
# Epoch 10/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0018 - loss: 6.1849e-06 - val_MAE: 9.5871e-04 - val_loss: 2.0651e-06 - learning_rate: 2.0000e-04
# Epoch 11/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0019 - loss: 6.6810e-06 - val_MAE: 9.6828e-04 - val_loss: 2.0833e-06 - learning_rate: 2.0000e-04
# Epoch 12/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0018 - loss: 5.7467e-06 - val_MAE: 9.6912e-04 - val_loss: 2.0990e-06 - learning_rate: 4.0000e-05
# Epoch 13/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0018 - loss: 6.4436e-06 - val_MAE: 9.5866e-04 - val_loss: 2.0684e-06 - learning_rate: 4.0000e-05
# Epoch 14/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0018 - loss: 6.2691e-06 - val_MAE: 9.7009e-04 - val_loss: 2.1003e-06 - learning_rate: 4.0000e-05
# Epoch 15/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0019 - loss: 6.3663e-06 - val_MAE: 9.5489e-04 - val_loss: 2.0610e-06 - learning_rate: 4.0000e-05
# Epoch 16/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0018 - loss: 6.2734e-06 - val_MAE: 9.5860e-04 - val_loss: 2.0701e-06 - learning_rate: 4.0000e-05
# Epoch 17/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0018 - loss: 6.5454e-06 - val_MAE: 9.6217e-04 - val_loss: 2.0786e-06 - learning_rate: 1.0000e-05
# Epoch 18/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0018 - loss: 5.9141e-06 - val_MAE: 9.6333e-04 - val_loss: 2.0812e-06 - learning_rate: 1.0000e-05
# Epoch 19/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0018 - loss: 5.8458e-06 - val_MAE: 9.6767e-04 - val_loss: 2.0916e-06 - learning_rate: 1.0000e-05
# Epoch 20/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0018 - loss: 5.7693e-06 - val_MAE: 9.5492e-04 - val_loss: 2.0609e-06 - learning_rate: 1.0000e-05
# Epoch 21/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0018 - loss: 5.5626e-06 - val_MAE: 9.5823e-04 - val_loss: 2.0685e-06 - learning_rate: 1.0000e-05
# Epoch 22/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0018 - loss: 5.6106e-06 - val_MAE: 9.7293e-04 - val_loss: 2.1047e-06 - learning_rate: 1.0000e-05
# Epoch 23/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0017 - loss: 5.5615e-06 - val_MAE: 9.5830e-04 - val_loss: 2.0685e-06 - learning_rate: 1.0000e-05
# Epoch 24/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0018 - loss: 5.4915e-06 - val_MAE: 9.6012e-04 - val_loss: 2.0726e-06 - learning_rate: 1.0000e-05
# Epoch 25/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0019 - loss: 6.2936e-06 - val_MAE: 9.6304e-04 - val_loss: 2.0796e-06 - learning_rate: 1.0000e-05
# Epoch 26/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0018 - loss: 5.8357e-06 - val_MAE: 9.5816e-04 - val_loss: 2.0677e-06 - learning_rate: 1.0000e-05
# Epoch 27/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0018 - loss: 5.7541e-06 - val_MAE: 9.8022e-04 - val_loss: 2.1228e-06 - learning_rate: 1.0000e-05
# Epoch 28/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0018 - loss: 6.1209e-06 - val_MAE: 9.7030e-04 - val_loss: 2.0973e-06 - learning_rate: 1.0000e-05
# Epoch 29/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0018 - loss: 6.8066e-06 - val_MAE: 9.6896e-04 - val_loss: 2.0937e-06 - learning_rate: 1.0000e-05
# Epoch 30/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0018 - loss: 5.8751e-06 - val_MAE: 9.6139e-04 - val_loss: 2.0752e-06 - learning_rate: 1.0000e-05
# RMSprop Optimizer - Loss (MSE): 0.000002, Mean Absolute Error: 0.000955
#
# Training with SGD optimizer and swish activation function...
# Epoch 1/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - MAE: 0.0018 - loss: 6.6567e-06 - val_MAE: 9.9032e-04 - val_loss: 2.1501e-06 - learning_rate: 0.0100
# Epoch 2/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0017 - loss: 5.2948e-06 - val_MAE: 9.5478e-04 - val_loss: 2.0595e-06 - learning_rate: 0.0100
# Epoch 3/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0019 - loss: 6.4317e-06 - val_MAE: 9.9232e-04 - val_loss: 2.1552e-06 - learning_rate: 0.0100
# Epoch 4/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0018 - loss: 6.1776e-06 - val_MAE: 9.7235e-04 - val_loss: 2.1025e-06 - learning_rate: 0.0100
# Epoch 5/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0019 - loss: 6.3846e-06 - val_MAE: 9.6286e-04 - val_loss: 2.0783e-06 - learning_rate: 0.0100
# Epoch 6/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0019 - loss: 6.1241e-06 - val_MAE: 0.0010 - val_loss: 2.2354e-06 - learning_rate: 0.0100
# Epoch 7/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0019 - loss: 6.3463e-06 - val_MAE: 9.6713e-04 - val_loss: 2.0889e-06 - learning_rate: 0.0020
# Epoch 8/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0019 - loss: 6.1993e-06 - val_MAE: 9.6776e-04 - val_loss: 2.0905e-06 - learning_rate: 0.0020
# Epoch 9/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0018 - loss: 6.0005e-06 - val_MAE: 9.6883e-04 - val_loss: 2.0930e-06 - learning_rate: 0.0020
# Epoch 10/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAE: 0.0017 - loss: 6.1026e-06 - val_MAE: 9.6390e-04 - val_loss: 2.0808e-06 - learning_rate: 0.0020
# Epoch 11/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0018 - loss: 5.9321e-06 - val_MAE: 9.6153e-04 - val_loss: 2.0751e-06 - learning_rate: 0.0020
# Epoch 12/100
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MAE: 0.0018 - loss: 6.0606e-06 - val_MAE: 9.5559e-04 - val_loss: 2.0609e-06 - learning_rate: 4.0000e-04
# SGD Optimizer - Loss (MSE): 0.000002, Mean Absolute Error: 0.000955

# %%
print(all_mae_values)
print(all_loss_values)
print(all_labels)
# Out:
# [0.0014009365113452077, 0.0014230349333956838, 0.001397983287461102, 0.0013246495509520173, 0.0013003107160329819, 0.0013479588087648153, 0.00118521589320153, 0.0009376514935865998, 0.0009346415172331035, 0.001866739010438323, 0.0016491964925080538, 0.0016270189080387354, 0.0009660833748057485, 0.0009549175156280398, 0.000954780203755945]
# [3.739891099030501e-06, 3.6928793178958585e-06, 3.963585641031386e-06, 3.513515594022465e-06, 3.318818926345557e-06, 3.8251932892308105e-06, 2.69347788162122e-06, 2.0443105768208625e-06, 2.0442705590539845e-06, 6.4305045270884875e-06, 5.01450949741411e-06, 5.232760031503858e-06, 2.0801039681828115e-06, 2.0608765680663055e-06, 2.059512326013646e-06]
# ['relu, Adamax', 'relu, RMSprop', 'relu, SGD', 'leaky_relu, Adamax', 'leaky_relu, RMSprop', 'leaky_relu, SGD', 'elu, Adamax', 'elu, RMSprop', 'elu, SGD', 'prelu, Adamax', 'prelu, RMSprop', 'prelu, SGD', 'swish, Adamax', 'swish, RMSprop', 'swish, SGD']

# %%
# Create a DataFrame
cancer_models_df = pd.DataFrame({
    'Model': all_labels,
    'Activation_Function': all_activation_functions, 
    'Optimizer': all_optimizers, 
    'MAE': all_mae_values,
    'Loss': all_loss_values
})

cancer_models_df
# Out:
#                   Model Activation_Function Optimizer       MAE      Loss
# 0          relu, Adamax                relu    Adamax  0.001401  0.000004
# 1         relu, RMSprop                relu   RMSprop  0.001423  0.000004
# 2             relu, SGD                relu       SGD  0.001398  0.000004
# 3    leaky_relu, Adamax          leaky_relu    Adamax  0.001325  0.000004
# 4   leaky_relu, RMSprop          leaky_relu   RMSprop  0.001300  0.000003
# 5       leaky_relu, SGD          leaky_relu       SGD  0.001348  0.000004
# 6           elu, Adamax                 elu    Adamax  0.001185  0.000003
# 7          elu, RMSprop                 elu   RMSprop  0.000938  0.000002
# 8              elu, SGD                 elu       SGD  0.000935  0.000002
# 9         prelu, Adamax               prelu    Adamax  0.001867  0.000006
# 10       prelu, RMSprop               prelu   RMSprop  0.001649  0.000005
# 11           prelu, SGD               prelu       SGD  0.001627  0.000005
# 12        swish, Adamax               swish    Adamax  0.000966  0.000002
# 13       swish, RMSprop               swish   RMSprop  0.000955  0.000002
# 14           swish, SGD               swish       SGD  0.000955  0.000002

# %%
# Plotting
fig, ax1 = plt.subplots(figsize=(14, 8))

# Bar plot for Accuracy
color = 'tab:blue'
ax1.set_xlabel('Model')
ax1.set_ylabel('Mean Absolute Error', color=color)
ax1.bar(cancer_models_df['Model'], cancer_models_df['MAE'], color=color, alpha=0.6, label='MAE')
ax1.tick_params(axis='y', labelcolor=color)
ax1.set_xticks(range(len(cancer_models_df['Model'])))
ax1.set_xticklabels(cancer_models_df['Model'], rotation=90)

# Create a second y-axis for Loss
ax2 = ax1.twinx()
color = 'tab:red'
ax2.set_ylabel('Loss (MSE)', color=color)
ax2.plot(cancer_models_df['Model'], cancer_models_df['Loss'], color=color, marker='o', linestyle='-', linewidth=2, markersize=8, label='Loss')
ax2.tick_params(axis='y', labelcolor=color)

# Title and layout
plt.title('MAE and Loss for Cancer Models')
fig.tight_layout()
plt.show()

# %%
# Rank the models based on MAE (lower is better)
cancer_models_df['MAE_Rank'] = cancer_models_df['MAE'].rank()

# Rank the models based on Loss (lower is better)
cancer_models_df['Loss_Rank'] = cancer_models_df['Loss'].rank()

# Calculate the average rank
cancer_models_df['Average_Rank'] = (cancer_models_df['MAE_Rank'] + cancer_models_df['Loss_Rank']) / 2

# Find the top two ranked models
best_model_avg_rank = cancer_models_df.sort_values('Average_Rank').iloc[0]
print(best_model_avg_rank)
# Out:
# Model                  elu, SGD
# Activation_Function         elu
# Optimizer                   SGD
# MAE                    0.000935
# Loss                   0.000002
# MAE_Rank                    1.0
# Loss_Rank                   1.0
# Average_Rank                1.0
# Name: 8, dtype: object

# %%
# Initialize train and get predictions with the random forest regressor
cancer_rf = RandomForestRegressor(n_estimators=500, random_state=78)
cancer_rf.fit(X_train, y_train)
predictions = cancer_rf.predict(X_test)

# Evaluate using MAE MSE RMSE and R2 metrics
mae = mean_absolute_error(y_test, predictions)
mse = mean_squared_error(y_test, predictions)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, predictions)

# Print Evaluation Metrics
print(f"MAE: {mae}")
print(f"MSE: {mse}")
print(f"RMSE: {rmse}")
print(f"R²: {r2}")
# Out:
# MAE: 0.0008245149544863479
# MSE: 1.4317078699609826e-06
# RMSE: 0.0011965399575279475
# R²: 0.848404630408665

# %%
# Get Feature Importance
importances = cancer_rf.feature_importances_

# Extract feature names
feature_names = cancer_df.drop(columns=['target_cancer', 'county_index']).columns

# Visualize the features by importance
importances_df = pd.DataFrame(sorted(zip(cancer_rf.feature_importances_, feature_names), reverse=True))
importances_df.set_index(importances_df[1], inplace=True)
importances_df.drop(columns=1, inplace=True)
importances_df.rename(columns={0: 'Feature Importances'}, inplace=True)
importances_sorted = importances_df.sort_values(by='Feature Importances')
importances_sorted.plot(kind='barh', color='lightgreen', title= 'Cancer Features Importances', legend=False)
# Out:
# <Axes: title={'center': 'Cancer Features Importances'}, ylabel='1'>
